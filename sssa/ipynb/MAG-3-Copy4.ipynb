# %%
import sys
sys.path.append('/home/sheng/sssa/')
sys.path.append('/home/sheng/sssa/')
# sys.path.append('/home/sheng/sssa/CLIP/')

import os
import json
import re
import time
import pickle
from typing import Union, List
from pprint import pprint
from tqdm import tqdm
from copy import deepcopy
import random
import itertools
import numpy as np
from functools import reduce, partial
from itertools import zip_longest
import seaborn as sns
from collections import Counter, defaultdict, OrderedDict
import matplotlib.pyplot as plt
import heapq
from wordnet_utils import *
import scipy.io
from PIL import Image

import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode
from torchvision.datasets import ImageFolder

from ipynb_utils import get_hier_datasets, get_classifier, MCMF_assign_labels
# import clip
import model as clip
from data.datasets import build_transform, get_hier_datasets, Vocab
from data.imagenet_datasets import get_datasets_oszsl


class Config:
    device = 'cuda:1'
    arch = 'ViT-B/16'
    dataset = 'make_entity13'
    n_sampled_classes = 100
    input_size = 224
    estimate_k = 252
    
    batch_size = 256
    use_def = False
    clip_checkpoint = None
    f_classifier = './cache/wordnet_classifier_in21k_word.pth'
    # f_classifier = './cache/wordnet_classifier_in21k_word_L.pth'
    templates_name = 'templates_small'
    seed = 0
    
args = Config()

def load_templates(args):
    with open(f'../{args.templates_name}.json', 'rb') as f:
        templates = json.load(f)['imagenet']
    return templates

def get_vocab():
    """
    Args:
        vocab: {`names`: list, `ids`: synset ids, `parents`: [{synset ids}]}
    """
    with open('/home/sheng/dataset/wordnet_nouns_with_synset_4.pkl', 'rb') as f:
        vocab = pickle.load(f)
    return vocab

def get_subsample_vocab(sample_synset_id: set):
    vocab = get_vocab()
    index = np.array([ i for i in range(len(vocab['synsets'])) if vocab['synsets'][i] in sample_synset_id ]).astype(np.int32)
    for k in vocab.keys():
        vocab[k] = np.array(vocab[k])[index].tolist()
    return vocab

def read_imagenet21k_classes():
    with open('/home/sheng/dataset/imagenet21k/imagenet21k_wordnet_ids.txt', 'r') as f:
        data = f.read()
        data = list(filter(lambda x: len(x), data.split('\n')))
    return data

templates = load_templates(args)
vocab = get_vocab()
nouns = [ wn.synset(s) for s in vocab['synsets'] ]
classnames = vocab['names']
parents = vocab['parents']
defs = vocab['def']
# Out:
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
def load_clip(args):
    model, preprocess = clip.load(args.arch)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model, preprocess

def load_clip2(args):
    model = clip.load(args.arch, device=args.device)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model

def load_mixture_clip(args, decay=1.0):
    model1 = clip.load(args.arch)
    if args.clip_checkpoint:
        model1.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model1.to(args.device).eval()
    model2 = clip.load(args.arch)
    model2.to(args.device).eval()
    with torch.no_grad():
        msd = model1.state_dict()
        for k, ema_v in model2.state_dict().items():
            # if needs_module:
            #     k = 'module.' + k
            model_v = msd[k].detach()
            ema_v.copy_(ema_v * decay + (1. - decay) * model_v)
    return model2

def topk_acc(all_pred_voc_topk, all_gt_voc):
    acc = []
    ### topK accuracy
    for i in range(all_pred_voc_topk.size(1)):
        vec = torch.zeros(all_pred_voc_topk.size(0)).bool()
        for j in range(i+1):
            vec |= (all_pred_voc_topk[:, j]==all_gt_voc)
        print(f'k={i} acc={vec.float().mean()}')
        acc.append(vec.float().mean().item())
    return acc

def semantic_acc(y_pred, y_true, metrics={}):
    """ compute soft semantic acc for @y_pred and @y_true """
    assert len(metrics)>0
    assert y_pred.size(0)==y_true.size(0)
    scores = {m:[] for m in metrics.keys()}
    with tqdm(total=y_pred.size(0)) as pbar:
        for i in range(y_pred.size(0)):
            syn_pred = mapping_vocidx_to_synsets(y_pred[i].item(), vocab)
            syn_true = mapping_vocidx_to_synsets(y_true[i].item(), vocab)
            pairs = list(itertools.product(range(len(syn_pred)), range(len(syn_true))))
            for m_name, m in metrics.items():
                scores[m_name].append( max([ m(syn_pred[p[0]], syn_true[p[1]]) for p in pairs ]) )
            pbar.update(1)
    for m_name in metrics.keys():
        scores[m_name] = np.array(scores[m_name]).mean()
    return scores
    
""" from MUST """
from clip.simple_tokenizer import SimpleTokenizer as _Tokenizer
_tokenizer = _Tokenizer()

def tokenize(texts: Union[str, List[str]], context_length: int = 77, truncate: bool = False) -> torch.LongTensor:
    if isinstance(texts, str):
        texts = [texts]

    sot_token = _tokenizer.encoder["<|startoftext|>"]
    eot_token = _tokenizer.encoder["<|endoftext|>"]
    all_tokens = [[sot_token] + _tokenizer.encode(text) + [eot_token] for text in texts]
    result = torch.zeros(len(all_tokens), context_length, dtype=torch.long)

    for i, tokens in enumerate(all_tokens):
        if len(tokens) > context_length:
            if truncate:
                tokens = tokens[:context_length]
                tokens[-1] = eot_token
            else:
                raise RuntimeError(f"Input {texts[i]} is too long for context length {context_length}")
        result[i, :len(tokens)] = torch.tensor(tokens)

    return result

# %%
""" prepare dataset and load CLIP """
classes = read_imagenet21k_classes() + os.listdir('/home/sheng/dataset/imagenet-img/')
classes = [wn.synset_from_pos_and_offset('n', int(x[1:])).name() for x in classes]
classes = set(classes)
vocab = get_subsample_vocab(classes)
vocab = Vocab(vocab=vocab)

transform_val = build_transform(is_train=False, args=args, train_config=None)
dataset = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_val, seed=0)
loader_val = torch.utils.data.DataLoader(dataset, num_workers=8, batch_size=args.batch_size, shuffle=False)
print('dataset size', len(dataset))

model = load_clip2(args)
# Out:
# dataset size 334718
# ===load nonjit===
# missing keys:
# ['visual.projection_head.0.weight', 'visual.projection_head.0.bias', 'visual.projection_head.2.weight', 'visual.projection_head.2.bias']
# Model parameters: 428,928,513
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %%
""" compute parent subgraph with hierarchical closure """
### compute hierarchical closure of @classes
classes_closure = classes
for c in classes:
    classes_closure = classes_closure | predecessor_set(G, source=c)

subgraph = G.subgraph(list(classes_closure))

parent_classes = set()
for c in classes:
    parent_classes = parent_classes | predecessor_set(G, source=c)

# %%
""" 
1. compute parent classes at K level
2. build classifier per name
"""
k_hier = 6
parent_classes_at_k = list(filter(lambda x: G.nodes[x]['depth']==k_hier, parent_classes))
# print(len(parent_classes_at_k))
# pprint(parent_classes_at_k, compact=True)
parent_classes_at_k = sorted(list(set(map(lambda x: x.split('.')[0], parent_classes_at_k))))
classifier = build_classifier(args, model, templates, parent_classes_at_k)

# %%
mapping_synset_to_parents = {k: predecessor_set(G, source=k) for k in classes}
vfeatures = np.load(f'./cache/vfeatures-{args.dataset}.npy')

sim = torch.from_numpy(vfeatures)@classifier.cpu().t()
pred_topk = sim.topk(k=5).indices

# %%
pred_topk = np.array(parent_classes_at_k)[pred_topk.flatten()].reshape(-1, 5)
to_name = lambda r: list(map(lambda x: x.split('.')[0], r))
instance_to_parents = [
    to_name(reduce(lambda x,y: x|y, list(map(lambda x: mapping_synset_to_parents[x.name()], mapping_vocidx_to_synsets(x.item(), vocab)))))
    for x in all_gt_voc
]

# %%
# """ visualization: adding `type` causes confusion of classifier """
# parent_classes_at_k = list(filter(lambda x: G.nodes[x]['depth']==k_hier, parent_classes))
# parent_classes_at_k = sorted(list(parent_classes_at_k))
# name_parent_classes_at_k = list(map(lambda x: x.split('.')[0], parent_classes_at_k))
# parent_parent_classes_at_k = [ ', '.join([pp.name().split('.')[0] for pp in wn.synset(p).hypernyms()]) for p in parent_classes_at_k]
# classifier_p = build_classifier(args, model, templates, name_parent_classes_at_k, parent_parent_classes_at_k)

# sim = classifier@classifier.t()
# sns.distplot(sim.topk(k=10).values[:, 1].cpu().numpy(), bins=100)

# sim = classifier_p@classifier_p.t()
# sns.distplot(sim.topk(k=10).values[:, 1].cpu().numpy(), bins=100)

# %% [markdown]
# #### build classifier

# %%
""" from MUST """
from clip.simple_tokenizer import SimpleTokenizer as _Tokenizer
_tokenizer = _Tokenizer()

def tokenize(texts: Union[str, List[str]], context_length: int = 77, truncate: bool = False) -> torch.LongTensor:
    if isinstance(texts, str):
        texts = [texts]

    sot_token = _tokenizer.encoder["<|startoftext|>"]
    eot_token = _tokenizer.encoder["<|endoftext|>"]
    all_tokens = [[sot_token] + _tokenizer.encode(text) + [eot_token] for text in texts]
    result = torch.zeros(len(all_tokens), context_length, dtype=torch.long)

    for i, tokens in enumerate(all_tokens):
        if len(tokens) > context_length:
            if truncate:
                tokens = tokens[:context_length]
                tokens[-1] = eot_token
            else:
                raise RuntimeError(f"Input {texts[i]} is too long for context length {context_length}")
        result[i, :len(tokens)] = torch.tensor(tokens)
    return result


def build_classifier(args, model, templates, vocab_classnames, parent_classnames=None):
    batch_size = 64
    with torch.no_grad():
        zeroshot_weights = []
        assert parent_classnames is None
        with tqdm(total=len(vocab_classnames)//batch_size) as pbar:
            for classname_set in np.array_split(vocab_classnames, len(vocab_classnames)//batch_size):
                texts = [template.format(classname) for classname in classname_set for template in templates] #format with class
                texts = tokenize(texts).to(args.device) #tokenize
                class_embeddings = model.encode_text(texts).float() #embed with text encoder
                class_embeddings = class_embeddings.view(-1, len(templates), class_embeddings.size(-1))
                class_embeddings = F.normalize(class_embeddings, dim=-1)
                class_embedding = class_embeddings.mean(dim=1)
                class_embedding /= class_embedding.norm(dim=-1, keepdim=True)
                zeroshot_weights.append(class_embedding.cpu())
                pbar.update(1)
        # else:
        #     with tqdm(total=len(vocab_classnames)//batch_size) as pbar:
        #         for classname_set, parentname_set in zip(
        #             np.array_split(vocab_classnames, len(vocab_classnames)//batch_size),
        #             np.array_split(parent_classnames, len(parent_classnames)//batch_size),
        #         ):
        #             texts = [template.format(classname)+f' A type of {pname}.' for classname, pname in zip(classname_set, parentname_set) for template in templates] #format with class
        #             texts = tokenize(texts).to(args.device) #tokenize
        #             class_embeddings = model.encode_text(texts).float() #embed with text encoder
        #             class_embeddings = class_embeddings.view(-1, len(templates), class_embeddings.size(-1))
        #             class_embeddings = F.normalize(class_embeddings, dim=-1)
        #             class_embedding = class_embeddings.mean(dim=1)
        #             class_embedding /= class_embedding.norm(dim=-1, keepdim=True)
        #             zeroshot_weights.append(class_embedding.cpu())
        #             pbar.update(1)
    classifier = torch.cat(zeroshot_weights, dim=0)
    return classifier

# %%
classifier = build_classifier(args, model, templates, vocab.classnames)
# torch.save(classifier, f'./cache/{args.exp}-{args.vocabname}.pth')
torch.save(classifier, f'./cache/wordnet_classifier_in21k_word_L.pth')

# %% [markdown]
# ### performance test

# %% [markdown]
# #### SCD

# %%
from sklearn.cluster import KMeans
from my_util_package_oszsl.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment

subset = ['train', 'val'][0]
mean = (0.48145466, 0.4578275, 0.40821073)
std = (0.26862954, 0.26130258, 0.27577711)

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(args.input_size, interpolation=InterpolationMode.BICUBIC),
    transforms.CenterCrop(args.input_size),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=torch.tensor(mean),
        std=torch.tensor(std))
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
if subset == 'train':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=0)
elif subset == 'val':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=0)
args.nb_classes = dataset_f.num_classes
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=4, batch_size=args.batch_size, shuffle=False)

# %%
def agg_by_pred_cluster(args, pred_kmeans, all_topk_voc, voc_size):
    """
    Args:
        pred_kmeans: np.array([N])
        all_topk_voc: np.array([N x K])
        voc_size: int
    Returns:
        all_clu_pred: tensor([C x V])
    """
    print('agg_by_pred_cluster')
    all_clu_pred = []
    n_count = []
    for i in np.unique(pred_kmeans):
        selected = (pred_kmeans==i)
        n_count.append( selected.sum().item() )
        counter_voc_ind, counter_val = np.unique((all_topk_voc[selected, :]).ravel(), return_counts=True)
        # counter_val = counter_val/(n_count+1e-20) # L1 norm
        clu_pred = torch.zeros(args.num_voc) # cluster-wise prob
        clu_pred[torch.from_numpy(counter_voc_ind).long()] = torch.from_numpy(counter_val).float()
        # clu_pred = F.normalize(all_topk_voc[selected].sum(dim=0), dim=-1, p=1)
        all_clu_pred.append(clu_pred)
    all_clu_pred = torch.stack(all_clu_pred, dim=0).cpu()
    n_count = torch.tensor(n_count).cpu()
    
    # all_clu_pred = setdiff_assignment(all_clu_pred)
    
    all_clu_pred = all_clu_pred/(n_count.view(-1, 1) + 1e-20)
    
    print('is mutex assignment::', all_clu_pred.argmax(dim=-1).size(0)==all_clu_pred.argmax(dim=-1).unique().size(0))
    print('assignment collision num::', len(list(filter(lambda x: x>1, Counter(all_clu_pred.argmax(dim=-1).numpy()).values()))))
    return all_clu_pred

def linear_assign(all_clu_pred, pred_kmeans, all_gt_voc, return_results=False):
    print('linear_assign')
    cost_mat = all_clu_pred.cpu().numpy()
    print(f'assignment shape={cost_mat.shape}')
    res_ass = linear_assignment(cost_mat.max() - cost_mat)
    label_voc_kmeans = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])
    inst_acc = (label_voc_kmeans==all_gt_voc).float().mean().item()
    print('instance label acc::', inst_acc)
    if return_results:
        return label_voc_kmeans, res_ass, inst_acc
    return label_voc_kmeans, res_ass

def reassign_by_pred_cluster(label_voc_kmeans, model, classifier, device, 
                             all_prob=None, 
                             instance_selected=None, 
                             classifier_selected=None):
    """
    Args:
        classifier_selected: tensor([C2])
    """
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device)
    if all_prob is None:
        cluster_ind = []
        with tqdm(total=len(loader_f)) as pbar:
            if hasattr(model, 'eval'):
                model.eval()
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                if (instance_selected is not None) and ((~instance_selected[idx_img]).all()):
                    continue
                with amp_autocast():
                    with torch.no_grad():
                        if (instance_selected is not None):
                            logits = model.visual(images[instance_selected[idx_img]])
                        else:
                            logits = model.visual(images)
                            
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        if classifier_selected is not None:
                            similarity = 100 * logits @ classifier[classifier_selected].t()
                            prob = classifier_selected[similarity.softmax(-1)]
                            cluster_ind.append(deepcopy(prob.cpu().argmax(dim=-1)))
                        else:
                            similarity = 100 * logits @ classifier.t()
                            prob = similarity.softmax(-1)
                            cluster_ind.append(deepcopy(prob[:, label_voc_kmeans].cpu().argmax(dim=-1)))
                pbar.update(1)
        cluster_ind = torch.cat(cluster_ind, dim=0)
    else:
        all_prob = all_prob[:, label_voc_kmeans]
        cluster_ind = all_prob.argmax(dim=-1)
        
    if classifier_selected is not None:
        cluster_ind_voc = classifier_selected[cluster_ind]
    else:
        cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc


def reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, device, 
                             preextracted_vfeatures=None):
    """ given vocab label set @label_voc_kmeans, 
    Args:
        label_voc_kmeans: cluster-assigned label on vocab
        ...
        preextracted_vfeatures: np.array([N x D])
    Returns:
        cluster_ind: tensor([N]): re-ordered cluster assignment
        cluster_ind_voc: tensor([N]): cluster assignment indiced by vocab
    """
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device).unique()
    cluster_ind = []
    with tqdm(total=len(loader_f)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        if preextracted_vfeatures is not None:
            N = len(loader_f.dataset)
            batch_size = 10000
            indices = np.array_split(np.arange(N), N//batch_size)
            with torch.no_grad():
                for group in indices:
                    logits = torch.from_numpy(preextracted_vfeatures[group]).float()
                    logits = logits/logits.norm(dim=-1, keepdim=True)
                    similarity = 100 * logits@classifier.t().cpu()
                    prob = similarity.softmax(-1)
                    cluster_ind.append(deepcopy(prob[:, label_voc_kmeans.cpu()].argmax(dim=-1)))
        else:
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                with amp_autocast():
                    with torch.no_grad():
                        if preextracted_vfeatures is not None:
                            logits = torch.from_numpy(preextracted_vfeatures[idx_img.cpu().numpy()]).float().to(device)
                        else:
                            logits = model.ema.extract_vfeatures(images)
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        similarity = 100 * logits @ classifier.t()
                        prob = similarity.softmax(-1)
                        cluster_ind.append(deepcopy(prob[:, label_voc_kmeans].cpu().argmax(dim=-1)))
                pbar.update(1)
    cluster_ind = torch.cat(cluster_ind, dim=0)
    cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def computation_reassign_by_pred_cluster(row, idx, args, model, classifier, candidate_classifier_ind):
    """
    candidate_classifier_ind = label_voc_kmeans.unique().to(args.device)
    """
    images, label_voc, label_clu, idx_img = row[:4]
    images = images.to(args.device)
    with amp_autocast():
        vfeatures = model.visual(images).float()
        # vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
    vfeatures = F.normalize(vfeatures, dim=-1)
    batch_sim = 100*vfeatures@classifier[candidate_classifier_ind].t()
    cluster_ind = batch_sim.argmax(dim=-1)
    cluster_ind_voc = candidate_classifier_ind[cluster_ind].cpu()
    return cluster_ind_voc

def aggregation_reassign_by_pred_cluster(r, candidate_classifier_ind):
    cluster_ind_voc = torch.cat(r, dim=0)
    mapping_ind = dict(zip(cluster_ind_voc.unique().numpy(), torch.arange(cluster_ind_voc.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind_voc])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def extract_vfeatures(model, data_loader, device):
    amp_autocast = torch.cuda.amp.autocast
    all_vfeatures = []
    with tqdm(total=len(data_loader)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        for idx_batch, batch in enumerate(data_loader):
            images, label_voc, label_clu, idx_img = batch[:4]
            images = images.to(device)
            with amp_autocast():
                vfeatures = model.visual(images).float()
            vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
            all_vfeatures.append(vfeatures.cpu().numpy())
            pbar.update(1)
    all_vfeatures = np.concatenate(all_vfeatures)
    return all_vfeatures


@torch.no_grad()
def loop_row_collect_results_nograd(obj_iter, computations={}, aggregations={}):
    """ compute and aggregate results, looping over @obj_iter 
    func_computation(@row, @index_row)
    aggregations(list(@results_computation))
    """
    assert set(list(computations.keys())) == set(list(aggregations.keys()))
    collector = { k:[] for k in computations }
    with tqdm(total=len(obj_iter)) as pbar:
        for i, row in enumerate(obj_iter):
            ### apply computations
            for k, func in computations.items():
                collector[k].append(func(row, i))
            pbar.update(1)
    ### aggregate results
    results = {}
    for k, func_agg in aggregations.items():
        results[k] = func_agg(collector[k])
    return results

# %%
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=4, batch_size=args.batch_size, shuffle=False)
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
amp_autocast = torch.cuda.amp.autocast
### collect variables
prob_k = 1
all_topk_voc = []
all_gt_voc = []
all_label_clu = []
all_vfeatures = []
with tqdm(total=len(loader_f)) as pbar:
    if hasattr(model, 'eval'):
        model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch[:4]
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual.extract_features(images)
                # logits = model.extract_vfeatures(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = 100 * logits @ classifier.t()
                prob = similarity.softmax(-1)
                prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                all_topk_voc.append(deepcopy(prob_topk_ind.cpu().numpy()))
                all_gt_voc.append(deepcopy(label_voc))
                all_label_clu.append(deepcopy(label_clu))
                all_vfeatures.append(deepcopy(logits.cpu().numpy()))
        pbar.update(1)

all_topk_voc = np.concatenate(all_topk_voc)
all_gt_voc = torch.cat(all_gt_voc, dim=0)
all_label_clu = torch.cat(all_label_clu, dim=0)
all_vfeatures = np.concatenate(all_vfeatures)
# Out:
# 100%|██████████| 1308/1308 [22:52<00:00,  1.05s/it]

# %%
pred_kmeans = torch.from_numpy(np.load(f'./cache/cluster/kmeans-{args.dataset}.npy'))
pred_kmeans_t = pred_kmeans
history_set_pred = []
for t in range(3):
    record_pred_kmeans_t = pred_kmeans_t
    all_clu_pred = agg_by_pred_cluster(args, pred_kmeans_t.numpy(), all_topk_voc, voc_size=args.num_voc)
    label_voc_kmeans, res_ass = linear_assign(all_clu_pred, pred_kmeans_t, all_gt_voc)
    pred_kmeans_t, cluster_ind_voc = reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)
    set_pred = set(res_ass[1].tolist())
    set_gt = set(all_gt_voc.unique().numpy().tolist())
    print('missing label::', len(set_gt - set_pred))
    print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=pred_kmeans_t.numpy()))
    history_set_pred.append(set_pred)
    
    set_pred = set(res_ass[1].tolist())
    set_gt = set(all_gt_voc.unique().numpy().tolist())
    n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
    n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
    iou_voc = n_inter/n_union
    n_missing_label = all_gt_voc.unique().shape[0] - n_inter
    print('missing label::', n_missing_label)
    print('iou voc::', iou_voc)
# Out:
# agg_by_pred_cluster
# is mutex assignment:: False
# assignment collision num:: 24
# linear_assign
# assignment shape=(260, 20071)
# instance label acc:: 0.3680471181869507
# reassign_by_pred_cluster
#   0%|          | 0/1308 [00:16<?, ?it/s]
# missing label:: 113
# cluster acc 0.7575959464384945
# missing label:: 113
# iou voc:: 0.3941018766756032
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# assignment shape=(260, 20071)
# instance label acc:: 0.4864931106567383
# reassign_by_pred_cluster
#   0%|          | 0/1308 [00:24<?, ?it/s]
# missing label:: 112
# cluster acc 0.7623731021337364
# missing label:: 112
# iou voc:: 0.3978494623655914
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# assignment shape=(260, 20071)
# instance label acc:: 0.4882199466228485
# reassign_by_pred_cluster
#   0%|          | 0/1308 [00:20<?, ?it/s]
# missing label:: 112
# cluster acc 0.7623731021337364
# missing label:: 112
# iou voc:: 0.3978494623655914

# %% [markdown]
# ### CHATGPT request

# %%
import openai
def openai_chatgpt_post(content, parameters={'temperature': 0.7}):
    openai.api_key = "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"
    while 1:
        try:
            completion = openai.ChatCompletion.create(
              model="gpt-3.5-turbo-0301",
              messages=[
                {"role": "user", "content": content},
              ],
            **parameters,
            )
            result = completion['choices'][0]['message']['content']
            break
        except Exception as e:
            print(e)
    return result

all_clu_gt_voc = []
for c in record_pred_kmeans_t.unique():
    select = (record_pred_kmeans_t==c)
    all_clu_gt_voc.append(all_gt_voc[select].mode().values)

all_clu_gt_voc = torch.tensor(all_clu_gt_voc)
k_1 = 3
topk_all_clu_pred = all_clu_pred.topk(k=k_1).indices
cluster_is_correct = torch.zeros(topk_all_clu_pred.size(0)).bool()
for i in range(k_1):
    cluster_is_correct |= (topk_all_clu_pred[:, i]==all_clu_gt_voc)

print(f'recall@{k_1} = {cluster_is_correct.float().mean()}')

""" gather concepts """
to_name = lambda x: [ s.name() + ': ' + s.definition() for s in x ]
cluster_row_synsets = []
for row in topk_all_clu_pred:
    row_synsets = [to_name(mapping_vocidx_to_synsets(voc_idx.item(), vocab)) for voc_idx in row]
    cluster_row_synsets.append(row_synsets)


""" generate concept requests """
concept_request = []
for row in cluster_row_synsets:
    ccpts = reduce(lambda x, y: x+y, row)
    ccpts = list(map(lambda x: "'"+x+".'", ccpts))
    ccpts = ', '.join(ccpts)
    concept_request.append(ccpts)
    
""" generate concept templates """
template_1 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all alternative concept names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
with open('/home/sheng/OSZSL/templates_chatgpt.json', 'r') as f:
    template_chatgpt = json.load(f)
template_2 = lambda concept_list: template_chatgpt['pictionary-long'].format(concept_list)
template_3 = lambda concept_list: template_chatgpt['pictionary-short'].format(concept_list)
template_4 = lambda concept_list: template_chatgpt['direct'].format(concept_list)
template_5 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all synonym concept names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
template_6 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all category names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
template_7 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all parent-type category names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
template_8 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all possible descriptive phrases of image captions for each visual concept. List in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
template_9 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all possible visiual descriptive phrases for each visual concept without duplication. List in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
# template_10 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all possible visiual descriptive phrases for each visual concept without duplication. List in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
template_13 = lambda concept_list: "Given visual concepts: "+ concept_list + "Please list all possible adjective phrases of visual descriptions for each visual concept without duplication. Please list in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
template_9_1 = lambda concept_list: "Given visual concepts: "+ concept_list + "Please list all possible visual descriptive phrases for each visual concept without duplication. Please list in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."

    
template_in_use = template_9_1
concept_templates = []
for row in concept_request:
    concept_templates.append(template_in_use(row))
    
n_repeat = 3
# Out:
# recall@3 = 0.720588207244873

# %%
""" collect chatgpt res """
all_chatgpt_res = [[] for _ in range(n_repeat)]
with tqdm(total=len(concept_templates)*n_repeat) as pbar:
    for i in range(n_repeat):
        for row in concept_templates:
            all_chatgpt_res[i].append(openai_chatgpt_post(row))

            pbar.update(1)
# Out:
# 100%|██████████| 312/312 [23:15<00:00,  4.47s/it]

# %%
while 1:
    """ integrity check """
    while 1:
        invalid_res = []
        for i in range(n_repeat):
            for j, row in enumerate(all_chatgpt_res[i]):
                extract_synsetid = lambda r: list(map(lambda x: x.split(': ')[0], r))
                remove_space = lambda r: list(filter(lambda x: len(x), r))
                synsets = extract_synsetid(remove_space(row.lower().replace('\n\n', '\n').split('\n')))
                gt_synsets = extract_synsetid(reduce(lambda x,y: x+y, cluster_row_synsets[j]))
                try:
                    start_idx = [ synsets[k].find(s) for k, s in enumerate(gt_synsets) ]
                    synsets = [ synsets[k][start_idx[k]:start_idx[k]+len(gt_synsets[k])] for k, s in enumerate(synsets) ]
                    assert set(synsets)==set(gt_synsets)
                except Exception as e:
                    print(i, j)
                    print(synsets, gt_synsets)
                    invalid_res.append((i,j))

        if len(invalid_res)==0:
            break
        else:
            for i,j in invalid_res:
                print(f'repair {(i,j)}')
                content = concept_templates[j]
                while 1:
                    try:
                        res = openai_chatgpt_post(content)
                        break
                    except Exception as e:
                        print(e)
                all_chatgpt_res[i][j] = res



    """ extract key-value-list from @chatgpt-res """
    extracted_chatgpt_res = []
    for j, row in enumerate(all_chatgpt_res[0]):
        # all_chatgpt_res[0][j] = 
        chatgpt_row_res = {}
        extract_synsetid = lambda r: list(map(lambda x: x.split(': ')[0], r))
        remove_space = lambda r: list(filter(lambda x: len(x), r))
        extract_synnames = lambda r: list(map(lambda x: x.split(': ')[1].split('; '), r))
        for i in range(n_repeat):
            row = all_chatgpt_res[i][j]
            row_data = remove_space(row.lower().replace('\n\n', '\n').split('\n'))
            synsets = extract_synsetid(row_data)
            synnames = extract_synnames(row_data)
            gt_synsets = extract_synsetid(reduce(lambda x,y: x+y, cluster_row_synsets[j]))
            start_idx = [ synsets[k].find(s) for k, s in enumerate(gt_synsets) ]
            synsets = [ synsets[k][start_idx[k]:start_idx[k]+len(gt_synsets[k])] for k, s in enumerate(synsets) ]
            for idx_s, s in enumerate(synsets):
                chatgpt_row_res.setdefault(s, [])
                chatgpt_row_res[s].append( remove_space(synnames[idx_s]) )
        extracted_chatgpt_res.append(chatgpt_row_res)

    """ deduplication """
    use_dedup = True
    all_candidates = []
    all_candidates_set = []
    for i, row in enumerate(extracted_chatgpt_res):
        ### flatten multiple results
        row_all_synset_names = list(map(lambda x: x.split('.')[0], row.keys()))
        row_candidates = {}
        row_candidates_set = {}
        for k, v in row.items():
            candidates = list(reduce(lambda x, y: x+y, v))
            candidates = [c for c in candidates if c not in row_all_synset_names] ### remove competing synset names
            set_candidates = set(candidates)
            k = k.split('.')[0] ### key synset name
            row_candidates.setdefault(k, [])
            row_candidates_set.setdefault(k, set([]))
            row_candidates[k].extend(candidates)
            row_candidates_set[k] |= set_candidates
        ### collect duplicates
        duplicates = set()
        for k1, v1 in row.items():
            k1 = k1.split('.')[0]
            for k2, v2 in row.items():
                k2 = k2.split('.')[0]
                if k1!=k2:
                    duplicates |= row_candidates_set[k1]&row_candidates_set[k2]
        ### remove duplication with synset-names (keys)
        row_candidates_update = {}
        row_candidates_set_update = {}
        for k1, v1 in row.items():
            k1 = k1.split('.')[0]
            for k2, v2 in row.items():
                k2 = k2.split('.')[0]
            row_candidates_set_update[k1] = row_candidates_set[k1] - duplicates if use_dedup else row_candidates_set[k1]
            row_candidates_update[k1] = [item for item in row_candidates[k1] if item not in duplicates ] if row_candidates_set[k1] else row_candidates[k1]

        all_candidates.append(row_candidates_update)
        all_candidates_set.append(row_candidates_set_update)


    ### check non-empty
    empty_list = []
    for i, line in enumerate(all_candidates_set):
        for k, v in line.items():
            if len(v)==0:
                for j in range(n_repeat):
                    empty_list.append(j)
                    print(f'repair {i} {j}')
                    while 1:
                        try:
                            res = openai_chatgpt_post(concept_templates[i])
                            break
                        except Exception as e:
                            print(e)
                    all_chatgpt_res[j][i] = res

    if len(empty_list)==0:
        break

# %%
with open(f'./cache/openai/topk=1-visual-inov-template=9_1-k_1={k_1}-repeat={n_repeat}-data={args.dataset}.pkl', 'wb') as f:
    pickle.dump(all_chatgpt_res, f)

# %%
data = \
{
    'all_candidates': all_candidates,
    'all_candidates_set': all_candidates_set,
}

""" counter sorting """
all_candidates = data['all_candidates']
all_counter_candidates = []
all_number_candidates = []
for row in all_candidates:
    row_counter = {}
    total_num = 0
    for k, v in row.items():
        ct = Counter(v)
        row_counter[k] = OrderedDict(sorted(ct.items())) ### order key
        total_num += sum(ct.values())
    all_counter_candidates.append(OrderedDict(sorted(row_counter.items()))) ### order key
    all_number_candidates.append(total_num)

### flatten
all_row_mapping_idx_synset_name = []
all_row_chatgpt_names = []
all_row_i_syn = []
all_row_weight = []
all_row_key_name = []
for i in range(len(all_counter_candidates)):
    row_synset_names = all_counter_candidates[i].keys()
    row_mapping_idx_synset_name = dict(zip(range(len(row_synset_names)), row_synset_names))
    row_i_syn = []
    row_chatgpt_names = []
    row_weight = []
    for i_syn, syn in enumerate(row_synset_names):
        row_i_syn.extend([i_syn for _ in range(len(all_counter_candidates[i][syn]))])
        row_chatgpt_names.extend(list(all_counter_candidates[i][syn]))
        row_weight.extend(list(all_counter_candidates[i][syn].values()))
    
    all_row_mapping_idx_synset_name.append(row_mapping_idx_synset_name)
    all_row_chatgpt_names.append(row_chatgpt_names)
    all_row_i_syn.append(row_i_syn)
    all_row_weight.append(row_weight)
    all_row_key_name.append(list(map(lambda x: row_mapping_idx_synset_name[x], row_i_syn)))

# %%
@torch.no_grad()
def build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=None):
    """ build classifier for chatgpt
    Args:
        all_row_chatgpt_names: [[names]]
    """
    if all_row_key_name is None: ### single name
        with open('../templates_small.json', 'rb') as f: ### template 1
            templates = json.load(f)['imagenet']
    else:
        with open('../templates_small.json', 'rb') as f: ### template 2
            templates = json.load(f)[f'{args.dataset}-parent-3']
            
    len_t = len(templates)
    row_classifier = []
    with tqdm(total=len(all_row_chatgpt_names)) as pbar:
        for idx, row in enumerate(all_row_chatgpt_names):
            len_row = len(row)
            if all_row_key_name is None:
                row_t = [ t.format(name) for name in row for t in templates ]
            else:
                row_t = [ t.format(pname, name) for pname, name in zip(all_row_key_name[idx], row) for t in templates ]
            row_t = tokenize(row_t).to(args.device)
            features = model.encode_text(row_t)
            features = features.view(len_row, len_t, -1).float()
            features = features/features.norm(dim=-1, keepdim=True)
            features = features.mean(dim=1)
            features = features/features.norm(dim=-1, keepdim=True)
            row_classifier.append(features.cpu())
            
            pbar.update(1)
    return row_classifier

# %%
all_row_classifier = build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=all_row_key_name)
# Out:
# 100%|██████████| 104/104 [00:31<00:00,  3.31it/s]

# %%
# vfeatures = np.load(f'./cache/features/vfeatures-{args.dataset}.npy')
"""
Args:
    all_clu_pred: shape
    all_row_classifier
    record_pred_kmeans_t
    all_row_weight
    all_row_i_syn
    vfeatures
"""
vfeatures = all_vfeatures
all_clu_pred_chatgpt = torch.zeros_like(all_clu_pred)
is_correct = []
k_2 = 3
enable_weight = True
instance_pred_voc = torch.zeros_like(record_pred_kmeans_t)
for c in range(len(all_row_classifier)):
    select = (record_pred_kmeans_t==c)
    row_classifier = all_row_classifier[c]
    sim = torch.from_numpy(vfeatures[select, ...]).to(args.device)@row_classifier.to(args.device).t()
    sim_topk = sim.topk(k=k_2)
    ind, val = sim_topk.indices.flatten().cpu().unique(return_counts=True)
    count_names = torch.zeros(row_classifier.size(0)).long()
    count_names[ind] = val ### count of each name
    count_smask = []
    smask = np.array(all_row_i_syn[c]) ### partition mask
    for s in np.unique(smask):
        if enable_weight:
            row_weight = torch.tensor(all_row_weight[c]).float()
            row_weight[smask==s] = row_weight[smask==s] / row_weight[(smask==s)].sum()
            row_weight /= row_weight.sum()
            count_smask.append((row_weight[smask==s]*count_names[smask==s]).sum().item())
        else:
            count_smask.append(count_names[smask==s].sum())
    name_pred = all_row_mapping_idx_synset_name[c][np.argmax(count_smask)]
    name_gt = all_gt_voc[select].mode().values
    name_gt = vocab.mapping_idx_names[name_gt.item()]
    is_correct.append(name_pred==name_gt)
    instance_pred_voc[select] = vocab.mapping_names_idx[name_pred]
    
    val_count = torch.tensor(count_smask)
    ind_count = [ all_row_mapping_idx_synset_name[c][ii] for ii in range(k_1) ]
    ind_count = torch.tensor([vocab.mapping_names_idx[xx] for xx in ind_count])
    all_clu_pred_chatgpt[c, ind_count] = val_count
    
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
a, res_ass = linear_assign(all_clu_pred_chatgpt, record_pred_kmeans_t, all_gt_voc)
r_pred_kmeans_t, r_cluster_ind_voc = reassign_by_pred_cluster(a, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)
set_pred = set(res_ass[1].tolist())
set_gt = set(all_gt_voc.unique().numpy().tolist())
n_inter = all_gt_voc[r_cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([r_cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
print('iou voc::', iou_voc)
print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=r_pred_kmeans_t.numpy()))
n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)

# %%
name_acc = np.array(is_correct).mean().item()
instance_acc = (instance_pred_voc==all_gt_voc).float().mean().item()
missing = all_gt_voc.unique().size(0) - all_gt_voc[(instance_pred_voc==all_gt_voc)].unique().size(0)

print(f'name_acc={name_acc}, instance_acc={instance_acc}, missing={missing}')
instance_pred_voc.unique().shape, all_gt_voc.unique().shape

# %%
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
a, res_ass = linear_assign(all_clu_pred_chatgpt, record_pred_kmeans_t, all_gt_voc)
r_pred_kmeans_t, r_cluster_ind_voc = reassign_by_pred_cluster(a, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)
# Out:
# linear_assign
# assignment shape=(104, 20071)
# instance label acc:: 0.5225169062614441
# reassign_by_pred_cluster
#   0%|          | 0/519 [00:06<?, ?it/s]

# %%
set_pred = set(res_ass[1].tolist())
set_gt = set(all_gt_voc.unique().numpy().tolist())
n_inter = all_gt_voc[r_cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([r_cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
print('iou voc::', iou_voc)
print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=r_pred_kmeans_t.numpy()))
n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
# Out:
# missing label:: 38
# iou voc:: 0.4647887323943662
# cluster acc 0.7106283941039565
# missing label:: 41

# %%
result_data = {
    'r_pred_kmeans_t': r_pred_kmeans_t.cpu(),
    'r_cluster_ind_voc': r_cluster_ind_voc.cpu(),
}
if args.arch == 'ViT-B/16':
    torch.save(result_data, f'/home/sheng/sssa/ipynb/cache/training/topk=1-cache-inov-{args.dataset}-clip-chatgpt.pth')
elif args.arch == 'ViT-L/14':
    torch.save(result_data, f'/home/sheng/sssa/ipynb/cache/training/topk=1-cache-inov-{args.dataset}-clip-chatgpt-L.pth')
else:
    raise NotImplementedError()

# %%
all_cate_descriptions_new = {}
for k, v in all_cate_descriptions.items():
    all_cate_descriptions_new[k] = \
        list(
            map(lambda x: 
                list(map(lambda y: y.strip(' ').strip('\n'), x.split('- ')))[1:], 
                v)
        )

for k, v in all_cate_descriptions_new.items():
    all_cate_descriptions_new[k] = reduce(lambda x, y: x+y, all_cate_descriptions_new[k])

# %%
with open(f'./cache/openai/vcd-total.pkl', 'wb') as f:
    pickle.dump(all_cate_descriptions, f)

# %%
with open(f'./cache/openai/vcd-clean-total.pkl', 'wb') as f:
    pickle.dump(all_cate_descriptions_new, f)

# %%
all_row_chatgpt_names = []
all_row_key_name = []
all_row_weight = []
all_row_i_syn = []
for row in cluster_row_synsets:
    row_chatgpt_names = []
    row_key_name = []
    row_i_syn = []
    for i, cate in enumerate(row):
        cate_name = cate[0].split('.')[0]
        desc = all_cate_descriptions_new[cate_name]
        if len(desc)==0:
            print(f'desc=0 for {cate_name}')
        desc = [cate[0].split(':')[-1]]
        row_key_name.extend([cate_name]*len(desc))
        row_chatgpt_names.extend(desc)
        row_i_syn.extend([i]*len(desc))
    all_row_chatgpt_names.append(row_chatgpt_names)
    all_row_key_name.append(row_key_name)
    all_row_weight.append([1]*len(row_chatgpt_names))
    all_row_i_syn.append(row_i_syn)

all_row_classifier = build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=all_row_key_name)
# Out:
# desc=0 for anglican
# 100%|██████████| 100/100 [00:04<00:00, 23.73it/s]

# %%
# vfeatures = np.load(f'./cache/features/vfeatures-{args.dataset}.npy')
"""
Args:
    all_clu_pred: shape
    all_row_classifier
    record_pred_kmeans_t
    all_row_weight
    all_row_i_syn
    vfeatures
"""
vfeatures = all_vfeatures
all_clu_pred_chatgpt = torch.zeros_like(all_clu_pred)
is_correct = []
all_name_gt = []
k_2 = 3
enable_weight = True
instance_pred_voc = torch.zeros_like(record_pred_kmeans_t)
for c in range(len(all_row_classifier)):
    select = (record_pred_kmeans_t==c)
    row_classifier = all_row_classifier[c]
    sim = torch.from_numpy(vfeatures[select, ...]).to(args.device)@row_classifier.to(args.device).t()
    sim_topk = sim.topk(k=k_2)
    ind, val = sim_topk.indices.flatten().cpu().unique(return_counts=True)
    count_names = torch.zeros(row_classifier.size(0)).long()
    count_names[ind] = val ### count of each name
    count_smask = []
    smask = np.array(all_row_i_syn[c]) ### partition mask
    for s in np.unique(smask):
        if enable_weight:
            row_weight = torch.tensor(all_row_weight[c]).float()
            row_weight[smask==s] = row_weight[smask==s] / row_weight[(smask==s)].sum()
            row_weight /= row_weight.sum()
            count_smask.append((row_weight[smask==s]*count_names[smask==s]).sum().item())
        else:
            count_smask.append(count_names[smask==s].sum())
    # name_pred = all_row_mapping_idx_synset_name[c][np.argmax(count_smask)]
    name_gt = all_gt_voc[select].mode().values
    name_gt = vocab.mapping_idx_names[name_gt.item()]
    all_name_gt.append(name_gt)
    # is_correct.append(name_pred==name_gt)
    # instance_pred_voc[select] = vocab.mapping_names_idx[name_pred]
    
    val_count = torch.tensor(count_smask)
    ind_count = topk_all_clu_pred[c]
    # ind_count = torch.tensor([vocab.mapping_names_idx[xx] for xx in ind_count])
    all_clu_pred_chatgpt[c, ind_count] = val_count

# %%
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
a, res_ass = linear_assign(all_clu_pred_chatgpt, record_pred_kmeans_t, all_gt_voc)
r_pred_kmeans_t, r_cluster_ind_voc = reassign_by_pred_cluster(a, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)
# Out:
# linear_assign
# assignment shape=(100, 20071)
# instance label acc:: 0.19070133566856384
# reassign_by_pred_cluster
#   0%|          | 0/497 [00:05<?, ?it/s]

# %%
set_pred = set(res_ass[1].tolist())
set_gt = set(all_gt_voc.unique().numpy().tolist())
n_inter = all_gt_voc[r_cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([r_cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
print('iou voc::', iou_voc)
print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=r_pred_kmeans_t.numpy()))
n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
# Out:
# missing label:: 78
# iou voc:: 0.12359550561797752
# cluster acc 0.701364905793966
# missing label:: 46

# %%
from lavis.models import load_model_and_preprocess

model, vis_processors, txt_processors = load_model_and_preprocess(name="blip_vqa", model_type="vqav2", is_eval=True, device=args.device)
dataset_raw = get_datasets_oszsl(args, vocab, is_train=True, transform=None, seed=0)
loader_r = torch.utils.data.DataLoader(dataset_raw, num_workers=4, batch_size=20, shuffle=False)

# %%
to_name = lambda x: x.name().split('.')[0]
cluster_row_synsets = []
for row in topk_all_clu_pred:
    row_synsets = [vocab.mapping_idx_names[voc_idx.item()] for voc_idx in row]
    cluster_row_synsets.append(row_synsets)

# %%
bsize = 1
q = lambda c: f"which category does the object in the photo belong to? a. {c[0]}\nb. {c[1]}\nc. {c[2]}."
q = lambda c: f"what is category name of the dog in the photo?  {c[0]}, {c[1]}, or {c[2]}?"
with tqdm(total=len(dataset_raw)) as pbar:
    batch_label_voc, batch_label_clu = [], []
    batch_img, batch_q = [], []
    all_ans = []
    all_voc, all_clu = [], []
    for idx, item in enumerate(dataset_raw):
        image, label_voc, label_clu, idx_img = item[:4]
        image = vis_processors["eval"](image)
        question = txt_processors["eval"](q(cluster_row_synsets[pred_kmeans_t[idx_img]]))
        batch_label_voc.append(label_voc)
        batch_label_clu.append(label_clu)
        batch_img.append(image)
        batch_q.append(question)

        if idx%bsize==(bsize-1):
            ans = model.predict_answers(samples={"image": torch.stack(batch_img, dim=0).to(args.device), 
                                                 "text_input": batch_q}, inference_method="generate")
            all_ans.append(ans)
            all_voc.extend(batch_label_voc)
            all_clu.extend(batch_label_clu)
            
            batch_label_voc, batch_label_clu = [], []
            batch_img, batch_q = [], []

        pbar.update(1)
# Out:
# 100%|██████████| 12000/12000 [1:12:27<00:00,  2.76it/s]

# %%
from pprint import pprint
pprint(reduce(lambda x, y: x+y, all_ans), compact=True)
pprint([vocab.mapping_idx_names[x] for x in all_voc], compact=True)
# Out:
# ['jack russell terrier', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'terrier', 'chihuahua', 'chihuahua', 'chihuahua',
#  'terrier', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'terrier',
#  'chiwawa', 'terrier', 'chihuahua', 'mutt', 'pomeranian', 'chihuahua',
#  'terrier', 'chihuahua', 'chihuahua', 'chihuahua', 'terrier', 'chihuahua',
#  'chihuahua', 'chihuahua', 'terrier', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'pitbull', 'chihuahua', 'chihuahua', 'pitbull', 'chihuahua',
#  'jack russell terrier', 'terrier', 'chihuahua', 'chihuahua', 'chihuahua',
#  'fido', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'terrier', 'rottweiler', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'jack russell terrier', 'chihuahua', 'chihuahua', 'chihuahua',
#  'terrier', 'chihuahua', 'chihuahua', 'jack russell terrier', 'fido',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'terrier', 'jack russell terrier', 'fido', 'mutt',
#  'dachshund', 'chihuahua', 'pitbull', 'jack russell terrier', 'schnauzer',
#  'chihuahua', 'chihuahua', 'chihuahua', 'terrier', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'border collie', 'terrier', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'pug', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'cocker spaniel', 'shih tzu', 'shih tzu', 'collie',
#  'cocker spaniel', 'shih tzu', 'shih tzu', 'collie', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'spaniel', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'border collie', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'spot', 'border collie', 'shih tzu', 'shih tzu', 'cocker spaniel',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'terrier', 'spaniel',
#  'shih tzu', 'shih tzu', 'terrier', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'pug', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'cocker spaniel', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'border collie',
#  'terrier', 'shih tzu', 'shih tzu', 'shih tzu', 'pug', 'shih tzu', 'shih tzu',
#  'shih tzu', 'poodle', 'poodle', 'terrier', 'shih tzu', 'shih tzu', 'poodle',
#  'shih tzu', 'poodle', 'poodle', 'shih tzu', 'terrier', 'shih tzu', 'shih tzu',
#  'terrier', 'poodle', 'poodle', 'terrier', 'poodle', 'poodle', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'terrier', 'poodle', 'poodle', 'poodle',
#  'poodle', 'shih tzu', 'shih tzu', 'shih tzu', 'poodle', 'poodle', 'shih tzu',
#  'poodle', 'poodle', 'poodle', 'shih tzu', 'shih tzu', 'shih tzu', 'poodle',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'terrier', 'shih tzu',
#  'terrier', 'shih tzu', 'poodle', 'shih tzu', 'terrier', 'shih tzu', 'shih tzu',
#  'shih tzu', 'poodle', 'poodle', 'shih tzu', 'shih tzu', 'terrier', 'terrier',
#  'shih tzu', 'poodle', 'poodle', 'terrier', 'poodle', 'terrier', 'shih tzu',
#  'shih tzu', 'poodle', 'shih tzu', 'shih tzu', 'shih tzu', 'poodle', 'shih tzu',
#  'poodle', 'poodle', 'shih tzu', 'shih tzu', 'shih tzu', 'poodle', 'fido',
#  'shih tzu', 'shih tzu', 'terrier', 'shih tzu', 'poodle', 'shih tzu',
#  'shih tzu', 'shih tzu', 'schnauzer', 'poodle', 'shih tzu', 'poodle', 'terrier',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'terrier', 'shih tzu',
#  'shih tzu', 'pug', 'shih tzu', 'pekingese', 'pomeranian', 'pug', 'pug',
#  'shih tzu', 'shih tzu', 'pug', 'shih tzu', 'pomeranian', 'pomeranian',
#  'chiwawa', 'pug', 'pug', 'terrier', 'shih tzu', 'pug', 'shih tzu', 'shih tzu',
#  'pug', 'pekingese', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'pug', 'jack russell terrier', 'terrier', 'terrier', 'terrier', 'pug', 'pug',
#  'shih tzu', 'pug', 'terrier', 'shih tzu', 'poodle', 'shih tzu', 'shih tzu',
#  'pekingese', 'shih tzu', 'shih tzu', 'pug', 'shih tzu', 'shih tzu', 'pug',
#  'poodle', 'pug', 'fido', 'mutt', 'shih tzu', 'pug', 'terrier', 'shih tzu',
#  'pug', 'pug', 'pekingese', 'cocker spaniel', 'pug', 'shih tzu', 'pug', 'pug',
#  'shih tzu', 'shih tzu', 'shih tzu', 'schnauzer', 'pug', 'pug', 'shih tzu',
#  'shih tzu', 'pekingese', 'pug', 'shih tzu', 'shih tzu', 'shih tzu', 'puppy',
#  'pekingese', 'pug', 'shih tzu', 'shih tzu', 'terrier', 'shih tzu', 'shih tzu',
#  'pug', 'terrier', 'pug', 'shih tzu', 'shih tzu', 'shih tzu', 'pug', 'pug',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'schnauzer', 'shih tzu', 'shih tzu', 'shih tzu', 'terrier', 'shih tzu',
#  'schnauzer', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'poodle', 'terrier', 'shih tzu', 'shih tzu', 'terrier', 'shih tzu',
#  'pug', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'schnauzer', 'shih tzu', 'terrier', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'terrier', 'schnauzer', 'schnauzer', 'shih tzu',
#  'cocker spaniel', 'shih tzu', 'shih tzu', 'cocker spaniel', 'shih tzu',
#  'poodle', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'schnauzer',
#  'shih tzu', 'shih tzu', 'terrier', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'schnauzer', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu',
#  'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'shih tzu', 'terrier',
#  'cocker spaniel', 'spaniel', 'cocker spaniel', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'cocker spaniel',
#  'puppy', 'cocker spaniel', 'cocker spaniel', 'spaniel', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'beagle', 'cocker spaniel',
#  'jack russell terrier', 'cocker spaniel', 'jack russell terrier', 'puppy',
#  'cocker spaniel', 'cocker spaniel', 'spaniel', 'cocker spaniel',
#  'cocker spaniel', 'terrier', 'cocker spaniel', 'terrier', 'cocker spaniel',
#  'cocker spaniel', 'terrier', 'cocker spaniel', 'miles', 'spaniel', 'puppy',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'spaniel',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'collie',
#  'cocker spaniel', 'beagle', 'spaniel', 'cocker spaniel', 'terrier',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'terrier',
#  'cocker spaniel', 'cocker spaniel', 'puppy', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'schnauzer', 'cocker spaniel', 'terrier',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'spaniel',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'cocker spaniel',
#  'spaniel', 'cocker spaniel', 'cocker spaniel', 'cocker spaniel',
#  'cocker spaniel', 'jack russell terrier', 'cocker spaniel', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'spaniel', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'cocker spaniel',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'spaniel',
#  'cocker spaniel', 'shih tzu', 'shih tzu', 'terrier', 'terrier', 'terrier',
#  'shih tzu', 'terrier', 'collie', 'terrier', 'terrier', 'terrier', 'terrier',
#  'terrier', 'shih tzu', 'collie', 'spaniel', 'terrier', 'terrier', 'terrier',
#  'terrier', 'shih tzu', 'terrier', 'border collie', 'terrier', 'shih tzu',
#  'shih tzu', 'terrier', 'collie', 'terrier', 'terrier', 'collie', 'terrier',
#  'border collie', 'terrier', 'terrier', 'terrier', 'chihuahua', 'pomeranian',
#  'terrier', 'terrier', 'terrier', 'terrier', 'terrier', 'shih tzu', 'collie',
#  'shih tzu', 'terrier', 'collie', 'shih tzu', 'terrier', 'terrier', 'terrier',
#  'border collie', 'shih tzu', 'terrier', 'terrier', 'terrier', 'terrier',
#  'terrier', 'terrier', 'terrier', 'terrier', 'corgi', 'terrier', 'pomeranian',
#  'terrier', 'collie', 'shih tzu', 'pomeranian', 'spaniel', 'terrier', 'corgi',
#  'shih tzu', 'terrier', 'terrier', 'terrier', 'terrier', 'jack russell terrier',
#  'terrier', 'terrier', 'terrier', 'terrier', 'terrier', 'terrier', 'terrier',
#  'terrier', 'shih tzu', 'shih tzu', 'spaniel', 'terrier', 'pomeranian',
#  'shih tzu', 'terrier', 'terrier', 'shih tzu', 'terrier', 'shih tzu', 'terrier',
#  'terrier', 'pomeranian', 'terrier', 'chihuahua', 'chihuahua', 'chihuahua',
#  'terrier', 'terrier', 'doberman', 'fido', 'terrier', 'chihuahua', 'chihuahua',
#  'chihuahua', 'fido', 'terrier', 'chihuahua', 'jack russell terrier', 'mutt',
#  'jack russell terrier', 'terrier', 'terrier', 'terrier', 'yorkie',
#  'rottweiler', 'chihuahua', 'jack russell', 'jack russell terrier', 'terrier',
#  'chihuahua', 'chihuahua', 'boston terrier', 'fido', 'fido', 'rottweiler',
#  'jack russell terrier', 'fido', 'spot', 'terrier', 'chihuahua',
#  'jack russell terrier', 'chihuahua', 'chihuahua', 'chihuahua',
#  'jack russell terrier', 'terrier', 'jack russell terrier', 'terrier', 'pug',
#  'jack russell terrier', 'fido', 'jack russell terrier', 'terrier', 'yorkie',
#  'jack russell', 'terrier', 'terrier', 'jack russell terrier', 'terrier',
#  'chihuahua', 'jack russell terrier', 'dachshund', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'dachshund', 'terrier', 'terrier',
#  'chihuahua', 'boston terrier', 'terrier', 'terrier', 'chihuahua', 'terrier',
#  'terrier', 'chihuahua', 'chihuahua', 'terrier', 'boston terrier', 'chihuahua',
#  'terrier', 'terrier', 'pitbull', 'chihuahua', 'jack russell terrier',
#  'dachshund', 'rottweiler', 'jack', 'chihuahua', 'jack russell terrier',
#  'terrier', 'doberman', 'chihuahua', 'terrier', 'terrier', 'chihuahua',
#  'terrier', 'chihuahua', 'dachshund', 'terrier', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'doberman', 'pitbull', 'mutt', 'puppy', 'pitbull',
#  'mutt', 'pitbull', 'pitbull', 'pitbull', 'dachshund', 'doberman', 'pitbull',
#  'lab', 'mutt', 'pitbull', 'mutt', 'doberman', 'pitbull', 'pitbull', 'pitbull',
#  'lab', 'collie', 'pitbull', 'pitbull', 'dachshund', 'beagle', 'mutt',
#  'pitbull', 'pitbull', 'mutt', 'mutt', 'mutt', 'doberman', 'pitbull', 'pitbull',
#  'pitbull', 'doberman', 'pitbull', 'pitbull', 'lab', 'pitbull', 'pitbull',
#  'pitbull', 'dachshund', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'doberman', 'pitbull', 'lab', 'mutt', 'pitbull', 'dachshund', 'pitbull',
#  'mutt', 'dachshund', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'dachshund',
#  'dachshund', 'pitbull', 'pitbull', 'pitbull', 'rover', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'dachshund', 'lab', 'pitbull', 'lab',
#  'pitbull', 'mutt', 'dachshund', 'mutt', 'pitbull', 'pitbull', 'dachshund',
#  'pitbull', 'pitbull', 'pitbull', 'mutt', 'mutt', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'mutt', 'pitbull', 'cocker spaniel',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'collie', 'cocker spaniel',
#  'long haired dachshund', 'cocker spaniel', 'collie', 'poodle', 'collie',
#  'collie', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'cocker spaniel', 'collie', 'long haired dachshund', 'terrier',
#  'border collie', 'schnauzer', 'collie', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'cocker spaniel', 'collie', 'schnauzer', 'schnauzer', 'schnauzer',
#  'cocker spaniel', 'schnauzer', 'collie', 'cocker spaniel', 'collie',
#  'schnauzer', 'schnauzer', 'cocker spaniel', 'collie', 'schnauzer', 'schnauzer',
#  'lhasa apso', 'cocker spaniel', 'schnauzer', 'schnauzer', 'schnauzer',
#  'collie', 'cocker spaniel', 'collie', 'cocker spaniel', 'poodle', 'collie',
#  'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'cocker spaniel', 'schnauzer', 'cocker spaniel', 'schnauzer',
#  'collie', 'collie', 'lhasa apso', 'schnauzer', 'shih tzu', 'spaniel', 'poodle',
#  'collie', 'collie', 'collie', 'schnauzer', 'collie', 'schnauzer',
#  'cocker spaniel', 'cocker spaniel', 'cocker spaniel', 'dachshund',
#  'cocker spaniel', 'cocker spaniel', 'collie', "don't know", 'cocker spaniel',
#  'collie', 'schnauzer', 'schnauzer', 'collie', 'schnauzer', 'cocker spaniel',
#  'schnauzer', 'cocker spaniel', 'cocker spaniel', 'collie', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'basset hound', 'beagle', 'basset hound', 'beagle', 'beagle', 'beagle',
#  'basset hound', 'beagle', 'bulldog', 'beagle', 'beagle', 'basset hound',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'rottweiler', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'pitbull', 'beagle', 'beagle', 'beagle',
#  'jack russell terrier', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'dachshund', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'basset hound', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'dachshund', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'dachshund', 'beagle', 'beagle', 'beagle', 'beagle', 'jack russell', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'dachshund', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'lab', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'jack russell', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'jack russell terrier', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'dachshund', 'dachshund', 'mastiff', 'hound', 'dachshund',
#  'beagle', 'mutt', 'bloodhound', 'hound', 'dachshund', 'hound', 'hound',
#  'basset hound', 'beagle', 'rottweiler', 'dachshund', 'rottweiler', 'pitbull',
#  'beagle', 'fido', 'beagle', 'basset hound', 'mutt', 'dachshund', 'dachshund',
#  'hound', 'hound', 'dachshund', 'beagle', 'bloodhound', 'bulldog', 'hound',
#  'beagle', 'mutt', "don't know", 'mutt', 'dachshund', 'beagle', 'beagle',
#  'beagle', 'hound', 'dachshund', 'dachshund', 'dachshund', 'hound', 'mutt',
#  'beagle', 'dachshund', 'hound', 'mutt', 'beagle', 'beagle', 'dachshund',
#  'dachshund', 'basset hound', 'hound', 'mutt', 'lab', 'beagle', 'beagle',
#  'mutt', 'mutt', 'dachshund', 'beagle', 'beagle', 'mutt', 'hound', 'hound',
#  'hound', 'basset hound', 'mutt', 'beagle', 'beagle', 'dachshund', 'dachshund',
#  'dachshund', 'beagle', 'beagle', 'beagle', 'dachshund', 'dachshund', 'mutt',
#  'basset hound', 'hound', 'pitbull', 'mastiff', 'mutt', 'mutt', 'dachshund',
#  'dachshund', 'hound', 'bloodhound', 'mutt', 'doberman', 'hound', 'hound',
#  'beagle', 'mutt', 'beagle', 'dachshund', 'dachshund', 'dachshund', 'dachshund',
#  'jack russell terrier', 'dalmatian', 'dalmatian', 'mutt', 'rottweiler', 'mutt',
#  'beagle', 'beagle', 'beagle', 'beagle', 'dalmatian', 'beagle', 'beagle',
#  'terrier', 'beagle', 'dalmatian', 'dachshund', 'rottweiler', 'dachshund',
#  'beagle', 'beagle', 'dachshund', 'dachshund', 'beagle', 'fido', 'beagle',
#  'dachshund', 'dachshund', 'dachshund', 'beagle', 'mutt', 'dalmatian', 'mutt',
#  'dachshund', 'dachshund', 'beagle', 'beagle', 'beagle', 'dachshund',
#  'dachshund', 'fido', 'collie', 'beagle', 'dachshund', 'mutt', 'dalmatian',
#  'beagle', 'dalmatian', 'beagle', 'beagle', 'fido', 'beagle', 'mutt',
#  'dachshund', 'dalmatian', 'beagle', 'mutt', 'beagle', 'dalmatian', 'dalmatian',
#  'dalmatian', 'mutt', 'dachshund', 'beagle', 'jack russell terrier', 'mutt',
#  'beagle', 'dachshund', 'beagle', 'beagle', 'jack russell terrier', 'beagle',
#  'dachshund', 'jack russell terrier', 'beagle', 'dalmatian', 'beagle', 'beagle',
#  'bob', 'beagle', 'beagle', 'rottweiler', 'jack russell terrier', 'rottweiler',
#  'dalmatian', 'dalmatian', 'beagle', 'fido', 'dachshund', 'rottweiler',
#  'rottweiler', 'beagle', 'dachshund', 'mutt', 'rottweiler', 'beagle', 'mutt',
#  'rottweiler', 'dachshund', 'rottweiler', 'doberman', 'dachshund', 'dachshund',
#  'dachshund', 'dachshund', 'dachshund', 'dachshund', 'dachshund', 'dachshund',
#  'dachshund', 'dachshund', 'dachshund', 'dachshund', 'dachshund', 'beagle',
#  'mutt', 'dachshund', 'dachshund', 'dachshund', 'rottweiler', 'dachshund',
#  'dachshund', 'dachshund', 'rottweiler', 'dachshund', 'rottweiler',
#  'rottweiler', 'dachshund', 'dachshund', 'dachshund', 'dachshund', 'rottweiler',
#  'dachshund', 'dachshund', 'dachshund', 'dachshund', 'dachshund', 'rottweiler',
#  'rottweiler', 'dachshund', 'dachshund', 'dachshund', 'rottweiler',
#  'rottweiler', 'dachshund', 'dachshund', 'dachshund', 'doberman', 'dachshund',
#  'dachshund', 'jack russell terrier', 'dachshund', 'rottweiler', 'dachshund',
#  'rottweiler', 'dachshund', 'rottweiler', 'dachshund', 'rottweiler', 'mutt',
#  'rottweiler', 'dachshund', 'doberman', 'dachshund', 'rottweiler', 'dachshund',
#  'dachshund', 'dachshund', 'rottweiler', 'dachshund', 'dachshund', 'rottweiler',
#  'dachshund', 'rottweiler', 'dachshund', 'dachshund', 'dachshund', 'doberman',
#  'rottweiler', 'dachshund', 'dachshund', 'rottweiler', 'dachshund', 'dachshund',
#  'dachshund', 'dachshund', 'dachshund', 'dachshund', 'dachshund', 'dachshund',
#  'dachshund', 'dachshund', 'rottweiler', 'dachshund', 'dachshund', 'dachshund',
#  'dachshund', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'jack russell', 'beagle',
#  'beagle', 'beagle', 'beagle', 'jack russell', 'beagle', 'beagle', 'beagle',
#  'jack russell terrier', 'beagle', 'beagle', 'beagle', 'jack russell terrier',
#  'beagle', 'beagle', 'beagle', 'beagle', 'jack russell terrier', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'dalmatian', 'beagle', 'beagle', 'lab', 'beagle',
#  'pitbull', 'jack russell', 'beagle', 'beagle', 'beagle', 'beagle',
#  'jack russell terrier', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'jack russell', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'jack russell', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'hound', 'beagle', 'beagle', 'jack russell terrier', 'beagle', 'beagle',
#  'beagle', 'beagle', 'pitbull', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'jack russell',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'basset hound',
#  'beagle', 'beagle', 'beagle', 'jack russell', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'beagle',
#  'beagle', 'beagle', 'beagle', 'beagle', 'beagle', 'hound', 'dachshund',
#  'dachshund', 'fido', 'dachshund', 'mutt', 'dachshund', 'dachshund', 'mutt',
#  'mutt', 'mutt', 'dachshund', 'fido', 'dachshund', 'mutt', 'dachshund',
#  'dachshund', 'dachshund', 'dachshund', 'mutt', 'beagle', 'beagle', 'dachshund',
#  'lab', 'dachshund', 'mutt', 'fido', 'dachshund', 'dachshund', 'mutt',
#  'dachshund', 'fido', 'dachshund', 'dachshund', 'fido', 'beagle', 'dachshund',
#  'dachshund', 'dachshund', 'pitbull', 'dachshund', 'mutt', 'dachshund',
#  'dachshund', 'mutt', 'dachshund', 'dachshund', 'doberman', 'dachshund',
#  'dachshund', 'dachshund', 'pitbull', 'dachshund', 'dachshund', 'dachshund',
#  'mutt', 'lab', 'dachshund', 'mutt', 'dachshund', 'lab', 'dachshund', 'lab',
#  'pitbull', 'mutt', 'mutt', 'mutt', 'pitbull', 'dachshund', 'dachshund', 'mutt',
#  'dachshund', 'mutt', 'dachshund', 'dachshund', 'dachshund', 'red', 'pitbull',
#  'dachshund', 'beagle', 'lab', 'dachshund', 'dachshund', 'dachshund',
#  'dachshund', 'fido', 'dachshund', 'dachshund', 'mutt', 'dachshund',
#  'dachshund', 'dachshund', 'mutt', 'pitbull', 'dachshund', 'beagle', 'lab',
#  'fido', 'dachshund', 'mutt', 'collie', 'collie', 'collie', 'collie', 'collie',
#  'collie', 'collie', 'collie', 'collie', 'jack russell', 'fido', 'collie',
#  'collie', 'collie', 'collie', 'collie', 'fido', 'collie', 'collie', 'collie',
#  'collie', 'collie', 'collie', 'collie', 'sheepdog', 'collie', 'collie',
#  'collie', 'collie', 'terrier', 'collie', 'collie', 'collie', 'collie',
#  'collie', 'border collie', 'collie', 'collie', 'jack russell terrier',
#  'collie', 'mutt', 'collie', 'collie', 'collie', 'collie', 'collie', 'collie',
#  'collie', 'collie', 'bozenka', 'collie', 'collie', 'collie', 'collie',
#  'collie', 'collie', 'collie', 'collie', 'collie', 'collie', 'bozenka',
#  'collie', 'collie', 'george washington', 'collie', 'jack russell', 'collie',
#  'collie', 'terrier', 'collie', 'collie', 'dalmatian', 'collie', 'fido', 'mutt',
#  'collie', 'golden retriever', 'sheepdog', 'jack russell terrier', 'collie',
#  'collie', 'collie', 'collie', 'collie', 'lab', 'terrier', 'collie', 'collie',
#  'collie', 'collie', 'collie', 'collie', 'fido', 'collie', 'collie', 'collie',
#  'collie', 'collie', 'collie', 'mutt', 'schnauzer', 'terrier', 'husky',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'terrier', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'pitbull', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'collie', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'mutt',
#  'mutt', 'terrier', 'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'mutt',
#  'dachshund', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'mutt', 'collie', 'mutt', 'schnauzer', 'terrier', 'mutt', 'terrier',
#  'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'terrier', 'collie',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'mutt', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'greyhound', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'fido',
#  'pitbull', 'pitbull', 'chihuahua', 'terrier', 'pitbull', 'pitbull',
#  'chihuahua', 'pitbull', 'terrier', 'schnauzer', 'pitbull',
#  'jack russell terrier', 'pitbull', 'fido', 'pitbull', 'jack russell terrier',
#  'pitbull', 'jack russell', 'terrier', 'terrier', 'pitbull', 'pitbull',
#  'doberman', 'chihuahua', 'fido', 'pitbull', 'do not know', 'pitbull',
#  'chihuahua', 'pitbull', 'doberman', 'pitbull', 'pitbull',
#  'jack russell terrier', 'pitbull', 'pitbull', 'doberman', 'terrier', 'mutt',
#  'chihuahua', 'doberman', 'pitbull', 'dachshund', 'fido',
#  'jack russell terrier', 'pitbull', 'pitbull', 'chihuahua', 'fido',
#  "i don't know", 'pitbull', 'fido', 'fido', 'fido', 'pitbull', 'mutt',
#  'jack russell terrier', 'chihuahua', 'pitbull', 'jack russell terrier',
#  'jack russell terrier', 'pitbull', 'pitbull', 'jack russell terrier', 'fido',
#  'pitbull', 'dalmatian', 'terrier', 'fido', 'schnauzer', 'fido', 'terrier',
#  'fido', 'dachshund', 'terrier', 'doberman', 'jack russell terrier', 'pitbull',
#  'pitbull', 'jack russell terrier', 'fido', 'pitbull', 'pitbull', 'terrier',
#  'doberman', 'pitbull', 'pitbull', 'terrier', 'pitbull', 'pitbull',
#  'jack russell terrier', 'jack russell terrier', 'doberman', 'fido', 'doberman',
#  'pitbull', 'terrier', 'terrier', 'doberman', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'greyhound', 'pitbull', 'pitbull', 'jack russell terrier',
#  'pitbull', 'mutt', 'jack russell terrier', 'jack russell terrier', 'pitbull',
#  'pitbull', 'jack russell terrier', 'pitbull', 'pitbull', 'fido', 'fido',
#  'terrier', 'pitbull', "don't know", 'pitbull', 'dachshund', 'fido', 'fido',
#  'pitbull', 'greyhound', 'greyhound', 'fido', 'jack russell', 'pitbull',
#  'bulldog', 'dalmatian', 'pitbull', 'jack russell terrier', 'dalmatian', 'fido',
#  'doberman', 'beagle', 'pitbull', 'dingo', 'pitbull', 'pitbull', 'fido',
#  'pitbull', 'jack russell terrier', 'pitbull', 'mutt', 'dalmatian', 'dalmatian',
#  'pitbull', 'pitbull', 'pitbull', 'fido', 'dalmatian', 'pitbull', 'greyhound',
#  'doberman', 'dalmatian', 'jack russell terrier', 'terrier', 'pitbull',
#  'dalmatian', 'pitbull', 'jack russell terrier', 'pitbull', 'pitbull', 'mutt',
#  'pitbull', 'chihuahua', 'fido', 'pitbull', 'jack russell', 'pitbull',
#  'pitbull', 'fido', 'pitbull', 'dalmatian', 'pitbull', 'pitbull', 'fido',
#  'dalmatian', 'jack russell', 'pitbull', 'pitbull', 'pitbull', 'fido',
#  'pitbull', 'fido', 'pitbull', 'dachshund', 'jack russell', 'jack russell',
#  'jack russell', 'greyhound', 'pitbull', 'pitbull', 'doberman', 'pitbull',
#  "don't know", 'terrier', 'pitbull', 'pitbull', 'doberman', 'pitbull',
#  'terrier', 'terrier', 'pitbull', 'terrier', 'jack russell', 'pitbull',
#  'pitbull', 'pitbull', 'jack russell terrier', 'pitbull', 'doberman', 'pitbull',
#  'terrier', 'doberman', 'jack russell terrier', 'pitbull', 'doberman',
#  'pitbull', 'pitbull', 'jack russell', 'pitbull', 'terrier', 'jack russell',
#  'jack russell', 'husky', 'doberman', 'chihuahua', 'jack russell terrier',
#  'pitbull', "don't know", 'jack russell', 'jack russell',
#  'jack russell terrier', 'pitbull', 'jack russell terrier', 'pitbull',
#  "don't know", 'terrier', 'pitbull', 'pitbull', 'jack russell', 'pitbull',
#  'pitbull', 'jack russell', 'terrier', 'pitbull', 'terrier', 'pitbull',
#  'terrier', 'jack russell', 'jack russell', 'pitbull', 'jack russell terrier',
#  'jack russell terrier', 'jack russell', 'jack russell', 'jack russell terrier',
#  'jack russell', "don't know", 'pitbull', 'doberman', 'jack russell', 'pitbull',
#  'pitbull', 'jack russell', 'pitbull', 'jack russell', 'jack russell',
#  'jack russell terrier', 'pitbull', "don't know", 'pitbull', 'jack russell',
#  'terrier', 'jack russell terrier', 'dalmatian', 'jack russell terrier',
#  'jack russell terrier', 'dalmatian', 'jack russell terrier', 'pitbull',
#  'pitbull', 'jack russell', 'jack russell', 'pitbull', 'doberman',
#  'jack russell terrier', 'pitbull', 'terrier', 'pitbull', 'fido', 'beagle',
#  'pitbull', 'jack russell terrier', 'pug', 'german shepherd', 'pug', 'mutt',
#  'mutt', 'german shepherd', 'husky', 'mutt', 'husky', 'pug', 'mutt', 'husky',
#  'husky', 'husky', 'husky', 'mutt', 'husky', 'husky', 'german shepherd', 'mutt',
#  'husky', 'husky', 'husky', 'husky', 'german shepherd', 'husky', 'fido',
#  'husky', 'terrier', 'german shepherd', 'husky', 'german shepherd', 'husky',
#  'german shepherd', 'husky', 'husky', 'german shepherd', 'german shepherd',
#  'german shepherd', 'german shepherd', 'husky', 'husky', 'german shepherd',
#  'german shepherd', 'german shepherd', 'husky', 'husky', 'husky', 'husky',
#  'husky', 'pug', 'pug', 'husky', 'german shepherd', 'german shepherd', 'mutt',
#  'german shepherd', 'husky', 'german shepherd', 'mutt', 'husky', 'husky',
#  'husky', 'pug', 'husky', 'german shepherd', 'mutt', 'schnauzer',
#  'german shepherd', 'german shepherd', 'husky', 'husky', 'german shepherd',
#  'mutt', 'german shepherd', 'husky', 'husky', 'husky', 'german shepherd',
#  'mutt', 'german shepherd', 'german shepherd', 'german shepherd',
#  'german shepherd', 'mutt', 'husky', 'german shepherd', 'mutt', 'shiba inu',
#  'mutt', 'husky', 'husky', 'husky', 'german shepherd', 'husky', 'husky',
#  'husky', 'german shepherd', 'pug', 'husky', 'schnauzer', 'mutt',
#  'cocker spaniel', 'schnauzer', 'schnauzer', 'beagle', 'schnauzer', 'schnauzer',
#  'collie', 'cocker spaniel', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'mutt', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'shih tzu', 'schnauzer',
#  'cocker spaniel', 'schnauzer', 'schnauzer', 'cocker spaniel', 'cocker spaniel',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'cocker spaniel', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'mutt', 'schnauzer', 'mutt', 'schnauzer',
#  'charles spaniel', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'collie', 'schnauzer', 'schnauzer', 'cocker spaniel', 'schnauzer', 'mutt',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'cocker spaniel',
#  'schnauzer', 'mutt', 'schnauzer', 'schnauzer', 'mutt', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'mutt', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'collie', 'mutt', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'terrier', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'collie', 'collie', 'dachshund', 'collie', 'fido', 'collie',
#  'mutt', 'mutt', "don't know", 'collie', 'collie', 'fido',
#  'jack russell terrier', 'collie', 'collie', 'collie', 'mutt', 'mutt',
#  'jack russell terrier', 'collie', "don't know", 'collie', 'mutt',
#  'cocker spaniel', 'dachshund', 'collie', 'mutt', 'collie', 'mutt', 'collie',
#  'jack russell terrier', 'pitbull', 'collie', 'dalmatian', 'fido', 'poodle',
#  'cocker spaniel', 'poodle', 'terrier', 'poodle', 'collie', 'golden retriever',
#  'mutt', 'collie', 'fido', 'mutt', 'mutt', 'cocker spaniel', 'collie', 'collie',
#  'collie', 'dachshund', 'mutt', 'collie', 'collie', "don't know", 'mutt',
#  'mutt', 'dalmatian', 'cocker spaniel', 'collie', 'dachshund', 'fido', 'lab',
#  'collie', 'collie', 'collie', 'mutt', 'golden retriever', 'beagle', 'collie',
#  'lab', 'jack russell terrier', 'collie', 'collie', 'mutt', 'cocker spaniel',
#  'collie', 'collie', 'collie', 'mutt', 'mutt', 'jack russell terrier', 'mutt',
#  'fido', 'mutt', 'fido', 'collie', 'jack russell terrier', 'collie',
#  'jack russell terrier', 'collie', 'fido', 'beagle', 'dalmatian', 'lab',
#  'collie', 'golden retriever', 'collie', 'collie', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'collie',
#  'collie', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', "don't know",
#  'schnauzer', 'mutt', 'mutt', 'schnauzer', 'mutt', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'collie', 'jack russell terrier',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'collie', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'mutt', 'schnauzer', 'schnauzer', 'schnauzer',
#  'mutt', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'collie', 'schnauzer', 'poodle', 'terrier', 'schnauzer',
#  'schnauzer', 'schnauzer', 'collie', 'mutt', 'schnauzer', 'schnauzer',
#  'schnauzer', 'fido', 'schnauzer', 'schnauzer', 'schnauzer', 'sheepdog',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'mutt', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'dachshund', 'dachshund', 'dachshund', 'fido',
#  'dachshund', 'dachshund', 'lab', 'lab', 'pitbull', 'pitbull', 'pitbull',
#  'dachshund', 'weimaraner', 'dachshund', 'weimaraner', 'pitbull', 'pitbull',
#  'weimaraner', 'labrador', 'doberman', 'weimaraner', 'fido', 'mutt',
#  'dachshund', 'labrador', 'lab', 'fido', 'dachshund', 'dachshund', 'dachshund',
#  'weimaraner', 'pitbull', 'hound', 'dachshund', 'dachshund', 'pitbull',
#  'dachshund', 'weimaraner', 'pitbull', 'fido', 'dachshund', 'dachshund',
#  'dachshund', 'weimaraner', 'fido', 'dachshund', 'pitbull', 'dachshund',
#  'pitbull', 'mutt', 'pitbull', 'pitbull', 'pitbull', 'doberman', 'dachshund',
#  'dachshund', 'pitbull', 'pitbull', 'pitbull', 'dachshund', 'mutt', 'dachshund',
#  'fido', 'dachshund', 'weimaraner', 'pitbull', 'dachshund', 'doberman', 'fido',
#  'doberman', 'lab', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'dachshund',
#  'lab', 'pitbull', 'weimaraner', 'dachshund', 'dachshund', 'dachshund',
#  'pitbull', 'weimaraner', 'lab', 'pitbull', 'dachshund', 'weimaraner',
#  'weimaraner', 'pitbull', 'dachshund', 'dachshund', 'fido', 'pitbull',
#  'weimaraner', 'mutt', 'weimaraner', 'pitbull', 'dachshund', "don't know",
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pug', 'lab', 'pug', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'bulldog', 'pitbull', 'pitbull', 'bulldog', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pug', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pug', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'lab', 'pitbull', 'pitbull', 'pug', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'lab', 'pitbull',
#  'pitbull', 'bulldog', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'bulldog', 'pitbull', 'pitbull', 'pitbull', 'bulldog', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'bulldog', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pug',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'bulldog', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'jack russell', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'bulldog', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'jack russell terrier', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'bulldog', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull', 'pitbull',
#  'pitbull', 'pitbull', 'pitbull', 'poodle', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'schnauzer',
#  'poodle', 'poodle', 'fido', 'poodle', 'poodle', 'poodle', 'fido', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'schnauzer', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'schnauzer', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'jack russell', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'fido', 'schnauzer', 'poodle', 'fido',
#  'pitbull', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'poodle',
#  'poodle', 'poodle', 'poodle', 'poodle', 'poodle', 'terrier', 'terrier', 'fido',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer', 'terrier',
#  'terrier', 'terrier', 'terrier', 'schnauzer', 'fido', 'schnauzer', 'terrier',
#  'schnauzer', 'terrier', 'terrier', 'schnauzer', 'terrier', 'schnauzer',
#  'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'terrier',
#  'terrier', 'mutt', 'schnauzer', 'mutt', 'terrier', 'dachshund', 'schnauzer',
#  'terrier', 'mutt', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'mutt',
#  'schnauzer', 'schnauzer', 'terrier', 'terrier', 'fido', 'terrier', 'schnauzer',
#  'schnauzer', 'terrier', 'terrier', 'mutt', 'schnauzer', 'terrier', 'terrier',
#  'terrier', 'terrier', 'schnauzer', 'pitbull', 'terrier', 'mutt', 'terrier',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'terrier',
#  'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'terrier', 'terrier',
#  'terrier', 'schnauzer', 'terrier', 'schnauzer', 'mutt', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'jack', 'schnauzer',
#  'schnauzer', 'schnauzer', 'terrier', 'terrier', 'schnauzer', 'terrier',
#  'terrier', 'poodle', 'poodle', 'schnauzer', 'poodle', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'poodle', 'poodle', 'poodle', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'poodle', 'poodle', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'poodle', 'poodle', 'poodle', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'poodle', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'poodle', 'schnauzer',
#  'poodle', 'poodle', 'poodle', 'schnauzer', 'poodle', 'poodle', 'poodle',
#  'poodle', 'schnauzer', 'schnauzer', 'poodle', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'poodle', 'schnauzer',
#  'poodle', 'poodle', 'fido', 'poodle', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'poodle', 'schnauzer', 'poodle', 'schnauzer', 'schnauzer',
#  'poodle', 'poodle', 'poodle', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer',
#  'poodle', 'dalmatian', 'poodle', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer',
#  'terrier', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer',
#  'terrier', 'mutt', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'mutt', 'terrier', 'schnauzer', 'schnauzer',
#  'schnauzer', 'mutt', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'terrier', 'terrier', 'schnauzer', 'fido', 'schnauzer',
#  'schnauzer', 'schnauzer', 'pitbull', 'schnauzer', 'terrier', 'mutt',
#  'schnauzer', 'schnauzer', 'terrier', 'fido', 'fido', 'mutt', 'schnauzer',
#  'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer',
#  'terrier', 'mutt', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'mutt', 'terrier', 'mutt', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'terrier', 'terrier', 'schnauzer', 'schnauzer', 'mutt',
#  'schnauzer', 'schnauzer', 'pitbull', 'terrier', 'schnauzer', 'mutt', 'fido',
#  'schnauzer', 'schnauzer', 'spot', 'schnauzer', 'terrier', 'terrier',
#  'schnauzer', 'schnauzer', 'fido', 'terrier', 'pitbull', 'dachshund',
#  'schnauzer', 'terrier', 'terrier', 'schnauzer', 'terrier', 'shih tzu',
#  'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer', 'schnauzer',
#  'terrier', 'terrier', 'schnauzer', 'terrier', 'schnauzer', 'terrier',
#  'terrier', 'terrier', 'terrier', 'schnauzer', 'terrier', 'schnauzer',
#  'terrier', 'terrier', 'schnauzer', 'terrier', 'terrier', 'yorkie', 'schnauzer',
#  'schnauzer', 'schnauzer', 'terrier', 'terrier', 'terrier', 'yorkie', 'terrier',
#  'terrier', 'terrier', 'schnauzer', 'terrier', 'terrier', 'schnauzer',
#  'terrier', 'schnauzer', 'schnauzer', 'terrier', 'terrier', 'terrier',
#  'terrier', 'terrier', 'schnauzer', 'yorkie', 'schnauzer', 'schnauzer',
#  'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer', 'schnauzer',
#  'schnauzer', 'terrier', 'schnauzer', 'terrier', 'terrier', 'yorkie', 'terrier',
#  'schnauzer', 'terrier', 'schnauzer', 'terrier', 'schnauzer', 'fido',
#  'schnauzer', 'terrier', 'terrier', 'yorkie', 'mutt', 'schnauzer', 'terrier',
#  'schnauzer', 'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'terrier', 'schnauzer', 'terrier', 'terrier', 'terrier', 'schnauzer',
#  'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer', 'fido', 'yorkie',
#  'schnauzer', 'schnauzer', 'terrier', 'terrier', 'terrier', 'terrier',
#  'terrier', 'fido', 'terrier', 'terrier', 'terrier', 'schnauzer', 'terrier',
#  'terrier', 'terrier', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer',
#  'terrier', 'schnauzer', 'terrier', 'terrier', 'terrier', 'schnauzer',
#  'terrier', 'schnauzer', 'terrier', 'terrier', 'schnauzer', 'terrier', 'pug',
#  'terrier', 'jack russell terrier', 'terrier', 'schnauzer', 'schnauzer',
#  'schnauzer', 'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer',
#  'terrier', 'terrier', 'schnauzer', 'schnauzer', 'terrier', 'schnauzer',
#  'terrier', 'terrier', 'yorkie', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'terrier', 'terrier', 'schnauzer', 'terrier',
#  'terrier', 'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer', 'terrier',
#  'schnauzer', 'terrier', 'terrier', 'terrier', 'terrier', 'terrier', 'terrier',
#  'terrier', 'terrier', 'yorkie', 'fido', 'terrier', 'schnauzer', 'terrier',
#  'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'terrier', 'terrier', 'schnauzer', 'schnauzer', 'yorkie', 'yorkie', 'yorkie',
#  'yorkie', 'yorkie', 'terrier', 'yorkie', 'schnauzer', 'schnauzer', 'yorkie',
#  'yorkie', 'yorkie', 'yorkie', 'yorkie', 'yorkie', 'terrier', 'terrier',
#  'yorkie', 'yorkie', 'yorkie', 'yorkie', 'yorkie', 'terrier', 'yorkie',
#  'yorkie', 'terrier', 'shih tzu', 'terrier', 'terrier', 'yorkie', 'schnauzer',
#  'yorkie', 'yorkie', 'terrier', 'yorkie', 'yorkie', 'yorkie', 'terrier',
#  'yorkie', 'shih tzu', 'yorkie', 'yorkie', 'yorkie', 'yorkie', 'terrier',
#  'yorkie', 'terrier', 'yorkie', 'yorkie', 'yorkie', 'yorkie', 'yorkie',
#  'yorkie', 'schnauzer', 'yorkie', 'yorkie', 'yorkie', 'terrier', 'yorkie',
#  'shih tzu', 'terrier', 'yorkie', 'yorkie', 'yorkie', 'yorkie', 'yorkie',
#  'yorkie', 'terrier', 'yorkie', 'terrier', 'yorkie', 'terrier', 'schnauzer',
#  'yorkie', 'terrier', 'yorkie', 'yorkie', 'schnauzer', 'schnauzer', 'yorkie',
#  'yorkie', 'yorkie', 'shih tzu', 'yorkie', 'terrier', 'yorkie', 'yorkie',
#  'yorkie', 'yorkie', 'yorkie', 'yorkie', 'terrier', 'yorkie', 'yorkie',
#  'terrier', 'yorkie', 'yorkie', 'shih tzu', 'yorkie', 'terrier', 'terrier',
#  'terrier', 'terrier', 'terrier', 'schnauzer', 'terrier', 'terrier', 'terrier',
#  'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer', 'beagle', 'terrier',
#  'schnauzer', 'terrier', 'terrier', 'terrier', 'terrier', 'schnauzer', 'beagle',
#  'terrier', 'terrier', 'terrier', 'schnauzer', 'terrier', 'schnauzer',
#  'terrier', 'terrier', 'schnauzer', 'schnauzer', 'terrier', 'terrier',
#  'terrier', 'terrier', 'schnauzer', 'terrier', 'terrier', 'terrier', 'terrier',
#  'jack russell terrier', 'schnauzer', 'schnauzer', 'terrier', 'terrier',
#  'terrier', 'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'terrier', 'terrier', 'terrier', 'schnauzer',
#  'terrier', 'terrier', 'poodle', 'terrier', 'terrier', 'poodle', 'schnauzer',
#  'terrier', 'terrier', 'terrier', 'beagle', 'beagle', 'terrier', 'beagle',
#  'terrier', 'terrier', 'poodle', 'terrier', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'poodle', 'terrier', 'schnauzer', 'beagle', 'terrier', 'terrier',
#  'terrier', 'terrier', 'terrier', 'schnauzer', 'terrier', 'schnauzer',
#  'terrier', 'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'beagle',
#  'terrier', 'terrier', 'terrier', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'collie', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'terrier', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'schnauzer', 'poodle', 'schnauzer', 'terrier',
#  'poodle', 'schnauzer', 'schnauzer', 'terrier', 'terrier', 'schnauzer',
#  'poodle', 'schnauzer', 'poodle', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'terrier', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'fido', 'schnauzer', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'terrier', 'fido', 'fido', 'mutt', 'schnauzer', 'terrier', 'terrier',
#  'schnauzer', 'terrier', 'poodle', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'terrier', 'schnauzer', 'terrier', 'schnauzer',
#  'schnauzer', 'schnauzer', 'poodle', 'poodle', 'shih tzu', 'schnauzer',
#  'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer', 'poodle',
#  'terrier', 'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'poodle', 'schnauzer', 'schnauzer',
#  'schnauzer', 'poodle', 'terrier', 'schnauzer', 'schnauzer', 'schnauzer',
#  'poodle', 'schnauzer', 'schnauzer', 'poodle', 'cocker spaniel', 'schnauzer',
#  'terrier', 'poodle', 'schnauzer', 'schnauzer', 'terrier', 'terrier',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'poodle', 'schnauzer',
#  'schnauzer', 'terrier', 'poodle', 'schnauzer', 'schnauzer', 'poodle',
#  'terrier', 'schnauzer', 'schnauzer', 'poodle', 'poodle', 'schnauzer', 'poodle',
#  'terrier', 'schnauzer', 'poodle', 'poodle', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'poodle', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer', 'schnauzer',
#  'terrier', 'poodle', 'poodle', 'schnauzer', 'jack russell terrier',
#  'schnauzer', 'terrier', 'poodle', 'cocker spaniel', 'schnauzer', 'shih tzu',
#  'schnauzer', 'sheepdog', 'schnauzer', 'schnauzer', 'schnauzer', 'terrier',
#  'schnauzer', 'schnauzer', 'terrier', 'terrier', 'schnauzer', 'schnauzer',
#  'schnauzer', 'schnauzer', 'rottweiler', 'schnauzer', 'schnauzer', 'schnauzer',
#  'schnauzer', 'terrier', 'terrier', 'terrier', 'schnauzer', 'schnauzer',
# ...
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon',
#  'brabancon_griffon', 'brabancon_griffon', 'brabancon_griffon', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke', 'pembroke',
#  'pembroke', 'pembroke', 'pembroke', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan', 'cardigan',
#  'cardigan', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle', 'toy_poodle',
#  'toy_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'miniature_poodle', 'miniature_poodle', 'miniature_poodle',
#  'miniature_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'standard_poodle', 'standard_poodle', 'standard_poodle',
#  'standard_poodle', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'mexican_hairless', 'mexican_hairless', 'mexican_hairless',
#  'mexican_hairless', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo',
#  'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dingo', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole', 'dhole',
#  'dhole', 'dhole', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog', 'african_hunting_dog',
#  'african_hunting_dog', 'african_hunting_dog']

# %%
pprint(reduce(lambda x, y: x+y, all_ans), compact=True)
pprint([vocab.mapping_idx_names[x] for x in all_voc], compact=True)
# Out:
# ['chihuahua', 'chihuahua', 'chihuahua', 'terrier', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'pomeranian',
#  'chihuahua', 'chihuahua', 'terrier', 'pomeranian', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'terrier', 'chihuahua', 'chihuahua',
#  'chihuahua', 'corgi', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'pitbull', 'chihuahua', 'chihuahua', 'pitbull', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'corgi', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'terrier', 'terrier', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua']
# ['chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua', 'chihuahua',
#  'chihuahua', 'chihuahua']

# %%
cluster_row_synsets[pred_kmeans_t[idx_img]]
# Out:
# ['chihuahua', 'papillon', 'heart']

# %%
a = np.array([vocab.mapping_idx_names[x] for x in all_voc])
b = np.array(reduce(lambda x, y: x+y, all_ans))

# %%
c = np.array([vocab.mapping_idx_names[x] for x in all_voc])
d = np.array(reduce(lambda x, y: x+y, all_ans))

# %%
from my_util_package.evaluate import measure_similarity_bert

# %%
measure_similarity_bert(vocab, torch.tensor(all_voc), d, device=args.device)
# Out:
# {'nli-bert-large': 0.6334427093404035, 'all-mpnet-base-v2': 0.4514954079175368}

# %%
measure_similarity_bert(vocab, torch.tensor(all_voc), [vocab.mapping_idx_names[x.item()] for x in cluster_ind_voc], device=args.device)
# Out:
# {'nli-bert-large': 0.824810572716097, 'all-mpnet-base-v2': 0.7411530370429779}

# %%
for c in pred_kmeans_t.unique():

# %%
clip = [37.31, 33.35, 30.09, 30.09, 53.43]
scd = [43.33, 52.18, 40.46, 46.29, 52.63,  48.89, 37.06]
sat = [48.34, 56.20, 45.21, 50.41, 58.94,  52.08, 42.43, ]

# %%
np.mean(sat) - np.mean(scd)
# Out:
# 4.681428571428576

# %%
import sys
sys.path.append('/home/sheng/MUST')
import os
import json
import re
import time
import pickle
from typing import Union, List
from pprint import pprint
from tqdm import tqdm
from copy import deepcopy
import random
import itertools
import numpy as np
from functools import reduce, partial
from itertools import zip_longest
import seaborn as sns
from collections import Counter, defaultdict, OrderedDict
import matplotlib.pyplot as plt
import heapq
from wordnet_utils import *
import scipy.io
from PIL import Image

import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode
from torchvision.datasets import ImageFolder

from ipynb_utils import get_hier_datasets, get_classifier, MCMF_assign_labels
# import clip
import model as clip
from data.datasets import build_transform, get_hier_datasets, Vocab
from data.imagenet_datasets import get_datasets_oszsl


class Config:
    device = 'cuda:2'
    arch = 'ViT-B/16'
    dataset = 'imagenet'
    n_sampled_classes = 100
    input_size = 224
    estimate_k = 252
    
    batch_size = 256
    use_def = False
    clip_checkpoint = None
    # clip_checkpoint = '/home/sheng/MUST-output/make_nonliving26/baseline-04_22_1/checkpoint-current.pth'
    # clip_checkpoint = '/home/sheng/MUST-output/make_nonliving26/chatgpt_init-warmup=2/checkpoint-current.pth'
    # clip_checkpoint = '/home/sheng/MUST-output/make_entity13/sssa/checkpoint-current.pth'
    f_classifier = './cache/wordnet_classifier_in21k_word.pth'
    # f_classifier = './cache/wordnet_classifier_in21k_word_L.pth'
    templates_name = 'templates_small'
    seed = 0
    
args = Config()


def load_templates(args):
    with open(f'../{args.templates_name}.json', 'rb') as f:
        templates = json.load(f)['imagenet']
    return templates

def get_vocab():
    """
    Args:
        vocab: {`names`: list, `ids`: synset ids, `parents`: [{synset ids}]}
    """
    with open('/home/sheng/dataset/wordnet_nouns_with_synset_4.pkl', 'rb') as f:
        vocab = pickle.load(f)
    return vocab

def get_subsample_vocab(sample_synset_id: set):
    vocab = get_vocab()
    index = np.array([ i for i in range(len(vocab['synsets'])) if vocab['synsets'][i] in sample_synset_id ]).astype(np.int32)
    for k in vocab.keys():
        vocab[k] = np.array(vocab[k])[index].tolist()
    return vocab

def read_imagenet21k_classes():
    with open('/home/sheng/dataset/imagenet21k/imagenet21k_wordnet_ids.txt', 'r') as f:
        data = f.read()
        data = list(filter(lambda x: len(x), data.split('\n')))
    return data

templates = load_templates(args)
vocab = get_vocab()
nouns = [ wn.synset(s) for s in vocab['synsets'] ]
classnames = vocab['names']
parents = vocab['parents']
defs = vocab['def']


def load_clip(args):
    model, preprocess = clip.load(args.arch)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model, preprocess

def load_clip2(args):
    model = clip.load(args.arch, device=args.device)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model

def load_mixture_clip(args, decay=1.0):
    model1 = clip.load(args.arch)
    if args.clip_checkpoint:
        model1.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model1.to(args.device).eval()
    model2 = clip.load(args.arch)
    model2.to(args.device).eval()
    with torch.no_grad():
        msd = model1.state_dict()
        for k, ema_v in model2.state_dict().items():
            # if needs_module:
            #     k = 'module.' + k
            model_v = msd[k].detach()
            ema_v.copy_(ema_v * decay + (1. - decay) * model_v)
    return model2

def topk_acc(all_pred_voc_topk, all_gt_voc):
    acc = []
    ### topK accuracy
    for i in range(all_pred_voc_topk.size(1)):
        vec = torch.zeros(all_pred_voc_topk.size(0)).bool()
        for j in range(i+1):
            vec |= (all_pred_voc_topk[:, j]==all_gt_voc)
        print(f'k={i} acc={vec.float().mean()}')
        acc.append(vec.float().mean().item())
    return acc

def semantic_acc(y_pred, y_true, metrics={}):
    """ compute soft semantic acc for @y_pred and @y_true """
    assert len(metrics)>0
    assert y_pred.size(0)==y_true.size(0)
    scores = {m:[] for m in metrics.keys()}
    with tqdm(total=y_pred.size(0)) as pbar:
        for i in range(y_pred.size(0)):
            syn_pred = mapping_vocidx_to_synsets(y_pred[i].item(), vocab)
            syn_true = mapping_vocidx_to_synsets(y_true[i].item(), vocab)
            pairs = list(itertools.product(range(len(syn_pred)), range(len(syn_true))))
            for m_name, m in metrics.items():
                scores[m_name].append( max([ m(syn_pred[p[0]], syn_true[p[1]]) for p in pairs ]) )
            pbar.update(1)
    for m_name in metrics.keys():
        scores[m_name] = np.array(scores[m_name]).mean()
    return scores
    
""" from MUST """
from clip.simple_tokenizer import SimpleTokenizer as _Tokenizer
_tokenizer = _Tokenizer()

def tokenize(texts: Union[str, List[str]], context_length: int = 77, truncate: bool = False) -> torch.LongTensor:
    if isinstance(texts, str):
        texts = [texts]

    sot_token = _tokenizer.encoder["<|startoftext|>"]
    eot_token = _tokenizer.encoder["<|endoftext|>"]
    all_tokens = [[sot_token] + _tokenizer.encode(text) + [eot_token] for text in texts]
    result = torch.zeros(len(all_tokens), context_length, dtype=torch.long)

    for i, tokens in enumerate(all_tokens):
        if len(tokens) > context_length:
            if truncate:
                tokens = tokens[:context_length]
                tokens[-1] = eot_token
            else:
                raise RuntimeError(f"Input {texts[i]} is too long for context length {context_length}")
        result[i, :len(tokens)] = torch.tensor(tokens)

    return result


def agg_by_pred_cluster(args, pred_kmeans, all_topk_voc, voc_size):
    """
    Args:
        pred_kmeans: np.array([N])
        all_topk_voc: np.array([N x K])
        voc_size: int
    Returns:
        all_clu_pred: tensor([C x V])
    """
    print('agg_by_pred_cluster')
    all_clu_pred = []
    n_count = []
    for i in np.unique(pred_kmeans):
        selected = (pred_kmeans==i)
        n_count.append( selected.sum().item() )
        counter_voc_ind, counter_val = np.unique((all_topk_voc[selected, :]).ravel(), return_counts=True)
        # counter_val = counter_val/(n_count+1e-20) # L1 norm
        clu_pred = torch.zeros(args.num_voc) # cluster-wise prob
        clu_pred[torch.from_numpy(counter_voc_ind).long()] = torch.from_numpy(counter_val).float()
        # clu_pred = F.normalize(all_topk_voc[selected].sum(dim=0), dim=-1, p=1)
        all_clu_pred.append(clu_pred)
    all_clu_pred = torch.stack(all_clu_pred, dim=0).cpu()
    n_count = torch.tensor(n_count).cpu()
    
    # all_clu_pred = setdiff_assignment(all_clu_pred)
    
    all_clu_pred = all_clu_pred/(n_count.view(-1, 1) + 1e-20)
    
    print('is mutex assignment::', all_clu_pred.argmax(dim=-1).size(0)==all_clu_pred.argmax(dim=-1).unique().size(0))
    print('assignment collision num::', len(list(filter(lambda x: x>1, Counter(all_clu_pred.argmax(dim=-1).numpy()).values()))))
    return all_clu_pred

def linear_assign(all_clu_pred, pred_kmeans, all_gt_voc, return_results=False):
    print('linear_assign')
    cost_mat = all_clu_pred.cpu().numpy()
    print(f'assignment shape={cost_mat.shape}')
    res_ass = linear_assignment(cost_mat.max() - cost_mat)
    label_voc_kmeans = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])
    inst_acc = (label_voc_kmeans==all_gt_voc).float().mean().item()
    print('instance label acc::', inst_acc)
    if return_results:
        return label_voc_kmeans, res_ass, inst_acc
    return label_voc_kmeans, res_ass

def reassign_by_pred_cluster(label_voc_kmeans, model, classifier, device, 
                             all_prob=None, 
                             instance_selected=None, 
                             classifier_selected=None):
    """
    Args:
        classifier_selected: tensor([C2])
    """
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device)
    if all_prob is None:
        cluster_ind = []
        with tqdm(total=len(loader_f)) as pbar:
            if hasattr(model, 'eval'):
                model.eval()
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                if (instance_selected is not None) and ((~instance_selected[idx_img]).all()):
                    continue
                with amp_autocast():
                    with torch.no_grad():
                        if (instance_selected is not None):
                            logits = model.visual(images[instance_selected[idx_img]])
                        else:
                            logits = model.visual(images)
                            
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        if classifier_selected is not None:
                            similarity = 100 * logits @ classifier[classifier_selected].t()
                            prob = classifier_selected[similarity.softmax(-1)]
                            cluster_ind.append(deepcopy(prob.cpu().argmax(dim=-1)))
                        else:
                            similarity = 100 * logits @ classifier.t()
                            prob = similarity.softmax(-1)
                            cluster_ind.append(deepcopy(prob[:, label_voc_kmeans].cpu().argmax(dim=-1)))
                pbar.update(1)
        cluster_ind = torch.cat(cluster_ind, dim=0)
    else:
        all_prob = all_prob[:, label_voc_kmeans]
        cluster_ind = all_prob.argmax(dim=-1)
        
    if classifier_selected is not None:
        cluster_ind_voc = classifier_selected[cluster_ind]
    else:
        cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc


def reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, device, 
                             preextracted_vfeatures=None):
    """ given vocab label set @label_voc_kmeans, 
    Args:
        label_voc_kmeans: cluster-assigned label on vocab
        ...
        preextracted_vfeatures: np.array([N x D])
    Returns:
        cluster_ind: tensor([N]): re-ordered cluster assignment
        cluster_ind_voc: tensor([N]): cluster assignment indiced by vocab
    """
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device).unique()
    cluster_ind = []
    with tqdm(total=len(loader_f)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        if preextracted_vfeatures is not None:
            N = len(loader_f.dataset)
            batch_size = 10000
            indices = np.array_split(np.arange(N), N//batch_size)
            with torch.no_grad():
                for group in indices:
                    logits = torch.from_numpy(preextracted_vfeatures[group]).float()
                    logits = logits/logits.norm(dim=-1, keepdim=True)
                    similarity = 100 * logits@classifier.t().cpu()
                    prob = similarity.softmax(-1)
                    cluster_ind.append(deepcopy(prob[:, label_voc_kmeans.cpu()].argmax(dim=-1)))
        else:
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                with amp_autocast():
                    with torch.no_grad():
                        if preextracted_vfeatures is not None:
                            logits = torch.from_numpy(preextracted_vfeatures[idx_img.cpu().numpy()]).float().to(device)
                        else:
                            logits = model.ema.extract_vfeatures(images)
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        similarity = 100 * logits @ classifier.t()
                        prob = similarity.softmax(-1)
                        cluster_ind.append(deepcopy(prob[:, label_voc_kmeans].cpu().argmax(dim=-1)))
                pbar.update(1)
    cluster_ind = torch.cat(cluster_ind, dim=0)
    cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def computation_reassign_by_pred_cluster(row, idx, args, model, classifier, candidate_classifier_ind):
    """
    candidate_classifier_ind = label_voc_kmeans.unique().to(args.device)
    """
    images, label_voc, label_clu, idx_img = row[:4]
    images = images.to(args.device)
    with amp_autocast():
        vfeatures = model.visual(images).float()
        # vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
    vfeatures = F.normalize(vfeatures, dim=-1)
    batch_sim = 100*vfeatures@classifier[candidate_classifier_ind].t()
    cluster_ind = batch_sim.argmax(dim=-1)
    cluster_ind_voc = candidate_classifier_ind[cluster_ind].cpu()
    return cluster_ind_voc

def aggregation_reassign_by_pred_cluster(r, candidate_classifier_ind):
    cluster_ind_voc = torch.cat(r, dim=0)
    mapping_ind = dict(zip(cluster_ind_voc.unique().numpy(), torch.arange(cluster_ind_voc.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind_voc])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def extract_vfeatures(model, data_loader, device):
    amp_autocast = torch.cuda.amp.autocast
    all_vfeatures = []
    with tqdm(total=len(data_loader)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        for idx_batch, batch in enumerate(data_loader):
            images, label_voc, label_clu, idx_img = batch[:4]
            images = images.to(device)
            with amp_autocast():
                vfeatures = model.visual(images).float()
            vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
            all_vfeatures.append(vfeatures.cpu().numpy())
            pbar.update(1)
    all_vfeatures = np.concatenate(all_vfeatures)
    return all_vfeatures


@torch.no_grad()
def loop_row_collect_results_nograd(obj_iter, computations={}, aggregations={}):
    """ compute and aggregate results, looping over @obj_iter 
    func_computation(@row, @index_row)
    aggregations(list(@results_computation))
    """
    assert set(list(computations.keys())) == set(list(aggregations.keys()))
    collector = { k:[] for k in computations }
    with tqdm(total=len(obj_iter)) as pbar:
        for i, row in enumerate(obj_iter):
            ### apply computations
            for k, func in computations.items():
                collector[k].append(func(row, i))
            pbar.update(1)
    ### aggregate results
    results = {}
    for k, func_agg in aggregations.items():
        results[k] = func_agg(collector[k])
    return results


import openai
def openai_chatgpt_post(content, parameters={'temperature': 0.7}):
    openai.api_key = "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"
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo-0301",
      messages=[
        {"role": "user", "content": content},
      ],
    **parameters,
    )
    result = completion['choices'][0]['message']['content']
    return result


@torch.no_grad()
def build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=None):
    """ build classifier for chatgpt
    Args:
        all_row_chatgpt_names: [[names]]
    """
    if all_row_key_name is None: ### single name
        with open('../templates_small.json', 'rb') as f: ### template 1
            templates = json.load(f)['imagenet']
    else:
        with open('../templates_small.json', 'rb') as f: ### template 2
            templates = json.load(f)[f'{args.dataset}-parent-3']
            
    len_t = len(templates)
    row_classifier = []
    with tqdm(total=len(all_row_chatgpt_names)) as pbar:
        for idx, row in enumerate(all_row_chatgpt_names):
            len_row = len(row)
            if all_row_key_name is None:
                row_t = [ t.format(name) for name in row for t in templates ]
            else:
                row_t = [ t.format(pname, name) for pname, name in zip(all_row_key_name[idx], row) for t in templates ]
            row_t = tokenize(row_t).to(args.device)
            features = model.encode_text(row_t)
            features = features.view(len_row, len_t, -1).float()
            features = features/features.norm(dim=-1, keepdim=True)
            features = features.mean(dim=1)
            features = features/features.norm(dim=-1, keepdim=True)
            row_classifier.append(features.cpu())
            
            pbar.update(1)
    return row_classifier
    



from sklearn.cluster import KMeans
from my_util_package_oszsl.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment

subset = ['train', 'val'][0]
mean = (0.48145466, 0.4578275, 0.40821073)
std = (0.26862954, 0.26130258, 0.27577711)

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(args.input_size, interpolation=InterpolationMode.BICUBIC),
    transforms.CenterCrop(args.input_size),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=torch.tensor(mean),
        std=torch.tensor(std))
])

""" prepare dataset and load CLIP """
classes = read_imagenet21k_classes() + os.listdir('/home/sheng/dataset/imagenet-img/')
classes = [wn.synset_from_pos_and_offset('n', int(x[1:])).name() for x in classes]
classes = set(classes)
vocab = get_subsample_vocab(classes)
vocab = Vocab(vocab=vocab)

model = load_clip2(args)


for dataset_name in ['sdogs']:
    print('='*30)
    print(f'dataset={dataset_name}')
    args.dataset = dataset_name
    # dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
    if subset == 'train':
        dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=0)
    elif subset == 'val':
        dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=0)
    args.nb_classes = dataset_f.num_classes
    loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=4, batch_size=args.batch_size, shuffle=False)

    loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=4, batch_size=args.batch_size, shuffle=False)
    classifier = get_classifier(args)
    classifier = classifier/classifier.norm(dim=-1, keepdim=True)
    args.num_voc = classifier.size(0)
    amp_autocast = torch.cuda.amp.autocast
    ### collect variables
    prob_k = 1
    all_topk_voc = []
    all_gt_voc = []
    all_label_clu = []
    all_vfeatures = []
    with tqdm(total=len(loader_f)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        for idx_batch, batch in enumerate(loader_f):
            images, label_voc, label_clu, idx_img = batch[:4]
            images = images.to(args.device)
            with amp_autocast():
                with torch.no_grad():
                    logits = model.visual.extract_features(images)
                    # logits = model.extract_vfeatures(images)
                    logits = logits/logits.norm(dim=-1, keepdim=True)
                    similarity = 100 * logits @ classifier.t()
                    prob = similarity.softmax(-1)
                    prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                    all_topk_voc.append(deepcopy(prob_topk_ind.cpu().numpy()))
                    all_gt_voc.append(deepcopy(label_voc))
                    all_label_clu.append(deepcopy(label_clu))
                    all_vfeatures.append(deepcopy(logits.cpu().numpy()))
            pbar.update(1)

    all_topk_voc = np.concatenate(all_topk_voc)
    all_gt_voc = torch.cat(all_gt_voc, dim=0)
    all_label_clu = torch.cat(all_label_clu, dim=0)
    all_vfeatures = np.concatenate(all_vfeatures)


    # pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset}-train-clip.npy'))
    pred_kmeans = torch.from_numpy(np.load(f'./cache/cluster/kmeans-{args.dataset}.npy'))
    # pred_kmeans = torch.from_numpy(np.load('/home/sheng/MUST-output/make_nonliving26/baseline-04_22_1/pred_kmeans_t.npy'))
    # pred_kmeans = torch.from_numpy(np.load('/home/sheng/MUST-output/make_nonliving26/chatgpt_init-warmup=2/pred_kmeans_t.npy'))
    pred_kmeans_t = pred_kmeans
    history_set_pred = []
    for t in range(3):
        record_pred_kmeans_t = pred_kmeans_t
        all_clu_pred = agg_by_pred_cluster(args, pred_kmeans_t.numpy(), all_topk_voc, voc_size=args.num_voc)
        label_voc_kmeans, res_ass = linear_assign(all_clu_pred, pred_kmeans_t, all_gt_voc)
        pred_kmeans_t, cluster_ind_voc = reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)
        set_pred = set(res_ass[1].tolist())
        set_gt = set(all_gt_voc.unique().numpy().tolist())
        print('missing label::', len(set_gt - set_pred))
        print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=pred_kmeans_t.numpy()))
        history_set_pred.append(set_pred)

        set_pred = set(res_ass[1].tolist())
        set_gt = set(all_gt_voc.unique().numpy().tolist())
        n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
        n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
        iou_voc = n_inter/n_union
        n_missing_label = all_gt_voc.unique().shape[0] - n_inter
        print('missing label::', n_missing_label)
        print('iou voc::', iou_voc)


    all_clu_gt_voc = []
    for c in record_pred_kmeans_t.unique():
        select = (record_pred_kmeans_t==c)
        all_clu_gt_voc.append(all_gt_voc[select].mode().values)
    all_clu_gt_voc = torch.tensor(all_clu_gt_voc)
    k_1 = 3
    topk_all_clu_pred = all_clu_pred.topk(k=k_1).indices
    cluster_is_correct = torch.zeros(topk_all_clu_pred.size(0)).bool()
    for i in range(k_1):
        cluster_is_correct |= (topk_all_clu_pred[:, i]==all_clu_gt_voc)
    print(f'recall@{k_1} = {cluster_is_correct.float().mean()}')
    """ gather concepts """
    to_name = lambda x: [ s.name() + ': ' + s.definition() for s in x ]
    cluster_row_synsets = []
    for row in topk_all_clu_pred:
        row_synsets = [to_name(mapping_vocidx_to_synsets(voc_idx.item(), vocab)) for voc_idx in row]
        cluster_row_synsets.append(row_synsets)

    """ generate concept requests """
    concept_request = []
    for row in cluster_row_synsets:
        ccpts = reduce(lambda x, y: x+y, row)
        ccpts = list(map(lambda x: "'"+x+".'", ccpts))
        ccpts = ', '.join(ccpts)
        concept_request.append(ccpts)

    """ generate concept templates """
    template_1 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all alternative concept names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
    with open('/home/sheng/OSZSL/templates_chatgpt.json', 'r') as f:
        template_chatgpt = json.load(f)
    template_2 = lambda concept_list: template_chatgpt['pictionary-long'].format(concept_list)
    template_3 = lambda concept_list: template_chatgpt['pictionary-short'].format(concept_list)
    template_4 = lambda concept_list: template_chatgpt['direct'].format(concept_list)
    template_5 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all synonym concept names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
    template_6 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all category names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
    template_7 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all parent-type category names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
    template_8 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all possible descriptive phrases of image captions for each visual concept. List in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
    template_9 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all possible visiual descriptive phrases for each visual concept without duplication. List in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
    # template_10 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all possible visiual descriptive phrases for each visual concept without duplication. List in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
    template_13 = lambda concept_list: "Given visual concepts: "+ concept_list + "Please list all possible adjective phrases of visual descriptions for each visual concept without duplication. Please list in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
    template_9_1 = lambda concept_list: "Given visual concepts: "+ concept_list + "Please list all possible visual descriptive phrases for each visual concept without duplication. Please list in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."


    template_in_use = template_9_1
    concept_templates = []
    for row in concept_request:
        concept_templates.append(template_in_use(row))

    n_repeat = 3


    request = lambda c: f"what are useful visual features for distinguishing a {c} in a photo? please list descriptive phrases in bullet points."
    request = lambda c: f"Generate a bullet points separated list of 10 types of the following:\n\n>{c}:"

    try:
        with open('./cache/openai/vcdch-total.pkl', 'rb') as f:
            all_cate_descriptions = pickle.load(f)
    except Exception as e:
        print(e)
        all_cate_descriptions = {}

    with tqdm(total=len(cluster_row_synsets)*n_repeat) as pbar:
        for row in cluster_row_synsets:
            for cate in row:
                cate_name = cate[0].split('.')[0]
                if cate_name in all_cate_descriptions.keys():
                    continue
                else:
                    all_cate_descriptions.setdefault(cate_name, [])
                    for i in range(n_repeat):
                        while 1:
                            try:
                                response = openai_chatgpt_post(request(cate_name))
                            except Exception as e:
                                print(e)
                            break
                        all_cate_descriptions[cate_name].append(response)

                        pbar.update(1)

    with open(f'./cache/openai/vcdch-total.pkl', 'wb') as f:
        pickle.dump(all_cate_descriptions, f)
        
    all_cate_descriptions_new = {}
    for k, v in all_cate_descriptions.items():
        all_cate_descriptions_new[k] = \
            list(
                map(lambda x: 
                    [re.sub(r'^\d+\.\s', '', phrase) for phrase in x.split('\n') if phrase.strip()],
                    v)
            )

    for k, v in all_cate_descriptions_new.items():
        all_cate_descriptions_new[k] = reduce(lambda x, y: x+y, all_cate_descriptions_new[k])

    with open(f'./cache/openai/vcdch-clean-total.pkl', 'wb') as f:
        pickle.dump(all_cate_descriptions_new, f)


    all_row_chatgpt_names = []
    all_row_key_name = []
    all_row_weight = []
    all_row_i_syn = []
    for row in cluster_row_synsets:
        row_chatgpt_names = []
        row_key_name = []
        row_i_syn = []
        for i, cate in enumerate(row):
            cate_name = cate[0].split('.')[0]
            desc = all_cate_descriptions_new[cate_name]
            if len(desc)==0:
                print(f'desc=0 for {cate_name}')
                desc = [cate[0].split(':')[-1]]
            row_key_name.extend([cate_name]*len(desc))
            row_chatgpt_names.extend(desc)
            row_i_syn.extend([i]*len(desc))
        all_row_chatgpt_names.append(row_chatgpt_names)
        all_row_key_name.append(row_key_name)
        all_row_weight.append([1]*len(row_chatgpt_names))
        all_row_i_syn.append(row_i_syn)

    all_row_classifier = build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=all_row_key_name)

# %%
all_row_chatgpt_names = []
all_row_key_name = []
all_row_weight = []
all_row_i_syn = []
for row in cluster_row_synsets:
    row_chatgpt_names = []
    row_key_name = []
    row_i_syn = []
    for i, cate in enumerate(row):
        cate_name = cate[0].split('.')[0]
        desc = all_cate_descriptions_new[cate_name]
        if len(desc)==0:
            print(f'desc=0 for {cate_name}')
            desc = [cate[0].split(':')[-1]]
        row_key_name.extend([cate_name]*len(desc))
        row_chatgpt_names.extend(desc)
        row_i_syn.extend([i]*len(desc))
    all_row_chatgpt_names.append(row_chatgpt_names)
    all_row_key_name.append(row_key_name)
    all_row_weight.append([1]*len(row_chatgpt_names))
    all_row_i_syn.append(row_i_syn)

all_row_classifier = build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=all_row_key_name)
# Out:
# 100%|██████████| 120/120 [01:54<00:00,  1.05it/s]

# %%
# vfeatures = np.load(f'./cache/features/vfeatures-{args.dataset}.npy')
"""
Args:
    all_clu_pred: shape
    all_row_classifier
    record_pred_kmeans_t
    all_row_weight
    all_row_i_syn
    vfeatures
"""
vfeatures = all_vfeatures
all_clu_pred_chatgpt = torch.zeros_like(all_clu_pred)
is_correct = []
all_name_gt = []
k_2 = 3
enable_weight = True
instance_pred_voc = torch.zeros_like(record_pred_kmeans_t)
for c in range(len(all_row_classifier)):
    select = (record_pred_kmeans_t==c)
    row_classifier = all_row_classifier[c]
    sim = torch.from_numpy(vfeatures[select, ...]).to(args.device)@row_classifier.to(args.device).t()
    sim_topk = sim.topk(k=k_2)
    ind, val = sim_topk.indices.flatten().cpu().unique(return_counts=True)
    count_names = torch.zeros(row_classifier.size(0)).long()
    count_names[ind] = val ### count of each name
    count_smask = []
    smask = np.array(all_row_i_syn[c]) ### partition mask
    for s in np.unique(smask):
        if enable_weight:
            row_weight = torch.tensor(all_row_weight[c]).float()
            row_weight[smask==s] = row_weight[smask==s] / row_weight[(smask==s)].sum()
            row_weight /= row_weight.sum()
            count_smask.append((row_weight[smask==s]*count_names[smask==s]).sum().item())
        else:
            count_smask.append(count_names[smask==s].sum())
    # name_pred = all_row_mapping_idx_synset_name[c][np.argmax(count_smask)]
    name_gt = all_gt_voc[select].mode().values
    name_gt = vocab.mapping_idx_names[name_gt.item()]
    all_name_gt.append(name_gt)
    # is_correct.append(name_pred==name_gt)
    # instance_pred_voc[select] = vocab.mapping_names_idx[name_pred]

    val_count = torch.tensor(count_smask)
    ind_count = topk_all_clu_pred[c]
    # ind_count = torch.tensor([vocab.mapping_names_idx[xx] for xx in ind_count])
    all_clu_pred_chatgpt[c, ind_count] = val_count


classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
a, res_ass = linear_assign(all_clu_pred_chatgpt, record_pred_kmeans_t, all_gt_voc)
r_pred_kmeans_t, r_cluster_ind_voc = reassign_by_pred_cluster(a, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)
set_pred = set(res_ass[1].tolist())
set_gt = set(all_gt_voc.unique().numpy().tolist())
n_inter = all_gt_voc[r_cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([r_cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
print('iou voc::', iou_voc)
print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=r_pred_kmeans_t.numpy()))
n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
# Out:
# linear_assign
# assignment shape=(120, 20071)
# instance label acc:: 0.5132499933242798
# reassign_by_pred_cluster
#   0%|          | 0/47 [00:00<?, ?it/s]
# missing label:: 27
# iou voc:: 0.6326530612244898
# cluster acc 0.5548333333333333
# missing label:: 25
