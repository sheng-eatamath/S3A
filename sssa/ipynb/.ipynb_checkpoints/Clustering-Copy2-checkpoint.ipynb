# %%
import sys
sys.path.append('/home/sheng/sssa/')
sys.path.append('/home/sheng/sssa/')
# sys.path.append('/home/sheng/sssa/CLIP/')

import os
import json
import re
import time
import pickle
from typing import Union, List
from pprint import pprint
from tqdm import tqdm
from copy import deepcopy
import random
import itertools
import numpy as np
from functools import reduce, partial
from itertools import zip_longest
import seaborn as sns
from collections import Counter, defaultdict, OrderedDict
import matplotlib.pyplot as plt
import heapq
from wordnet_utils import *

import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode

from ipynb_utils import get_hier_datasets, get_classifier, MCMF_assign_labels
# import clip
import model as clip
from data.datasets import build_transform, get_hier_datasets, Vocab
# from data.imagenet_datasets import get_datasets_oszsl
from data.imagenet_datasets import get_datasets_oszsl
# Out:
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
class Config:
    device = 'cuda:3'
    arch = 'ViT-B/16'
    dataset = 'sun'
    n_sampled_classes = 100
    input_size = 224
    seed = 0
    
    batch_size = 512
    use_def = False
    clip_checkpoint = None
    f_classifier = './cache/wordnet_classifier_in21k_word.pth'
    templates_name = 'templates_small'
    
args = Config()

# %%
def load_templates(args):
    with open(f'../{args.templates_name}.json', 'rb') as f:
        templates = json.load(f)['imagenet']
    return templates

def get_vocab():
    """
    Args:
        vocab: {`names`: list, `ids`: synset ids, `parents`: [{synset ids}]}
    """
    with open('/home/sheng/dataset/wordnet_nouns_with_synset_4.pkl', 'rb') as f:
        vocab = pickle.load(f)
    return vocab

def get_subsample_vocab(sample_synset_id: set):
    vocab = get_vocab()
    index = np.array([ i for i in range(len(vocab['synsets'])) if vocab['synsets'][i] in sample_synset_id ]).astype(np.int32)
    for k in vocab.keys():
        vocab[k] = np.array(vocab[k])[index].tolist()
    return vocab

def read_imagenet21k_classes():
    with open('/home/sheng/dataset/imagenet21k/imagenet21k_wordnet_ids.txt', 'r') as f:
        data = f.read()
        data = list(filter(lambda x: len(x), data.split('\n')))
    return data

def read_lvis_imagenet21k_classes():
    with open('/home/sheng/dataset/imagenet21k/lvis_imagenet21k_wordnet_ids.txt', 'r') as f:
        data = f.read()
        data = list(filter(lambda x: len(x), data.split('\n')))
        # data = list(map(lambda x: x.split('.')[0], data))
    return data

def load_clip2(args):
    model = clip.load(args.arch, device=args.device)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model

templates = load_templates(args)
vocab = get_vocab()
nouns = [ wn.synset(s) for s in vocab['synsets'] ]
classnames = vocab['names']
parents = vocab['parents']
defs = vocab['def']

# %%
""" prepare dataset and load CLIP """
classes = read_imagenet21k_classes() + os.listdir('/home/sheng/dataset/imagenet-img/')
classes = [wn.synset_from_pos_and_offset('n', int(x[1:])).name() for x in classes]
classes = set(classes)
if args.dataset == 'lvis':
    classes = read_lvis_imagenet21k_classes()
    classes = set(classes)
vocab = get_subsample_vocab(classes)
vocab = Vocab(vocab=vocab)

transform_val = build_transform(is_train=False, args=args, train_config=None)
mean = (0.48145466, 0.4578275, 0.40821073)
std = (0.26862954, 0.26130258, 0.27577711)

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(args.input_size, interpolation=InterpolationMode.BICUBIC),
    transforms.CenterCrop(args.input_size),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=torch.tensor(mean),
        std=torch.tensor(std))
])
dataset = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=0)
loader_val = torch.utils.data.DataLoader(dataset, num_workers=4, batch_size=256, shuffle=False)
print('dataset size', len(dataset))

# model, preprocess = load_clip(args)
model = load_clip2(args)
# Out:
# dataset size 87003
# missing keys:
# ['visual.projection_head.0.weight', 'visual.projection_head.0.bias', 'visual.projection_head.2.weight', 'visual.projection_head.2.bias']
# Model parameters: 150,408,193
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %%
amp_autocast = torch.cuda.amp.autocast

all_vfeatures = []
all_clu_label = []
with tqdm(total=len(loader_val)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_val):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual.extract_features(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                all_vfeatures.append(deepcopy(logits.cpu().numpy()))
                all_clu_label.append(deepcopy(label_clu.numpy()))
        pbar.update(1)

all_vfeatures = np.concatenate(all_vfeatures)
all_clu_label = np.concatenate(all_clu_label)
# Out:
# 100%|██████████| 340/340 [10:23<00:00,  1.83s/it]

# %%
len(all_vfeatures)
# Out:
# 105538

# %%
np.save(f'./cache/features/vfeatures-{args.dataset}.npy', all_vfeatures)

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans
from my_util_package_oszsl.evaluation import cluster_acc
K = dataset.dataset.num_classes if hasattr(dataset, 'dataset') else dataset.num_classes
print(f'K={K}')
print(np.unique(all_clu_label).shape)
# kmeans = MiniBatchKMeans(n_clusters=10*K, batch_size=2048, random_state=0, n_init=10, max_iter=500, verbose=2).fit(all_vfeatures)
# preds = kmeans.labels_
# Out:
# K=397
# (397,)

# %%
kmeans = KMeans(n_clusters=K, random_state=0, n_init=17, max_iter=1000, verbose=1).fit(all_vfeatures)
preds = kmeans.labels_
# Out:
# Initialization complete
# Iteration 0, inertia 33443.70703125.
# Iteration 1, inertia 22390.701171875.
# Iteration 2, inertia 21856.548828125.
# Iteration 3, inertia 21645.294921875.
# Iteration 4, inertia 21537.3359375.
# Iteration 5, inertia 21468.740234375.
# Iteration 6, inertia 21427.48828125.
# Iteration 7, inertia 21397.9453125.
# Iteration 8, inertia 21372.9765625.
# Iteration 9, inertia 21351.07421875.
# Iteration 10, inertia 21332.36328125.
# Iteration 11, inertia 21317.666015625.
# Iteration 12, inertia 21308.166015625.
# Iteration 13, inertia 21301.05078125.
# Iteration 14, inertia 21294.919921875.
# Iteration 15, inertia 21290.12109375.
# Iteration 16, inertia 21285.625.
# Iteration 17, inertia 21281.84375.
# Iteration 18, inertia 21278.6796875.
# Iteration 19, inertia 21275.853515625.
# Iteration 20, inertia 21272.658203125.
# Iteration 21, inertia 21269.0.
# Iteration 22, inertia 21264.875.
# Iteration 23, inertia 21260.291015625.
# Iteration 24, inertia 21257.259765625.
# Iteration 25, inertia 21255.119140625.
# Iteration 26, inertia 21253.61328125.
# Iteration 27, inertia 21252.490234375.
# Iteration 28, inertia 21251.65625.
# Iteration 29, inertia 21250.86328125.
# Iteration 30, inertia 21250.041015625.
# Iteration 31, inertia 21249.416015625.
# Iteration 32, inertia 21248.810546875.
# Iteration 33, inertia 21248.310546875.
# Iteration 34, inertia 21247.736328125.
# Iteration 35, inertia 21247.20703125.
# Iteration 36, inertia 21246.603515625.
# Iteration 37, inertia 21246.03515625.
# Iteration 38, inertia 21245.470703125.
# Iteration 39, inertia 21245.07421875.
# Iteration 40, inertia 21244.73828125.
# Iteration 41, inertia 21244.3828125.
# Iteration 42, inertia 21244.15625.
# Iteration 43, inertia 21243.888671875.
# Iteration 44, inertia 21243.673828125.
# Iteration 45, inertia 21243.43359375.
# Iteration 46, inertia 21243.25.
# Iteration 47, inertia 21243.046875.
# Iteration 48, inertia 21242.88671875.
# Iteration 49, inertia 21242.802734375.
# Iteration 50, inertia 21242.734375.
# Iteration 51, inertia 21242.654296875.
# Iteration 52, inertia 21242.59375.
# Iteration 53, inertia 21242.5390625.
# Iteration 54, inertia 21242.46875.
# Iteration 55, inertia 21242.341796875.
# Iteration 56, inertia 21242.154296875.
# Iteration 57, inertia 21241.916015625.
# Iteration 58, inertia 21241.478515625.
# Iteration 59, inertia 21240.7734375.
# Iteration 60, inertia 21239.9765625.
# Iteration 61, inertia 21239.40625.
# Iteration 62, inertia 21239.046875.
# Iteration 63, inertia 21238.734375.
# Iteration 64, inertia 21238.50390625.
# Iteration 65, inertia 21238.302734375.
# Iteration 66, inertia 21238.13671875.
# Iteration 67, inertia 21237.9453125.
# Iteration 68, inertia 21237.7578125.
# Iteration 69, inertia 21237.6015625.
# Iteration 70, inertia 21237.42578125.
# Iteration 71, inertia 21237.220703125.
# Iteration 72, inertia 21237.037109375.
# Iteration 73, inertia 21236.9140625.
# Iteration 74, inertia 21236.81640625.
# Iteration 75, inertia 21236.7109375.
# Iteration 76, inertia 21236.638671875.
# Iteration 77, inertia 21236.58203125.
# Iteration 78, inertia 21236.53125.
# Iteration 79, inertia 21236.484375.
# Iteration 80, inertia 21236.474609375.
# Iteration 81, inertia 21236.462890625.
# Iteration 82, inertia 21236.439453125.
# Iteration 83, inertia 21236.421875.
# Iteration 84, inertia 21236.400390625.
# Iteration 85, inertia 21236.396484375.
# Iteration 86, inertia 21236.380859375.
# Iteration 87, inertia 21236.365234375.
# Iteration 88, inertia 21236.36328125.
# Iteration 89, inertia 21236.359375.
# Iteration 90, inertia 21236.357421875.
# Converged at iteration 90: strict convergence.
# Initialization complete
# Iteration 0, inertia 33592.3515625.
# Iteration 1, inertia 22302.041015625.
# Iteration 2, inertia 21821.36328125.
# Iteration 3, inertia 21649.482421875.
# Iteration 4, inertia 21556.51953125.
# Iteration 5, inertia 21489.75.
# Iteration 6, inertia 21434.052734375.
# Iteration 7, inertia 21399.005859375.
# Iteration 8, inertia 21375.5625.
# Iteration 9, inertia 21356.23046875.
# Iteration 10, inertia 21338.603515625.
# Iteration 11, inertia 21323.416015625.
# Iteration 12, inertia 21311.392578125.
# Iteration 13, inertia 21304.10546875.
# Iteration 14, inertia 21298.86328125.
# Iteration 15, inertia 21294.97265625.
# Iteration 16, inertia 21291.95703125.
# Iteration 17, inertia 21288.83203125.
# Iteration 18, inertia 21285.96484375.
# Iteration 19, inertia 21283.505859375.
# Iteration 20, inertia 21280.99609375.
# Iteration 21, inertia 21277.357421875.
# Iteration 22, inertia 21274.173828125.
# Iteration 23, inertia 21271.78515625.
# Iteration 24, inertia 21270.2578125.
# Iteration 25, inertia 21268.97265625.
# Iteration 26, inertia 21267.77734375.
# Iteration 27, inertia 21266.654296875.
# Iteration 28, inertia 21265.423828125.
# Iteration 29, inertia 21263.970703125.
# Iteration 30, inertia 21261.896484375.
# Iteration 31, inertia 21259.650390625.
# Iteration 32, inertia 21258.041015625.
# Iteration 33, inertia 21257.01953125.
# Iteration 34, inertia 21256.298828125.
# Iteration 35, inertia 21255.505859375.
# Iteration 36, inertia 21254.609375.
# Iteration 37, inertia 21254.01953125.
# Iteration 38, inertia 21253.3359375.
# Iteration 39, inertia 21252.6953125.
# Iteration 40, inertia 21252.2734375.
# Iteration 41, inertia 21251.931640625.
# Iteration 42, inertia 21251.28515625.
# Iteration 43, inertia 21250.587890625.
# Iteration 44, inertia 21250.021484375.
# Iteration 45, inertia 21249.546875.
# Iteration 46, inertia 21249.205078125.
# Iteration 47, inertia 21248.82421875.
# Iteration 48, inertia 21248.359375.
# Iteration 49, inertia 21247.7578125.
# Iteration 50, inertia 21247.1875.
# Iteration 51, inertia 21246.505859375.
# Iteration 52, inertia 21246.15234375.
# Iteration 53, inertia 21245.939453125.
# Iteration 54, inertia 21245.802734375.
# Iteration 55, inertia 21245.72265625.
# Iteration 56, inertia 21245.662109375.
# Iteration 57, inertia 21245.60546875.
# Iteration 58, inertia 21245.57421875.
# Iteration 59, inertia 21245.544921875.
# Iteration 60, inertia 21245.5234375.
# Iteration 61, inertia 21245.51171875.
# Iteration 62, inertia 21245.5078125.
# Iteration 63, inertia 21245.501953125.
# Converged at iteration 63: strict convergence.
# Initialization complete
# Iteration 0, inertia 33627.77734375.
# Iteration 1, inertia 22315.125.
# Iteration 2, inertia 21827.75.
# Iteration 3, inertia 21648.962890625.
# Iteration 4, inertia 21548.728515625.
# Iteration 5, inertia 21483.8984375.
# Iteration 6, inertia 21434.935546875.
# Iteration 7, inertia 21395.20703125.
# Iteration 8, inertia 21364.486328125.
# Iteration 9, inertia 21341.62890625.
# Iteration 10, inertia 21325.13671875.
# Iteration 11, inertia 21311.287109375.
# Iteration 12, inertia 21300.158203125.
# Iteration 13, inertia 21291.326171875.
# Iteration 14, inertia 21284.7578125.
# Iteration 15, inertia 21278.9765625.
# Iteration 16, inertia 21275.3828125.
# Iteration 17, inertia 21271.287109375.
# Iteration 18, inertia 21267.609375.
# Iteration 19, inertia 21265.099609375.
# Iteration 20, inertia 21263.232421875.
# Iteration 21, inertia 21261.73828125.
# Iteration 22, inertia 21260.546875.
# Iteration 23, inertia 21259.52734375.
# Iteration 24, inertia 21258.6796875.
# Iteration 25, inertia 21257.765625.
# Iteration 26, inertia 21256.82421875.
# Iteration 27, inertia 21255.77734375.
# Iteration 28, inertia 21254.794921875.
# Iteration 29, inertia 21253.685546875.
# Iteration 30, inertia 21252.611328125.
# Iteration 31, inertia 21251.26953125.
# Iteration 32, inertia 21249.349609375.
# Iteration 33, inertia 21247.24609375.
# Iteration 34, inertia 21245.326171875.
# Iteration 35, inertia 21243.9765625.
# Iteration 36, inertia 21243.232421875.
# Iteration 37, inertia 21242.708984375.
# Iteration 38, inertia 21242.150390625.
# Iteration 39, inertia 21241.59765625.
# Iteration 40, inertia 21241.16796875.
# Iteration 41, inertia 21240.865234375.
# Iteration 42, inertia 21240.560546875.
# Iteration 43, inertia 21240.26953125.
# Iteration 44, inertia 21240.03125.
# Iteration 45, inertia 21239.87890625.
# Iteration 46, inertia 21239.78125.
# Iteration 47, inertia 21239.681640625.
# Iteration 48, inertia 21239.5859375.
# Iteration 49, inertia 21239.51953125.
# Iteration 50, inertia 21239.4453125.
# Iteration 51, inertia 21239.40234375.
# Iteration 52, inertia 21239.361328125.
# Iteration 53, inertia 21239.322265625.
# Iteration 54, inertia 21239.275390625.
# Iteration 55, inertia 21239.2109375.
# Iteration 56, inertia 21239.140625.
# Iteration 57, inertia 21239.09375.
# Iteration 58, inertia 21239.02734375.
# Iteration 59, inertia 21238.94921875.
# Iteration 60, inertia 21238.908203125.
# Iteration 61, inertia 21238.8671875.
# Iteration 62, inertia 21238.826171875.
# Iteration 63, inertia 21238.775390625.
# Iteration 64, inertia 21238.724609375.
# Iteration 65, inertia 21238.6875.
# Iteration 66, inertia 21238.650390625.
# Iteration 67, inertia 21238.6015625.
# Iteration 68, inertia 21238.56640625.
# Iteration 69, inertia 21238.53515625.
# Iteration 70, inertia 21238.48828125.
# Iteration 71, inertia 21238.4296875.
# Iteration 72, inertia 21238.396484375.
# Iteration 73, inertia 21238.375.
# Iteration 74, inertia 21238.361328125.
# Iteration 75, inertia 21238.349609375.
# Iteration 76, inertia 21238.353515625.
# Iteration 77, inertia 21238.349609375.
# Iteration 78, inertia 21238.345703125.
# Converged at iteration 78: strict convergence.
# Initialization complete
# Iteration 0, inertia 33590.26171875.
# Iteration 1, inertia 22339.62890625.
# Iteration 2, inertia 21832.22265625.
# Iteration 3, inertia 21655.99609375.
# Iteration 4, inertia 21565.390625.
# Iteration 5, inertia 21503.76171875.
# Iteration 6, inertia 21457.53125.
# Iteration 7, inertia 21421.615234375.
# Iteration 8, inertia 21394.63671875.
# Iteration 9, inertia 21375.87109375.
# Iteration 10, inertia 21360.216796875.
# Iteration 11, inertia 21345.98828125.
# Iteration 12, inertia 21333.6796875.
# Iteration 13, inertia 21322.57421875.
# Iteration 14, inertia 21312.6640625.
# Iteration 15, inertia 21302.482421875.
# Iteration 16, inertia 21295.119140625.
# Iteration 17, inertia 21289.45703125.
# Iteration 18, inertia 21284.03515625.
# Iteration 19, inertia 21279.21875.
# Iteration 20, inertia 21274.912109375.
# Iteration 21, inertia 21271.873046875.
# Iteration 22, inertia 21269.576171875.
# Iteration 23, inertia 21267.759765625.
# Iteration 24, inertia 21266.19140625.
# Iteration 25, inertia 21264.787109375.
# Iteration 26, inertia 21263.376953125.
# Iteration 27, inertia 21261.73828125.
# Iteration 28, inertia 21259.833984375.
# Iteration 29, inertia 21257.689453125.
# Iteration 30, inertia 21256.017578125.
# Iteration 31, inertia 21254.302734375.
# Iteration 32, inertia 21252.28515625.
# Iteration 33, inertia 21249.9921875.
# Iteration 34, inertia 21247.5546875.
# Iteration 35, inertia 21246.046875.
# Iteration 36, inertia 21244.966796875.
# Iteration 37, inertia 21244.232421875.
# Iteration 38, inertia 21243.74609375.
# Iteration 39, inertia 21243.384765625.
# Iteration 40, inertia 21243.0390625.
# Iteration 41, inertia 21242.6796875.
# Iteration 42, inertia 21242.390625.
# Iteration 43, inertia 21242.205078125.
# Iteration 44, inertia 21242.013671875.
# Iteration 45, inertia 21241.876953125.
# Iteration 46, inertia 21241.763671875.
# Iteration 47, inertia 21241.66796875.
# Iteration 48, inertia 21241.599609375.
# Iteration 49, inertia 21241.52734375.
# Iteration 50, inertia 21241.423828125.
# Iteration 51, inertia 21241.296875.
# Iteration 52, inertia 21241.107421875.
# Iteration 53, inertia 21240.90625.
# Iteration 54, inertia 21240.74609375.
# Iteration 55, inertia 21240.5078125.
# Iteration 56, inertia 21240.228515625.
# Iteration 57, inertia 21239.986328125.
# Iteration 58, inertia 21239.75.
# Iteration 59, inertia 21239.427734375.
# Iteration 60, inertia 21239.275390625.
# Iteration 61, inertia 21239.1640625.
# Iteration 62, inertia 21239.130859375.
# Iteration 63, inertia 21239.10546875.
# Iteration 64, inertia 21239.078125.
# Iteration 65, inertia 21239.052734375.
# Iteration 66, inertia 21239.03125.
# Iteration 67, inertia 21239.01953125.
# Iteration 68, inertia 21239.01171875.
# Iteration 69, inertia 21239.01171875.
# Iteration 70, inertia 21239.001953125.
# Iteration 71, inertia 21239.0.
# Iteration 72, inertia 21238.9921875.
# Iteration 73, inertia 21238.986328125.
# Iteration 74, inertia 21238.984375.
# Iteration 75, inertia 21238.97265625.
# Iteration 76, inertia 21238.97265625.
# Iteration 77, inertia 21238.970703125.
# Iteration 78, inertia 21238.9609375.
# Iteration 79, inertia 21238.962890625.
# Iteration 80, inertia 21238.962890625.
# Iteration 81, inertia 21238.962890625.
# Converged at iteration 81: strict convergence.
# Initialization complete
# Iteration 0, inertia 33588.015625.
# Iteration 1, inertia 22344.87890625.
# Iteration 2, inertia 21855.5234375.
# Iteration 3, inertia 21661.66796875.
# Iteration 4, inertia 21552.54296875.
# Iteration 5, inertia 21480.138671875.
# Iteration 6, inertia 21432.80078125.
# Iteration 7, inertia 21401.95703125.
# Iteration 8, inertia 21380.267578125.
# Iteration 9, inertia 21365.033203125.
# Iteration 10, inertia 21353.1484375.
# Iteration 11, inertia 21343.08984375.
# Iteration 12, inertia 21333.0078125.
# Iteration 13, inertia 21322.34375.
# Iteration 14, inertia 21313.880859375.
# Iteration 15, inertia 21306.984375.
# Iteration 16, inertia 21300.888671875.
# Iteration 17, inertia 21295.603515625.
# Iteration 18, inertia 21291.2578125.
# Iteration 19, inertia 21286.958984375.
# Iteration 20, inertia 21282.740234375.
# Iteration 21, inertia 21278.66015625.
# Iteration 22, inertia 21275.046875.
# Iteration 23, inertia 21271.80078125.
# Iteration 24, inertia 21268.166015625.
# Iteration 25, inertia 21263.833984375.
# Iteration 26, inertia 21259.439453125.
# Iteration 27, inertia 21255.9140625.
# Iteration 28, inertia 21253.388671875.
# Iteration 29, inertia 21251.607421875.
# Iteration 30, inertia 21250.306640625.
# Iteration 31, inertia 21249.1171875.
# Iteration 32, inertia 21248.013671875.
# Iteration 33, inertia 21247.0390625.
# Iteration 34, inertia 21246.205078125.
# Iteration 35, inertia 21245.5859375.
# Iteration 36, inertia 21245.087890625.
# Iteration 37, inertia 21244.677734375.
# Iteration 38, inertia 21244.2421875.
# Iteration 39, inertia 21243.87109375.
# Iteration 40, inertia 21243.521484375.
# Iteration 41, inertia 21243.169921875.
# Iteration 42, inertia 21242.728515625.
# Iteration 43, inertia 21242.216796875.
# Iteration 44, inertia 21241.685546875.
# Iteration 45, inertia 21241.033203125.
# Iteration 46, inertia 21240.234375.
# Iteration 47, inertia 21239.431640625.
# Iteration 48, inertia 21238.828125.
# Iteration 49, inertia 21238.37890625.
# Iteration 50, inertia 21238.009765625.
# Iteration 51, inertia 21237.736328125.
# Iteration 52, inertia 21237.541015625.
# Iteration 53, inertia 21237.36328125.
# Iteration 54, inertia 21237.1875.
# Iteration 55, inertia 21236.978515625.
# Iteration 56, inertia 21236.7265625.
# Iteration 57, inertia 21236.474609375.
# Iteration 58, inertia 21236.3359375.
# Iteration 59, inertia 21236.2578125.
# Iteration 60, inertia 21236.19140625.
# Iteration 61, inertia 21236.087890625.
# Iteration 62, inertia 21235.9921875.
# Iteration 63, inertia 21235.87890625.
# Iteration 64, inertia 21235.78515625.
# Iteration 65, inertia 21235.716796875.
# Iteration 66, inertia 21235.62109375.
# Iteration 67, inertia 21235.5546875.
# Iteration 68, inertia 21235.52734375.
# Iteration 69, inertia 21235.501953125.
# Iteration 70, inertia 21235.482421875.
# Iteration 71, inertia 21235.44921875.
# Iteration 72, inertia 21235.431640625.
# Iteration 73, inertia 21235.42578125.
# Iteration 74, inertia 21235.40625.
# Iteration 75, inertia 21235.388671875.
# Iteration 76, inertia 21235.365234375.
# Iteration 77, inertia 21235.353515625.
# Converged at iteration 77: strict convergence.
# Initialization complete
# Iteration 0, inertia 33432.4921875.
# Iteration 1, inertia 22257.458984375.
# Iteration 2, inertia 21791.94921875.
# Iteration 3, inertia 21632.099609375.
# Iteration 4, inertia 21529.57421875.
# Iteration 5, inertia 21449.677734375.
# Iteration 6, inertia 21397.408203125.
# Iteration 7, inertia 21364.8359375.
# Iteration 8, inertia 21340.904296875.
# Iteration 9, inertia 21323.75.
# Iteration 10, inertia 21310.93359375.
# Iteration 11, inertia 21300.689453125.
# Iteration 12, inertia 21290.119140625.
# Iteration 13, inertia 21280.271484375.
# Iteration 14, inertia 21273.08984375.
# Iteration 15, inertia 21266.57421875.
# Iteration 16, inertia 21260.416015625.
# Iteration 17, inertia 21256.10546875.
# Iteration 18, inertia 21252.7109375.
# Iteration 19, inertia 21250.05859375.
# Iteration 20, inertia 21247.935546875.
# Iteration 21, inertia 21246.052734375.
# Iteration 22, inertia 21244.5703125.
# Iteration 23, inertia 21243.181640625.
# Iteration 24, inertia 21241.80078125.
# Iteration 25, inertia 21240.580078125.
# Iteration 26, inertia 21239.3359375.
# Iteration 27, inertia 21237.8828125.
# Iteration 28, inertia 21235.904296875.
# Iteration 29, inertia 21234.810546875.
# Iteration 30, inertia 21234.248046875.
# Iteration 31, inertia 21233.69921875.
# Iteration 32, inertia 21233.123046875.
# Iteration 33, inertia 21232.6796875.
# Iteration 34, inertia 21232.296875.
# Iteration 35, inertia 21231.955078125.
# Iteration 36, inertia 21231.63671875.
# Iteration 37, inertia 21231.296875.
# Iteration 38, inertia 21231.005859375.
# Iteration 39, inertia 21230.62109375.
# Iteration 40, inertia 21230.171875.
# Iteration 41, inertia 21229.603515625.
# Iteration 42, inertia 21229.1953125.
# Iteration 43, inertia 21228.845703125.
# Iteration 44, inertia 21228.591796875.
# Iteration 45, inertia 21228.2890625.
# Iteration 46, inertia 21228.0546875.
# Iteration 47, inertia 21227.892578125.
# Iteration 48, inertia 21227.78125.
# Iteration 49, inertia 21227.697265625.
# Iteration 50, inertia 21227.640625.
# Iteration 51, inertia 21227.587890625.
# Iteration 52, inertia 21227.576171875.
# Iteration 53, inertia 21227.576171875.
# Iteration 54, inertia 21227.56640625.
# Converged at iteration 54: strict convergence.
# Initialization complete
# Iteration 0, inertia 33701.015625.
# Iteration 1, inertia 22342.791015625.
# Iteration 2, inertia 21835.865234375.
# Iteration 3, inertia 21655.537109375.
# Iteration 4, inertia 21563.478515625.
# Iteration 5, inertia 21499.228515625.
# Iteration 6, inertia 21449.6953125.
# Iteration 7, inertia 21409.896484375.
# Iteration 8, inertia 21379.048828125.
# Iteration 9, inertia 21352.884765625.
# Iteration 10, inertia 21332.2265625.
# Iteration 11, inertia 21315.66796875.
# Iteration 12, inertia 21302.650390625.
# Iteration 13, inertia 21293.705078125.
# Iteration 14, inertia 21287.02734375.
# Iteration 15, inertia 21280.32421875.
# Iteration 16, inertia 21274.34375.
# Iteration 17, inertia 21269.341796875.
# Iteration 18, inertia 21264.197265625.
# Iteration 19, inertia 21259.333984375.
# Iteration 20, inertia 21254.9375.
# Iteration 21, inertia 21251.9296875.
# Iteration 22, inertia 21249.771484375.
# Iteration 23, inertia 21247.998046875.
# Iteration 24, inertia 21246.259765625.
# Iteration 25, inertia 21244.548828125.
# Iteration 26, inertia 21243.1328125.
# Iteration 27, inertia 21241.7109375.
# Iteration 28, inertia 21240.5546875.
# Iteration 29, inertia 21239.529296875.
# Iteration 30, inertia 21238.533203125.
# Iteration 31, inertia 21237.541015625.
# Iteration 32, inertia 21236.49609375.
# Iteration 33, inertia 21235.60546875.
# Iteration 34, inertia 21234.6875.
# Iteration 35, inertia 21233.927734375.
# Iteration 36, inertia 21233.126953125.
# Iteration 37, inertia 21232.525390625.
# Iteration 38, inertia 21232.037109375.
# Iteration 39, inertia 21231.412109375.
# Iteration 40, inertia 21230.884765625.
# Iteration 41, inertia 21230.330078125.
# Iteration 42, inertia 21229.841796875.
# Iteration 43, inertia 21229.4375.
# Iteration 44, inertia 21229.111328125.
# Iteration 45, inertia 21228.861328125.
# Iteration 46, inertia 21228.6640625.
# Iteration 47, inertia 21228.47265625.
# Iteration 48, inertia 21228.345703125.
# Iteration 49, inertia 21228.22265625.
# Iteration 50, inertia 21228.111328125.
# Iteration 51, inertia 21227.90234375.
# Iteration 52, inertia 21227.609375.
# Iteration 53, inertia 21227.33984375.
# Iteration 54, inertia 21227.083984375.
# Iteration 55, inertia 21226.78515625.
# Iteration 56, inertia 21226.458984375.
# Iteration 57, inertia 21226.1640625.
# Iteration 58, inertia 21225.822265625.
# Iteration 59, inertia 21225.5234375.
# Iteration 60, inertia 21225.279296875.
# Iteration 61, inertia 21224.953125.
# Iteration 62, inertia 21224.568359375.
# Iteration 63, inertia 21224.28515625.
# Iteration 64, inertia 21224.1640625.
# Iteration 65, inertia 21224.06640625.
# Iteration 66, inertia 21223.986328125.
# Iteration 67, inertia 21223.9140625.
# Iteration 68, inertia 21223.83203125.
# Iteration 69, inertia 21223.7578125.
# Iteration 70, inertia 21223.673828125.
# Iteration 71, inertia 21223.587890625.
# Iteration 72, inertia 21223.53515625.
# Iteration 73, inertia 21223.49609375.
# Iteration 74, inertia 21223.482421875.
# Iteration 75, inertia 21223.46875.
# Iteration 76, inertia 21223.44921875.
# Iteration 77, inertia 21223.4296875.
# Iteration 78, inertia 21223.423828125.
# Iteration 79, inertia 21223.416015625.
# Iteration 80, inertia 21223.41015625.
# Iteration 81, inertia 21223.412109375.
# Converged at iteration 81: strict convergence.
# Initialization complete
# Iteration 0, inertia 33466.67578125.
# Iteration 1, inertia 22304.13671875.
# Iteration 2, inertia 21813.068359375.
# Iteration 3, inertia 21643.5.
# Iteration 4, inertia 21552.5234375.
# Iteration 5, inertia 21492.083984375.
# Iteration 6, inertia 21449.92578125.
# Iteration 7, inertia 21414.28515625.
# Iteration 8, inertia 21386.056640625.
# Iteration 9, inertia 21365.248046875.
# Iteration 10, inertia 21349.673828125.
# Iteration 11, inertia 21337.146484375.
# Iteration 12, inertia 21326.376953125.
# Iteration 13, inertia 21316.1171875.
# Iteration 14, inertia 21305.07421875.
# Iteration 15, inertia 21293.294921875.
# Iteration 16, inertia 21285.193359375.
# Iteration 17, inertia 21279.748046875.
# Iteration 18, inertia 21275.71484375.
# Iteration 19, inertia 21271.96875.
# Iteration 20, inertia 21269.232421875.
# Iteration 21, inertia 21267.001953125.
# Iteration 22, inertia 21265.11328125.
# Iteration 23, inertia 21262.810546875.
# Iteration 24, inertia 21260.345703125.
# Iteration 25, inertia 21258.638671875.
# Iteration 26, inertia 21257.28125.
# Iteration 27, inertia 21256.265625.
# Iteration 28, inertia 21255.451171875.
# Iteration 29, inertia 21254.69921875.
# Iteration 30, inertia 21253.978515625.
# Iteration 31, inertia 21253.283203125.
# Iteration 32, inertia 21252.697265625.
# Iteration 33, inertia 21252.02734375.
# Iteration 34, inertia 21251.16015625.
# Iteration 35, inertia 21250.240234375.
# Iteration 36, inertia 21249.490234375.
# Iteration 37, inertia 21248.640625.
# Iteration 38, inertia 21247.55078125.
# Iteration 39, inertia 21246.58984375.
# Iteration 40, inertia 21245.41015625.
# Iteration 41, inertia 21244.388671875.
# Iteration 42, inertia 21243.470703125.
# Iteration 43, inertia 21242.7734375.
# Iteration 44, inertia 21242.0859375.
# Iteration 45, inertia 21241.185546875.
# Iteration 46, inertia 21239.8828125.
# Iteration 47, inertia 21238.927734375.
# Iteration 48, inertia 21238.248046875.
# Iteration 49, inertia 21237.724609375.
# Iteration 50, inertia 21237.126953125.
# Iteration 51, inertia 21236.69921875.
# Iteration 52, inertia 21236.41796875.
# Iteration 53, inertia 21236.1875.
# Iteration 54, inertia 21236.076171875.
# Iteration 55, inertia 21236.00390625.
# Iteration 56, inertia 21235.916015625.
# Iteration 57, inertia 21235.8046875.
# Iteration 58, inertia 21235.71484375.
# Iteration 59, inertia 21235.595703125.
# Iteration 60, inertia 21235.517578125.
# Iteration 61, inertia 21235.400390625.
# Iteration 62, inertia 21235.3046875.
# Iteration 63, inertia 21235.265625.
# Iteration 64, inertia 21235.240234375.
# Iteration 65, inertia 21235.2265625.
# Iteration 66, inertia 21235.203125.
# Iteration 67, inertia 21235.181640625.
# Iteration 68, inertia 21235.162109375.
# Iteration 69, inertia 21235.142578125.
# Iteration 70, inertia 21235.111328125.
# Iteration 71, inertia 21235.068359375.
# Iteration 72, inertia 21235.05078125.
# Iteration 73, inertia 21235.041015625.
# Iteration 74, inertia 21235.017578125.
# Iteration 75, inertia 21235.0.
# Iteration 76, inertia 21234.986328125.
# Iteration 77, inertia 21234.96875.
# Iteration 78, inertia 21234.93359375.
# Iteration 79, inertia 21234.861328125.
# Iteration 80, inertia 21234.79296875.
# Iteration 81, inertia 21234.755859375.
# Iteration 82, inertia 21234.73046875.
# Iteration 83, inertia 21234.697265625.
# Iteration 84, inertia 21234.658203125.
# Iteration 85, inertia 21234.599609375.
# Iteration 86, inertia 21234.53125.
# Iteration 87, inertia 21234.482421875.
# Iteration 88, inertia 21234.46484375.
# Iteration 89, inertia 21234.458984375.
# Converged at iteration 89: strict convergence.
# Initialization complete
# Iteration 0, inertia 33401.671875.
# Iteration 1, inertia 22250.53515625.
# Iteration 2, inertia 21808.65234375.
# Iteration 3, inertia 21644.236328125.
# Iteration 4, inertia 21547.4765625.
# Iteration 5, inertia 21488.451171875.
# Iteration 6, inertia 21446.572265625.
# Iteration 7, inertia 21413.8515625.
# Iteration 8, inertia 21388.00390625.
# Iteration 9, inertia 21366.30859375.
# Iteration 10, inertia 21347.75390625.
# Iteration 11, inertia 21332.126953125.
# Iteration 12, inertia 21318.03125.
# Iteration 13, inertia 21306.7421875.
# Iteration 14, inertia 21297.81640625.
# Iteration 15, inertia 21291.0.
# Iteration 16, inertia 21285.46875.
# Iteration 17, inertia 21280.55078125.
# Iteration 18, inertia 21275.994140625.
# Iteration 19, inertia 21271.734375.
# Iteration 20, inertia 21267.92578125.
# Iteration 21, inertia 21264.0859375.
# Iteration 22, inertia 21260.0625.
# Iteration 23, inertia 21256.00390625.
# Iteration 24, inertia 21252.408203125.
# Iteration 25, inertia 21249.53125.
# Iteration 26, inertia 21247.0.
# Iteration 27, inertia 21244.794921875.
# Iteration 28, inertia 21242.71875.
# Iteration 29, inertia 21241.080078125.
# Iteration 30, inertia 21239.72265625.
# Iteration 31, inertia 21238.466796875.
# Iteration 32, inertia 21237.3359375.
# Iteration 33, inertia 21236.513671875.
# Iteration 34, inertia 21235.81640625.
# Iteration 35, inertia 21235.328125.
# Iteration 36, inertia 21234.875.
# Iteration 37, inertia 21234.544921875.
# Iteration 38, inertia 21234.27734375.
# Iteration 39, inertia 21234.08984375.
# Iteration 40, inertia 21233.9375.
# Iteration 41, inertia 21233.810546875.
# Iteration 42, inertia 21233.724609375.
# Iteration 43, inertia 21233.66796875.
# Iteration 44, inertia 21233.623046875.
# Iteration 45, inertia 21233.556640625.
# Iteration 46, inertia 21233.517578125.
# Iteration 47, inertia 21233.47265625.
# Iteration 48, inertia 21233.416015625.
# Iteration 49, inertia 21233.3359375.
# Iteration 50, inertia 21233.244140625.
# Iteration 51, inertia 21233.1640625.
# Iteration 52, inertia 21233.080078125.
# Iteration 53, inertia 21232.97265625.
# Iteration 54, inertia 21232.822265625.
# Iteration 55, inertia 21232.609375.
# Iteration 56, inertia 21232.4296875.
# Iteration 57, inertia 21232.2890625.
# Iteration 58, inertia 21232.19140625.
# Iteration 59, inertia 21232.138671875.
# Iteration 60, inertia 21232.11328125.
# Iteration 61, inertia 21232.0625.
# Iteration 62, inertia 21232.025390625.
# Iteration 63, inertia 21231.962890625.
# Iteration 64, inertia 21231.87890625.
# Iteration 65, inertia 21231.740234375.
# Iteration 66, inertia 21231.568359375.
# Iteration 67, inertia 21231.439453125.
# Iteration 68, inertia 21231.3203125.
# Iteration 69, inertia 21231.171875.
# Iteration 70, inertia 21231.060546875.
# Iteration 71, inertia 21230.962890625.
# Iteration 72, inertia 21230.8671875.
# Iteration 73, inertia 21230.806640625.
# Iteration 74, inertia 21230.755859375.
# Iteration 75, inertia 21230.703125.
# Iteration 76, inertia 21230.67578125.
# Iteration 77, inertia 21230.66015625.
# Iteration 78, inertia 21230.642578125.
# Iteration 79, inertia 21230.591796875.
# Iteration 80, inertia 21230.568359375.
# Iteration 81, inertia 21230.5390625.
# Iteration 82, inertia 21230.451171875.
# Iteration 83, inertia 21230.40234375.
# Iteration 84, inertia 21230.36328125.
# Iteration 85, inertia 21230.33984375.
# Iteration 86, inertia 21230.326171875.
# Iteration 87, inertia 21230.326171875.
# Converged at iteration 87: strict convergence.
# Initialization complete
# Iteration 0, inertia 33629.421875.
# Iteration 1, inertia 22468.72265625.
# Iteration 2, inertia 21910.541015625.
# Iteration 3, inertia 21693.30859375.
# Iteration 4, inertia 21582.009765625.
# Iteration 5, inertia 21505.9765625.
# Iteration 6, inertia 21455.052734375.
# Iteration 7, inertia 21419.970703125.
# Iteration 8, inertia 21390.30078125.
# Iteration 9, inertia 21365.048828125.
# Iteration 10, inertia 21346.9140625.
# Iteration 11, inertia 21333.62890625.
# Iteration 12, inertia 21324.498046875.
# Iteration 13, inertia 21317.634765625.
# Iteration 14, inertia 21312.29296875.
# Iteration 15, inertia 21307.546875.
# Iteration 16, inertia 21303.490234375.
# Iteration 17, inertia 21299.775390625.
# Iteration 18, inertia 21296.271484375.
# Iteration 19, inertia 21293.51171875.
# Iteration 20, inertia 21290.93359375.
# Iteration 21, inertia 21288.5703125.
# Iteration 22, inertia 21286.40234375.
# Iteration 23, inertia 21284.294921875.
# Iteration 24, inertia 21282.1640625.
# Iteration 25, inertia 21280.12109375.
# Iteration 26, inertia 21278.0546875.
# Iteration 27, inertia 21276.197265625.
# Iteration 28, inertia 21274.9765625.
# Iteration 29, inertia 21274.25.
# Iteration 30, inertia 21273.69921875.
# Iteration 31, inertia 21273.193359375.
# Iteration 32, inertia 21272.71484375.
# Iteration 33, inertia 21272.35546875.
# Iteration 34, inertia 21272.072265625.
# Iteration 35, inertia 21271.80859375.
# Iteration 36, inertia 21271.58203125.
# Iteration 37, inertia 21271.341796875.
# Iteration 38, inertia 21271.162109375.
# Iteration 39, inertia 21270.998046875.
# Iteration 40, inertia 21270.849609375.
# Iteration 41, inertia 21270.732421875.
# Iteration 42, inertia 21270.583984375.
# Iteration 43, inertia 21270.416015625.
# Iteration 44, inertia 21270.189453125.
# Iteration 45, inertia 21269.833984375.
# Iteration 46, inertia 21269.283203125.
# Iteration 47, inertia 21269.001953125.
# Iteration 48, inertia 21268.72265625.
# Iteration 49, inertia 21268.611328125.
# Iteration 50, inertia 21268.548828125.
# Iteration 51, inertia 21268.466796875.
# Iteration 52, inertia 21268.4296875.
# Iteration 53, inertia 21268.388671875.
# Iteration 54, inertia 21268.3203125.
# Iteration 55, inertia 21268.228515625.
# Iteration 56, inertia 21268.140625.
# Iteration 57, inertia 21268.037109375.
# Iteration 58, inertia 21267.92578125.
# Iteration 59, inertia 21267.828125.
# Iteration 60, inertia 21267.720703125.
# Iteration 61, inertia 21267.60546875.
# Iteration 62, inertia 21267.466796875.
# Iteration 63, inertia 21267.302734375.
# Iteration 64, inertia 21267.15625.
# Iteration 65, inertia 21267.029296875.
# Iteration 66, inertia 21266.943359375.
# Iteration 67, inertia 21266.845703125.
# Iteration 68, inertia 21266.693359375.
# Iteration 69, inertia 21266.54296875.
# Iteration 70, inertia 21266.375.
# Iteration 71, inertia 21266.232421875.
# Iteration 72, inertia 21265.8984375.
# Iteration 73, inertia 21265.533203125.
# Iteration 74, inertia 21265.208984375.
# Iteration 75, inertia 21264.9296875.
# Iteration 76, inertia 21264.759765625.
# Iteration 77, inertia 21264.689453125.
# Iteration 78, inertia 21264.599609375.
# Iteration 79, inertia 21264.529296875.
# Iteration 80, inertia 21264.4609375.
# Iteration 81, inertia 21264.353515625.
# Iteration 82, inertia 21264.302734375.
# Iteration 83, inertia 21264.224609375.
# Iteration 84, inertia 21264.1484375.
# Iteration 85, inertia 21264.109375.
# Iteration 86, inertia 21264.083984375.
# Iteration 87, inertia 21264.06640625.
# Iteration 88, inertia 21264.060546875.
# Iteration 89, inertia 21264.044921875.
# Iteration 90, inertia 21264.029296875.
# Iteration 91, inertia 21264.02734375.
# Iteration 92, inertia 21264.01953125.
# Iteration 93, inertia 21264.01171875.
# Iteration 94, inertia 21264.0.
# Iteration 95, inertia 21264.001953125.
# Iteration 96, inertia 21263.9765625.
# Iteration 97, inertia 21263.943359375.
# Iteration 98, inertia 21263.91015625.
# Iteration 99, inertia 21263.892578125.
# Iteration 100, inertia 21263.87109375.
# Iteration 101, inertia 21263.861328125.
# Iteration 102, inertia 21263.853515625.
# Iteration 103, inertia 21263.8359375.
# Iteration 104, inertia 21263.8125.
# Iteration 105, inertia 21263.802734375.
# Iteration 106, inertia 21263.794921875.
# Iteration 107, inertia 21263.7890625.
# Iteration 108, inertia 21263.779296875.
# Iteration 109, inertia 21263.779296875.
# Iteration 110, inertia 21263.765625.
# Iteration 111, inertia 21263.76171875.
# Iteration 112, inertia 21263.75.
# Iteration 113, inertia 21263.748046875.
# Converged at iteration 113: strict convergence.
# Initialization complete
# Iteration 0, inertia 33591.46484375.
# Iteration 1, inertia 22301.48046875.
# Iteration 2, inertia 21821.89453125.
# Iteration 3, inertia 21646.3125.
# Iteration 4, inertia 21539.828125.
# Iteration 5, inertia 21467.08203125.
# Iteration 6, inertia 21416.759765625.
# Iteration 7, inertia 21380.31640625.
# Iteration 8, inertia 21353.607421875.
# Iteration 9, inertia 21333.73828125.
# Iteration 10, inertia 21317.5703125.
# Iteration 11, inertia 21305.01171875.
# Iteration 12, inertia 21295.271484375.
# Iteration 13, inertia 21287.44140625.
# Iteration 14, inertia 21281.13671875.
# Iteration 15, inertia 21276.267578125.
# Iteration 16, inertia 21271.521484375.
# Iteration 17, inertia 21266.8671875.
# Iteration 18, inertia 21263.013671875.
# Iteration 19, inertia 21259.083984375.
# Iteration 20, inertia 21255.150390625.
# Iteration 21, inertia 21251.51171875.
# Iteration 22, inertia 21247.912109375.
# Iteration 23, inertia 21244.154296875.
# Iteration 24, inertia 21241.677734375.
# Iteration 25, inertia 21239.291015625.
# Iteration 26, inertia 21237.3125.
# Iteration 27, inertia 21235.6484375.
# Iteration 28, inertia 21234.189453125.
# Iteration 29, inertia 21232.962890625.
# Iteration 30, inertia 21232.0625.
# Iteration 31, inertia 21231.427734375.
# Iteration 32, inertia 21231.015625.
# Iteration 33, inertia 21230.65234375.
# Iteration 34, inertia 21230.24609375.
# Iteration 35, inertia 21229.8125.
# Iteration 36, inertia 21229.44140625.
# Iteration 37, inertia 21229.140625.
# Iteration 38, inertia 21228.80078125.
# Iteration 39, inertia 21228.46484375.
# Iteration 40, inertia 21228.130859375.
# Iteration 41, inertia 21227.7890625.
# Iteration 42, inertia 21227.5078125.
# Iteration 43, inertia 21227.240234375.
# Iteration 44, inertia 21227.041015625.
# Iteration 45, inertia 21226.84765625.
# Iteration 46, inertia 21226.6484375.
# Iteration 47, inertia 21226.380859375.
# Iteration 48, inertia 21226.072265625.
# Iteration 49, inertia 21225.79296875.
# Iteration 50, inertia 21225.498046875.
# Iteration 51, inertia 21225.162109375.
# Iteration 52, inertia 21224.908203125.
# Iteration 53, inertia 21224.7109375.
# Iteration 54, inertia 21224.560546875.
# Iteration 55, inertia 21224.3828125.
# Iteration 56, inertia 21224.125.
# Iteration 57, inertia 21223.791015625.
# Iteration 58, inertia 21223.615234375.
# Iteration 59, inertia 21223.517578125.
# Iteration 60, inertia 21223.443359375.
# Iteration 61, inertia 21223.39453125.
# Iteration 62, inertia 21223.369140625.
# Iteration 63, inertia 21223.3359375.
# Iteration 64, inertia 21223.294921875.
# Iteration 65, inertia 21223.240234375.
# Iteration 66, inertia 21223.154296875.
# Iteration 67, inertia 21223.05859375.
# Iteration 68, inertia 21222.943359375.
# Iteration 69, inertia 21222.837890625.
# Iteration 70, inertia 21222.650390625.
# Iteration 71, inertia 21222.4140625.
# Iteration 72, inertia 21222.07421875.
# Iteration 73, inertia 21221.771484375.
# Iteration 74, inertia 21221.322265625.
# Iteration 75, inertia 21220.9375.
# Iteration 76, inertia 21220.71484375.
# Iteration 77, inertia 21220.53515625.
# Iteration 78, inertia 21220.4375.
# Iteration 79, inertia 21220.38671875.
# Iteration 80, inertia 21220.3671875.
# Iteration 81, inertia 21220.345703125.
# Iteration 82, inertia 21220.3359375.
# Iteration 83, inertia 21220.326171875.
# Iteration 84, inertia 21220.322265625.
# Converged at iteration 84: strict convergence.
# Initialization complete
# Iteration 0, inertia 33572.3046875.
# Iteration 1, inertia 22378.65625.
# Iteration 2, inertia 21858.8828125.
# Iteration 3, inertia 21641.146484375.
# Iteration 4, inertia 21523.923828125.
# Iteration 5, inertia 21454.154296875.
# Iteration 6, inertia 21409.634765625.
# Iteration 7, inertia 21376.626953125.
# Iteration 8, inertia 21352.09375.
# Iteration 9, inertia 21335.015625.
# Iteration 10, inertia 21321.150390625.
# Iteration 11, inertia 21308.49609375.
# Iteration 12, inertia 21299.0546875.
# Iteration 13, inertia 21290.94140625.
# Iteration 14, inertia 21283.494140625.
# Iteration 15, inertia 21277.505859375.
# Iteration 16, inertia 21272.5859375.
# Iteration 17, inertia 21268.376953125.
# Iteration 18, inertia 21264.482421875.
# Iteration 19, inertia 21260.822265625.
# Iteration 20, inertia 21257.7109375.
# Iteration 21, inertia 21254.99609375.
# Iteration 22, inertia 21252.095703125.
# Iteration 23, inertia 21248.662109375.
# Iteration 24, inertia 21246.1171875.
# Iteration 25, inertia 21243.974609375.
# Iteration 26, inertia 21241.921875.
# Iteration 27, inertia 21240.33984375.
# Iteration 28, inertia 21238.939453125.
# Iteration 29, inertia 21237.943359375.
# Iteration 30, inertia 21237.048828125.
# Iteration 31, inertia 21236.169921875.
# Iteration 32, inertia 21235.30078125.
# Iteration 33, inertia 21234.486328125.
# Iteration 34, inertia 21233.75.
# Iteration 35, inertia 21233.02734375.
# Iteration 36, inertia 21232.361328125.
# Iteration 37, inertia 21231.75.
# Iteration 38, inertia 21231.171875.
# Iteration 39, inertia 21230.638671875.
# Iteration 40, inertia 21230.087890625.
# Iteration 41, inertia 21229.544921875.
# Iteration 42, inertia 21229.11328125.
# Iteration 43, inertia 21228.56640625.
# Iteration 44, inertia 21228.052734375.
# Iteration 45, inertia 21227.5625.
# Iteration 46, inertia 21227.216796875.
# Iteration 47, inertia 21226.85546875.
# Iteration 48, inertia 21226.546875.
# Iteration 49, inertia 21226.25.
# Iteration 50, inertia 21225.935546875.
# Iteration 51, inertia 21225.693359375.
# Iteration 52, inertia 21225.41015625.
# Iteration 53, inertia 21225.09375.
# Iteration 54, inertia 21224.728515625.
# Iteration 55, inertia 21224.466796875.
# Iteration 56, inertia 21224.203125.
# Iteration 57, inertia 21223.966796875.
# Iteration 58, inertia 21223.798828125.
# Iteration 59, inertia 21223.560546875.
# Iteration 60, inertia 21223.357421875.
# Iteration 61, inertia 21223.2265625.
# Iteration 62, inertia 21223.1015625.
# Iteration 63, inertia 21222.998046875.
# Iteration 64, inertia 21222.93359375.
# Iteration 65, inertia 21222.875.
# Iteration 66, inertia 21222.81640625.
# Iteration 67, inertia 21222.7890625.
# Iteration 68, inertia 21222.775390625.
# Iteration 69, inertia 21222.775390625.
# Converged at iteration 69: strict convergence.
# Initialization complete
# Iteration 0, inertia 33489.5625.
# Iteration 1, inertia 22263.703125.
# Iteration 2, inertia 21782.890625.
# Iteration 3, inertia 21606.00390625.
# Iteration 4, inertia 21506.287109375.
# Iteration 5, inertia 21435.83203125.
# Iteration 6, inertia 21387.26171875.
# Iteration 7, inertia 21353.517578125.
# Iteration 8, inertia 21329.17578125.
# Iteration 9, inertia 21310.419921875.
# Iteration 10, inertia 21298.341796875.
# Iteration 11, inertia 21288.89453125.
# Iteration 12, inertia 21281.65625.
# Iteration 13, inertia 21275.158203125.
# Iteration 14, inertia 21269.712890625.
# Iteration 15, inertia 21265.259765625.
# Iteration 16, inertia 21261.025390625.
# Iteration 17, inertia 21256.982421875.
# Iteration 18, inertia 21252.12890625.
# Iteration 19, inertia 21247.369140625.
# Iteration 20, inertia 21244.005859375.
# Iteration 21, inertia 21241.998046875.
# Iteration 22, inertia 21240.310546875.
# Iteration 23, inertia 21239.09765625.
# Iteration 24, inertia 21237.900390625.
# Iteration 25, inertia 21236.357421875.
# Iteration 26, inertia 21234.919921875.
# Iteration 27, inertia 21233.830078125.
# Iteration 28, inertia 21232.8984375.
# Iteration 29, inertia 21232.08203125.
# Iteration 30, inertia 21231.572265625.
# Iteration 31, inertia 21231.083984375.
# Iteration 32, inertia 21230.607421875.
# Iteration 33, inertia 21230.12109375.
# Iteration 34, inertia 21229.759765625.
# Iteration 35, inertia 21229.462890625.
# Iteration 36, inertia 21229.267578125.
# Iteration 37, inertia 21229.13671875.
# Iteration 38, inertia 21229.0546875.
# Iteration 39, inertia 21229.005859375.
# Iteration 40, inertia 21228.96484375.
# Iteration 41, inertia 21228.9296875.
# Iteration 42, inertia 21228.90234375.
# Iteration 43, inertia 21228.8828125.
# Iteration 44, inertia 21228.861328125.
# Iteration 45, inertia 21228.849609375.
# Iteration 46, inertia 21228.818359375.
# Iteration 47, inertia 21228.7890625.
# Iteration 48, inertia 21228.76171875.
# Iteration 49, inertia 21228.720703125.
# Iteration 50, inertia 21228.70703125.
# Iteration 51, inertia 21228.6953125.
# Iteration 52, inertia 21228.68359375.
# Iteration 53, inertia 21228.677734375.
# Iteration 54, inertia 21228.6640625.
# Iteration 55, inertia 21228.65234375.
# Iteration 56, inertia 21228.6484375.
# Iteration 57, inertia 21228.64453125.
# Converged at iteration 57: strict convergence.
# Initialization complete
# Iteration 0, inertia 33800.69921875.
# Iteration 1, inertia 22395.904296875.
# Iteration 2, inertia 21881.8671875.
# Iteration 3, inertia 21671.875.
# Iteration 4, inertia 21550.1640625.
# Iteration 5, inertia 21470.181640625.
# Iteration 6, inertia 21419.013671875.
# Iteration 7, inertia 21387.876953125.
# Iteration 8, inertia 21366.146484375.
# Iteration 9, inertia 21349.9609375.
# Iteration 10, inertia 21337.451171875.
# Iteration 11, inertia 21327.513671875.
# Iteration 12, inertia 21319.521484375.
# Iteration 13, inertia 21313.185546875.
# Iteration 14, inertia 21307.8203125.
# Iteration 15, inertia 21302.646484375.
# Iteration 16, inertia 21297.95703125.
# Iteration 17, inertia 21293.630859375.
# Iteration 18, inertia 21289.513671875.
# Iteration 19, inertia 21285.375.
# Iteration 20, inertia 21281.728515625.
# Iteration 21, inertia 21278.58984375.
# Iteration 22, inertia 21275.763671875.
# Iteration 23, inertia 21272.2109375.
# Iteration 24, inertia 21269.751953125.
# Iteration 25, inertia 21268.453125.
# Iteration 26, inertia 21267.44140625.
# Iteration 27, inertia 21266.18359375.
# Iteration 28, inertia 21264.646484375.
# Iteration 29, inertia 21263.396484375.
# Iteration 30, inertia 21262.33203125.
# Iteration 31, inertia 21261.267578125.
# Iteration 32, inertia 21260.328125.
# Iteration 33, inertia 21259.5.
# Iteration 34, inertia 21258.67578125.
# Iteration 35, inertia 21257.76171875.
# Iteration 36, inertia 21256.86328125.
# Iteration 37, inertia 21256.236328125.
# Iteration 38, inertia 21255.73046875.
# Iteration 39, inertia 21255.390625.
# Iteration 40, inertia 21255.15234375.
# Iteration 41, inertia 21254.9375.
# Iteration 42, inertia 21254.76171875.
# Iteration 43, inertia 21254.5234375.
# Iteration 44, inertia 21254.302734375.
# Iteration 45, inertia 21254.068359375.
# Iteration 46, inertia 21253.802734375.
# Iteration 47, inertia 21253.599609375.
# Iteration 48, inertia 21253.451171875.
# Iteration 49, inertia 21253.322265625.
# Iteration 50, inertia 21253.15625.
# Iteration 51, inertia 21253.009765625.
# Iteration 52, inertia 21252.841796875.
# Iteration 53, inertia 21252.58203125.
# Iteration 54, inertia 21252.189453125.
# Iteration 55, inertia 21251.8359375.
# Iteration 56, inertia 21251.544921875.
# Iteration 57, inertia 21251.248046875.
# Iteration 58, inertia 21250.876953125.
# Iteration 59, inertia 21250.44921875.
# Iteration 60, inertia 21250.013671875.
# Iteration 61, inertia 21249.69140625.
# Iteration 62, inertia 21249.447265625.
# Iteration 63, inertia 21249.25.
# Iteration 64, inertia 21249.03125.
# Iteration 65, inertia 21248.85546875.
# Iteration 66, inertia 21248.669921875.
# Iteration 67, inertia 21248.396484375.
# Iteration 68, inertia 21248.056640625.
# Iteration 69, inertia 21247.662109375.
# Iteration 70, inertia 21247.330078125.
# Iteration 71, inertia 21247.109375.
# Iteration 72, inertia 21246.8671875.
# Iteration 73, inertia 21246.66796875.
# Iteration 74, inertia 21246.51953125.
# Iteration 75, inertia 21246.431640625.
# Iteration 76, inertia 21246.38671875.
# Iteration 77, inertia 21246.361328125.
# Iteration 78, inertia 21246.33203125.
# Iteration 79, inertia 21246.322265625.
# Iteration 80, inertia 21246.3046875.
# Iteration 81, inertia 21246.30078125.
# Iteration 82, inertia 21246.298828125.
# Iteration 83, inertia 21246.2890625.
# Iteration 84, inertia 21246.275390625.
# Iteration 85, inertia 21246.275390625.
# Iteration 86, inertia 21246.265625.
# Iteration 87, inertia 21246.265625.
# Iteration 88, inertia 21246.25390625.
# Iteration 89, inertia 21246.2578125.
# Converged at iteration 89: strict convergence.
# Initialization complete
# Iteration 0, inertia 33519.23046875.
# Iteration 1, inertia 22390.892578125.
# Iteration 2, inertia 21865.3828125.
# Iteration 3, inertia 21655.41796875.
# Iteration 4, inertia 21547.0625.
# Iteration 5, inertia 21482.40625.
# Iteration 6, inertia 21433.91796875.
# Iteration 7, inertia 21397.96484375.
# Iteration 8, inertia 21370.015625.
# Iteration 9, inertia 21347.150390625.
# Iteration 10, inertia 21328.890625.
# Iteration 11, inertia 21313.40234375.
# Iteration 12, inertia 21300.28125.
# Iteration 13, inertia 21289.5.
# Iteration 14, inertia 21281.212890625.
# Iteration 15, inertia 21274.775390625.
# Iteration 16, inertia 21269.669921875.
# Iteration 17, inertia 21264.998046875.
# Iteration 18, inertia 21260.814453125.
# Iteration 19, inertia 21256.892578125.
# Iteration 20, inertia 21253.263671875.
# Iteration 21, inertia 21249.478515625.
# Iteration 22, inertia 21245.310546875.
# Iteration 23, inertia 21240.603515625.
# Iteration 24, inertia 21235.455078125.
# Iteration 25, inertia 21231.2421875.
# Iteration 26, inertia 21228.20703125.
# Iteration 27, inertia 21226.958984375.
# Iteration 28, inertia 21226.017578125.
# Iteration 29, inertia 21224.994140625.
# Iteration 30, inertia 21224.05859375.
# Iteration 31, inertia 21223.064453125.
# Iteration 32, inertia 21222.166015625.
# Iteration 33, inertia 21221.28515625.
# Iteration 34, inertia 21220.376953125.
# Iteration 35, inertia 21219.62109375.
# Iteration 36, inertia 21218.884765625.
# Iteration 37, inertia 21218.37109375.
# Iteration 38, inertia 21217.990234375.
# Iteration 39, inertia 21217.654296875.
# Iteration 40, inertia 21217.291015625.
# Iteration 41, inertia 21216.9140625.
# Iteration 42, inertia 21216.572265625.
# Iteration 43, inertia 21216.39453125.
# Iteration 44, inertia 21216.22265625.
# Iteration 45, inertia 21216.0859375.
# Iteration 46, inertia 21215.943359375.
# Iteration 47, inertia 21215.8125.
# Iteration 48, inertia 21215.658203125.
# Iteration 49, inertia 21215.51953125.
# Iteration 50, inertia 21215.36328125.
# Iteration 51, inertia 21215.201171875.
# Iteration 52, inertia 21215.046875.
# Iteration 53, inertia 21214.927734375.
# Iteration 54, inertia 21214.84765625.
# Iteration 55, inertia 21214.755859375.
# Iteration 56, inertia 21214.689453125.
# Iteration 57, inertia 21214.572265625.
# Iteration 58, inertia 21214.4375.
# Iteration 59, inertia 21214.193359375.
# Iteration 60, inertia 21213.974609375.
# Iteration 61, inertia 21213.74609375.
# Iteration 62, inertia 21213.60546875.
# Iteration 63, inertia 21213.486328125.
# Iteration 64, inertia 21213.431640625.
# Iteration 65, inertia 21213.390625.
# Iteration 66, inertia 21213.349609375.
# Iteration 67, inertia 21213.27734375.
# Iteration 68, inertia 21213.171875.
# Iteration 69, inertia 21213.1171875.
# Iteration 70, inertia 21213.0859375.
# Iteration 71, inertia 21213.037109375.
# Iteration 72, inertia 21212.9921875.
# Iteration 73, inertia 21212.953125.
# Iteration 74, inertia 21212.904296875.
# Iteration 75, inertia 21212.87109375.
# Iteration 76, inertia 21212.845703125.
# Iteration 77, inertia 21212.83203125.
# Iteration 78, inertia 21212.814453125.
# Iteration 79, inertia 21212.8046875.
# Iteration 80, inertia 21212.802734375.
# Iteration 81, inertia 21212.798828125.
# Iteration 82, inertia 21212.794921875.
# Iteration 83, inertia 21212.791015625.
# Iteration 84, inertia 21212.775390625.
# Iteration 85, inertia 21212.763671875.
# Iteration 86, inertia 21212.75390625.
# Iteration 87, inertia 21212.73828125.
# Iteration 88, inertia 21212.734375.
# Iteration 89, inertia 21212.728515625.
# Iteration 90, inertia 21212.720703125.
# Converged at iteration 90: strict convergence.
# Initialization complete
# Iteration 0, inertia 33582.015625.
# Iteration 1, inertia 22295.337890625.
# Iteration 2, inertia 21791.830078125.
# Iteration 3, inertia 21611.40234375.
# Iteration 4, inertia 21515.005859375.
# Iteration 5, inertia 21458.60546875.
# Iteration 6, inertia 21422.697265625.
# Iteration 7, inertia 21397.865234375.
# Iteration 8, inertia 21379.462890625.
# Iteration 9, inertia 21365.08203125.
# Iteration 10, inertia 21351.34765625.
# Iteration 11, inertia 21337.79296875.
# Iteration 12, inertia 21324.630859375.
# Iteration 13, inertia 21314.130859375.
# Iteration 14, inertia 21306.7890625.
# Iteration 15, inertia 21300.693359375.
# Iteration 16, inertia 21294.890625.
# Iteration 17, inertia 21288.515625.
# Iteration 18, inertia 21281.75.
# Iteration 19, inertia 21276.2890625.
# Iteration 20, inertia 21271.53125.
# Iteration 21, inertia 21267.28515625.
# Iteration 22, inertia 21263.296875.
# Iteration 23, inertia 21260.009765625.
# Iteration 24, inertia 21257.599609375.
# Iteration 25, inertia 21255.625.
# Iteration 26, inertia 21253.736328125.
# Iteration 27, inertia 21251.69140625.
# Iteration 28, inertia 21249.6875.
# Iteration 29, inertia 21247.759765625.
# Iteration 30, inertia 21246.302734375.
# Iteration 31, inertia 21245.19921875.
# Iteration 32, inertia 21244.3203125.
# Iteration 33, inertia 21243.615234375.
# Iteration 34, inertia 21242.744140625.
# Iteration 35, inertia 21241.81640625.
# Iteration 36, inertia 21240.73046875.
# Iteration 37, inertia 21239.458984375.
# Iteration 38, inertia 21237.93359375.
# Iteration 39, inertia 21236.6640625.
# Iteration 40, inertia 21235.568359375.
# Iteration 41, inertia 21234.626953125.
# Iteration 42, inertia 21233.63671875.
# Iteration 43, inertia 21233.09375.
# Iteration 44, inertia 21232.80859375.
# Iteration 45, inertia 21232.611328125.
# Iteration 46, inertia 21232.44921875.
# Iteration 47, inertia 21232.310546875.
# Iteration 48, inertia 21232.216796875.
# Iteration 49, inertia 21232.13671875.
# Iteration 50, inertia 21232.048828125.
# Iteration 51, inertia 21231.9375.
# Iteration 52, inertia 21231.841796875.
# Iteration 53, inertia 21231.765625.
# Iteration 54, inertia 21231.728515625.
# Iteration 55, inertia 21231.703125.
# Iteration 56, inertia 21231.671875.
# Iteration 57, inertia 21231.62890625.
# Iteration 58, inertia 21231.5703125.
# Iteration 59, inertia 21231.5234375.
# Iteration 60, inertia 21231.501953125.
# Iteration 61, inertia 21231.44921875.
# Iteration 62, inertia 21231.349609375.
# Iteration 63, inertia 21231.14453125.
# Iteration 64, inertia 21230.927734375.
# Iteration 65, inertia 21230.697265625.
# Iteration 66, inertia 21230.462890625.
# Iteration 67, inertia 21230.2578125.
# Iteration 68, inertia 21230.06640625.
# Iteration 69, inertia 21229.919921875.
# Iteration 70, inertia 21229.798828125.
# Iteration 71, inertia 21229.728515625.
# Iteration 72, inertia 21229.6875.
# Iteration 73, inertia 21229.646484375.
# Iteration 74, inertia 21229.599609375.
# Iteration 75, inertia 21229.576171875.
# Iteration 76, inertia 21229.5625.
# Iteration 77, inertia 21229.560546875.
# Iteration 78, inertia 21229.552734375.
# Iteration 79, inertia 21229.5390625.
# Iteration 80, inertia 21229.53125.
# Iteration 81, inertia 21229.5234375.
# Iteration 82, inertia 21229.51953125.
# Iteration 83, inertia 21229.513671875.
# Iteration 84, inertia 21229.501953125.
# Iteration 85, inertia 21229.482421875.
# Iteration 86, inertia 21229.482421875.
# Iteration 87, inertia 21229.482421875.
# Iteration 88, inertia 21229.4765625.
# Iteration 89, inertia 21229.470703125.
# Iteration 90, inertia 21229.451171875.
# Iteration 91, inertia 21229.439453125.
# Iteration 92, inertia 21229.416015625.
# Iteration 93, inertia 21229.408203125.
# Iteration 94, inertia 21229.40625.
# Iteration 95, inertia 21229.390625.
# Iteration 96, inertia 21229.384765625.
# Iteration 97, inertia 21229.373046875.
# Converged at iteration 97: strict convergence.
# Initialization complete
# Iteration 0, inertia 33427.10546875.
# Iteration 1, inertia 22298.3046875.
# Iteration 2, inertia 21831.751953125.
# Iteration 3, inertia 21652.57421875.
# Iteration 4, inertia 21557.962890625.
# Iteration 5, inertia 21494.40625.
# Iteration 6, inertia 21446.90234375.
# Iteration 7, inertia 21411.67578125.
# Iteration 8, inertia 21384.708984375.
# Iteration 9, inertia 21365.025390625.
# Iteration 10, inertia 21350.55078125.
# Iteration 11, inertia 21339.69921875.
# Iteration 12, inertia 21329.734375.
# Iteration 13, inertia 21320.0078125.
# Iteration 14, inertia 21311.39453125.
# Iteration 15, inertia 21305.140625.
# Iteration 16, inertia 21299.88671875.
# Iteration 17, inertia 21295.75.
# Iteration 18, inertia 21292.34765625.
# Iteration 19, inertia 21289.6015625.
# Iteration 20, inertia 21287.076171875.
# Iteration 21, inertia 21284.630859375.
# Iteration 22, inertia 21282.376953125.
# Iteration 23, inertia 21280.123046875.
# Iteration 24, inertia 21277.919921875.
# Iteration 25, inertia 21275.78515625.
# Iteration 26, inertia 21273.884765625.
# Iteration 27, inertia 21271.9921875.
# Iteration 28, inertia 21269.931640625.
# Iteration 29, inertia 21267.984375.
# Iteration 30, inertia 21265.974609375.
# Iteration 31, inertia 21264.09765625.
# Iteration 32, inertia 21262.615234375.
# Iteration 33, inertia 21261.318359375.
# Iteration 34, inertia 21259.869140625.
# Iteration 35, inertia 21258.025390625.
# Iteration 36, inertia 21256.345703125.
# Iteration 37, inertia 21254.73828125.
# Iteration 38, inertia 21253.53515625.
# Iteration 39, inertia 21252.52734375.
# Iteration 40, inertia 21251.58203125.
# Iteration 41, inertia 21250.626953125.
# Iteration 42, inertia 21249.630859375.
# Iteration 43, inertia 21248.80078125.
# Iteration 44, inertia 21248.068359375.
# Iteration 45, inertia 21247.357421875.
# Iteration 46, inertia 21246.791015625.
# Iteration 47, inertia 21246.490234375.
# Iteration 48, inertia 21246.23828125.
# Iteration 49, inertia 21245.98046875.
# Iteration 50, inertia 21245.712890625.
# Iteration 51, inertia 21245.521484375.
# Iteration 52, inertia 21245.365234375.
# Iteration 53, inertia 21245.26171875.
# Iteration 54, inertia 21245.16796875.
# Iteration 55, inertia 21245.048828125.
# Iteration 56, inertia 21244.9453125.
# Iteration 57, inertia 21244.837890625.
# Iteration 58, inertia 21244.74609375.
# Iteration 59, inertia 21244.669921875.
# Iteration 60, inertia 21244.6171875.
# Iteration 61, inertia 21244.54296875.
# Iteration 62, inertia 21244.47265625.
# Iteration 63, inertia 21244.384765625.
# Iteration 64, inertia 21244.306640625.
# Iteration 65, inertia 21244.2265625.
# Iteration 66, inertia 21244.16796875.
# Iteration 67, inertia 21244.091796875.
# Iteration 68, inertia 21244.01171875.
# Iteration 69, inertia 21243.9765625.
# Iteration 70, inertia 21243.9375.
# Iteration 71, inertia 21243.90234375.
# Iteration 72, inertia 21243.8828125.
# Iteration 73, inertia 21243.8671875.
# Iteration 74, inertia 21243.8515625.
# Iteration 75, inertia 21243.8359375.
# Iteration 76, inertia 21243.810546875.
# Iteration 77, inertia 21243.78515625.
# Iteration 78, inertia 21243.765625.
# Iteration 79, inertia 21243.75390625.
# Iteration 80, inertia 21243.74609375.
# Iteration 81, inertia 21243.736328125.
# Iteration 82, inertia 21243.734375.
# Converged at iteration 82: strict convergence.

# %%
cluster_acc(all_clu_label, preds)
# Out:
# 0.46628277185844164

# %%
np.save(f'./cache/cluster/topk=1-cache-inov-make_nonliving26-clip-uk101.pth', preds)

# %%
np.load(f'./cache/cluster/topk=1-cache-inov-make_entity30-clip-uk206.pth.npy')
# Out:
# array([119, 119, 119, ...,  84, 121,  69], dtype=int32)

# %%
np.save(f'./cache/cluster/kmeans-{args.dataset}2.npy', preds)

# %%
from my_util_package.dino import vision_transformer as vits
from config import dino_pretrain_path
from sklearn.cluster import KMeans, MiniBatchKMeans
from my_util_package_oszsl.evaluation import cluster_acc

dino = vits.vit_base()
dino.load_state_dict(torch.load(dino_pretrain_path, map_location='cpu'))
dino = dino.to(args.device)

all_vfeatures = []
all_clu_label = []
with tqdm(total=len(loader_val)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_val):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with torch.no_grad():
            features = dino(images)
            features = F.normalize(features, dim=-1)
            all_vfeatures.append(deepcopy(features.cpu().numpy()))
            all_clu_label.append(deepcopy(label_clu.numpy()))
        pbar.update(1)
        
all_vfeatures = np.concatenate(all_vfeatures)
all_clu_label = np.concatenate(all_clu_label)

# %%
kmeans = KMeans(n_clusters=dataset.num_classes, random_state=0, n_init=10, max_iter=1000, verbose=1).fit(all_vfeatures)
preds = kmeans.labels_
acc = cluster_acc(all_clu_label, preds)

with open(f'./cache/dino/dino-{args.dataset}.pkl', 'wb') as f:
    f.dump({
        'all_vfeatures': all_vfeatures,
        'all_clu_label': all_clu_label,
        'acc': acc,
    }, f)

# %%
acc
# Out:
# 0.6281455482160476

# %%
for c in all_gt_label_voc.unique():
    select = (all_gt_label_voc==c)
    subset_features = torch.from_numpy(all_features[select]).to(args.device)
    subset_features = subset_features/subset_features.norm(dim=-1, keepdim=True)
    
    target_classifier = classifier[c].to(args.device).view(1, -1)
    target_classifier = target_classifier/target_classifier.norm(dim=-1, keepdim=True)
    
    sim_intra_img_text = subset_features@target_classifier.t()
    print(sim_intra_img_text.mean())
    
    sim_intra = subset_features@subset_features.t()
    mask = torch.ones_like(sim_intra)
    mask = torch.scatter(mask, 1, torch.arange(mask.size(0), device=args.device).view(-1, 1), 0).bool()
    intra_topk_ind, intra_topk_val = compute_knn_batch(subset_features.to(args.device), 
                                                       k=5, exclude_self=True, batch_size=512, 
                                                       device=args.device)

# %%
intra_topk_ind, intra_topk_val = compute_knn_batch(torch.from_numpy(all_features).to(args.device), 
                                                   k=5, exclude_self=True, batch_size=512, 
                                                   device=args.device)

# %%
for c in all_gt_label_voc.unique():
    select = (all_gt_label_voc==c)
    class_features = torch.from_numpy(all_features)[select].to(args.device)
    sim = class_features@class_features.t()
    mask = torch.ones_like(sim)
    mask = torch.scatter(mask, 1, torch.arange(mask.size(0), device=args.device).view(-1, 1), 0).bool()
    print(sim[mask].mean(dim=-1).mean())
    # intra_topk_ind, intra_topk_val = compute_knn_batch(torch.from_numpy(all_features)[select].to(args.device), 
    #                                                    k=5, exclude_self=True, batch_size=512, 
    #                                                    device=args.device)
