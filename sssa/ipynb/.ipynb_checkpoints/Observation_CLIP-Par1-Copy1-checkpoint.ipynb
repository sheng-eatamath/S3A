# %% [markdown]
# - observe image KNN
#
# - observe initial assignment performance
#
# - observe text distribution
#
# - observe vocab filtering performance w.r.t. different strategies

# %%
import sys
sys.path.append('/home/sheng/OSZSL/')
sys.path.append('/home/sheng/OSZSL/CLIP/')

import os
import json
import pickle
import math
from typing import Union, List
from pprint import pprint
from tqdm import tqdm
from copy import deepcopy
import numpy as np
from functools import reduce
from itertools import zip_longest
import seaborn as sns
from collections import Counter, defaultdict

import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from ipynb_utils import get_hier_datasets, get_classifier
import clip
from data.datasets import get_datasets_oszsl, build_transform

# %%
class Config:
    device = 'cuda:3'
    arch = 'ViT-B/16'
    dataset_name = 'make_nonliving26'
    n_sampled_classes = 100
    input_size = 224
    
    batch_size = 1024
    use_def = False
    # clip_checkpoint = '/home/sheng/MUST-output/make_nonliving26/classifier=false-em=model_ema-w_fair=0.2-conf=0.5-B128x2-test/checkpoint-current.pth'
    clip_checkpoint = None
    vocab_fpath = None #'wordnet_nouns_complete'
    f_classifier = None #'./cache/wordnet_classifier_complete.pth'
    
args = Config()

# %%
with open('../templates_small.json', 'rb') as f:
    templates = json.load(f)

if args.use_def:
    with open('../templates-def.json', 'rb') as f:
        templates = json.load(f)

def get_vocab(fpath=None):
    """
    Args:
        vocab: {`names`: list, `ids`: synset ids, `parents`: [{synset ids}]}
    """
    with open('/home/sheng/dataset/wordnet_nouns.pkl', 'rb') as f:
        vocab = pickle.load(f)
    if fpath is not None:
        with open(f'/home/sheng/dataset/{fpath}.pkl', 'rb') as f:
            vocab = pickle.load(f)
        
    # with open('/home/sheng/dataset/wordnet_nouns_no_abstract.pkl', 'rb') as f:
    #     vocab = pickle.load(f)
    return vocab

vocab = get_vocab(args.vocab_fpath)
templates = templates['imagenet']
classnames = vocab['names']
parents = vocab['parents']
defs = vocab['def']

# %% [markdown]
# ### build vocab

# %%
class Vocab:
    """ classname indexed vocab """
    def __init__(self, vocab):
        self.vocab = vocab
        self.indexing()
        ### {global_synset: global_names}
        self.mapping_ids_names = dict(zip(vocab['ids'], vocab['names']))
        # self.mapping_names_ids = dict(zip(vocab['names'], vocab['ids']))
        ### {local_idx: local_names}
        self.mapping_idx_names = dict(zip(range(len(self.classnames)), self.classnames))
        ### {local_names: local_idx}
        self.mapping_names_idx = dict(zip(self.classnames, range(len(self.classnames))))
        ### {global_synset: global_idx}
        self.mapping_ids_global_idx = dict(zip(vocab['ids'], range(len(vocab['ids']))))
        self.mapping_global_idx_ids = dict(zip(range(len(vocab['ids'])), vocab['ids']))
        
        ### {global_names: [global_idx]}
        self.vocab_mapping_names_idx = defaultdict(list)
        for k, v in zip(vocab['names'], range(len(vocab['names']))):
            self.vocab_mapping_names_idx[k].append(v)
            
        ### {local_idx: global_idx}
        self.mapping_idx_global_idx = {}
        for i in range(len(self)):
            self.mapping_idx_global_idx[i] = self.vocab_mapping_names_idx[self.mapping_idx_names[i]]

        return
    
    def __len__(self):
        return len(self.classnames)
    
    def __getitem__(self, idx):
        return self.classnames[idx]
    
    def indexing(self):
        self.classnames = sorted(list(set(self.vocab['names'])))
        ### global index retained
        # self.classnames = list(self.vocab['names'])
        return
    
def calibrate_vocab(vocab, method, **kwargs):
    if method == 'topk':
        K = kwargs['K']
    elif method == 'upperbound':
        synids = kwargs['classids']
        synids
        
def subsample_vocab(vocab, sampling_idx):
    """ [to revise] subsample vocab based on @sampling_idx on @vocab """
    assert len(sampling_idx)>0
    set_sampling_idx = set(sampling_idx)
    sub_vocab = deepcopy(vocab)
    sub_vocab.mapping_idx_ids = {k: v for k, v in vocab.mapping_idx_ids.items() if k in set_sampling_idx}
    sub_vocab.mapping_ids_idx = {v: k for k, v in sub_vocab.mapping_idx_ids.items()}
    set_sampling_ids = set(sub_vocab.mapping_ids_idx)
    sub_vocab.mapping_ids_names = {k: v for k, v in vocab.mapping_ids_names.items() if k in set_sampling_ids}
    sub_vocab.mapping_names_ids = {v: k for k, v in sub_vocab.mapping_ids_names.items()}
    return sub_vocab

# %%
vocab = Vocab(vocab=vocab)

# %% [markdown]
# ### load CLIP

# %%
""" from MUST """
from clip.simple_tokenizer import SimpleTokenizer as _Tokenizer
_tokenizer = _Tokenizer()

def tokenize(texts: Union[str, List[str]], context_length: int = 77, truncate: bool = False) -> torch.LongTensor:
    if isinstance(texts, str):
        texts = [texts]

    sot_token = _tokenizer.encoder["<|startoftext|>"]
    eot_token = _tokenizer.encoder["<|endoftext|>"]
    all_tokens = [[sot_token] + _tokenizer.encode(text) + [eot_token] for text in texts]
    result = torch.zeros(len(all_tokens), context_length, dtype=torch.long)

    for i, tokens in enumerate(all_tokens):
        if len(tokens) > context_length:
            if truncate:
                tokens = tokens[:context_length]
                tokens[-1] = eot_token
            else:
                raise RuntimeError(f"Input {texts[i]} is too long for context length {context_length}")
        result[i, :len(tokens)] = torch.tensor(tokens)

    return result

# %%
model, preprocess = clip.load(args.arch)
if args.clip_checkpoint:
    model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
model.to(args.device).eval()
input_resolution = model.visual.input_resolution
context_length = model.context_length
vocab_size = model.vocab_size

print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
print("Input resolution:", input_resolution)
print("Context length:", context_length)
print("Vocab size:", vocab_size)
# Out:
# Model parameters: 149,620,737
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %% [markdown]
# ### load dataset

# %%
transform_val = build_transform(is_train=False, args=args, train_config=None)
dataset_raw = get_datasets_oszsl(args, None, is_train=True, transform=transform_val, seed=1)
dataset = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_val, seed=1)

loader_val = torch.utils.data.DataLoader(dataset, num_workers=8, batch_size=args.batch_size, shuffle=False)

# %%
len(dataset.labels)==len(dataset.samples), \
np.unique(dataset.labels), np.unique(dataset.labels_transformed), \
dataset.num_classes

# %%
len(dataset_raw.labels)==len(dataset_raw.samples), \
np.unique(dataset_raw.labels), np.unique(dataset_raw.labels_transformed), \
dataset_raw.num_classes

# %% [markdown]
# ### build classifier

# %%
# if args.use_def:
#     batch_size = 64
#     with torch.no_grad():
#         zeroshot_weights = []
#         with tqdm(total=len(vocab.classnames)//batch_size) as pbar:
#             for idx_set, classname_set in zip(np.array_split(np.arange(len(vocab.classnames)), len(vocab.classnames)//batch_size), 
#                                      np.array_split(vocab.classnames, len(vocab.classnames)//batch_size)):
#                 # idx_set = [vocab.mapping_idx_global_idx[ii] for ii in idx_set]
#                 texts = [template.format(classname, defs[idx])[:77] for idx, classname in zip(idx_set, classname_set) for template in templates] #format with class
#                 texts = tokenize(texts).to(args.device) #tokenize
#                 class_embeddings = model.encode_text(texts) #embed with text encoder
#                 class_embeddings = class_embeddings.view(-1, len(templates), class_embeddings.size(-1))
#                 class_embeddings /= class_embeddings.norm(dim=-1, keepdim=True)
#                 class_embedding = class_embeddings.mean(dim=1)
#                 class_embedding /= class_embedding.norm()
#                 zeroshot_weights.append(class_embedding.cpu())

#                 pbar.update(1)

#     classifier = torch.cat(zeroshot_weights, dim=0)
#     torch.save(classifier, './cache/wordnet_classifier_def.pth') 
# else:
batch_size = 64
with torch.no_grad():
    zeroshot_weights = []
    with tqdm(total=len(vocab.classnames)//batch_size) as pbar:
        for classname_set in np.array_split(vocab.classnames, len(vocab.classnames)//batch_size):
            texts = [template.format(classname) for classname in classname_set for template in templates] #format with class
            texts = tokenize(texts).to(args.device) #tokenize
            class_embeddings = model.encode_text(texts) #embed with text encoder
            break
            class_embeddings = class_embeddings.view(-1, len(templates), class_embeddings.size(-1))
            class_embeddings /= class_embeddings.norm(dim=-1, keepdim=True)
            class_embedding = class_embeddings.mean(dim=1)
            class_embedding /= class_embedding.norm()
            zeroshot_weights.append(class_embedding.cpu())
            # break

            pbar.update(1)

# classifier = torch.cat(zeroshot_weights, dim=0)
# torch.save(classifier, './cache/wordnet_classifier_complete.pth')
# Out:
#   0%|          | 0/1049 [00:00<?, ?it/s]

# %%
def get_classifier(args):
    if args.use_def:
        classifier = torch.load('./cache/wordnet_classifier_def.pth')
    else:
        classifier = torch.load('./cache/wordnet_classifier.pth')
    classifier = classifier.to(args.device)
    return classifier

classifier = get_classifier(args)

# %% [markdown]
# ### CLIP performance investigation -- initial assignment

# %% [markdown]
# raw performance

# %%
classifier = get_classifier(args)
use_norm = True
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True) if use_norm else classifier
use_select = False

if use_select:
    quantile = 0.1
    selected = torch.from_numpy(np.load(f'./{args.dataset_name}-ent_selection-q={quantile}.npy'))

all_pred_voc = []
all_gt_voc = []
all_pred_voc_topk = []
all_img_features = []
with tqdm(total=len(loader_val)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_val):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                if use_select:
                    similarity = model.logit_scale.exp() * logits @ classifier[selected].t()
                else:
                    similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                all_pred_voc.append(prob.argmax(dim=-1).cpu())
                all_gt_voc.append(label_voc)
                all_pred_voc_topk.append(prob.topk(k=5, dim=-1).indices.cpu())
                all_img_features.append(logits.cpu().numpy())
        pbar.update(1)

all_pred_voc = torch.cat(all_pred_voc, dim=0)
if use_select:
    all_pred_voc = selected[all_pred_voc]
all_gt_voc = torch.cat(all_gt_voc, dim=0)
all_pred_voc_topk = torch.cat(all_pred_voc_topk, dim=0)
all_img_features = np.concatenate(all_img_features)
# Out:
# 100%|██████████| 5/5 [00:20<00:00,  4.02s/it]

# %%
print(f'acc={(all_pred_voc == all_gt_voc).float().mean()}')
# Out:
# acc=0.2531999945640564

# %%
### topK accuracy
for i in range(all_pred_voc_topk.size(1)):
    vec = torch.zeros(all_pred_voc_topk.size(0)).bool()
    for j in range(i+1):
        vec |= (all_pred_voc_topk[:, j]==all_gt_voc)
    print(f'k={i} acc={vec.float().mean()}')

# %% [markdown]
# topK performance

# %%
classifier = get_classifier(args)
use_soft = True
use_norm = True
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True) if use_norm else classifier
topK = 5
voc_beta = 5000
mapping_classifier = None

for voc_beta in [10000, 5000, 1000, 500]:
    """ compute distribution over classifier
    """
    vec_count = torch.zeros(classifier.size(0))
    all_gt_labels = []
    with tqdm(total=len(loader_val)) as pbar:
        model.eval()
        for idx_batch, batch in enumerate(loader_val):
            images, label_voc, label_clu, idx_img = batch
            images = images.to(args.device)
            all_gt_labels.append(label_voc)
            with amp_autocast():
                with torch.no_grad():
                    logits = model.visual(images)
                    logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                    similarity = model.logit_scale.exp() * logits @ classifier.t()
                    prob = similarity.softmax(-1)

                    topk_prob = prob.topk(k=topK, dim=-1)
                    topk_ind = topk_prob.indices
                    topk_val = topk_prob.values.flatten().cpu().numpy()
                    batch_counter = Counter(topk_ind.flatten().cpu().numpy())
                    if use_soft:
                        for i, k in enumerate(topk_ind.flatten().cpu().numpy()):
                            vec_count[k] += topk_val[i]
                    else:
                        for k, v in batch_counter.items():
                            vec_count[k] += v
            pbar.update(1)

    all_gt_labels = torch.cat(all_gt_labels, dim=0)
    all_valid_idx = vec_count.topk(k=voc_beta).indices
    if mapping_classifier is None:
        mapping_classifier = torch.tensor(sorted(all_valid_idx), device=args.device)
    else:
        mapping_classifier = torch.gather(mapping_classifier, 0, torch.tensor(sorted(all_valid_idx), device=args.device))
    mask = torch.zeros(classifier.size(0), device=args.device)
    mask = torch.scatter(mask, 0, torch.tensor(sorted(all_valid_idx), device=args.device), 1)
    classifier = classifier[mask.bool()]

    """ assignment on selected vocab
    """
    all_pred_voc = []
    all_gt_voc = []
    with tqdm(total=len(loader_val)) as pbar:
        model.eval()
        for idx_batch, batch in enumerate(loader_val):
            images, label_voc, label_clu, idx_img = batch
            images = images.to(args.device)
            all_gt_voc.append(label_voc)
            with amp_autocast():
                with torch.no_grad():
                    logits = model.visual(images)
                    logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                    similarity = model.logit_scale.exp() * logits @ classifier.t()
                    prob = similarity.softmax(-1)

                    pred_label = prob.argmax(dim=-1)
                    pred_label = torch.gather(mapping_classifier, 0, pred_label)
                    all_pred_voc.append(pred_label.cpu())

            pbar.update(1)

        all_pred_voc = torch.cat(all_pred_voc, dim=0)
        all_gt_voc = torch.cat(all_gt_voc, dim=0)
        print(f'acc={(all_pred_voc == all_gt_voc).float().mean()}')

        print(f'missing={len(set(all_gt_labels.cpu().numpy()) - set(mapping_classifier.cpu().numpy()))}')

# %%
sns.distplot(vec_count.topk(k=voc_beta*dataset.num_classes).values.cpu().numpy(), bins=100)

# %%
print(f'acc={(all_pred_voc == all_gt_voc).float().mean()}')

# %% [markdown]
# upperbound

# %%
classifier = get_classifier(args)
use_norm = True
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True) if use_norm else classifier

mask = torch.zeros(classifier.size(0), device=args.device)
mapping_classifier = torch.tensor(sorted(set(dataset.labels)), device=args.device)
mask = torch.scatter(mask, 0, mapping_classifier, 1)
classifier = classifier[mask.bool()]

all_pred_voc = []
all_gt_voc = []
with tqdm(total=len(loader_val)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_val):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                all_pred_voc.append(prob.argmax(dim=-1).cpu())
                all_gt_voc.append(label_voc)
        pbar.update(1)

all_pred_voc = torch.cat(all_pred_voc, dim=0)
all_gt_voc = torch.cat(all_gt_voc, dim=0)

all_pred_voc = torch.gather(mapping_classifier.cpu(), 0, all_pred_voc)

print(f'acc={(all_pred_voc == all_gt_voc).float().mean()}')

# %% [markdown]
# hierarchy accuracy

# %%
classifier = get_classifier(args)
use_norm = True
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True) if use_norm else classifier


all_pred_voc = []
all_gt_voc = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                all_pred_voc.append(prob.argmax(dim=-1).cpu())
                # label_voc = torch.tensor(list(map(lambda x: vocab.mapping_names_idx[x], label_voc)))
                all_gt_voc.append(label_voc)
        pbar.update(1)

all_pred_voc = torch.cat(all_pred_voc, dim=0)
all_gt_voc = torch.cat(all_gt_voc, dim=0)

# %%
mapping_i2gi = vocab.mapping_idx_global_idx
isin = lambda x, y: np.array([xx in y for xx in x])
all_pred_hier = []
for i in range(len(all_gt_voc)):
    cond1 = isin(mapping_i2gi[all_gt_voc[i].item()], reduce(lambda x,y: x|y, [parents[p] for p in mapping_i2gi[all_pred_voc[i].item()]])).any()
    cond2 = isin(mapping_i2gi[all_pred_voc[i].item()], reduce(lambda x,y: x|y, [parents[p] for p in mapping_i2gi[all_gt_voc[i].item()]])).any()
    pred_hier = cond1 | cond2
    all_pred_hier.append(pred_hier)

# %%
(all_pred_voc==all_gt_voc).float().mean()

# %% [markdown]
# KNN performance investigation

# %%
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
# classifier = F.normalize(classifier, dim=-1)

# %%
similarity = classifier@classifier.T

# %%
K = 5
topk_ind = similarity.topk(k=K+1).indices

# %%
list(map(lambda x: list(map(lambda y: classnames[y], x)), topk_ind.cpu().numpy().tolist()))

# %%
len(classnames)

# %% [markdown]
# ### SSL performance investigation

# %%
arch = 'vit_dino'
# arch = 'resnet_dino'

def load_checkpoint(arch, model_fpath=None):
    if arch == 'resnet_dino':
        ckpt = torch.load('/home/sheng/dino/cache/make_nonliving26-resnet50_test_E500/checkpoint.pth', map_location='cpu')
    elif arch == 'vit_dino':
        # ckpt = torch.load('/home/sheng/SimGCD/cache/checkpoints/checkpoint.pth', map_location='cpu')
        ckpt = torch.load('/home/sheng/OSZSL/cache/nonliving26_vitb16.pth', map_location='cpu')

    state_dict = {k[len('module.'):]: v for k, v in ckpt['student'].items() if k.startswith('module.')}
    state_dict = {k[len('backbone.'):]: v for k, v in state_dict.items() if k.startswith('backbone.')}
    if model_fpath is None:
        state_dict = torch.load('/home/sheng/dino/checkpoint/dino_vitbase16_pretrain.pth', map_location='cpu')
    else:
        state_dict = torch.load(model_fpath, map_location='cpu')
    return state_dict

state_dict = load_checkpoint(arch)
if arch == 'resnet_dino':
    modelf = torchvision.models.resnet50()
    modelf.load_state_dict(state_dict, strict=False)
    modelf.fc = nn.Identity()
elif arch == 'vit_dino':
    modelf = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
    modelf.load_state_dict(state_dict, strict=False)

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(256, interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.CenterCrop(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=1)
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=8, batch_size=args.batch_size, shuffle=False)
# Out:
# Using cache found in /home/sheng/.cache/torch/hub/facebookresearch_dino_main

# %% [markdown]
# clustering

# %%
""" SSL clustering acc """

from sklearn.cluster import KMeans

all_features = []
all_labels = []
all_idx_img = []
modelf = modelf.to(args.device)
modelf.eval()
with tqdm(total=len(loader_f)) as pbar:
    for batch in loader_f:
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        
        with torch.no_grad():
            features = modelf(images)
            features = F.normalize(features, dim=-1)
            
        all_features.append(features.detach().cpu())
        all_labels.append(label_clu)
        all_idx_img.append(idx_img)
        
        pbar.update(1)
        
all_features = torch.cat(all_features, dim=0)
all_labels = torch.cat(all_labels, dim=0)
all_idx_img = torch.cat(all_idx_img, dim=0)

# kmeans = KMeans(n_clusters=len(all_labels.unique()), n_init=100, max_iter=1000, random_state=43)
# pred_clu = kmeans.fit_predict(all_features.numpy())
# Out:
# 100%|██████████| 130/130 [06:12<00:00,  2.87s/it]

# %%
pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-vit_dino.npy'))

# %%
np.save(f'./pred_clu-{args.dataset_name}-train-{arch}.npy', pred_clu)
# pred_clu = np.load(f'./pred_clu-{args.dataset_name}-train-{arch}.npy')

# %%
def generate_ssl_knn(all_features, all_labels, K=100):
    all_features = all_features.cpu()
    all_labels = all_labels.cpu()
    all_sim = []
    N = all_features.size(0)
    batch_size = 10000
    sim_topK = []
    sim_topK_val = []
    with tqdm(total=math.ceil(N//batch_size)) as pbar:
        for i in range(math.ceil(N//batch_size)+1):
            sim = all_features[i*batch_size: min((i+1)*batch_size, N), :]@all_features.t()
            sim_topK.append( sim.topk(k=K).indices.numpy() )
            sim_topK_val.append( sim.topk(k=K).values.numpy() )
            pbar.update(1)
    sim_topK = np.concatenate(sim_topK)
    sim_topK_val = np.concatenate(sim_topK_val)
    label_sim_topK = all_labels[sim_topK.reshape(-1)].reshape(-1, K)
    label_match_sim_topK = all_labels.view(-1, 1)==label_sim_topK
    return sim_topK, sim_topK_val, label_sim_topK, label_match_sim_topK

sim_topK, sim_topK_val, label_sim_topK, label_match_sim_topK = generate_ssl_knn(all_features, all_labels, K=100)
# Out:
# 14it [00:30,  2.21s/it]

# %%
ssl_knn_info = {
    'sim_top100': sim_topK,
    'sim_top100_val': sim_topK_val,
    'label_sim_top100': label_sim_topK,
    'label_match_sim_top100': label_match_sim_topK,
}
torch.save(ssl_knn_info, f'./cache/ssl_knn_info-{args.dataset_name}.pth')

# %%
cond = torch.from_numpy(sim_topK_val)[:, 1:]>0.7
sns.distplot(((label_match_sim_topK[:, 1:]*cond).float().sum(dim=-1)/(cond.float().sum(dim=-1) + 1e-20))[cond.float().sum(dim=-1)!=0].numpy(), bins=100)
# Out:
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
cond.float().mean()
# Out:
# tensor(0.5125)

# %%
torch.where(sim_top100_val>0.8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 torch.where(sim_top100_val>0.8)
#
# NameError: name 'sim_top100_val' is not defined

# %%
import seaborn as sns
sns.distplot(label_match_sim_top100.float().mean(dim=-1).numpy(), bins=100)
# Out:
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(sim_top100_val[label_match_sim_top100].numpy(), bins=100)
sns.distplot(sim_top100_val[~label_match_sim_top100].numpy(), bins=100)
# Out:
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
match, sim.topk(k=100).indices
# Out:
# tensor([[     0,    934,    732,  ...,     59,    820,    592],
#         [     1,     97,    581,  ...,    519,    403,    647],
#         [     2,    330,    353,  ...,   1051,    169,    467],
#         ...,
#         [128887, 127735, 128426,  ..., 127644, 128880, 128095],
#         [128888, 128208, 128403,  ..., 128469, 128736, 128593],
#         [128889, 128846, 128770,  ..., 128047, 127629, 128595]])

# %%
from my_util_package.evaluation import cluster_acc

cluster_acc(pred_clu, all_labels.numpy())

# %%
from my_util_package.evaluation import cluster_acc

cluster_acc(pred_clu, all_labels.numpy())

# %% [markdown]
# CLIP clustering

# %%
pred_clu = np.load(f'./pred_clu-{args.dataset_name}-train-{arch}.npy')

# %%
""" CLIP clustering acc """

from sklearn.cluster import KMeans
from my_util_package.evaluation import cluster_acc

amp_autocast = torch.cuda.amp.autocast
all_features = []
all_labels = []
all_idx_img = []
modelf = modelf.to(args.device)
modelf.eval()
with tqdm(total=len(loader_f)) as pbar:
    for batch in loader_f:
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                features = model.visual(images)
                features = F.normalize(features, dim=-1)
                features = features/features.norm(dim=-1, keepdim=True)
        all_features.append(features.detach().cpu())
        all_labels.append(label_clu)
        all_idx_img.append(idx_img)
        
        pbar.update(1)
        
all_features = torch.cat(all_features, dim=0)
all_labels = torch.cat(all_labels, dim=0)
all_idx_img = torch.cat(all_idx_img, dim=0)

# print(cluster_acc(pred_clu, all_labels.numpy()))

kmeans = KMeans(n_clusters=len(all_labels.unique()), n_init=100, max_iter=1000, random_state=43)
pred_clu = kmeans.fit_predict(all_features.numpy())

# %%
pred_clu

# %%
np.save(f'./pred_clu-{args.dataset_name}-train-clip.npy', pred_clu)

# %% [markdown]
# Cluster navigation (depends on clustering)

# %%
""" topk prediction from CLIP """
classifier = get_classifier(args)
use_norm = True
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True) if use_norm else classifier

prob_k = 5
all_topk_voc = []
all_gt_voc = []
all_labels = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                pred_topk_scattered = torch.scatter(torch.zeros([images.size(0), classifier.size(0)], 
                                                                device=args.device), 1, prob_topk_ind, 1)
                all_topk_voc.append(pred_topk_scattered.cpu())
                all_gt_voc.append(label_voc)
        pbar.update(1)

all_topk_voc = torch.cat(all_topk_voc, dim=0)
all_gt_voc = torch.cat(all_gt_voc, dim=0)

# %%
from scipy.optimize import linear_sum_assignment as linear_assignment

### per predicted-cluster voting
pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-{arch}.npy'))

pred_kmeans_t = pred_kmeans
# for it in range(10):
#     print(f'iteration {it}')

# cluster agg
all_clu_pred = []
for i in range(len(all_gt_voc.unique())):
    selected = (pred_kmeans==i)
    clu_pred = F.normalize(all_topk_voc[selected].sum(dim=0), dim=-1, p=1)
    all_clu_pred.append(clu_pred)
all_clu_pred = torch.stack(all_clu_pred, dim=0)

# linear assignment
print('is mutex assignment::', all_clu_pred.argmax(dim=-1).size(0)==all_clu_pred.argmax(dim=-1).unique().size(0))
print('assignment collision num::', len(list(filter(lambda x: x>1, Counter(all_clu_pred.argmax(dim=-1).numpy()).values()))))

cost_mat = all_clu_pred.cpu().numpy()
res_ass = linear_assignment(cost_mat.max() - cost_mat)
label_kmeans_voc = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])

print('instance label acc::', (label_kmeans_voc==all_gt_voc).float().mean().item())

# %%
prob_k = 5
all_topk_voc = []
all_gt_voc = []
all_labels = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                pred_topk_scattered = torch.scatter(torch.zeros([images.size(0), classifier.size(0)], 
                                                                device=args.device), 1, prob_topk_ind, 1)
                all_topk_voc.append(pred_topk_scattered.cpu())
                all_gt_voc.append(label_voc)
        pbar.update(1)

all_topk_voc = torch.cat(all_topk_voc, dim=0)
all_gt_voc = torch.cat(all_gt_voc, dim=0)

# %%
### subset vocab
col_subset = all_clu_pred.nonzero()[:, 1]
col_subset = col_subset.unique().sort().values

# %% [markdown]
# KNN investigation

# %%
neighborhood_size = np.arange(5, 500, 5)
similarity = all_features@all_features.T
label_match = all_labels.view(-1, 1)==all_labels.view(1, -1)
for K in neighborhood_size:
    topk_res = similarity.topk(k=K+1)
    topk_ind = topk_res.indices[:, 1:]
    topk_match = torch.gather(label_match, 1, topk_ind)
    topk_acc = topk_match.float().mean(dim=-1).mean()
    print(f'K={K} acc={topk_acc}')

# %%
from my_util_package.graph import compute_consensus_on_features
neighborhood_size = np.arange(5, 50, 5)
similarity = all_features@all_features.T
label_match = all_labels.view(-1, 1)==all_labels.view(1, -1)
for K in neighborhood_size:
    _, _, pred_affinity = compute_consensus_on_features(all_features, k=K+1, q=0.8)
    acc = ((pred_affinity & label_match).float().sum(1)/(pred_affinity.float().sum(1)+1e-10)).mean()
    n_nn = pred_affinity.float().sum(1).mean()
    print(f'K={K} acc={acc} n_nn={n_nn}')

# %%
neighborhood_size = np.arange(5, 50, 5)
similarity = all_features@all_features.T
label_match = all_labels.view(-1, 1)==all_labels.view(1, -1)
for K in neighborhood_size:
    _, _, pred_affinity = compute_consensus_on_features(all_features, k=K+1, q=0.5)
    acc = ((pred_affinity & label_match).float().sum(1)/(pred_affinity.float().sum(1)+1e-10)).mean()
    n_nn = pred_affinity.float().sum(1).mean()
    print(f'K={K} acc={acc} n_nn={n_nn}')

# %%
""" KNN matrix output """
neighborhood_size = 315
similarity = all_features@all_features.T
label_match = (all_labels.view(-1, 1)==all_labels.view(1, -1))
K = neighborhood_size
topk_res = similarity.topk(k=K+1)
topk_ind = topk_res.indices

torch.save(topk_ind, f'./cache/{args.dataset_name}-clip-knn-{neighborhood_size}.pth')

# %% [markdown]
# ### SCD

# %%
from sklearn.cluster import KMeans
from my_util_package.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment

subset = ['train', 'val'][0]
modelf = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
arch = 'vit_dino'

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(256, interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.CenterCrop(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
if subset == 'train':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=1)
elif subset == 'val':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=1)
args.nb_classes = dataset_f.num_classes
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=8, batch_size=args.batch_size, shuffle=False)

if subset == 'train':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-{arch}.npy'))
elif subset == 'val':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-val-{arch}.npy'))
# Out:
# Using cache found in /home/sheng/.cache/torch/hub/facebookresearch_dino_main

# %%
model, preprocess = clip.load(args.arch)
if args.clip_checkpoint:
    model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
model.to(args.device).eval()
input_resolution = model.visual.input_resolution
context_length = model.context_length
vocab_size = model.vocab_size

print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
print("Input resolution:", input_resolution)
print("Context length:", context_length)
print("Vocab size:", vocab_size)
# Out:
# Model parameters: 149,620,737
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %%
""" topk prediction from CLIP """
classifier = get_classifier(args)
use_norm = True
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True) if use_norm else classifier

# initial topK prediction from CLIP
prob_k = 5
all_topk_voc = []
all_gt_voc = []
all_prob = []
all_label_clu = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                pred_topk_scattered = torch.scatter(torch.zeros([images.size(0), classifier.size(0)], 
                                                                device=args.device), 1, prob_topk_ind, 1)
                # all_prob.append(prob.cpu())
                all_topk_voc.append(pred_topk_scattered.cpu())
                all_gt_voc.append(label_voc)
                all_label_clu.append(label_clu)
        pbar.update(1)

# all_prob = torch.cat(all_prob, dim=0)
all_topk_voc = torch.cat(all_topk_voc, dim=0)
all_gt_voc = torch.cat(all_gt_voc, dim=0)
all_label_clu = torch.cat(all_label_clu, dim=0)
# Out:
# 100%|██████████| 126/126 [02:59<00:00,  1.43s/it]

# %%
# cluster agg
def agg_by_pred_cluster(args, pred_kmeans, all_topk_voc):
    all_clu_pred = []
    for i in range(args.nb_classes):
        selected = (pred_kmeans==i)
        clu_pred = F.normalize(all_topk_voc[selected].sum(dim=0), dim=-1, p=1)
        all_clu_pred.append(clu_pred)
    all_clu_pred = torch.stack(all_clu_pred, dim=0)
    print('is mutex assignment::', all_clu_pred.argmax(dim=-1).size(0)==all_clu_pred.argmax(dim=-1).unique().size(0))
    print('assignment collision num::', len(list(filter(lambda x: x>1, Counter(all_clu_pred.argmax(dim=-1).numpy()).values()))))
    return all_clu_pred

def linear_assign(all_clu_pred, pred_kmeans, all_gt_voc):
    cost_mat = all_clu_pred.cpu().numpy()
    res_ass = linear_assignment(cost_mat.max() - cost_mat)
    label_voc_kmeans = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])
    print('instance label acc::', (label_voc_kmeans==all_gt_voc).float().mean().item())
    return label_voc_kmeans, res_ass

def reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, args, all_prob=None):
    label_voc_kmeans = label_voc_kmeans.to(args.device)
    if all_prob is None:
        cluster_ind = []
        with tqdm(total=len(loader_f)) as pbar:
            model.eval()
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch
                images = images.to(args.device)
                with amp_autocast():
                    with torch.no_grad():
                        logits = model.visual(images)
                        logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                        similarity = model.logit_scale.exp() * logits @ classifier.t()
                        prob = similarity.softmax(-1)
                        cluster_ind.append(prob[:, label_voc_kmeans].cpu().argmax(dim=-1))
                pbar.update(1)
        cluster_ind = torch.cat(cluster_ind, dim=0)
    else:
        all_prob = all_prob[:, label_voc_kmeans]
        cluster_ind = all_prob.argmax(dim=-1)
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind

# %%
def agg_by_pred_cluster(args, pred_kmeans, all_topk_voc, voc_size):
    """
    Args:
        pred_kmeans: np.array([N])
        all_topk_voc: np.array([N x K])
        voc_size: int
    Returns:
        all_clu_pred: tensor([C x V])
    """
    print('agg_by_pred_cluster')
    all_clu_pred = []
    for i in np.unique(pred_kmeans):
        selected = (pred_kmeans==i)
        n_count = selected.sum().item()
        counter_voc_ind, counter_val = np.unique((all_topk_voc[selected]).ravel(), return_counts=True)
        counter_val = counter_val/(n_count+1e-20) # L1 norm
        clu_pred = torch.zeros(args.num_voc) # cluster-wise prob
        clu_pred[torch.from_numpy(counter_voc_ind).long()] = torch.from_numpy(counter_val).float()
        # clu_pred = F.normalize(all_topk_voc[selected].sum(dim=0), dim=-1, p=1)
        all_clu_pred.append(clu_pred)
    all_clu_pred = torch.stack(all_clu_pred, dim=0).cpu()
    print('is mutex assignment::', all_clu_pred.argmax(dim=-1).size(0)==all_clu_pred.argmax(dim=-1).unique().size(0))
    print('assignment collision num::', len(list(filter(lambda x: x>1, Counter(all_clu_pred.argmax(dim=-1).numpy()).values()))))
    return all_clu_pred

def linear_assign(all_clu_pred, pred_kmeans, all_gt_voc):
    print('linear_assign')
    cost_mat = all_clu_pred.cpu().numpy()
    print(f'assignment shape={cost_mat.shape}')
    res_ass = linear_assignment(cost_mat.max() - cost_mat)
    label_voc_kmeans = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])
    print('instance label acc::', (label_voc_kmeans==all_gt_voc).float().mean().item())
    return label_voc_kmeans, res_ass

def reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, device, all_prob=None, instance_selected=None):
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device)
    if all_prob is None:
        cluster_ind = []
        with tqdm(total=len(loader_f)) as pbar:
            if hasattr(model, 'eval'):
                model.eval()
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                if (instance_selected is not None) and ((~instance_selected[idx_img]).all()):
                    continue
                with amp_autocast():
                    with torch.no_grad():
                        if (instance_selected is not None):
                            logits = model.visual(images[instance_selected[idx_img]])
                        else:
                            logits = model.visual(images)
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        similarity = 100 * logits @ classifier.t()
                        prob = similarity.softmax(-1)
                        cluster_ind.append(prob[:, label_voc_kmeans].cpu().argmax(dim=-1))
                pbar.update(1)
        cluster_ind = torch.cat(cluster_ind, dim=0)
    else:
        all_prob = all_prob[:, label_voc_kmeans]
        cluster_ind = all_prob.argmax(dim=-1)
    cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc

# %%
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
amp_autocast = torch.cuda.amp.autocast
### collect variables
prob_k = 5
all_topk_voc = []
all_gt_voc = []
all_label_clu = []
with tqdm(total=len(loader_f)) as pbar:
    if hasattr(model, 'eval'):
        model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch[:4]
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = 100 * logits @ classifier.t()
                prob = similarity.softmax(-1)
                prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                all_topk_voc.append(prob_topk_ind.cpu().numpy())
                all_gt_voc.append(label_voc)
                all_label_clu.append(label_clu)
        pbar.update(1)

all_topk_voc = np.concatenate(all_topk_voc)
all_gt_voc = torch.cat(all_gt_voc, dim=0)
all_label_clu = torch.cat(all_label_clu, dim=0)

# pred_kmeans = torch.from_numpy(np.load(f'/home/sheng/OSZSL/ipynb/pred_clu-{args.dataset_name}-train-vit_dino-dino_stage1.npy'))
pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-vit_dino.npy'))
pred_kmeans_t = pred_kmeans
history_set_pred = []
for t in range(3):
    all_clu_pred = agg_by_pred_cluster(args, pred_kmeans_t.numpy(), all_topk_voc, voc_size=args.num_voc)
    label_voc_kmeans, res_ass = linear_assign(all_clu_pred, pred_kmeans_t, all_gt_voc)
    pred_kmeans_t, cluster_ind_voc = reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, args.device, all_prob=None)
    set_pred = set(res_ass[1].tolist())
    set_gt = set(all_gt_voc.unique().numpy().tolist())
    print('missing label::', len(set_gt - set_pred))
    print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=pred_kmeans_t.numpy()))
    history_set_pred.append(set_pred)
# Out:
# 100%|██████████| 126/126 [02:52<00:00,  1.37s/it]
# agg_by_pred_cluster
# is mutex assignment:: False
# assignment collision num:: 3
# linear_assign
# assignment shape=(99, 67174)
# instance label acc:: 0.370339035987854
# reassign_by_pred_cluster
# 100%|██████████| 126/126 [03:24<00:00,  1.62s/it]
# missing label:: 53
# cluster acc 0.8070059740864303
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# assignment shape=(99, 67174)
# instance label acc:: 0.41430675983428955
# reassign_by_pred_cluster
# 100%|██████████| 126/126 [03:28<00:00,  1.66s/it]
# missing label:: 53
# cluster acc 0.8068430444565133
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# assignment shape=(99, 67174)
# instance label acc:: 0.4144464135169983
# reassign_by_pred_cluster
# 100%|██████████| 126/126 [03:25<00:00,  1.63s/it]
# missing label:: 53
# cluster acc 0.8068740786717356

# %%
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
amp_autocast = torch.cuda.amp.autocast
### >>>
use_select = True
if use_select:
    quantile = 0.1
    selected = torch.from_numpy(np.load(f'./{args.dataset_name}-ent_selection-q={quantile}.npy'))
else:
    selected = None
### <<<
    
### collect variables
prob_k = 5
all_topk_voc = []
all_gt_voc = []
all_label_clu = []
with tqdm(total=len(loader_f)) as pbar:
    if hasattr(model, 'eval'):
        model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch[:4]
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                if use_select:
                    similarity = 100 * logits @ classifier[selected].t()
                else:
                    similarity = 100 * logits @ classifier.t()
                prob = similarity.softmax(-1)
                prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                all_topk_voc.append(prob_topk_ind.cpu().numpy())
                all_gt_voc.append(label_voc)
                all_label_clu.append(label_clu)
        pbar.update(1)

all_topk_voc = np.concatenate(all_topk_voc)
all_gt_voc = torch.cat(all_gt_voc, dim=0)
all_label_clu = torch.cat(all_label_clu, dim=0)

pred_kmeans = torch.from_numpy(np.load(f'/home/sheng/OSZSL/ipynb/pred_clu-{args.dataset_name}-train-vit_dino.npy'))
pred_kmeans_t = pred_kmeans
for t in range(3):
    all_clu_pred = agg_by_pred_cluster(args, pred_kmeans_t.numpy(), all_topk_voc, voc_size=selected.size(0) if selected is not None else args.num_voc)
    label_voc_kmeans, res_ass = linear_assign(all_clu_pred, pred_kmeans_t, all_gt_voc, selected=selected)
    pred_kmeans_t, cluster_ind_voc = reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, args.device, selected=selected)
    set_pred = set(res_ass[1].tolist())
    set_gt = set(all_gt_voc.unique().numpy().tolist())
    print('missing label::', len(set_gt - set_pred))
    print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=pred_kmeans_t.numpy()))
# Out:
# 100%|██████████| 126/126 [02:44<00:00,  1.30s/it]
# agg_by_pred_cluster
# is mutex assignment:: False
# assignment collision num:: 3
# linear_assign
# instance label acc:: 0.3761734664440155
# reassign_by_pred_cluster
# 100%|██████████| 126/126 [03:01<00:00,  1.44s/it]
# missing label:: 99
# cluster acc 0.7995810380944992
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# instance label acc:: 0.4146093428134918
# reassign_by_pred_cluster
# 100%|██████████| 126/126 [03:08<00:00,  1.49s/it]
# missing label:: 99
# cluster acc 0.797416401582745
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# instance label acc:: 0.41451624035835266
# reassign_by_pred_cluster
# 100%|██████████| 126/126 [02:59<00:00,  1.43s/it]
# missing label:: 99
# cluster acc 0.7974319186903561

# %%
print('linear_assign')
cost_mat = all_clu_pred.cpu().numpy()
res_ass = linear_assignment(cost_mat.max() - cost_mat)
label_voc_kmeans = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])

print('instance label acc::', (label_voc_kmeans==all_gt_voc).float().mean().item())
# Out:
# linear_assign
# instance label acc:: 0.0

# %%
(selected[label_voc_kmeans]==all_gt_voc).float().mean().item()
# Out:
# 0.37210801243782043

# %%
# pred_kmeans_t = pred_kmeans
# for t in range(5):
#     all_clu_pred = agg_by_pred_cluster(args, pred_kmeans_t, all_topk_voc)
#     label_voc_kmeans, res_ass = linear_assign(all_clu_pred, pred_kmeans_t, all_gt_voc)
#     pred_kmeans_t = reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, args, all_prob=None)
#     set_pred = set(res_ass[1].tolist())
#     set_gt = set(all_gt_voc.unique().numpy().tolist())
#     print('missing label::', len(set_gt - set_pred))
#     print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=pred_kmeans_t.numpy()))


""" get confident prediction """
th = 0.5
amp_autocast = torch.cuda.amp.autocast
label_voc_kmeans_t = label_voc_kmeans_t.to(args.device)
cluster_ind = []
selected_ind = []
with tqdm(total=len(loader_f)) as pbar:
    if hasattr(model, 'eval'):
        model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch[:4]
        images = images.to(device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = 100 * logits @ classifier.t()
                prob = similarity[:, label_voc_kmeans_t].softmax(dim=-1)
                selected = (prob.amax(dim=-1)>th)
                selected_ind.append(selected.cpu())
        pbar.update(1)
selected_ind = torch.cat(selected_ind, dim=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 15>()
#      13 th = 0.5
#      14 amp_autocast = torch.cuda.amp.autocast
# ---> 15 label_voc_kmeans_t = label_voc_kmeans_t.to(args.device)
#      16 cluster_ind = []
#      17 selected_ind = []
#
# NameError: name 'label_voc_kmeans_t' is not defined

# %%
precision = cluster_acc(y_true=all_label_clu[selected_ind].numpy(), y_pred=pred_kmeans_t[selected_ind].numpy())
recall = selected_ind.mean()
print(f'confidence selection precision={precision} recall={recall}')

# %%
np.save(f'./pred_clu_clip-{args.dataset_name}-train-{arch}.npy', pred_kmeans_t.cpu().numpy())

# %%
""" 
1. inverse entropy of prototype

2. top1 sim of proto-image

3. top1 sim of image-proto

"""
# candidate_ind = res_ass[1].unique()
# cls_proto_similarity = torch.zeros([len(dataset_f), candidate_ind.size()])
all_sim_proto_image_pred = []
all_sim_proto_image_gt = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        label_voc = label_voc.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(dim=-1)
                all_sim_proto_image_pred.append(similarity[:, prob.argmax(dim=-1)].cpu())
                all_sim_proto_image_gt.append(similarity[:, label_voc].cpu())
        pbar.update(1)
        
all_sim_proto_image_pred = torch.cat(all_sim_proto_image_pred, dim=0)
all_sim_proto_image_gt = torch.cat(all_sim_proto_image_gt, dim=0)

# %%
all_sim_proto_image_pred = torch.cat(all_sim_proto_image_pred, dim=0)
all_sim_proto_image_gt = torch.cat(all_sim_proto_image_gt, dim=0)

# %%
label_match = all_label_clu.view(-1, 1)@all_label_clu.view(1, -1)
pred_match_init = pred_kmeans.view(-1, 1)@pred_kmeans.view(1, -1)
pred_match = pred_kmeans_t.view(-1, 1)@pred_kmeans_t.view(1, -1)

# %%
pred_consensus = (pred_match_init==pred_match) 
((pred_consensus & label_match).float().sum(dim=-1) / (pred_consensus.sum(dim=-1)+1e-20)).mean()

# %%
(pred_consensus & label_match).float().sum(dim=-1).bool().float().mean()

# %%
all_clu_pred

# %% [markdown]
# ### Visualization

# %%
from sklearn.cluster import KMeans
from my_util_package.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment

subset = ['train', 'val'][0]
modelf = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
arch = 'vit_dino'

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(256, interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.CenterCrop(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
if subset == 'train':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=1)
elif subset == 'val':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=1)
args.nb_classes = dataset_f.num_classes
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=8, batch_size=args.batch_size, shuffle=False)

if subset == 'train':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-{arch}.npy'))
elif subset == 'val':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-val-{arch}.npy'))
    
model, preprocess = clip.load(args.arch)
if args.clip_checkpoint:
    model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
model.to(args.device).eval()
# Out:
# Using cache found in /home/sheng/.cache/torch/hub/facebookresearch_dino_main
# CLIP(
#   (visual): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16), bias=False)
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): Sequential(
#         (0): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (ln_post): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer): Transformer(
#     (resblocks): Sequential(
#       (0): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (7): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (8): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (9): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (10): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (11): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (token_embedding): Embedding(49408, 512)
#   (ln_final): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
# )

# %% [markdown]
# collect variables

# %%
model, preprocess = clip.load(args.arch)
if args.clip_checkpoint:
    model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
model.to(args.device).eval()
input_resolution = model.visual.input_resolution
context_length = model.context_length
vocab_size = model.vocab_size

print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
print("Input resolution:", input_resolution)
print("Context length:", context_length)
print("Vocab size:", vocab_size)
# Out:
# Model parameters: 149,620,737
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %%
""" topk prediction from CLIP """
classifier = get_classifier(args)
use_norm = True
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True) if use_norm else classifier

# initial topK prediction from CLIP
prob_k = 5
all_topk_voc = []
all_gt_voc = []
all_prob = []
all_max_ind = []
all_topk_vocinds = []
all_label_clu = []
all_topk_vals = []
all_topk_inds = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True) if use_norm else logits
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                pred_topk_scattered = torch.scatter(torch.zeros([images.size(0), classifier.size(0)], 
                                                                device=args.device), 1, prob_topk_ind, 1)
                # all_prob.append(prob.cpu())
                all_topk_voc.append(pred_topk_scattered.cpu())
                all_gt_voc.append(label_voc)
                all_label_clu.append(label_clu)
                all_max_ind.append(prob.argmax(dim=-1).cpu())
                all_topk_vocinds.append(prob.topk(k=10, dim=-1).indices.cpu())
                
                batch_topk_res = prob.topk(k=20, dim=-1)
                all_topk_vals.append(batch_topk_res.values.cpu())
                all_topk_inds.append(batch_topk_res.indices.cpu())
        pbar.update(1)

# all_prob = torch.cat(all_prob, dim=0)
all_topk_voc = torch.cat(all_topk_voc, dim=0)
all_gt_voc = torch.cat(all_gt_voc, dim=0)
all_label_clu = torch.cat(all_label_clu, dim=0)
all_max_ind = torch.cat(all_max_ind, dim=0)
all_topk_vocinds = torch.cat(all_topk_vocinds, dim=0)
all_topk_vals = torch.cat(all_topk_vals, dim=0)
all_topk_inds = torch.cat(all_topk_inds, dim=0)

# %% [markdown]
# text proto inspection

# %%
### KNN proto analysis
text_sim = classifier[all_gt_voc.unique(), :]@classifier.t()

# %%
text_topk = text_sim.topk(k=20)

# %%
pprint(np.array([vocab.mapping_idx_names[t.item()] for t in text_topk.indices[:, :].flatten().cpu()]).reshape(text_sim.size(0), -1).tolist(), compact=True)

# %%
import seaborn as sns 

sns.distplot(all_topk_vals[:, 0].cpu().numpy(), bins=200)
sns.distplot(all_topk_vals[:, 1].cpu().numpy(), bins=200)
sns.distplot(all_topk_vals[:, 2].cpu().numpy(), bins=200)

# %%
selected = (all_topk_vals[:, 0]>0.7)
'top1 acc', (all_gt_voc[selected] == all_max_ind[selected]).float().mean(), \
'selected percentile', selected.float().mean(), \
'class diversity', len(set(all_gt_voc.unique().numpy()) - set(all_max_ind[selected].unique().numpy())), \
'topk inclusion', torch.stack([all_topk_vocinds[selected, i]==all_gt_voc[selected] for i in range(all_topk_vocinds.size(1))], dim=1).float().sum(dim=-1).bool().float().mean(), \
'selected sample pred voc size', len(all_max_ind[selected].unique()), \
'average selected instance number per class', selected.sum()/len(all_gt_voc.unique()),

# %%
pred_kmeans_t

# %%
""" initial clip assignment """
list(filter(lambda x: x[1]<100, [(i.item(), (all_max_ind==i).sum().item()) for i in all_gt_voc.unique()]))

# %% [markdown]
# text to image entropy

# %%
amp_autocast = torch.cuda.amp.autocast
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)

### get all label and predicted label
all_label_voc = []
all_pred_voc = []
all_label_clu = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                pred_voc = prob.argmax(dim=-1)
        all_label_voc.append(label_voc)
        all_pred_voc.append(pred_voc.cpu())
        all_label_clu.append(label_clu)
        pbar.update(1)
all_label_voc = torch.cat(all_label_voc, dim=0)
all_pred_voc = torch.cat(all_pred_voc, dim=0)
all_label_clu = torch.cat(all_label_clu, dim=0)

                
### compute entropy
set_all_label_voc = all_label_voc.unique()
set_all_pred_voc = all_pred_voc.unique()
selected_classifier_ind = torch.cat([set_all_label_voc, set_all_pred_voc], dim=0).unique()
all_similarity = []
all_selected_sim = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        label_voc = label_voc.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                all_selected_sim.append(similarity[:, selected_classifier_ind].cpu())
                all_similarity.append(similarity.cpu().numpy())
        pbar.update(1)
        
all_selected_sim = torch.cat(all_selected_sim, dim=0)
all_similarity = np.concatenate(all_similarity)
# Out:
# 100%|██████████| 126/126 [05:34<00:00,  2.66s/it]
# 100%|██████████| 126/126 [05:44<00:00,  2.74s/it]

# %%
pred_kmeans_t = torch.from_numpy(np.load(f'./pred_clu_clip-{args.dataset_name}-train-{arch}.npy'))
classwise_all_selected_sim = []
for c in pred_kmeans_t.unique():
    subset = (pred_kmeans_t==c)
    classwise_all_selected_sim.append(all_selected_sim[subset, :].mean(dim=0).cpu())
classwise_all_selected_sim = torch.stack(classwise_all_selected_sim, dim=0)
p = classwise_all_selected_sim.float().softmax(dim=0)
ent = (-p*(p+1e-10).log2()).sum(dim=0)

# %%
from scipy.special import softmax
pred_kmeans_t = torch.from_numpy(np.load(f'./pred_clu_clip-{args.dataset_name}-train-{arch}.npy'))
classwise_all_sim = []
for c in pred_kmeans_t.unique():
    subset = (pred_kmeans_t==c)
    classwise_all_sim.append(all_similarity[subset, :].mean(axis=0))
classwise_all_sim = np.stack(classwise_all_sim)
classwise_all_sim = torch.from_numpy(classwise_all_sim).float()
p_all = classwise_all_sim.softmax(dim=0)
ent_all = (-p_all*(p_all+1e-10).log2()).sum(dim=0)

# %%
ent = torch.nan_to_num(ent)
ent_gt = ent[torch.isin(selected_classifier_ind, set_all_label_voc)]
ent_pred = ent[torch.isin(selected_classifier_ind, set_all_pred_voc)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(dpi=128)
sns.distplot(ent_gt.numpy(), bins=100)
sns.distplot(ent_pred.numpy(), bins=100)
sns.distplot(ent_all, bins=100)
# Out:
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
(ent_gt>2).sum(), (ent_gt>3).sum(), \
(ent_pred<2).sum(), (ent_pred<3).sum()
# Out:
# (tensor(14), tensor(9), tensor(3176), tensor(4867))

# %%
(ent_gt>2).sum(), (ent_gt>3).sum(), \
(ent_pred<2).sum(), (ent_pred<3).sum()
# Out:
# (tensor(14), tensor(9), tensor(3176), tensor(4867))

# %%
a = np.load(f'./pred_clu-make_nonliving26-train-vit_dino-dino_stage1.npy')
b = np.load(f'./pred_clu-make_nonliving26-train-vit_dino.npy')

# %%
""" select valid indices with quantile """
quantile = 0.3
q = np.quantile(ent_all, q=quantile)
selected = np.where(ent_all<q)[0]
unselected = np.where(ent_all>q)[0]

print(np.isin(all_label_voc.unique().numpy(), unselected).sum(), selected)

np.save(f'./{args.dataset_name}-ent_selection-q={quantile}.npy', selected)
# Out:
# 3 [   26    39    40 ... 67167 67168 67169]

# %% [markdown]
# visualize matching distribution

# %%
# amp_autocast = torch.cuda.amp.autocast
# classifier = get_classifier(args)
# classifier = classifier/classifier.norm(dim=-1, keepdim=True)

# ### random sampling
# all_inds = []
# all_gt_labels = []
# with tqdm(total=len(loader_f)) as pbar:
#     model.eval()
#     for idx_batch, batch in enumerate(loader_f):
#         images, label_voc, label_clu, idx_img = batch
#         all_gt_labels.append(label_voc)
#         all_inds.append(idx_img)
        
#         pbar.update(1)
# all_gt_labels = torch.cat(all_gt_labels, dim=0)
# all_inds = torch.cat(all_inds, dim=0)

# all_selected = torch.zeros(len(all_inds)).bool()
# with tqdm(total=len(all_gt_labels.unique())) as pbar:
#     for c in all_gt_labels.unique():
#         selected = (all_gt_labels==c)
#         subset = selected.nonzero()
#         selected = torch.from_numpy(np.random.permutation(len(all_inds[selected]))[:100])
#         all_selected[subset[selected]] = True
        
#         pbar.update(1)

### collect variables for selected instances
selected_features = []
selected_voc_labels = []
selected_knn_labels = []
selected_clu_labels = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        if (~all_selected[idx_img]).all():
            continue
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images[all_selected[idx_img]])
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                pred_voc = prob.argmax(dim=-1)
        selected_features.append(logits.cpu())
        selected_voc_labels.append(label_voc[all_selected[idx_img]])
        selected_knn_labels.append(pred_voc.cpu())
        selected_clu_labels.append(label_clu[all_selected[idx_img]])
        pbar.update(1)
selected_features = torch.cat(selected_features, dim=0)
selected_voc_labels = torch.cat(selected_voc_labels, dim=0)
selected_knn_labels = torch.cat(selected_knn_labels, dim=0)
selected_clu_labels = torch.cat(selected_clu_labels, dim=0)
# Out:
# 100%|██████████| 126/126 [01:57<00:00,  1.08it/s]

# %%
selected_classifier = classifier[torch.cat([selected_voc_labels, selected_knn_labels], dim=0).unique(), :]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, verbose=2)
ftr = tsne.fit_transform(torch.cat([selected_features, selected_classifier.cpu()], dim=0).cpu().numpy())
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 13000 samples in 0.004s...
# [t-SNE] Computed neighbors for 13000 samples in 3.693s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13000
# [t-SNE] Computed conditional probabilities for sample 2000 / 13000
# [t-SNE] Computed conditional probabilities for sample 3000 / 13000
# [t-SNE] Computed conditional probabilities for sample 4000 / 13000
# [t-SNE] Computed conditional probabilities for sample 5000 / 13000
# [t-SNE] Computed conditional probabilities for sample 6000 / 13000
# [t-SNE] Computed conditional probabilities for sample 7000 / 13000
# [t-SNE] Computed conditional probabilities for sample 8000 / 13000
# [t-SNE] Computed conditional probabilities for sample 9000 / 13000
# [t-SNE] Computed conditional probabilities for sample 10000 / 13000
# [t-SNE] Computed conditional probabilities for sample 11000 / 13000
# [t-SNE] Computed conditional probabilities for sample 12000 / 13000
# [t-SNE] Computed conditional probabilities for sample 13000 / 13000
# [t-SNE] Mean sigma: 0.206598
# [t-SNE] Computed conditional probabilities in 0.324s
# [t-SNE] Iteration 50: error = 99.2275085, gradient norm = 0.0036296 (50 iterations in 1.300s)
# [t-SNE] Iteration 100: error = 84.1977768, gradient norm = 0.0049336 (50 iterations in 1.242s)
# [t-SNE] Iteration 150: error = 81.8543549, gradient norm = 0.0027528 (50 iterations in 1.246s)
# [t-SNE] Iteration 200: error = 80.9725189, gradient norm = 0.0014708 (50 iterations in 1.242s)
# [t-SNE] Iteration 250: error = 80.5237732, gradient norm = 0.0016496 (50 iterations in 1.057s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.523773
# [t-SNE] Iteration 300: error = 3.0197074, gradient norm = 0.0014955 (50 iterations in 0.929s)
# [t-SNE] Iteration 350: error = 2.3976479, gradient norm = 0.0006350 (50 iterations in 0.929s)
# [t-SNE] Iteration 400: error = 2.1052780, gradient norm = 0.0003798 (50 iterations in 0.919s)
# [t-SNE] Iteration 450: error = 1.9340419, gradient norm = 0.0002595 (50 iterations in 0.928s)
# [t-SNE] Iteration 500: error = 1.8209599, gradient norm = 0.0001933 (50 iterations in 0.932s)
# [t-SNE] Iteration 550: error = 1.7407557, gradient norm = 0.0001513 (50 iterations in 0.930s)
# [t-SNE] Iteration 600: error = 1.6807848, gradient norm = 0.0001241 (50 iterations in 0.936s)
# [t-SNE] Iteration 650: error = 1.6346382, gradient norm = 0.0001052 (50 iterations in 0.939s)
# [t-SNE] Iteration 700: error = 1.5982052, gradient norm = 0.0000911 (50 iterations in 0.928s)
# [t-SNE] Iteration 750: error = 1.5690482, gradient norm = 0.0000818 (50 iterations in 0.936s)
# [t-SNE] Iteration 800: error = 1.5457780, gradient norm = 0.0000748 (50 iterations in 0.934s)
# [t-SNE] Iteration 850: error = 1.5269400, gradient norm = 0.0000703 (50 iterations in 1.215s)
# [t-SNE] Iteration 900: error = 1.5116813, gradient norm = 0.0000672 (50 iterations in 1.262s)
# [t-SNE] Iteration 950: error = 1.4998100, gradient norm = 0.0000635 (50 iterations in 1.311s)
# [t-SNE] Iteration 1000: error = 1.4903165, gradient norm = 0.0000613 (50 iterations in 1.307s)
# [t-SNE] KL divergence after 1000 iterations: 1.490317

# %%
selected_features_tr = ftr[:selected_features.size(0)]
selected_classifier_tr = ftr[selected_features.size(0):]

# %%
ind_1 = torch.isin(torch.cat([selected_voc_labels, selected_knn_labels], dim=0).unique(), selected_voc_labels)
ind_2 = torch.isin(torch.cat([selected_voc_labels, selected_knn_labels], dim=0).unique(), selected_knn_labels)

# %%
selected_voc_labels_tr = selected_classifier_tr[ind_1]
selected_knn_labels_tr = selected_classifier_tr[ind_2]

# %%
c = np.random.choice(selected_clu_labels.unique().numpy())
selected_class = (selected_clu_labels==c)
print(f'choose class={c}')
# Out:
# choose class=17

# %%
import matplotlib.pyplot as plt
plt.figure(dpi=128)
plt.scatter(x=selected_features_tr[:, 0], y=selected_features_tr[:, 1], s=3, c='b', alpha=0.3)
plt.scatter(x=selected_knn_labels_tr[:, 0], y=selected_knn_labels_tr[:, 1], s=2, c='r', alpha=0.8)
plt.scatter(x=selected_voc_labels_tr[:, 0], y=selected_voc_labels_tr[:, 1], s=2, c='g', alpha=0.8)
plt.scatter(x=selected_features_tr[selected_class, 0], y=selected_features_tr[selected_class, 1], s=3, c='orange', alpha=0.3)
plt.show()

# %%
plt.figure(dpi=128)
plt.scatter(x=selected_knn_labels_tr[:, 0], y=selected_knn_labels_tr[:, 1], s=2, c='r', alpha=0.8)
plt.scatter(x=selected_voc_labels_tr[:, 0], y=selected_voc_labels_tr[:, 1], s=2, c='g', alpha=0.8)
plt.show()

# %%
tsne = TSNE(n_components=2, verbose=2)
ftr = tsne.fit_transform(selected_classifier.cpu().numpy())
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3100 samples in 0.001s...

# %%
ind_1 = torch.isin(torch.cat([selected_voc_labels, selected_knn_labels], dim=0).unique(), selected_voc_labels)
ind_2 = torch.isin(torch.cat([selected_voc_labels, selected_knn_labels], dim=0).unique(), selected_knn_labels)
selected_voc_labels_tr = ftr[ind_1]
selected_knn_labels_tr = ftr[ind_2]

plt.figure(dpi=256)
plt.scatter(x=selected_knn_labels_tr[:, 0], y=selected_knn_labels_tr[:, 1], s=2, c='r', alpha=0.8)
plt.scatter(x=selected_voc_labels_tr[:, 0], y=selected_voc_labels_tr[:, 1], s=2, c='g', alpha=0.8)
plt.show()

# %% [markdown]
# ### hierarchy consistency

# %%
from sklearn.cluster import KMeans
from my_util_package.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment

subset = ['train', 'val'][0]
modelf = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
arch = 'vit_dino'

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(256, interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.CenterCrop(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
if subset == 'train':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=1)
elif subset == 'val':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=1)
args.nb_classes = dataset_f.num_classes
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=8, batch_size=args.batch_size, shuffle=False)

if subset == 'train':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-{arch}.npy'))
elif subset == 'val':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-val-{arch}.npy'))
    
model, preprocess = clip.load(args.arch)
if args.clip_checkpoint:
    model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
model.to(args.device).eval()
# Out:
# Using cache found in /home/sheng/.cache/torch/hub/facebookresearch_dino_main
# CLIP(
#   (visual): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16), bias=False)
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): Sequential(
#         (0): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (ln_post): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer): Transformer(
#     (resblocks): Sequential(
#       (0): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (7): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (8): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (9): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (10): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (11): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (token_embedding): Embedding(49408, 512)
#   (ln_final): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
# )

# %%
model, preprocess = clip.load(args.arch)
if args.clip_checkpoint:
    model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
model.to(args.device).eval()
input_resolution = model.visual.input_resolution
context_length = model.context_length
vocab_size = model.vocab_size

print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
print("Input resolution:", input_resolution)
print("Context length:", context_length)
print("Vocab size:", vocab_size)
# Out:
# Model parameters: 149,620,737
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %%
""" assumption: text embeddings in the same neighborhood of ground-truth voclabel vary in semantics """
# wn.path_similarity
classifier = get_classifier(args)
classifier /= classifier.norm(dim=-1, keepdim=True)

### collect variables for selected instances
topk = 5
selected_voc_labels = []
# selected_knn_labels = []
selected_clu_labels = []
with tqdm(total=len(loader_f)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_f):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        # with amp_autocast():
        #     with torch.no_grad():
        #         logits = model.visual(images[all_selected[idx_img]])
        #         logits = logits/logits.norm(dim=-1, keepdim=True)
        #         similarity = model.logit_scale.exp() * logits @ classifier.t()
        #         prob = similarity.softmax(-1)
        #         pred_voc = prob.argmax(dim=-1)
        selected_voc_labels.append(label_voc)
        # selected_knn_labels.append(pred_voc.cpu())
        selected_clu_labels.append(label_clu)
        pbar.update(1)
selected_voc_labels = torch.cat(selected_voc_labels, dim=0)
# selected_knn_labels = torch.cat(selected_knn_labels, dim=0)
selected_clu_labels = torch.cat(selected_clu_labels, dim=0)

# %%
selected_classifier = classifier[selected_voc_labels.unique(), :]
topk_voc_label = (selected_classifier@classifier.t()).topk(k=topk).indices

# %%
all_clu_pred.topk(k=5).indices,

# %%
from nltk.corpus import wordnet as wn
mapping_ids_synset = lambda x: wn.synset_from_pos_and_offset('n', int(x[1:]))
tree_distance = lambda x, y: x.path_similarity(y)
all_tree_dist = []
with tqdm(total=topk_voc_label.size(0)) as pbar:
    for i in range(topk_voc_label.size(0)):
        tree_dist = []
        anchor = topk_voc_label[i][0].item()
        candidates = topk_voc_label[i][1:].cpu().numpy().tolist()
        anchor_ids = [vocab.mapping_global_idx_ids[t] for t in vocab.mapping_idx_global_idx[anchor]]
        anchor_synsets = [mapping_ids_synset(t) for t in anchor_ids]
        for j in range(len(candidates)):
            candidate_ids = [vocab.mapping_global_idx_ids[t] for t in vocab.mapping_idx_global_idx[candidates[j]]]
            candidate_synsets = [mapping_ids_synset(t) for t in candidate_ids]
            distance = max([tree_distance(a, c) for a in anchor_synsets for c in candidate_synsets])
            tree_dist.append(distance)
            if distance<0.1:
                print(f'anchor={anchor_synsets} candidate={candidate_synsets}')
        all_tree_dist.append(tree_dist)
        pbar.update(1)
# Out:
#  89%|████████▉ | 88/99 [00:00<00:00, 438.37it/s]
# anchor=[Synset('african_crocodile.n.01')] candidate=[Synset('crocodylus.n.01')]
# anchor=[Synset('african_crocodile.n.01')] candidate=[Synset('crocodylidae.n.01')]
# anchor=[Synset('african_crocodile.n.01')] candidate=[Synset('crocodylia.n.01')]
# anchor=[Synset('agaric.n.02'), Synset('agaric.n.01')] candidate=[Synset('agaricus.n.01')]
# anchor=[Synset('airliner.n.01')] candidate=[Synset('plane.n.05'), Synset('plane.n.04'), Synset('plane.n.02'), Synset('plane.n.03')]
# anchor=[Synset('bathing_cap.n.01')] candidate=[Synset('thinking_cap.n.01')]
# anchor=[Synset('binder.n.04'), Synset('binder.n.03'), Synset('binder.n.01'), Synset('binder.n.02')] candidate=[Synset('highbinder.n.01')]
# anchor=[Synset('bonnet.n.01')] candidate=[Synset('headgear.n.03'), Synset('headgear.n.02')]
# anchor=[Synset('bottlecap.n.01')] candidate=[Synset('coin.n.01')]
# anchor=[Synset('bottlecap.n.01')] candidate=[Synset('coat_button.n.01')]
# anchor=[Synset('boxer.n.04'), Synset('boxer.n.01'), Synset('boxer.n.03')] candidate=[Synset('boxing.n.01')]
# anchor=[Synset('boxer.n.04'), Synset('boxer.n.01'), Synset('boxer.n.03')] candidate=[Synset('fighter.n.02')]
# anchor=[Synset('brabancon_griffon.n.01')] candidate=[Synset('gryphon.n.01')]
# anchor=[Synset('brabancon_griffon.n.01')] candidate=[Synset('crotaphion.n.01')]
# anchor=[Synset('bubble.n.04'), Synset('bubble.n.03'), Synset('bubble.n.01')] candidate=[Synset('bubbliness.n.01')]
# anchor=[Synset('bubble.n.04'), Synset('bubble.n.03'), Synset('bubble.n.01')] candidate=[Synset('bubble_dance.n.01')]
# anchor=[Synset('bubble.n.04'), Synset('bubble.n.03'), Synset('bubble.n.01')] candidate=[Synset('bubble_shell.n.01')]
# anchor=[Synset('cello.n.01')] candidate=[Synset('cellist.n.01')]
# anchor=[Synset('christmas_stocking.n.01')] candidate=[Synset('stocking_filler.n.01')]
# anchor=[Synset('christmas_stocking.n.01')] candidate=[Synset('christmas.n.02'), Synset('christmas.n.01')]
# anchor=[Synset('christmas_stocking.n.01')] candidate=[Synset('christmas_eve.n.01')]
# anchor=[Synset('clog.n.02'), Synset('clog.n.01')] candidate=[Synset('clog_dance.n.01')]
# anchor=[Synset('clog.n.02'), Synset('clog.n.01')] candidate=[Synset('shoeful.n.01')]
# anchor=[Synset('combination_lock.n.01')] candidate=[Synset('lock-gate.n.01')]
# anchor=[Synset('crane.n.05'), Synset('crane.n.04'), Synset('crane.n.02'), Synset('crane.n.01')] candidate=[Synset('birdie.n.01')]
# anchor=[Synset('crane.n.05'), Synset('crane.n.04'), Synset('crane.n.02'), Synset('crane.n.01')] candidate=[Synset('crane_fly.n.01')]
# anchor=[Synset('cup.n.01'), Synset('cup.n.08'), Synset('cup.n.07'), Synset('cup.n.06'), Synset('cup.n.05'), Synset('cup.n.04'), Synset('cup.n.02'), Synset('cup.n.03')] candidate=[Synset('cup_final.n.01')]
# anchor=[Synset('desktop_computer.n.01')] candidate=[Synset('computer_technology.n.01')]
# anchor=[Synset('dial_telephone.n.01')] candidate=[Synset('telephone_receiver.n.01')]
# anchor=[Synset('dogsled.n.01')] candidate=[Synset('sled_dog.n.01')]
# anchor=[Synset('dogsled.n.01')] candidate=[Synset('musher.n.01')]
# anchor=[Synset('dogsled.n.01')] candidate=[Synset('iditarod.n.01')]
# anchor=[Synset('earthstar.n.01')] candidate=[Synset('geastrum.n.01')]
# anchor=[Synset('earthstar.n.01')] candidate=[Synset('gastrocybe.n.01')]
# anchor=[Synset('go-kart.n.01')] candidate=[Synset('raceway.n.01')]
# anchor=[Synset('gong.n.01')] candidate=[Synset('ding.n.01')]
# anchor=[Synset('hand_blower.n.01')] candidate=[Synset('blow.n.07'), Synset('blow.n.01'), Synset('blow.n.02')]
# anchor=[Synset('harmonica.n.01')] candidate=[Synset('straight_flute.n.01')]
# anchor=[Synset('hook.n.07'), Synset('hook.n.06'), Synset('hook.n.05'), Synset('hook.n.04'), Synset('hook.n.01'), Synset('hook.n.02')] candidate=[Synset('hook_shot.n.01')]
# anchor=[Synset('hook.n.07'), Synset('hook.n.06'), Synset('hook.n.05'), Synset('hook.n.04'), Synset('hook.n.01'), Synset('hook.n.02')] candidate=[Synset('hooks.n.01')]
# anchor=[Synset('hummingbird.n.01')] candidate=[Synset('humming.n.02')]
# anchor=[Synset('hummingbird.n.01')] candidate=[Synset('birdie.n.01')]
# anchor=[Synset('hummingbird.n.01')] candidate=[Synset('bird_genus.n.01')]
# anchor=[Synset('ice_lolly.n.01')] candidate=[Synset('papulovesicle.n.01')]
# anchor=[Synset('kimono.n.01')] candidate=[Synset('shinto.n.02'), Synset('shinto.n.01')]
# anchor=[Synset('kimono.n.01')] candidate=[Synset('samisen.n.01')]
# anchor=[Synset('kimono.n.01')] candidate=[Synset('japanese.n.02'), Synset('japanese.n.01')]
# anchor=[Synset('lacewing.n.01')] candidate=[Synset('ephemeroptera.n.01')]
# anchor=[Synset('leatherback_turtle.n.01')] candidate=[Synset('caretta.n.01')]
# anchor=[Synset('lemon.n.05'), Synset('lemon.n.04'), Synset('lemon.n.01'), Synset('lemon.n.03')] candidate=[Synset('lemon_juice.n.01')]
# anchor=[Synset('lemon.n.05'), Synset('lemon.n.04'), Synset('lemon.n.01'), Synset('lemon.n.03')] candidate=[Synset('bitter_lemon.n.01')]
# anchor=[Synset('lemon.n.05'), Synset('lemon.n.04'), Synset('lemon.n.01'), Synset('lemon.n.03')] candidate=[Synset('lemon_zest.n.01')]
# anchor=[Synset('leonberg.n.01')] candidate=[Synset('leonurus.n.01')]
# anchor=[Synset('maillot.n.02'), Synset('maillot.n.01')] candidate=[Synset('new_jersey.n.01'), Synset('new_jersey.n.02')]
# anchor=[Synset('matchstick.n.01')] candidate=[Synset('cigarette.n.01')]
# anchor=[Synset('minibus.n.01')] candidate=[Synset('passenger_van.n.01')]
# anchor=[Synset('mountain_bike.n.01')] candidate=[Synset('cycling.n.01')]
# anchor=[Synset('mountain_bike.n.01')] candidate=[Synset('bicycling.n.01')]
# anchor=[Synset('nail.n.02'), Synset('nail.n.01'), Synset('nail.n.03')] candidate=[Synset('nail_pulling.n.01')]
# anchor=[Synset('odometer.n.01')] candidate=[Synset('mileage.n.01'), Synset('mileage.n.03'), Synset('mileage.n.02')]
# anchor=[Synset('oxygen_mask.n.01')] candidate=[Synset('oxygen.n.01')]
# anchor=[Synset('oxygen_mask.n.01')] candidate=[Synset('oxygenation.n.01')]
# anchor=[Synset('oxygen_mask.n.01')] candidate=[Synset('oxygen_debt.n.01')]
# anchor=[Synset('parallel_bars.n.01')] candidate=[Synset('double_bar.n.01')]
# anchor=[Synset('parallel_bars.n.01')] candidate=[Synset('parallel_operation.n.01')]
# anchor=[Synset('potpie.n.01')] candidate=[Synset('meat_pie.n.01')]
# anchor=[Synset('potpie.n.01')] candidate=[Synset('pie.n.01')]
# anchor=[Synset('potpie.n.01')] candidate=[Synset('pie_crust.n.01')]
# anchor=[Synset('potpie.n.01')] candidate=[Synset('shoofly_pie.n.01')]
# anchor=[Synset('projectile.n.01')] candidate=[Synset('explosive.n.01')]
# anchor=[Synset('projectile.n.01')] candidate=[Synset('gunfire.n.01')]
# anchor=[Synset('rain_barrel.n.01')] candidate=[Synset('barrels.n.01')]
# anchor=[Synset('rock_crab.n.01')] candidate=[Synset('wild_crab.n.01')]
# anchor=[Synset('samoyed.n.03'), Synset('samoyed.n.01')] candidate=[Synset('samoyedic.n.01')]
# anchor=[Synset('samoyed.n.03'), Synset('samoyed.n.01')] candidate=[Synset('chowchow.n.02'), Synset('chowchow.n.01')]
# anchor=[Synset('sea_anemone.n.01')] candidate=[Synset('anemone.n.01')]
# anchor=[Synset('sea_anemone.n.01')] candidate=[Synset('genus_anemone.n.01')]
# anchor=[Synset('sea_anemone.n.01')] candidate=[Synset('alpine_anemone.n.01')]
# anchor=[Synset('sea_anemone.n.01')] candidate=[Synset('anemonella.n.01')]
# anchor=[Synset('sea_snake.n.01')] candidate=[Synset('sea_serpent.n.01')]
# anchor=[Synset('space_bar.n.01')] candidate=[Synset('bar_bit.n.01')]
# anchor=[Synset('space_bar.n.01')] candidate=[Synset('space.n.01'), Synset('space.n.07'), Synset('space.n.05'), Synset('space.n.08'), Synset('space.n.03'), Synset('space.n.02')]
# anchor=[Synset('space_bar.n.01')] candidate=[Synset('space_age.n.01')]
# anchor=[Synset('space_shuttle.n.01')] candidate=[Synset('shuttle_diplomacy.n.01')]
# anchor=[Synset('space_shuttle.n.01')] candidate=[Synset('spaceflight.n.01')]
# anchor=[Synset('spindle.n.04'), Synset('spindle.n.03'), Synset('spindle.n.02'), Synset('spindle.n.01')] candidate=[Synset('spinney.n.01')]
# anchor=[Synset('spindle.n.04'), Synset('spindle.n.03'), Synset('spindle.n.02'), Synset('spindle.n.01')] candidate=[Synset('spin.n.05'), Synset('spin.n.03'), Synset('spin.n.02'), Synset('spin.n.01')]
# anchor=[Synset('spindle.n.04'), Synset('spindle.n.03'), Synset('spindle.n.02'), Synset('spindle.n.01')] candidate=[Synset('spinus.n.01')]
# anchor=[Synset('spotlight.n.02')] candidate=[Synset('very_light.n.01')]
# anchor=[Synset('steel_drum.n.01')] candidate=[Synset('percussion.n.02'), Synset('percussion.n.01'), Synset('percussion.n.04')]
# 100%|██████████| 99/99 [00:00<00:00, 441.58it/s]
# anchor=[Synset('sunscreen.n.01')] candidate=[Synset('sunburn.n.02')]
# anchor=[Synset('sunscreen.n.01')] candidate=[Synset('sun_protection_factor.n.01')]
# anchor=[Synset('sunscreen.n.01')] candidate=[Synset('skin_care.n.01')]
# anchor=[Synset('swing.n.04'), Synset('swing.n.09'), Synset('swing.n.03'), Synset('swing.n.02'), Synset('swing.n.05'), Synset('swing.n.01')] candidate=[Synset('swinging_chad.n.01')]
# anchor=[Synset('swing.n.04'), Synset('swing.n.09'), Synset('swing.n.03'), Synset('swing.n.02'), Synset('swing.n.05'), Synset('swing.n.01')] candidate=[Synset('swing_voter.n.01')]
# anchor=[Synset('tick.n.02'), Synset('tick.n.04'), Synset('tick.n.01')] candidate=[Synset('up-tick.n.01')]
# anchor=[Synset('tripod.n.01')] candidate=[Synset('standing.n.03'), Synset('standing.n.02'), Synset('standing.n.01')]
# anchor=[Synset('tripod.n.01')] candidate=[Synset('scope.n.01')]
# anchor=[Synset('tusker.n.01')] candidate=[Synset('musth.n.01')]
# anchor=[Synset('velvet.n.01')] candidate=[Synset('velvet_bent.n.01')]
# anchor=[Synset('velvet.n.01')] candidate=[Synset('v.n.04')]

# %%
knn_pattern = torch.cat([all_gt_voc.view(-1, 1), all_clu_pred.topk(k=5).indices[pred_kmeans_t]], dim=1).unique(dim=0)

# %%
knn_pattern = all_clu_pred.topk(k=5).indices
mapping_ids_synset = lambda x: wn.synset_from_pos_and_offset('n', int(x[1:]))
tree_distance = lambda x, y: x.path_similarity(y)
all_tree_dist = []
with tqdm(total=knn_pattern.size(0)) as pbar:
    for i in range(knn_pattern.size(0)):
        tree_dist = []
        record = []
        anchor = knn_pattern[i][0].item()
        candidates = knn_pattern[i][1:].cpu().numpy().tolist()
        anchor_ids = [vocab.mapping_global_idx_ids[t] for t in vocab.mapping_idx_global_idx[anchor]]
        anchor_synsets = [mapping_ids_synset(t) for t in anchor_ids]
        for j in range(len(candidates)):
            candidate_ids = [vocab.mapping_global_idx_ids[t] for t in vocab.mapping_idx_global_idx[candidates[j]]]
            candidate_synsets = [mapping_ids_synset(t) for t in candidate_ids]
            distance = max([tree_distance(a, c) for a in anchor_synsets for c in candidate_synsets])
            tree_dist.append(distance)
            record.append(candidate_synsets[0])
            # if distance>0.2:
                # print(f'anchor={anchor_synsets} candidate={candidate_synsets}')
        all_tree_dist.append(tree_dist)
        print(record)
        pbar.update(1)
# Out:
# 100%|██████████| 99/99 [00:00<00:00, 576.28it/s]
# [Synset('cownose_ray.n.01'), Synset('electric_ray.n.01'), Synset('stingray.n.01'), Synset('ray.n.07')]
# [Synset('roughtail_stingray.n.01'), Synset('electric_ray.n.01'), Synset('ray.n.07'), Synset('stingray.n.01')]
# [Synset('high-hat_cymbal.n.01'), Synset('cymbal.n.01'), Synset('percussion_instrument.n.01'), Synset('steel_drum.n.01')]
# [Synset('swimmer.n.02'), Synset('breaststroker.n.01'), Synset('swimming_event.n.01'), Synset('breaststroke.n.01')]
# [Synset('sea_turtle.n.01'), Synset('hawksbill_turtle.n.01'), Synset('green_turtle.n.01'), Synset('leatherback_turtle.n.01')]
# [Synset('red-bellied_terrapin.n.01'), Synset('mud_turtle.n.01'), Synset('diamondback_terrapin.n.01'), Synset('soft-shelled_turtle.n.01')]
# [Synset('caretta.n.01'), Synset('sea_turtle.n.01'), Synset('hawksbill_turtle.n.01'), Synset('soft-shelled_turtle.n.01')]
# [Synset('throw_pillow.n.01'), Synset('pillow_block.n.01'), Synset('cushion.n.03'), Synset('oilcloth.n.01')]
# [Synset('muskellunge.n.02'), Synset('esox.n.01'), Synset('bowfin.n.01'), Synset('northern_pike.n.01')]
# [Synset('beer_barrel.n.01'), Synset('barrel.n.02'), Synset('septic_tank.n.01'), Synset('barrels.n.01')]
# [Synset('african_crocodile.n.01'), Synset('crocodylus.n.01'), Synset('asian_crocodile.n.01'), Synset('caiman.n.01')]
# [Synset('rock_crab.n.01'), Synset('hard-shell_crab.n.01'), Synset('bechtel_crab.n.01'), Synset('stone_crab.n.02')]
# [Synset('steel_band.n.01'), Synset('drumming.n.01'), Synset('percussion_section.n.01'), Synset('percussion.n.02')]
# [Synset('blackfish.n.02'), Synset('cetacean.n.01'), Synset('marineland.n.01'), Synset('captivity.n.01')]
# [Synset('rocky_mountain_jay.n.01'), Synset('common_european_jay.n.01'), Synset('canada_jay.n.01'), Synset('blue_mockingbird.n.01')]
# [Synset('macaca.n.01'), Synset('mangabey.n.01'), Synset('squirrel_monkey.n.01'), Synset('howler_monkey.n.01')]
# [Synset('lorikeet.n.01'), Synset('rainbow_lorikeet.n.01'), Synset('lory.n.01'), Synset('parrotia.n.01')]
# [Synset('scarlet_runner.n.03'), Synset('paleacrita.n.01'), Synset('tody.n.01'), Synset('paleacrita_vernata.n.01')]
# [Synset('european_bittern.n.01'), Synset('bittern.n.01'), Synset('least_bittern.n.01'), Synset('tringa.n.01')]
# [Synset('geastrum.n.01'), Synset('earthstar.n.01'), Synset('clitocybe_robusta.n.01'), Synset('lycoperdaceae.n.01')]
# [Synset('clog_dance.n.01'), Synset('espadrille.n.01'), Synset('wedge_heel.n.01'), Synset('clog_dancer.n.01')]
# [Synset('anemone.n.01'), Synset('genus_anemone.n.01'), Synset('anemonella.n.01'), Synset('alpine_anemone.n.01')]
# [Synset('satin_weave.n.01'), Synset('viscose_rayon.n.01'), Synset('suede_cloth.n.01'), Synset('cloth_covering.n.01')]
# [Synset('samoyed.n.03'), Synset('eskimo_dog.n.01'), Synset('kuvasz.n.01'), Synset('white_wolf.n.01')]
# [Synset('sea_snake.n.01'), Synset('banded_sand_snake.n.01'), Synset('deepwater_pipefish.n.01'), Synset('common_eel.n.01')]
# [Synset('willet.n.01'), Synset('curlew_sandpiper.n.01'), Synset('european_sandpiper.n.01'), Synset('spotted_sandpiper.n.01')]
# [Synset('checkered_whiptail.n.01'), Synset('plateau_striped_whiptail.n.01'), Synset('western_skink.n.01'), Synset('alligator_lizard.n.01')]
# [Synset('rock_wallaby.n.01'), Synset('wallaby.n.01'), Synset('nail-tailed_wallaby.n.01'), Synset('macropus.n.01')]
# [Synset('trail_bike.n.01'), Synset('trail_riding.n.01'), Synset('cross-country_riding.n.01'), Synset('endurance_riding.n.01')]
# [Synset('pachycheilia.n.01'), Synset('tusker.n.01'), Synset('african_elephant.n.01'), Synset('mahout.n.01')]
# [Synset('rice_weevil.n.01'), Synset('pea_weevil.n.01'), Synset('curculionidae.n.01'), Synset('boll_weevil.n.01')]
# [Synset('bitter_lemon.n.01'), Synset('citron.n.01'), Synset('quercitron.n.01'), Synset('citrus.n.01')]
# [Synset('tick.n.02'), Synset('lyme_disease.n.01'), Synset('ixodes_scapularis.n.01'), Synset('ixodes_dammini.n.01')]
# [Synset('lacewing.n.01'), Synset('brown_lacewing.n.01'), Synset('mayfly.n.01'), Synset('neuroptera.n.01')]
# [Synset('agaric.n.02'), Synset('royal_agaric.n.01'), Synset('amanita.n.01'), Synset('hygrophorus_russula.n.01')]
# [Synset('banteng.n.01'), Synset('nguni.n.01'), Synset('oxcart.n.01'), Synset('brahman.n.04')]
# [Synset('bell_ringing.n.03'), Synset('mission_bells.n.02'), Synset('chime.n.01'), Synset('church_bell.n.01')]
# [Synset('skein.n.01'), Synset('bobbin.n.01'), Synset('spindle.n.04'), Synset('shetland_wool.n.01')]
# [Synset('beachwear.n.01'), Synset('bikini.n.02'), Synset('bikini_pants.n.01'), Synset('leotard.n.01')]
# [Synset('buckle.n.01'), Synset('sam_browne_belt.n.01'), Synset('belt.n.02'), Synset('leather_strip.n.01')]
# [Synset('woodenware.n.01'), Synset('kitchen_utensil.n.01'), Synset('runcible_spoon.n.01'), Synset('cooking_utensil.n.01')]
# [Synset('sunscreen.n.01'), Synset('sun_protection_factor.n.01'), Synset('body_lotion.n.01'), Synset('eye-lotion.n.01')]
# [Synset('beer_can.n.01'), Synset('beer_mat.n.01'), Synset('mescal_button.n.01'), Synset('beer_bottle.n.01')]
# [Synset('woodscrew.n.01'), Synset('lag_screw.n.01'), Synset('corrugated_fastener.n.01'), Synset('phillips_screw.n.01')]
# [Synset('graduated_cylinder.n.01'), Synset('pyrex.n.01'), Synset('milliliter.n.01'), Synset('shot_glass.n.01')]
# [Synset('flame-out.n.02'), Synset('flame_pea.n.01'), Synset('combustion.n.01'), Synset('fire_tongs.n.01')]
# [Synset('custard_apple.n.02'), Synset('sweetsop.n.02'), Synset('pulasan.n.02'), Synset('soursop.n.02')]
# [Synset('shih-tzu.n.01'), Synset('lhasa.n.02'), Synset('chug.n.01'), Synset('brachycephaly.n.01')]
# [Synset('tibetan_mastiff.n.01'), Synset('alsatian.n.01'), Synset('briard.n.01'), Synset('mastiff.n.01')]
# [Synset('dogsled.n.01'), Synset('iditarod_trail.n.01'), Synset('musher.n.01'), Synset('sled_dog.n.01')]
# [Synset('bubble_dance.n.01'), Synset('air_bubble.n.01'), Synset('bubble.n.04'), Synset('bubble_jet_printer.n.01')]
# [Synset('safety_match.n.01'), Synset('concentrated_fire.n.01'), Synset('joss_stick.n.01'), Synset('cigarette_burn.n.01')]
# [Synset('pail.n.02'), Synset('wine_bucket.n.01'), Synset('bucket_shop.n.02'), Synset('dredging_bucket.n.01')]
# [Synset('coffee_mug.n.01'), Synset('teacup.n.02'), Synset('demitasse.n.02'), Synset('chinaware.n.01')]
# [Synset('respirator.n.01'), Synset('breathing_device.n.01'), Synset('inhalation_anesthesia.n.01'), Synset('resuscitator.n.01')]
# [Synset('earflap.n.01'), Synset('plagiocephaly.n.01'), Synset('bonnet.n.01'), Synset('cloth_cap.n.01')]
# [Synset('takin.n.01'), Synset('yak.n.02'), Synset('gnu.n.01'), Synset('wisent.n.01')]
# [Synset('red_fox.n.03'), Synset('coydog.n.01'), Synset('dingo.n.01'), Synset('fossa.n.03')]
# [Synset('european_hare.n.01'), Synset('white-tailed_jackrabbit.n.01'), Synset('eastern_cottontail.n.01'), Synset('european_rabbit.n.01')]
# [Synset('howler_monkey.n.01'), Synset('alouatta.n.01'), Synset('langur.n.01'), Synset('woolly_monkey.n.01')]
# [Synset('tripod.n.01'), Synset('photographic_equipment.n.01'), Synset('point-and-shoot_camera.n.01'), Synset('surveying_instrument.n.01')]
# [Synset('climbing_frame.n.01'), Synset('swing_voter.n.01'), Synset('seesaw.n.01'), Synset('playground.n.02')]
# [Synset('welsh_terrier.n.01'), Synset('wire-haired_fox_terrier.n.01'), Synset('soft-coated_wheaten_terrier.n.01'), Synset('airedale.n.01')]
# [Synset('papulovesicle.n.01'), Synset('lollipop.n.02'), Synset('strawberry_ice_cream.n.01'), Synset('choc-ice.n.01')]
# [Synset('shoofly_pie.n.01'), Synset('tourtiere.n.01'), Synset('cottage_pie.n.01'), Synset('meat_pie.n.01')]
# [Synset('t-bar_lift.n.01'), Synset('erecting.n.01'), Synset('excavator.n.01'), Synset('construction.n.05')]
# [Synset('canoeist.n.01'), Synset('canoe.n.01'), Synset('portage.n.03'), Synset('dugout_canoe.n.01')]
# [Synset('schoolbag.n.01'), Synset('duffel_bag.n.01'), Synset('shoulder_bag.n.01'), Synset('drawstring_bag.n.01')]
# [Synset('geisha.n.01'), Synset('shinto.n.02'), Synset('chimariko.n.02'), Synset('shuha_shinto.n.01')]
# [Synset('american_staffordshire_terrier.n.01'), Synset('bull_mastiff.n.01'), Synset('mastiff.n.01'), Synset('staffordshire_bullterrier.n.01')]
# [Synset('airedale.n.01'), Synset('lakeland_terrier.n.01'), Synset('wire-haired_fox_terrier.n.01'), Synset('irish_terrier.n.01')]
# [Synset('neckwear.n.01'), Synset('black_tie.n.02'), Synset('eton_collar.n.01'), Synset('white_tie.n.01')]
# [Synset('bernese_mountain_dog.n.01'), Synset('greater_swiss_mountain_dog.n.01'), Synset('walker_hound.n.01'), Synset('coonhound.n.01')]
# [Synset('stocking.n.02'), Synset('stocking_filler.n.01'), Synset('sock.n.01'), Synset('athletic_sock.n.01')]
# [Synset('straight_chair.n.01'), Synset('morris_chair.n.01'), Synset('camp_chair.n.01'), Synset('lawn_chair.n.01')]
# [Synset('hair_care.n.01'), Synset('curling_iron.n.01'), Synset('sunscreen.n.01'), Synset('pepper_spray.n.01')]
# [Synset('recreational_vehicle.n.01'), Synset('camper.n.02'), Synset('minibus.n.01'), Synset('camper_trailer.n.01')]
# [Synset('san_francisco_bay.n.01'), Synset('benjamin_franklin_bridge.n.01'), Synset('tacoma_narrows_bridge.n.01'), Synset('commodore_john_barry_bridge.n.01')]
# [Synset('racing_start.n.01'), Synset('racing.n.01'), Synset('pace_lap.n.01'), Synset('racing_gig.n.01')]
# [Synset('keystroke.n.01'), Synset('qwerty_keyboard.n.01'), Synset('keyboard.n.02'), Synset('backspace_key.n.01')]
# [Synset('entertainment_center.n.01'), Synset('television_room.n.01'), Synset('livingroom_suite.n.01'), Synset('wall_unit.n.01')]
# [Synset('surface-to-air_missile.n.01'), Synset('ballistic_missile.n.01'), Synset('guided_missile.n.01'), Synset('air-to-air_missile.n.01')]
# [Synset('computer_graphics.n.01'), Synset('workstation.n.01'), Synset('computer_monitor.n.01'), Synset('workspace.n.01')]
# [Synset('gymnastics.n.01'), Synset('gymnastic_apparatus.n.01'), Synset('gymnastic_exercise.n.01'), Synset('pole_vault.n.01')]
# [Synset('mangabey.n.01'), Synset('vervet.n.01'), Synset('bonnet_macaque.n.01'), Synset('kenyapithecus.n.01')]
# [Synset('twinjet.n.01'), Synset('jumbojet.n.01'), Synset('narrowbody_aircraft.n.01'), Synset('airline.n.02')]
# [Synset('shuttle.n.03'), Synset('shuttlecock.n.01'), Synset('shuttle_diplomacy.n.01'), Synset('launch.n.01')]
# [Synset('recorder_player.n.01'), Synset('glasses_case.n.01'), Synset('kazoo.n.01'), Synset('cigarette_case.n.01')]
# [Synset('binder's_board.n.01'), Synset('file_folder.n.01'), Synset('stationery.n.01'), Synset('pencil_box.n.01')]
# [Synset('odometer.n.01'), Synset('tachometer.n.01'), Synset('mileage.n.01'), Synset('dashboard.n.02')]
# [Synset('teletypewriter.n.01'), Synset('electric_typewriter.n.01'), Synset('typewriter_font.n.01'), Synset('typewriter_keyboard.n.01')]
# [Synset('lemon.n.05'), Synset('lemon_extract.n.01'), Synset('bitter_lemon.n.01'), Synset('lemon_zest.n.01')]
# [Synset('laser_printer.n.01'), Synset('photocopier.n.01'), Synset('printing_unit.n.01'), Synset('printer.n.03')]
# [Synset('bookshelf.n.01'), Synset('shelf.n.01'), Synset('shelfful.n.01'), Synset('lending_library.n.01')]
# [Synset('telephone.n.01'), Synset('cellular_telephone.n.01'), Synset('telephone_unit.n.01'), Synset('desk_phone.n.01')]
# [Synset('padlock.n.01'), Synset('locking.n.01'), Synset('cylinder_lock.n.01'), Synset('lock.n.06')]
# [Synset('massager.n.01'), Synset('straightener.n.01'), Synset('hair_spray.n.01'), Synset('travel_iron.n.01')]
# [Synset('cello.n.01'), Synset('guarneri.n.02'), Synset('bowed_stringed_instrument.n.01'), Synset('violist.n.01')]
# [Synset('guard's_van.n.01'), Synset('minibus.n.01'), Synset('passenger_van.n.01'), Synset('police.n.01')]

# %%
cluster_acc(np.random.randint(low=0, high=100, size=[1000000]), np.random.randint(low=0, high=100, size=[1000000]))
# Out:
# 0.000391

# %%
candidate_synsets
# Out:
# [Synset('printer.n.03'), Synset('printer.n.02'), Synset('printer.n.01')]

# %%
mapping_ids_synset = lambda x: wn.synset_from_pos_and_offset('n', int(x[1:]))
tree_distance = lambda x, y: x.path_similarity(y)
all_tree_dist = []
with tqdm(total=knn_pattern.size(0)) as pbar:
    for i in range(knn_pattern.size(0)):
        tree_dist = []
        anchor = knn_pattern[i][0].item()
        candidates = knn_pattern[i][1:].cpu().numpy().tolist()
        anchor_ids = [vocab.mapping_global_idx_ids[t] for t in vocab.mapping_idx_global_idx[anchor]]
        anchor_synsets = [mapping_ids_synset(t) for t in anchor_ids]
        for j in range(len(candidates)):
            candidate_ids = [vocab.mapping_global_idx_ids[t] for t in vocab.mapping_idx_global_idx[candidates[j]]]
            candidate_synsets = [mapping_ids_synset(t) for t in candidate_ids]
            distance = max([tree_distance(a, c) for a in anchor_synsets for c in candidate_synsets])
            tree_dist.append(distance)
            if distance>0.2:
                print(f'anchor={anchor_synsets} candidate={candidate_synsets}')
        all_tree_dist.append(tree_dist)
        pbar.update(1)

# %% [markdown]
# ### Hierarchical structure inspection

# %%
from sklearn.cluster import KMeans
from my_util_package.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment
from nltk.corpus import wordnet as wn

subset = ['train', 'val'][0]
modelf = torch.hub.load('facebookresearch/dino:main', 'dino_vitb16')
arch = 'vit_dino'

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(256, interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.CenterCrop(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
if subset == 'train':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=1)
elif subset == 'val':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=1)
args.nb_classes = dataset_f.num_classes
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=8, batch_size=args.batch_size, shuffle=False)

if subset == 'train':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-{arch}.npy'))
elif subset == 'val':
    pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-val-{arch}.npy'))
    
model, preprocess = clip.load(args.arch)
if args.clip_checkpoint:
    model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
model.to(args.device).eval()

classifier = get_classifier(args)
# Out:
# Using cache found in /home/sheng/.cache/torch/hub/facebookresearch_dino_main

# %%
all_synset_ids = list(vocab.mapping_ids_global_idx.keys())

# %%
nouns = [x for x in wn.all_synsets(pos=wn.NOUN)]
parents = list(filter(lambda x: x.max_depth()==2, nouns))
hypo = lambda s: s.hyponyms()
children = [[x for x in w.closure(hypo, depth=1000)] for w in parents]
# Out:
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('lip.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('tongue.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('umbilical_cord.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('diaphragm.n.02') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('umbilical_cord.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('immunoglobulin.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('gamma_globulin.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('lower_jaw.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('nasal_concha.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('triglyceride.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('glucosamine.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('iceberg.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('piece_of_cloth.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('archeological_remains.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('article_of_commerce.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('stele.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('terry.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('brick.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('roman_building.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('laminate.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bar.n.08') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('perianth.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('coat_of_paint.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('globe.n.03') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('wheeled_vehicle.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('memory.n.04') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('backing.n.02') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('stock.n.03') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('central_processing_unit.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('life_preserver.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('sporting_goods.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('grindstone.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('frisbee.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('drawer.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('root_cellar.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('gambling_house.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('house.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dormitory.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('water_jump.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('amerindian.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('black.n.05') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cup.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dish.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('spoon.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('mask.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('mobile_home.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('jumper_cable.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('photoelectric_cell.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('swing.n.02') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('lashing.n.02') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('gusset.n.02') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('beam.n.02') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('brace.n.09') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pine-tar_rag.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('rosin_bag.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('golf_bag.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pool_table.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('plumber's_snake.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('burial_chamber.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('public_toilet.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('brewpub.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('lodging_house.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pea_shooter.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('leukocyte.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('black_woman.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('eurafrican.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pickaninny.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('black_man.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('boyfriend.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('inamorato.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('mortgagee.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('imam.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('patient.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('meson.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('safety_belt.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('mask.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('brassiere.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dress_hat.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('hand_blower.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bath_towel.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('place_mat.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dinner_dress.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('calcimine.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('vermiculation.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pull_chain.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('fishbowl.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cistern.n.03') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cruise_missile.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('solenoid.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('javelin.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('disk.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cd-rom.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('videocassette.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bass_fiddle.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bass_guitar.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bass_horn.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('accordion.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('computer_keyboard.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('joystick.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('scanner.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('crown.n.04') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dining-room_table.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('baseball_bat.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('toothpick.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('hand_shovel.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('t-square.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('poacher.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pot.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('eggbeater.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('skybox.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('alcazar.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bakery.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('sconce.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dry_wall.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('female_mammal.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('flea.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('colt.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('filly.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('puppy.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('acidophilus.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('working_girl.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('alcalde.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('misleader.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pawnbroker.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('witness.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('broadcast_journalist.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pitcher.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('mountaineer.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('suffragette.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('confederate.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('geisha.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('yellow_man.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('yellow_woman.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('boy_wonder.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('girl_wonder.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('ivy_leaguer.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('matriarch.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('patriarch.n.02') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('filibuster.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('system_administrator.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('tenant_farmer.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dancing_partner.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('nanny.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('female_offspring.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('male_offspring.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('satanist.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pope.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('wasp.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('picador.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('policyholder.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bridesmaid.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('signalman.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('incumbent.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('judge.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('officeholder.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('wildflower.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('clematis.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('legume.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('turtleneck.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('dinner_dress.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('clothes_dryer.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('nightgown.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('warplane.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('warship.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('paintball_gun.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('clostridium_perfringens.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('chemical_bomb.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pepper_spray.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('atom_bomb.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('hydrogen_bomb.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('megaton_bomb.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('wire_matrix_printer.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('water_faucet.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('tee.n.03') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('plane.n.05') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('scissors.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('young_fish.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('game_bird.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('greyhound.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bahai.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('matron.n.03') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('kidnapper.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('murderer.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('raper.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('retailer.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('sovereign.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('pinch_hitter.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('stitcher.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('altar_boy.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('eavesdropper.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('neurolinguist.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('sannyasi.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('shop_boy.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('shop_girl.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('traveling_salesman.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('mill-girl.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('kamikaze.n.02') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bean_counter.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('paper-pusher.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('military_adviser.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('potemkin.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('hydrogen_ion.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cranberry.n.02') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('nightgown.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('technical.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bomber.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('fighter.n.02') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# ...
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('foam_rubber.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('absorbent_cotton.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('glucocorticoid.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('hexane.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cellulose_nitrate.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('glyceride.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('chlorofluorocarbon.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('triglyceride.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('enzyme.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('epinephrine.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('gamma_aminobutyric_acid.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('taconite.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('gesso.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('drambuie.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('beta-carotene.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('animal_fat.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('animal_oil.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('beeswax.n.01') at depth 10
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('elaidic_acid.n.01') at depth 11
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('sucrose.n.01') at depth 11
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('gas_oil.n.01') at depth 11
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('calcium_ion.n.01') at depth 11
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('immunoglobulin.n.01') at depth 11
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('gamma_globulin.n.01') at depth 11
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('beta-hydroxybutyric_acid.n.01') at depth 12
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('noradrenaline.n.01') at depth 12
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('drying_oil.n.01') at depth 12
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('styrofoam.n.01') at depth 12
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('footprint_evidence.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('correspondence.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('newscast.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('red_flag.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('adagio.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('allegretto.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('allegro.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('andante.n.02') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('largo.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('fingerprint.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('previous_question.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('credits.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('platitude.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('written_agreement.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bar_line.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('blues.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('soul.n.05') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('self-accusation.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('bond.n.02') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('devanagari.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('blues.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('soul.n.05') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('received_pronunciation.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('haitian_creole.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('catchphrase.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('registered_bond.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('zero_coupon_bond.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cyrillic_alphabet.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('roman_alphabet.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('arabic_alphabet.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('hebrew_alphabet.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('prothalamion.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('maximum.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('temperature_scale.n.01') at depth 4
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('date.n.06') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('cent.n.01') at depth 6
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('stp.n.01') at depth 7
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('succoth.n.01') at depth 8
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('christmas.n.02') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):
# /home/sheng/anaconda3/envs/gcd/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('rosh_hashanah.n.01') at depth 9
#   for synset in acyclic_breadth_first(self, rel, depth):

# %%
# candidate_synsets = list(filter(lambda x: x.max_depth()==3, nouns))
get_offset = lambda ss: ss.pos()+str(ss.offset()).zfill(8)

parents_idx = [vocab.mapping_names_idx[vocab.mapping_ids_names[get_offset(p)]] for p in parents]
children_idx = [[vocab.mapping_names_idx[vocab.mapping_ids_names[get_offset(c)]] for c in ch] for ch in children]

# %%
classifier_parent = classifier[torch.tensor(parents_idx)]

all_children_ind = torch.tensor(reduce(lambda x, y: x+y, children_idx)).unique()
classifier_children = classifier[all_children_ind]
set_children_idx = list(map(lambda x: set(x), children_idx))

# %%
with tqdm(total=len(all_children_ind)) as pbar:
    all_label_children = []
    for ch in all_children_ind:
        label_children = torch.tensor([ch.item() in x for x in set_children_idx])
        all_label_children.append(label_children)
        pbar.update(1)

all_label_children = torch.stack(all_label_children, dim=0)
# Out:
# 100%|██████████| 61088/61088 [00:00<00:00, 77814.47it/s]

# %%
### remove multiparent children
classifier_children = classifier_children[all_label_children.sum(dim=-1)==1]
all_label_children = all_label_children[all_label_children.sum(dim=-1)==1]
### to parent label ind
all_label_children = all_label_children.float().argmax(dim=-1)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, verbose=2)
ftr = tsne.fit_transform(torch.cat([classifier_parent, classifier_children]).cpu().numpy())
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 46255 samples in 0.012s...
# [t-SNE] Computed neighbors for 46255 samples in 41.849s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 46255
# [t-SNE] Computed conditional probabilities for sample 2000 / 46255
# [t-SNE] Computed conditional probabilities for sample 3000 / 46255
# [t-SNE] Computed conditional probabilities for sample 4000 / 46255
# [t-SNE] Computed conditional probabilities for sample 5000 / 46255
# [t-SNE] Computed conditional probabilities for sample 6000 / 46255
# [t-SNE] Computed conditional probabilities for sample 7000 / 46255
# [t-SNE] Computed conditional probabilities for sample 8000 / 46255
# [t-SNE] Computed conditional probabilities for sample 9000 / 46255
# [t-SNE] Computed conditional probabilities for sample 10000 / 46255
# [t-SNE] Computed conditional probabilities for sample 11000 / 46255
# [t-SNE] Computed conditional probabilities for sample 12000 / 46255
# [t-SNE] Computed conditional probabilities for sample 13000 / 46255
# [t-SNE] Computed conditional probabilities for sample 14000 / 46255
# [t-SNE] Computed conditional probabilities for sample 15000 / 46255
# [t-SNE] Computed conditional probabilities for sample 16000 / 46255
# [t-SNE] Computed conditional probabilities for sample 17000 / 46255
# [t-SNE] Computed conditional probabilities for sample 18000 / 46255
# [t-SNE] Computed conditional probabilities for sample 19000 / 46255
# [t-SNE] Computed conditional probabilities for sample 20000 / 46255
# [t-SNE] Computed conditional probabilities for sample 21000 / 46255
# [t-SNE] Computed conditional probabilities for sample 22000 / 46255
# [t-SNE] Computed conditional probabilities for sample 23000 / 46255
# [t-SNE] Computed conditional probabilities for sample 24000 / 46255
# [t-SNE] Computed conditional probabilities for sample 25000 / 46255
# [t-SNE] Computed conditional probabilities for sample 26000 / 46255
# [t-SNE] Computed conditional probabilities for sample 27000 / 46255
# [t-SNE] Computed conditional probabilities for sample 28000 / 46255
# [t-SNE] Computed conditional probabilities for sample 29000 / 46255
# [t-SNE] Computed conditional probabilities for sample 30000 / 46255
# [t-SNE] Computed conditional probabilities for sample 31000 / 46255
# [t-SNE] Computed conditional probabilities for sample 32000 / 46255
# [t-SNE] Computed conditional probabilities for sample 33000 / 46255
# [t-SNE] Computed conditional probabilities for sample 34000 / 46255
# [t-SNE] Computed conditional probabilities for sample 35000 / 46255
# [t-SNE] Computed conditional probabilities for sample 36000 / 46255
# [t-SNE] Computed conditional probabilities for sample 37000 / 46255
# [t-SNE] Computed conditional probabilities for sample 38000 / 46255
# [t-SNE] Computed conditional probabilities for sample 39000 / 46255
# [t-SNE] Computed conditional probabilities for sample 40000 / 46255
# [t-SNE] Computed conditional probabilities for sample 41000 / 46255
# [t-SNE] Computed conditional probabilities for sample 42000 / 46255
# [t-SNE] Computed conditional probabilities for sample 43000 / 46255
# [t-SNE] Computed conditional probabilities for sample 44000 / 46255
# [t-SNE] Computed conditional probabilities for sample 45000 / 46255
# [t-SNE] Computed conditional probabilities for sample 46000 / 46255
# [t-SNE] Computed conditional probabilities for sample 46255 / 46255
# [t-SNE] Mean sigma: 0.017483
# [t-SNE] Computed conditional probabilities in 1.588s
# [t-SNE] Iteration 50: error = 113.1903305, gradient norm = 0.0215503 (50 iterations in 4.167s)
# [t-SNE] Iteration 100: error = 113.1689529, gradient norm = 0.0005196 (50 iterations in 4.437s)
# [t-SNE] Iteration 150: error = 110.6829071, gradient norm = 0.0133070 (50 iterations in 4.244s)
# [t-SNE] Iteration 200: error = 109.9958649, gradient norm = 0.0055465 (50 iterations in 4.058s)
# [t-SNE] Iteration 250: error = 109.9312286, gradient norm = 0.0027142 (50 iterations in 4.127s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 109.931229
# [t-SNE] Iteration 300: error = 5.3689122, gradient norm = 0.0016550 (50 iterations in 3.885s)
# [t-SNE] Iteration 350: error = 4.7353253, gradient norm = 0.0006531 (50 iterations in 3.780s)
# [t-SNE] Iteration 400: error = 4.3983603, gradient norm = 0.0004213 (50 iterations in 4.542s)
# [t-SNE] Iteration 450: error = 4.1743736, gradient norm = 0.0003073 (50 iterations in 4.192s)
# [t-SNE] Iteration 500: error = 4.0094476, gradient norm = 0.0002403 (50 iterations in 4.034s)
# [t-SNE] Iteration 550: error = 3.8804162, gradient norm = 0.0001949 (50 iterations in 4.746s)
# [t-SNE] Iteration 600: error = 3.7752440, gradient norm = 0.0001638 (50 iterations in 4.778s)
# [t-SNE] Iteration 650: error = 3.6873138, gradient norm = 0.0001408 (50 iterations in 4.659s)
# [t-SNE] Iteration 700: error = 3.6123071, gradient norm = 0.0001234 (50 iterations in 4.618s)
# [t-SNE] Iteration 750: error = 3.5472167, gradient norm = 0.0001098 (50 iterations in 4.673s)
# [t-SNE] Iteration 800: error = 3.4902530, gradient norm = 0.0000982 (50 iterations in 4.919s)
# [t-SNE] Iteration 850: error = 3.4400034, gradient norm = 0.0000887 (50 iterations in 4.882s)
# [t-SNE] Iteration 900: error = 3.3952575, gradient norm = 0.0000804 (50 iterations in 4.731s)
# [t-SNE] Iteration 950: error = 3.3549988, gradient norm = 0.0000733 (50 iterations in 4.577s)
# [t-SNE] Iteration 1000: error = 3.3185611, gradient norm = 0.0000673 (50 iterations in 4.812s)
# [t-SNE] KL divergence after 1000 iterations: 3.318561

# %%
import matplotlib.pyplot as plt
plt.figure(dpi=128)
plt.scatter(x=ftr[:len(classifier_parent)][:, 0], y=ftr[:len(classifier_parent)][:, 1], s=2, c=np.arange(len(classifier_parent)), alpha=0.6)
plt.scatter(x=ftr[len(classifier_parent):][:, 0], y=ftr[len(classifier_parent):][:, 1], s=2, c=all_label_children.numpy(), alpha=0.6)
plt.show()

# %%
len(set(reduce(lambda x, y: x+y, children_idx))), len(reduce(lambda x, y: x+y, children_idx))
# Out:
# (61088, 96282)

# %%
classifier_parent.shape, classifier_children.shape
# Out:
# (torch.Size([22, 512]), torch.Size([61088, 512]))
