# %%
import sys
sys.path.append('/home/sheng/OSZSL/')
sys.path.append('/home/sheng/OSZSL/CLIP/')

import os
import json
import re
import time
import pickle
from typing import Union, List
from pprint import pprint
from tqdm import tqdm
from copy import deepcopy
import random
import itertools
import numpy as np
from functools import reduce, partial
from itertools import zip_longest
import seaborn as sns
from collections import Counter, defaultdict, OrderedDict
import matplotlib.pyplot as plt
import heapq
from wordnet_utils import *

import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from ipynb_utils import get_hier_datasets, get_classifier, MCMF_assign_labels
import clip
from data.datasets import get_datasets_oszsl, build_transform, get_hier_datasets, Vocab

# %%
class Config:
    device = 'cuda:1'
    arch = 'ViT-B/16'
    dataset_name = 'imagenet'
    n_sampled_classes = 500
    input_size = 224
    
    batch_size = 512
    use_def = False
    clip_checkpoint = None
    f_classifier = './cache/wordnet_classifier_in21k_word.pth'
    templates_name = 'templates_small'
    
args = Config()

# %%
def load_templates(args):
    with open(f'../{args.templates_name}.json', 'rb') as f:
        templates = json.load(f)['imagenet']
    return templates

def get_vocab():
    """
    Args:
        vocab: {`names`: list, `ids`: synset ids, `parents`: [{synset ids}]}
    """
    with open('/home/sheng/dataset/wordnet_nouns_with_synset_4.pkl', 'rb') as f:
        vocab = pickle.load(f)
    return vocab

def get_subsample_vocab(sample_synset_id: set):
    vocab = get_vocab()
    index = np.array([ i for i in range(len(vocab['synsets'])) if vocab['synsets'][i] in sample_synset_id ]).astype(np.int32)
    for k in vocab.keys():
        vocab[k] = np.array(vocab[k])[index].tolist()
    return vocab

def read_imagenet21k_classes():
    with open('/home/sheng/dataset/imagenet21k/imagenet21k_wordnet_ids.txt', 'r') as f:
        data = f.read()
        data = list(filter(lambda x: len(x), data.split('\n')))
    return data

templates = load_templates(args)
vocab = get_vocab()
nouns = [ wn.synset(s) for s in vocab['synsets'] ]
classnames = vocab['names']
parents = vocab['parents']
defs = vocab['def']

# %%
# """ candidate subclasses """
# from data.datasets import read_breeds_class_hierarchy
# superclass = get_hier_datasets(args.dataset_name)[0][0]
# ### get all superclass synset
# parents_breeds = read_breeds_class_hierarchy()
# parents_breeds = { line[1]: line[0] for line in parents_breeds }
# superclass_synset = []
# for s in superclass:
#     if s[:len('dummy')]=='dummy':
#         superclass_synset.append( wn.synset_from_pos_and_offset('n', int(parents_breeds[s][1:])) )
#     else:
#         sup = wn.synset_from_pos_and_offset('n', int(s[1:]))
#         superclass_synset.append(sup)
# ### get all subclass synset id
# closeset_synsets = set()
# for s in superclass_synset:
#     closeset_synsets |= successor_set(G, source=s.name())

# print('candidate number', len(closeset_synsets))

# from robustness.tools.breeds_helpers import ClassHierarchy
# info_dir = '/home/sheng/OSZSL/breeds_hier/modified'
# dataset_hier, hier = get_hier_datasets(args.dataset_name)

# %%
""" build entire wn-graph """
from nxgraph_model import *

with open('/home/sheng/dataset/wordnet_nouns_with_synset.pkl', 'rb') as f:
    entire_vocab = pickle.load(f)
    
G = create_graph([wn.synset(x) for x in entire_vocab['synsets']], entire_vocab['ids'], entire_vocab['names'], entire_vocab['def'])

# %%
""" prepare dataset and load CLIP """
classes = read_imagenet21k_classes() + os.listdir('/home/sheng/dataset/imagenet-img/')
classes = [wn.synset_from_pos_and_offset('n', int(x[1:])).name() for x in classes]
classes = set(classes)
vocab = get_subsample_vocab(classes)
vocab = Vocab(vocab=vocab)

transform_val = build_transform(is_train=False, args=args, train_config=None)
dataset = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_val, seed=1)
loader_val = torch.utils.data.DataLoader(dataset, num_workers=8, batch_size=args.batch_size, shuffle=False)
print('dataset size', len(dataset))

model, preprocess = load_clip(args)
# Out:
# dataset size 132765
# Model parameters: 149,620,737
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %% [markdown]
# #### build classifier

# %%
""" from MUST """
from clip.simple_tokenizer import SimpleTokenizer as _Tokenizer
_tokenizer = _Tokenizer()

def tokenize(texts: Union[str, List[str]], context_length: int = 77, truncate: bool = False) -> torch.LongTensor:
    if isinstance(texts, str):
        texts = [texts]

    sot_token = _tokenizer.encoder["<|startoftext|>"]
    eot_token = _tokenizer.encoder["<|endoftext|>"]
    all_tokens = [[sot_token] + _tokenizer.encode(text) + [eot_token] for text in texts]
    result = torch.zeros(len(all_tokens), context_length, dtype=torch.long)

    for i, tokens in enumerate(all_tokens):
        if len(tokens) > context_length:
            if truncate:
                tokens = tokens[:context_length]
                tokens[-1] = eot_token
            else:
                raise RuntimeError(f"Input {texts[i]} is too long for context length {context_length}")
        result[i, :len(tokens)] = torch.tensor(tokens)

    return result

# %%
batch_size = 64
with torch.no_grad():
    zeroshot_weights = []
    with tqdm(total=len(vocab.classnames)//batch_size) as pbar:
        for classname_set in np.array_split(vocab.classnames, len(vocab.classnames)//batch_size):
            texts = [template.format(classname) for classname in classname_set for template in templates] #format with class
            texts = tokenize(texts).to(args.device) #tokenize
            class_embeddings = model.encode_text(texts).float() #embed with text encoder
            class_embeddings = class_embeddings.view(-1, len(templates), class_embeddings.size(-1))
            class_embeddings = F.normalize(class_embeddings, dim=-1)
            class_embedding = class_embeddings.mean(dim=1)
            class_embedding /= class_embedding.norm(dim=-1, keepdim=True)
            zeroshot_weights.append(class_embedding.cpu())

            pbar.update(1)

classifier = torch.cat(zeroshot_weights, dim=0)
torch.save(classifier, './cache/wordnet_classifier_in21k_word.pth')
# Out:
# 100%|██████████| 313/313 [00:41<00:00,  7.54it/s]

# %% [markdown]
# ### performance test

# %% [markdown]
# #### utils

# %%
def load_clip(args):
    model, preprocess = clip.load(args.arch)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model, preprocess

def topk_acc(all_pred_voc_topk, all_gt_voc):
    acc = []
    ### topK accuracy
    for i in range(all_pred_voc_topk.size(1)):
        vec = torch.zeros(all_pred_voc_topk.size(0)).bool()
        for j in range(i+1):
            vec |= (all_pred_voc_topk[:, j]==all_gt_voc)
        print(f'k={i} acc={vec.float().mean()}')
        acc.append(vec.float().mean().item())
    return acc

def semantic_acc(y_pred, y_true, metrics={}):
    """ compute soft semantic acc for @y_pred and @y_true """
    assert len(metrics)>0
    assert y_pred.size(0)==y_true.size(0)
    scores = {m:[] for m in metrics.keys()}
    with tqdm(total=y_pred.size(0)) as pbar:
        for i in range(y_pred.size(0)):
            syn_pred = mapping_vocidx_to_synsets(y_pred[i].item(), vocab)
            syn_true = mapping_vocidx_to_synsets(y_true[i].item(), vocab)
            pairs = list(itertools.product(range(len(syn_pred)), range(len(syn_true))))
            for m_name, m in metrics.items():
                scores[m_name].append( max([ m(syn_pred[p[0]], syn_true[p[1]]) for p in pairs ]) )
            pbar.update(1)
    for m_name in metrics.keys():
        scores[m_name] = np.array(scores[m_name]).mean()
    return scores

# %% [markdown]
# #### naive inference

# %%
classifier = get_classifier(args)
amp_autocast = torch.cuda.amp.autocast
classifier = classifier/classifier.norm(dim=-1, keepdim=True)

all_pred_voc = []
all_gt_voc = []
all_pred_voc_topk = []
with tqdm(total=len(loader_val)) as pbar:
    model.eval()
    for idx_batch, batch in enumerate(loader_val):
        images, label_voc, label_clu, idx_img = batch
        images = images.to(args.device)
        with amp_autocast():
            with torch.no_grad():
                logits = model.visual(images)
                logits = logits/logits.norm(dim=-1, keepdim=True)
                similarity = model.logit_scale.exp() * logits @ classifier.t()
                prob = similarity.softmax(-1)
                all_pred_voc.append(prob.argmax(dim=-1).cpu())
                all_gt_voc.append(label_voc)
                all_pred_voc_topk.append(prob.topk(k=5, dim=-1).indices.cpu())
        pbar.update(1)

all_pred_voc = torch.cat(all_pred_voc, dim=0)
all_gt_voc = torch.cat(all_gt_voc, dim=0)
all_pred_voc_topk = torch.cat(all_pred_voc_topk, dim=0)
# Out:
# 100%|██████████| 260/260 [02:35<00:00,  1.68it/s]

# %%
print(f'acc={(all_pred_voc == all_gt_voc).float().mean()}')
n_missing = len(set(all_gt_voc.unique().numpy()) - set(all_pred_voc.unique().numpy()))
print(f'n_missing={n_missing}')
# Out:
# acc=0.33346137404441833
# n_missing=2

# %%
score_baseline = semantic_acc(all_pred_voc, all_gt_voc, 
                              metrics={'wup_similarity': wn.wup_similarity, 'lch_similarity': wn.lch_similarity})
print(score_baseline)
# Out:
# 100%|██████████| 132765/132765 [01:03<00:00, 2096.07it/s]
# {'wup_similarity': 0.751388662643735, 'lch_similarity': 2.3188224544809772}

# %%
topk_acc(all_pred_voc_topk, all_gt_voc)
# Out:
# k=0 acc=0.33335593342781067
# k=1 acc=0.45885586738586426
# k=2 acc=0.5238654613494873
# k=3 acc=0.5691183805465698
# k=4 acc=0.6037208437919617
# [0.33335593342781067,
#  0.45885586738586426,
#  0.5238654613494873,
#  0.5691183805465698,
#  0.6037208437919617]

# %% [markdown]
# #### SCD

# %%
from sklearn.cluster import KMeans
from my_util_package.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment

subset = ['train', 'val'][0]

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(256, interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.CenterCrop(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
if subset == 'train':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=1)
elif subset == 'val':
    dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=1)
args.nb_classes = dataset_f.num_classes
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=4, batch_size=args.batch_size, shuffle=False)

# %%
def agg_by_pred_cluster(args, pred_kmeans, all_topk_voc, voc_size):
    """
    Args:
        pred_kmeans: np.array([N])
        all_topk_voc: np.array([N x K])
        voc_size: int
    Returns:
        all_clu_pred: tensor([C x V])
    """
    print('agg_by_pred_cluster')
    all_clu_pred = []
    n_count = []
    for i in np.unique(pred_kmeans):
        selected = (pred_kmeans==i)
        n_count.append( selected.sum().item() )
        counter_voc_ind, counter_val = np.unique((all_topk_voc[selected]).ravel(), return_counts=True)
        # counter_val = counter_val/(n_count+1e-20) # L1 norm
        clu_pred = torch.zeros(args.num_voc) # cluster-wise prob
        clu_pred[torch.from_numpy(counter_voc_ind).long()] = torch.from_numpy(counter_val).float()
        # clu_pred = F.normalize(all_topk_voc[selected].sum(dim=0), dim=-1, p=1)
        all_clu_pred.append(clu_pred)
    all_clu_pred = torch.stack(all_clu_pred, dim=0).cpu()
    n_count = torch.tensor(n_count).cpu()
    
    # all_clu_pred = setdiff_assignment(all_clu_pred)
    
    all_clu_pred = all_clu_pred/(n_count.view(-1, 1) + 1e-20)
    
    print('is mutex assignment::', all_clu_pred.argmax(dim=-1).size(0)==all_clu_pred.argmax(dim=-1).unique().size(0))
    print('assignment collision num::', len(list(filter(lambda x: x>1, Counter(all_clu_pred.argmax(dim=-1).numpy()).values()))))
    return all_clu_pred

def linear_assign(all_clu_pred, pred_kmeans, all_gt_voc, return_results=False):
    print('linear_assign')
    cost_mat = all_clu_pred.cpu().numpy()
    print(f'assignment shape={cost_mat.shape}')
    res_ass = linear_assignment(cost_mat.max() - cost_mat)
    label_voc_kmeans = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])
    inst_acc = (label_voc_kmeans==all_gt_voc).float().mean().item()
    print('instance label acc::', inst_acc)
    if return_results:
        return label_voc_kmeans, res_ass, inst_acc
    return label_voc_kmeans, res_ass

def reassign_by_pred_cluster(label_voc_kmeans, model, classifier, device, 
                             all_prob=None, 
                             instance_selected=None, 
                             classifier_selected=None):
    """
    Args:
        classifier_selected: tensor([C2])
    """
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device)
    if all_prob is None:
        cluster_ind = []
        with tqdm(total=len(loader_f)) as pbar:
            if hasattr(model, 'eval'):
                model.eval()
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                if (instance_selected is not None) and ((~instance_selected[idx_img]).all()):
                    continue
                with amp_autocast():
                    with torch.no_grad():
                        if (instance_selected is not None):
                            logits = model.visual(images[instance_selected[idx_img]])
                        else:
                            logits = model.visual(images)
                            
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        if classifier_selected is not None:
                            similarity = 100 * logits @ classifier[classifier_selected].t()
                            prob = classifier_selected[similarity.softmax(-1)]
                            cluster_ind.append(prob.cpu().argmax(dim=-1))
                        else:
                            similarity = 100 * logits @ classifier.t()
                            prob = similarity.softmax(-1)
                            cluster_ind.append(prob[:, label_voc_kmeans].cpu().argmax(dim=-1))
                pbar.update(1)
        cluster_ind = torch.cat(cluster_ind, dim=0)
    else:
        all_prob = all_prob[:, label_voc_kmeans]
        cluster_ind = all_prob.argmax(dim=-1)
        
    if classifier_selected is not None:
        cluster_ind_voc = classifier_selected[cluster_ind]
    else:
        cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def computation_reassign_by_pred_cluster(row, idx, args, model, classifier, candidate_classifier_ind):
    """
    candidate_classifier_ind = label_voc_kmeans.unique().to(args.device)
    """
    images, label_voc, label_clu, idx_img = row[:4]
    images = images.to(args.device)
    with amp_autocast():
        vfeatures = model.visual(images).float()
        # vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
    vfeatures = F.normalize(vfeatures, dim=-1)
    batch_sim = 100*vfeatures@classifier[candidate_classifier_ind].t()
    cluster_ind = batch_sim.argmax(dim=-1)
    cluster_ind_voc = candidate_classifier_ind[cluster_ind].cpu()
    return cluster_ind_voc

def aggregation_reassign_by_pred_cluster(r, candidate_classifier_ind):
    cluster_ind_voc = torch.cat(r, dim=0)
    mapping_ind = dict(zip(cluster_ind_voc.unique().numpy(), torch.arange(cluster_ind_voc.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind_voc])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def extract_vfeatures(model, data_loader, device):
    amp_autocast = torch.cuda.amp.autocast
    all_vfeatures = []
    with tqdm(total=len(data_loader)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        for idx_batch, batch in enumerate(data_loader):
            images, label_voc, label_clu, idx_img = batch[:4]
            images = images.to(device)
            with amp_autocast():
                vfeatures = model.visual(images).float()
            vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
            all_vfeatures.append(vfeatures.cpu().numpy())
            pbar.update(1)
    all_vfeatures = np.concatenate(all_vfeatures)
    return all_vfeatures


@torch.no_grad()
def loop_row_collect_results_nograd(obj_iter, computations={}, aggregations={}):
    """ compute and aggregate results, looping over @obj_iter 
    func_computation(@row, @index_row)
    aggregations(list(@results_computation))
    """
    assert set(list(computations.keys())) == set(list(aggregations.keys()))
    collector = { k:[] for k in computations }
    with tqdm(total=len(obj_iter)) as pbar:
        for i, row in enumerate(obj_iter):
            ### apply computations
            for k, func in computations.items():
                collector[k].append(func(row, i))
            pbar.update(1)
    ### aggregate results
    results = {}
    for k, func_agg in aggregations.items():
        results[k] = func_agg(collector[k])
    return results

# %%
loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=1, batch_size=args.batch_size, shuffle=False)
# classifier = get_classifier(args)
# classifier = classifier/classifier.norm(dim=-1, keepdim=True)
# args.num_voc = classifier.size(0)
# amp_autocast = torch.cuda.amp.autocast
# ### collect variables
# prob_k = 5
# all_topk_voc = []
# all_gt_voc = []
# all_label_clu = []
# with tqdm(total=len(loader_f)) as pbar:
#     if hasattr(model, 'eval'):
#         model.eval()
#     for idx_batch, batch in enumerate(loader_f):
#         images, label_voc, label_clu, idx_img = batch[:4]
#         images = images.to(args.device)
#         with amp_autocast():
#             with torch.no_grad():
#                 logits = model.visual(images)
#                 logits = logits/logits.norm(dim=-1, keepdim=True)
#                 similarity = 100 * logits @ classifier.t()
#                 prob = similarity.softmax(-1)
#                 prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
#                 all_topk_voc.append(prob_topk_ind.cpu().numpy())
#                 all_gt_voc.append(label_voc)
#                 all_label_clu.append(label_clu)
#         pbar.update(1)

# all_topk_voc = np.concatenate(all_topk_voc)
# all_gt_voc = torch.cat(all_gt_voc, dim=0)
# all_label_clu = torch.cat(all_label_clu, dim=0)

pred_kmeans = torch.from_numpy(np.load(f'./pred_clu-{args.dataset_name}-train-clip.npy'))
pred_kmeans_t = pred_kmeans
history_set_pred = []
for t in range(3):
    record_pred_kmeans_t = pred_kmeans_t
    all_clu_pred = agg_by_pred_cluster(args, pred_kmeans_t.numpy(), all_topk_voc, voc_size=args.num_voc)
    label_voc_kmeans, res_ass = linear_assign(all_clu_pred, pred_kmeans_t, all_gt_voc)
    # pred_kmeans_t, cluster_ind_voc = reassign_by_pred_cluster(label_voc_kmeans, model, classifier, args.device)
    results = \
    loop_row_collect_results_nograd(loader_f, 
                                    computations={
                                        'reassign_by_pred_cluster': partial(
                                            computation_reassign_by_pred_cluster, 
                                            args=args, 
                                            model=model, 
                                            classifier=classifier, 
                                            candidate_classifier_ind=label_voc_kmeans.unique().to(args.device),
                                        ),
                                    }, 
                                    aggregations={
                                        'reassign_by_pred_cluster': partial(
                                            aggregation_reassign_by_pred_cluster,
                                            candidate_classifier_ind=label_voc_kmeans.unique().to(args.device),
                                        ),
                                    },
                                   )
    pred_kmeans_t, cluster_ind_voc = results['reassign_by_pred_cluster']
    set_pred = set(res_ass[1].tolist())
    set_gt = set(all_gt_voc.unique().numpy().tolist())
    print('missing label::', len(set_gt - set_pred))
    print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=pred_kmeans_t.numpy()))
    history_set_pred.append(set_pred)
# Out:
# agg_by_pred_cluster
# is mutex assignment:: False
# assignment collision num:: 6
# linear_assign
# assignment shape=(104, 20071)
# instance label acc:: 0.3845817744731903
#  91%|█████████ | 237/260 [13:17<01:20,  3.48s/it]

# %% [markdown]
# #### CHATGPT request

# %%
import openai
def openai_chatgpt_post(content, parameters={'temperature': 0.7}):
    openai.api_key = "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"
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
      messages=[
        {"role": "user", "content": content},
      ],
    **parameters,
    )
    result = completion['choices'][0]['message']['content']
    # completion = openai.Completion.create(
    #     model="text-davinci-003",
    #     prompt=content,  
    #     temperature=0.7,
    #     max_tokens=256,
    #     top_p=1,
    #     frequency_penalty=0,
    #     presence_penalty=0,
    # )
    # result = completion['choices'][0]['text']
    return result

# %%
k_1 = 3
classifier = get_classifier(args).cpu()
sim_classifier = classifier@classifier.t()
topk_all_clu_pred = sim_classifier.topk(k=k_1).indices

# %%
""" gather concepts """
to_name = lambda x: [ s.name() + ': ' + s.definition() for s in x ]
to_name2 = lambda x: [ s.name() for s in x ]
cluster_row_synsets = []
cluster_row_synsets2 = []
for row in topk_all_clu_pred:
    row_synsets = [to_name(mapping_vocidx_to_synsets(voc_idx.item(), vocab)) for voc_idx in row]
    cluster_row_synsets.append(row_synsets)
    row_synsets2 = [to_name2(mapping_vocidx_to_synsets(voc_idx.item(), vocab)) for voc_idx in row]
    cluster_row_synsets2.append(reduce(lambda x,y: x+y, row_synsets2))

    
""" generate concept requests """
concept_request = []
for row in cluster_row_synsets:
    ccpts = reduce(lambda x, y: x+y, row)
    ccpts = list(map(lambda x: "'"+x+".'", ccpts))
    ccpts = ', '.join(ccpts)
    concept_request.append(ccpts)
    
""" generate concept templates """
template_1 = lambda concept_list: "Given visual concepts: "+ concept_list + "List all alternative concept names for each visual concept. List in the format \"{concept name}: {list of names separated by ';'}.\""
with open('/home/sheng/OSZSL/templates_chatgpt.json', 'r') as f:
    template_chatgpt = json.load(f)
template_2 = lambda concept_list: template_chatgpt['pictionary-long'].format(concept_list)
template_3 = lambda concept_list: template_chatgpt['pictionary-short'].format(concept_list)
template_4 = lambda concept_list: template_chatgpt['direct'].format(concept_list)
    
template_in_use = template_1
concept_templates = []
for row in concept_request:
    concept_templates.append(template_in_use(row))

# %%
""" collect chatgpt res """
n_repeat = 3
all_chatgpt_res = [[] for _ in range(n_repeat)]
with tqdm(total=len(concept_templates)*n_repeat) as pbar:
    for i in range(n_repeat):
        for row in concept_templates:
            while 1:
                try:
                    all_chatgpt_res[i].append(openai_chatgpt_post(row))
                    break
                except Exception as e:
                    print(e)

            pbar.update(1)

# %%
with open(f'./cache/openai/visual-inov-template=1-k_1={k_1}-repeat={n_repeat}-part=3.pkl', 'wb') as f:
    pickle.dump(all_chatgpt_res, f)

# %% [markdown]
# ### combine results

# %%
""" combine results """
extracted_res_chatgpt = [[] for _ in range(3)]
with open(f'./cache/openai/visual-inov-template=1-k_1={k_1}-repeat={n_repeat}-part=1.pkl', 'rb') as f:
    data = pickle.load(f)
    for i in range(3):
        extracted_res_chatgpt[i].extend(data[i])
    
with open(f'./cache/openai/visual-inov-template=1-k_1={k_1}-repeat={n_repeat}-part=2.pkl', 'rb') as f:
    data = pickle.load(f)
    for i in range(3):
        extracted_res_chatgpt[i].extend(data[i])
    
with open(f'./cache/openai/visual-inov-template=1-k_1={k_1}-repeat={n_repeat}-part=3.pkl', 'rb') as f:
    data = pickle.load(f)
    for i in range(3):
        extracted_res_chatgpt[i].extend(data[i])

# %%
""" integrity check """
while 1:
    invalid_indices = []
    for i in range(n_repeat):
        for j, row in enumerate(extracted_res_chatgpt[i]):
            remove_space = lambda r: list(filter(lambda x: len(x), r))
            extract_synsetid = lambda r: list(map(lambda x: x.split(': ')[0].strip('"'), r))
            extract_names = lambda r: map(lambda y: remove_space(y.split('; ')),
                                          map(lambda x: ': '.join(x.split(': ')[1:]), r),
                                         )
            row_data = remove_space(row.lower().replace('\n\n', '\n').split('\n'))
            row_data_concept = remove_space(concept_request[j].lower().replace('\n\n', '\n').split('\n'))
            gt_synsets = cluster_row_synsets2[j]
            try:
                synsets = extract_synsetid(row_data)
                names = list(extract_names(remove_space(row.lower().replace('\n\n', '\n').split('\n'))))
                for s in synsets:
                    assert len(s)>0
                for r in names:
                    assert len(r)>0
                assert set(gt_synsets)==set(synsets)
            except Exception as e:
                print(i, j)
                print(len(synsets), len(names), set(gt_synsets)==set(synsets))
                print(synsets, gt_synsets, names)
                invalid_indices.append((i, j))
    if len(invalid_indices):
        print('num_invalid=', len(invalid_indices))
        for i, j in invalid_indices:
            print(f'repair {i} {j} {extracted_res_chatgpt[i][j]}')
            z = openai_chatgpt_post(concept_templates[j], {'temperature': 0.8})
            extracted_res_chatgpt[i][j] = z
    else:
        break

# %%
# extracted_res_chatgpt[0][8930] = 'euopean_hoopoe.n.01: Eurasian hoopoe; Upupa epops\nwood_hoopoe.n.01: Forest hoopoe; Phoeniculus castaneiceps\nredheaded_woodpecker.n.01: Melanerpes erythrocephalus; redhead woodpecker'
# extracted_res_chatgpt[1][6084] = 'dusky-footed_woodrat.n.01: Woodrat host to Lyme disease tick (Ixodes pacificus) in northern California; Dusky-footed rat with Lyme disease tick host in Northern California\nwood_rat.n.01: Northern hemisphere rodent with soft grey and white fur and furred tails; Rodent with large ears and some are Lyme disease tick hosts; Small short-tailed rodent with fur and ears\nbrown_rat.n.01: Common domestic rat; Serious pest worldwide rat\n'
# extracted_res_chatgpt[1][8930] = 'euopean_hoopoe.n.01: Eurasian hoopoe; Upupa epops; pinkish-brown bird with black-and-white wings.\nWood_hoopoe.n.01: Forest hoopoe; Phoeniculus castaneiceps; African bird with metallic blackish plumage but no crest.\nRedheaded_woodpecker.n.01: Melanerpes erythrocephalus; North American woodpecker with black-and-white plumage and red head and neck; Red-headed flicker.'
# extracted_res_chatgpt[1][11774] = 'round-tailed_muskrat.n.01: Florida muskrat; round-tailed rat; Florida swamp rat\nbeaver_rat.n.01: Australian beaver rat; New Guinea amphibious rat; water rat\nbeaver.n.07: aquatic rodent; dam builder; flat-tailed rodent\nbeaver.n.06: fur hat; beaver pelt hat; warm hat\nbeaver.n.05: visor; face guard; helmet flap'
# extracted_res_chatgpt[2][11774] = 'round-tailed_muskrat.n.01: Florida muskrat; Florida water rat.\nbeaver_rat.n.01: Beaver rat; Water rat; Amphibious rodent.\nbeaver.n.07: North American beaver; Canadian beaver; Aquatic rodent.\nbeaver.n.06: Beaver hat; Fur hat; Top hat.\nbeaver.n.05: Lower face guard; Visor'

# %%
synset_to_names = {}
for i in range(n_repeat):
    for j, row in enumerate(extracted_res_chatgpt[i]):
        remove_space = lambda r: list(filter(lambda x: len(x), r))
        extract_synsetid = lambda r: list(map(lambda x: x.split(': ')[0].strip('"'), r))
        extract_names = lambda r: map(lambda y: remove_space(y.split('; ')),
                                      map(lambda x: ': '.join(x.split(': ')[1:]), r),
                                     )
        row_data = remove_space(row.lower().replace('\n\n', '\n').split('\n'))
        row_data_concept = remove_space(concept_request[j].lower().replace('\n\n', '\n').split('\n'))
        gt_synsets = cluster_row_synsets2[j]
        synsets = extract_synsetid(row_data)
        names = list(extract_names(remove_space(row.lower().replace('\n\n', '\n').split('\n'))))
        for s, n in zip(synsets, names):
            synset_to_names.setdefault(s.split('.')[0], [])
            synset_to_names[s.split('.')[0]].extend(n)

# %%
set(list(synset_to_names.keys()))
# Out:
# {'sun',
#  'rock_climbing',
#  'chub',
#  'black_belt',
#  'chuvash',
#  'stuffed_tomato',
#  'ray',
#  'parasol_mushroom',
#  'betting_shop',
#  'scauper',
#  'procyonid',
#  'common_teasel',
#  'ski_parka',
#  'bowling_alley',
#  'carrot_stick',
#  'wild_rosemary',
#  'vehicle',
#  'drip_pot',
#  'foster-brother',
#  'dryland_blueberry',
#  'pathogen',
#  'longan',
#  'eparchy',
#  'ciderpress',
#  'chandelier',
#  'citrus_mealybug',
#  'feverroot',
#  'field_brome',
#  'class_act',
#  'dressing_gown',
#  'wood_grain',
#  'field_artillery',
#  'alpine_goldenrod',
#  'lemon_lily',
#  'dog_stinkhorn',
#  'japanese_red_pine',
#  'new_world_blackbird',
#  'creme_de_cacao',
#  'sierra_plum',
#  'rough_green_snake',
#  'scabious',
#  'coast_live_oak',
#  'sound_spectrograph',
#  'container',
#  'recruiter',
#  'tarragon',
#  'trunk_line',
#  'vanilla_orchid',
#  'keyhole_limpet',
#  'defense_contractor',
#  'endive',
#  'water-cooled_reactor',
#  'european_hackberry',
#  'dining_table',
#  'agora',
#  'penknife',
#  'muscadet',
#  'romanian',
#  'european_goatsucker',
#  'thermograph',
#  'redshank',
#  'antiperspirant',
#  'goby',
#  'red_goatfish',
#  'drip_pan',
#  'rivet',
#  'apprehender',
#  'manta',
#  'oil_cake',
#  'nightingale',
#  'dancing-master',
#  'coraciiform_bird',
#  'dressing_sack',
#  'leukocyte',
#  'creeping_fern',
#  'lacewing',
#  'voltmeter',
#  'bowerbird',
#  'tailpipe',
#  'spritzer',
#  'syconium',
#  'sanitary_landfill',
#  'loosestrife',
#  'spring',
#  'wingstem',
#  'seat',
#  'betel',
#  'condiment',
#  'sweet',
#  'computer_scientist',
#  'pinfish',
#  'columnea',
#  'robber_fly',
#  'plier',
#  'sledding',
#  'dolly',
#  'button_snakeroot',
#  'pier_table',
#  'hornist',
#  'fritillary',
#  'western_buttercup',
#  'banquet',
#  'proprioceptor',
#  'naval_missile',
#  'plover',
#  'maleberry',
#  'mulligatawny',
#  'raven',
#  'cornish_heath',
#  'water_tower',
#  'muskmelon',
#  'elegist',
#  'cargo_container',
#  'secretary_of_the_interior',
#  'whitebark_pine',
#  'brant',
#  'clip_lead',
#  'vinifera',
#  'gametangium',
#  'disk_brake',
#  'pop',
#  'poker',
#  'storm_window',
#  'coastal_rein_orchid',
#  'bryony',
#  'jurist',
#  'gynobase',
#  'alpine_besseya',
#  'muffin_man',
#  'snowbell',
#  'thrust_bearing',
#  'sights',
#  'lunch',
#  'bunting',
#  'thousand_island_dressing',
#  'white_mallee',
#  'slug',
#  'cornetfish',
#  'nondescript',
#  'stallion',
#  'yellowbelly_marmot',
#  'european_larch',
#  'headquarters',
#  'baa-lamb',
#  'shumard_oak',
#  'banded_krait',
#  'treelet',
#  'lemming',
#  'safety_pin',
#  'boletus_zelleri',
#  'heir',
#  'ensemble',
#  'alpine_totara',
#  'grandmaster',
#  'segmental_arch',
#  'bleu',
#  'faceplate',
#  'khukuri',
#  'chinese_angelica',
#  'emperor_penguin',
#  'kaffir_bread',
#  'dish_rack',
#  'grissino',
#  'ceratozamia',
#  'hacksaw',
#  'holder',
#  'citrus_whitefly',
#  'hematologist',
#  'lithosphere',
#  'winter_crookneck',
#  'night_rider',
#  'spike_lavender',
#  'step-down_transformer',
#  'pedant',
#  'northern_phalarope',
#  'doodia',
#  'artifact',
#  'namibian',
#  'common_matrimony_vine',
#  'building',
#  'stately_home',
#  'conodont',
#  'bastard_wing',
#  'red_shrubby_penstemon',
#  'boom',
#  'little_egret',
#  'creeping_bugle',
#  'teleost_fish',
#  'dental_appliance',
#  'common_dandelion',
#  'grapefruit_juice',
#  'meadow_saxifrage',
#  'five-spot',
#  'home_plate',
#  'pullover',
#  'old_man',
#  'deck_chair',
#  'gladiator',
#  'trout',
#  'java_sparrow',
#  'airliner',
#  'mate',
#  'fore-topsail',
#  'debtor',
#  'silk',
#  'printer_cable',
#  'macadamia_integrifolia',
#  'service_tree',
#  'bull',
#  'mill_agent',
#  'jack-o-lantern_fungus',
#  'soapberry_vine',
#  'pellitory-of-the-wall',
#  'binocular_microscope',
#  'lean-to_tent',
#  'cappuccino',
#  'major',
#  'hang_glider',
#  'coelogyne',
#  'cavity_wall',
#  'whetstone',
#  'maidenhair',
#  'poisonous_plant',
#  'martin',
#  'sachet',
#  'boat_train',
#  'sawmill',
#  'trooper',
#  'margrave',
#  'parnassia',
#  'perianth',
#  'totara',
#  'tree_squirrel',
#  'beaver',
#  'liza',
#  'pulse_timing_circuit',
#  'narrow_wale',
#  'nuclear_reactor',
#  'bloodmobile',
#  'oak_chestnut',
#  'covered_wagon',
#  'safety_belt',
#  'seeded_raisin',
#  'sonic_depth_finder',
#  'sangoma',
#  'snap',
#  'indian_python',
#  'wife',
#  'marocain',
#  'english_toy_spaniel',
#  'radome',
#  'oncologist',
#  'liebfraumilch',
#  "wilson's_warbler",
#  'cubitiere',
#  'spearnose_bat',
#  'liver_fluke',
#  'optical_telescope',
#  'southern_cabbage_butterfly',
#  'pillow_lace',
#  'coffeeberry',
#  'lesser_calamint',
#  'saturniid',
#  "goldie's_fern",
#  'cistern',
#  'sweet_cider',
#  'cornishman',
#  'abbey',
#  'chachka',
#  'pawnbroker',
#  'snapdragon',
#  'rubber_eraser',
#  "carpenter's_hammer",
#  'town_crier',
#  'automobile_engine',
#  'fir_clubmoss',
#  'mechanical_engineer',
#  'autophyte',
#  'crypt',
#  'flowering_maple',
#  'kola',
#  'lancewood',
#  'beardless_iris',
#  'saltshaker',
#  'tannoy',
#  'crematory',
#  'chinese_goose',
#  'gelechiid',
#  'whale',
#  'percussion_cap',
#  'abrocome',
#  'positron_emission_tomography_scanner',
#  'glacier',
#  'silky_dogwood',
#  'kid',
#  'active',
#  'pipe_bomb',
#  'harrier',
#  'peristyle',
#  'hair_slide',
#  'conservatory',
#  'gruel',
#  'thermometer',
#  'barrage_balloon',
#  'western_diamondback',
#  'pedicel',
#  'slit_trench',
#  'hot_pot',
#  'eohippus',
#  'branchlet',
#  'siberian_husky',
#  'leadwort',
#  'tack',
#  'grocer',
#  'bailey',
#  'goal',
#  'addle-head',
#  'microphone',
#  'begonia',
#  'alligator_snapping_turtle',
#  'surface-to-air_missile_system',
#  'bookshop',
#  'perennial_ryegrass',
#  'wort',
#  'polypody',
#  'pouched_mouse',
#  'barley_water',
#  'jewels-of-opar',
#  'cutty_stool',
#  'darling_pea',
#  'tenter',
#  'superconducting_supercollider',
#  'gatherer',
#  'pavis',
#  'bannister',
#  'horned_viper',
#  'horn',
#  'cotton_rat',
#  "calf's-foot_jelly",
#  'pecopteris',
#  'bottom_rot_fungus',
#  'carob',
#  'tamandua',
#  'grosbeak',
#  'young_buck',
#  'gent',
#  'nightgown',
#  'wheat_rust',
#  'color_guard',
#  'pet_sitter',
#  'butt_hinge',
#  'wood_chisel',
#  'rock_crab',
#  'lepiota',
#  'superior',
#  'koala',
#  'water-mint',
#  'ball_valve',
#  'doughnut',
#  'contact_sport',
#  'vinegar_eel',
#  'microprocessor',
#  'elbow_pad',
#  'scarlet_plume',
#  'barbecue',
#  'grantee',
#  'king_charles_spaniel',
#  'ascomycete',
#  'cultivated_parsnip',
#  'sack',
#  'three-day_event',
#  'jacket_potato',
#  'giant_hornet',
#  "climbing_bird's_nest_fern",
#  'drilling_platform',
#  'key_lime',
#  'shrimp_cocktail',
#  'minicomputer',
#  'gempylid',
#  'spectrophotometer',
#  'clammy_locust',
#  'short-horned_grasshopper',
#  'pickerel_frog',
#  'doorsill',
#  'rock_rattlesnake',
#  'single-reed_instrument',
#  'needlefish',
#  'winter_aconite',
#  'chincapin',
#  'synchroscope',
#  'cushion_flower',
#  'cornmeal',
#  'hop',
#  'greater_masterwort',
#  'first_sergeant',
#  'meter',
#  'common_staghorn_fern',
#  'hawse',
#  'irish_water_spaniel',
#  'arranger',
#  'abutment_arch',
#  'cabin_car',
#  'doliolum',
#  'gas_holder',
#  'kaffir_boom',
#  "guard's_van",
#  'roller_bandage',
#  'shortgrass',
#  'anomaly',
#  'calliopsis',
#  'english_primrose',
#  'common_european_earwig',
#  'heating_pad',
#  'bandoneon',
#  'exhaust_valve',
#  'futurist',
#  'white_prairie_aster',
#  'colorimeter',
#  'headsail',
#  "red_angel's_trumpet",
#  'liederkranz',
#  'albatrellus_ovinus',
#  'boletus_luridus',
#  'sea_pen',
#  'garden_lettuce',
#  'orange',
#  'jewelled_headdress',
#  'lenten_rose',
#  'canthus',
#  'shrimp_newburg',
#  'system',
#  'ram',
#  'pippin',
#  'speakerphone',
#  'homespun',
#  'american_raspberry',
#  'olive_drab',
#  'passenger',
#  'quilt',
#  'right-hand_man',
#  'egg-and-dart',
#  'sandbar',
#  'common_wallaby',
#  'trailing_edge',
#  'circular_saw',
#  'wryneck',
#  'highboy',
#  'yardstick',
#  'paper_mill',
#  'commanding_officer',
#  'tortricid',
#  "clark's_nutcracker",
#  'hutment',
#  'manna_ash',
#  "levi's",
#  'bowling_shoe',
#  'chamomile',
#  'sweet_potato',
#  'silver_willow',
#  'snowy_orchid',
#  'high-definition_television',
#  'ingenue',
#  'sewer',
#  'slave-making_ant',
#  'chimney_swift',
#  'swamp',
#  'pelecaniform_seabird',
#  'sourball',
#  'clothes_dryer',
#  'fuddy-duddy',
#  'flying_boat',
#  'research_center',
#  'wild_celery',
#  'test_rocket',
#  'foredeck',
#  'safe_house',
#  'web_spinner',
#  'wooden_spoon',
#  'ripping_bar',
#  'sennit',
#  'bitewing',
#  'padrone',
#  'marsh_harrier',
#  'thunder_snake',
#  'x-ray_film',
#  'pogge',
#  'manipulator',
#  'aircraft_carrier',
#  'stranger',
#  'teashop',
#  'colobus',
#  'spaghetti_sauce',
#  'cauliflower',
#  'bedclothes',
#  'lash',
#  'piping_guan',
#  'chamberpot',
#  'shank',
#  'jail',
#  'golden_saxifrage',
#  'rainbow_cactus',
#  'communication_system',
#  'rampant_arch',
#  'cardinal',
#  'benedictine',
#  'germ_tube',
#  'dormitory',
#  'cup_hook',
#  'rocket_engineer',
#  'shuttle_helicopter',
#  'hatchel',
#  'canada_wild_rye',
#  'sclerite',
#  'old_world_white_pelican',
#  'draft_beer',
#  'radio_transmitter',
#  'bobby',
#  'teddy',
#  'freshwater_mussel',
#  'giant_taro',
#  'matchboard',
#  'backspace_key',
#  'flop',
#  'counselor',
#  'pitcher_plant',
#  'wing_tip',
#  'almond',
#  'downy_wood_mint',
#  'ridge',
#  'clitocybe_robusta',
#  'professional_tennis',
#  'shipwreck',
#  'char',
#  'flip-flop',
#  'paster',
#  'puffbird',
#  'crane_fly',
#  'stinking_goosefoot',
#  'scoter',
#  'spadix',
#  'stormy_petrel',
#  'cape_buffalo',
#  'black-backed_gull',
#  'fomite',
#  'hellebore',
#  'narrow_goldenrod',
#  'insect',
#  'gouger',
#  'paleolith',
#  'popcorn_ball',
#  'prosthesis',
#  'french_lavender',
#  'munj',
#  'big_game',
#  'mender',
#  'bird_louse',
#  'agriculturist',
#  'yellowfin',
#  'american_mistletoe',
#  'return_key',
#  'wax_myrtle',
#  'tyrannosaur',
#  'bergamot',
#  'pullet',
#  'unwelcome_person',
#  'arthroscope',
#  'actinomycete',
#  'swamp_cottonwood',
#  'surinam_cherry',
#  'inflorescence',
#  'northern_baptist',
#  'hutch',
#  'chlamydospore',
#  'headscarf',
#  'sports_equipment',
#  'cul',
#  'throne',
#  'lockstitch',
#  'ship-breaker',
#  'blood_sport',
#  'soursop',
#  'hand_tool',
#  'snake',
#  'mealybug',
#  'egg_white',
#  'folding_saw',
#  'death_camp',
#  'swiftlet',
#  'commissary',
#  'polynesian_tattler',
#  'bracteole',
#  "explorer's_gentian",
#  'lesser_centaury',
#  'professional_golf',
#  'landlocked_salmon',
#  'giant_ryegrass',
#  'celery_top_pine',
#  'bulblet_fern',
#  'vitamin_p',
#  "hooker's_onion",
#  'car_mirror',
#  'gin_and_it',
#  'cruel_plant',
#  'backsword',
#  'topknot',
#  'grainfield',
#  'automatic_transmission',
#  'surgery',
#  'lingonberry',
#  'thorny_skate',
#  'father-in-law',
#  'butt_joint',
#  'floor',
#  'great_grandmother',
#  'monocline',
#  'catmint',
#  'tomtate',
#  'contestant',
#  'white_sauce',
#  'procurer',
#  'chasuble',
#  'planter',
#  'columbine',
#  'jamaican_cherry',
#  'tory',
#  'whelk',
#  'marasca',
#  'endorser',
#  'whiffletree',
#  'cable_television',
#  'reeler',
#  'guest_worker',
#  'milliammeter',
#  'pontoon',
#  'stiff_aster',
#  'slate',
#  'academic_administrator',
#  'reovirus',
#  'red_spruce',
#  'levantine',
#  'may_apple',
#  'tent',
#  'gopher',
#  'jack_pine',
#  'young_bird',
#  'heartleaf_manzanita',
#  'nardoo',
#  'noncandidate',
#  'puce',
#  'abstainer',
#  'golden_eagle',
#  'authority',
#  'mouth',
#  'metal_wood',
#  'ash-pan',
#  'mexican_cypress',
#  'pale_yellow',
#  'scarlet_oak',
#  'naval_weaponry',
#  'voltage_regulator',
#  'thysanuran_insect',
#  'rachis',
#  'greens',
#  'sob_sister',
#  'gouache',
#  'shipping_agent',
#  'carboy',
#  'houseplant',
#  'turkey_stew',
#  'monocle',
#  'monocarp',
#  'meadow_salsify',
#  'bridesmaid',
#  'freak',
#  'dry-bulb_thermometer',
#  'mottle',
#  'class',
#  'ignition_coil',
#  'cuticle',
#  'cornice',
#  'alderman',
#  'poisonous_parasol',
#  'technician',
#  'great_hall',
#  'bowling_ball',
#  'curd',
#  'shotgun',
#  'court_game',
#  'matador',
#  'kaki',
#  'heron',
#  'silver_fir',
#  'cotton_thistle',
#  'blacktail_jackrabbit',
#  'stamping_machine',
#  'welsh_pony',
#  'space_heater',
#  'pluralist',
#  'arabidopsis_lyrata',
#  'cub_scout',
#  'sanicle',
#  'cargo_area',
#  'creeping_zinnia',
#  'hausa',
#  'government_office',
#  'goa_bean',
#  'doll',
#  'eulogist',
#  'texan',
#  'sugar_snap_pea',
#  'saw_palmetto',
#  'woodland_caribou',
#  'workmate',
#  'box_wrench',
#  'pacemaker',
#  'alaska_fur_seal',
#  'chile_bonito',
#  'skeg',
#  "bear's_breech",
#  'technical_sergeant',
#  'utahraptor',
#  'vacuum_flask',
#  'soupspoon',
#  'cardcase',
#  'shoreline',
#  'pomeranian',
#  'stopper_knot',
#  'plum-fruited_yew',
#  'marsh_pea',
#  'ice_rink',
#  'studio_couch',
#  'smooth_woodsia',
#  'swathe',
#  'waterbuck',
#  'purple_clematis',
#  'felwort',
#  'white-throated_sparrow',
#  'snook',
#  'niece',
#  'scrubber',
#  'black_oak',
#  'whiff',
#  'dressmaker',
#  'bighorn',
#  'new_zealand_spinach',
#  'hyssop',
#  'breaststroker',
#  'lepiota_rhacodes',
#  'mountain_avens',
#  'meadow_cranesbill',
#  'carolina_lupine',
#  'mestiza',
#  'munition',
#  'bibb_lettuce',
#  'rubber_boot',
#  'octagon',
#  'bunk_bed',
#  'hakim',
#  'burner',
#  'field_game',
#  'augur',
#  'water_parsnip',
#  'bomber',
#  'bulbil',
#  'candy',
#  'prophetess',
#  'gloxinia',
#  'santa_cruz_cypress',
#  'whip-snake',
#  'pattypan_squash',
#  'holdover',
#  'sleeping_bag',
#  'segregate',
#  'partridge',
#  'waiter',
#  'executive_secretary',
#  'catalufa',
#  'carabao',
#  'waxycap',
#  'razorblade',
#  'snakefly',
#  "cat's-claw",
#  'death_adder',
#  'cantilever',
#  'ranch_house',
#  'alcohol',
#  'overmantel',
#  'courbaril',
#  'cruciferous_vegetable',
#  'wire_cutter',
#  'looking_glass',
#  'edible_seed',
#  'roller_skate',
#  'mechanical_device',
#  'clog_dancer',
#  'smooth_softshell',
#  'guan',
#  'california_white_oak',
#  'old_world_porcupine',
#  'classroom',
#  'desk_phone',
#  'molasses_taffy',
#  'pteropus_capestratus',
#  'bitumastic',
#  'catboat',
#  'garter_snake',
#  'doorframe',
#  'video_recording',
#  'decolletage',
#  'wild_angelica',
#  'automation',
#  'dress_shirt',
#  "barrow's_goldeneye",
#  'spirula',
#  'latch',
#  'book_bag',
#  'outdoor_game',
#  "mother_carey's_chicken",
#  'hairbrush',
#  'weapons_carrier',
#  'marquess',
#  'plainsman',
#  'lobbyist',
#  'restrainer',
#  'aphakic',
#  "yellow_lady's_slipper",
#  'prayer_rug',
#  'carinate',
#  'tangle_orchid',
#  'pine',
#  "hare's-foot_fern",
#  'adjutant_general',
#  'floor_cover',
#  'white_mangrove',
#  'atlantic_herring',
#  'iron_tree',
#  'shirttail',
#  'insectivore',
#  'brain_coral',
#  'wild_sheep',
#  'beef',
#  'margarita',
#  'electric_organ',
#  'pearl_oyster',
#  'seeder',
#  'irish_stew',
#  'castle',
#  'proconsul',
#  'event_planner',
#  'velour',
#  'loop_knot',
#  'farm_boy',
#  'cricket_frog',
#  'bean',
#  'folk_dancer',
#  'headmaster',
#  'creme_de_menthe',
#  'videodisk',
#  'opera_cloak',
#  'astatic_galvanometer',
#  'racket',
#  'hip_boot',
#  'hot_pants',
#  'smooth_dogfish',
#  'baster',
#  'black-tailed_deer',
#  'whorled_aster',
#  'prosthetist',
#  "king's_counsel",
#  'seaside_centaury',
#  'grass_poly',
#  'bell_cote',
#  'pigeon_guillemot',
#  'fipple',
#  'man-of-war',
#  'greenishness',
#  'dispenser',
#  'grub',
#  'shop_girl',
#  'old-timer',
#  'covered_bridge',
#  "pallas's_sandgrouse",
#  'masseur',
#  'indian_elephant',
#  'pan',
#  'coontie',
#  'giant_water_bug',
#  'shed',
#  'nomia_melanderi',
#  'horse_wrangler',
#  "lamb's-quarter",
#  'tilt-top_table',
#  'personification',
#  'sick_person',
#  'feeder',
#  'oilseed',
#  'water_pump',
#  'shavian',
#  'spotted_eagle_ray',
#  'swamp_chestnut_oak',
#  'smuggler',
#  'scriber',
#  'fence_lizard',
#  'extremist',
#  'snapping_shrimp',
#  'clam_dip',
#  'wold',
#  'border_collie',
#  'inlay',
#  'tennis_racket',
#  'tadpole_shrimp',
#  'mother_figure',
#  'skateboarder',
#  'trifoliate_orange',
#  'still',
#  'alexandria_senna',
#  'lager',
#  'negro_peach',
#  'obtuse_triangle',
#  'camel',
#  'casuist',
#  'grassfinch',
#  'chickeree',
#  'stelis',
#  'boxing',
#  'wallet',
#  'stalker',
#  'point_lace',
#  'broad-leaved_plantain',
#  'slave_ant',
#  'lambkin',
#  'maternity_ward',
#  'racing_boat',
#  'hole',
#  'cryostat',
#  'tattler',
#  'water_mold',
#  'pedestal',
#  'projectile',
#  'pacific_sardine',
#  'two-eyed_violet',
#  'vestry',
#  'syncopator',
#  'chimney_plant',
#  'body_lotion',
#  'caretaker',
#  'grate',
#  'yellow_salsify',
#  'queen_mother',
#  'pill_bug',
#  'honest_woman',
#  'gearing',
#  'water_meter',
#  'house_sitter',
#  'adenovirus',
#  'lesser_wintergreen',
#  'bluefin',
#  'bushing',
#  'dandelion',
#  'balloon_vine',
#  'roadbed',
#  'orange_marmalade',
#  'cola',
#  'nut_butter',
#  'american_germander',
#  'circaea_lutetiana',
#  'toehold',
#  'hunting_dog',
#  'noncommissioned_officer',
#  'fagot_stitch',
#  'galoot',
#  'lunchroom',
#  'chinning_bar',
#  'brabancon_griffon',
#  'girl',
#  'brown_root_rot_fungus',
#  'wastrel',
#  'old-age_pensioner',
#  'kamia',
#  'cartridge_holder',
#  'balloon_sail',
#  'lepidopterous_insect',
#  'mussel',
#  'scyphus',
#  'well',
#  'body',
#  'fetterbush',
#  'spiny_dogfish',
#  'harnessed_antelope',
#  'great_grey_owl',
#  'wren',
#  'casque',
#  'grindelia_robusta',
#  'seal',
#  'overshoe',
#  'finger_paint',
#  'suspension',
#  'mason',
#  'wild_plum',
#  'clock_pendulum',
#  ...}

# %%
import pickle
with open(f'/home/sheng/OSZSL/ipynb/cache/openai/visual-inov-template=9-k_1=3-repeat=3-data=make_nonliving26.pkl', 'rb') as f:
    all_chatgpt_res = pickle.load(f)

# %%
all_chatgpt_res
# Out:
# [['accordion.n.01: portable; box-shaped; free-reed instrument; reeds vibrate; controlled by player; bellows; \n\nbandoneon.n.01: concertina; popular in South America; free-reed instrument\n\nconcertina.n.02: free-reed instrument; accordion-like; push ends together; force air through reeds\n\nconcertina.n.01: coiled barbed wire; obstacle.',
#   'percussionist.n.01: musician playing percussion instruments; person playing drums, cymbals, and other percussion instruments; drummer specializing in percussion instruments\n\ndrummer.n.01: musician playing a drum; person playing a snare, bass, or tom-tom drum; percussionist playing drums\n\npercussion_cap.n.01: detonator triggered by striking; small explosive device activated by impact; explosive cap set off by percussion',
#   'portable_computer.n.01: can be carried by hand; compact size; lightweight; easy to transport; mobile; travel-friendly; can be taken anywhere; convenient size\n\npersonal_computer.n.01: small size; designed for one person; desktop computer alternative; compact design; individual use; microprocessor-based; for personal use; non-networked\n\nlaptop.n.01: small enough for lap use; portable design; compact size; lightweight; can be carried easily; mobile computer; travel-friendly; easy to transport',
#   'percussion_instrument.n.01: produces sound by striking one object against another; commonly used in musical performances; includes instruments such as drums, cymbals, and maracas\n\ndrum.n.01: cylindrical shape; two membranes stretched across each end; produces sound when struck with drumsticks or hands; commonly used in music genres such as rock, jazz, and marching bands\n\ndrum.n.04: cylindrical metal container; used for storing or shipping liquids; may have a removable lid or spout for pouring\n\ngong.n.01: metal plate with a concave shape; produces a deep, resonant sound when struck with a soft-headed drumstick; commonly used in orchestral music and meditation practices',
#   'tetherball.n.01: game with two players; players use rackets; rackets strike a ball; ball is tethered to the top of a pole; object is to wrap the string around the pole.\n\nstickball.n.01: form of baseball; played in the streets; rubber ball used; broomstick handle used.\n\nathletic_game.n.01: game involving athletic activity.',
#   'piano.n.01: keyboard instrument; black and white keys; hammers striking strings; musical instrument; grand piano; upright piano; acoustic piano; stringed instrument; musical keys; ivory keys; wooden cabinet; soundboard; pedals; lid; music stand\n\nbaby_grand.n.01: small grand piano; petite piano; compact grand piano; baby grand; mini grand piano; small-sized grand piano; small concert grand; miniature grand piano\n\nspinet.n.02: early model harpsichord; one string per note; compact harpsichord; keyboard instrument; historical instrument; antique instrument; wooden construction; plucking mechanism\n\nspinet.n.01: small upright piano; compact piano; vertical piano; spinet piano; small-sized piano; mini piano; petite piano; slimline piano',
#   'banjo.n.01: long neck; circular body; strings; frets; tuning pegs; bridge; sound hole; resonator back; pickguard\n\nmandolin.n.01: lute-like; pear-shaped body; curved top; flat back; sound hole; strings; frets; tuning pegs; bridge; pickguard; plectrum\n\nresonator.n.03: vibrating system; sound amplification; frequency enhancement; tone modification; acoustic resonance; electromagnetic resonance\n\nresonator.n.01: hollow chamber; electromagnetic waves; acoustic waves; oscillation; frequency; resonance; amplification; sound production.',
#   'computer_user.n.01: a person typing on a keyboard in front of a computer monitor; a person using a computer for work; a person playing video games on a computer; a person video chatting on a computer; a person using a computer for online shopping or banking; a person programming on a computer; a person using a computer for graphic design or video editing.\n\ndesktop_computer.n.01: a computer tower on a desk; a computer monitor and keyboard on a desk; a small computer on a desk; a personal computer on a desk; a compact computer on a desk.\n\nworkstation.n.01: a powerful computer on a desk; a computer with multiple monitors on a desk; a computer used for graphic design or video editing; a computer used for scientific research or data analysis; a computer used for programming or software development.',
#   'marimba.n.01: percussion instrument; wooden bars; tuned chromatically; resonators; small mallets; \nvibraphone.n.01: percussion instrument; metal bars; rotating disks; resonators; vibrato sound; xylophone-like;\npercussion_instrument.n.01: sound produced by striking objects; musical instrument.',
#   'digital_clock.n.01: clock with digital display; clock with numeric display; clock with electronic display; clock with LED display; clock with LCD display; clock with binary display; clock with 24-hour display; clock with AM/PM display\n\nelectric_clock.n.01: clock with electric motor; clock with quartz movement; clock with battery power; clock with plug-in power; clock with winding mechanism; clock with tick-tock sound; clock with second hand; clock with minute hand; clock with hour hand\n\ntime_clock.n.01: clock for tracking work hours; clock for tracking employee hours; clock for tracking attendance; clock for tracking time cards; clock for payroll purposes; clock for hourly workers; clock for shift workers; clock for punch cards; clock for time stamps',
#   "oboe_da_caccia.n.01: alto oboe; precursor of English horn; pitched in F; conical bore; curved metal tube; double reed instrument\n\nflutist.n.01: plays the flute; musician who plays the flute; skilled in playing the flute; flute player; person who performs on the flute\n\noboe_d'amore.n.01: oboe pitched a minor third lower than ordinary oboe; used to perform baroque music; sweet and melancholic sound; looks like a regular oboe; conical bore; double reed instrument",
#   'hobble_skirt.n.01: long skirt; narrow below knees; 1910-1914 fashion; restrictive movement; tapered silhouette\nfull_skirt.n.01: long skirt; gathered at waist; voluminous; feminine silhouette; 1950s fashion\nminiskirt.n.01: very short skirt; above knee length; 1960s fashion; youthful; flirty silhouette',
#   'b-flat_clarinet.n.01: ordinary clarinet; middle range clarinet; woodwind instrument; musical instrument; black clarinet; silver keys; cylindrical bore; single reed mouthpiece; keywork system; finger holes; tone holes\n\nbass_clarinet.n.01: large clarinet; low range clarinet; woodwind instrument; musical instrument; black clarinet; silver keys; cylindrical bore; single reed mouthpiece; keywork system; finger holes; tone holes; deep sound; resonant sound\n\noboe.n.01: slender instrument; double-reed instrument; woodwind instrument; musical instrument; black oboe; silver keys; conical bore; double-reed mouthpiece; keywork system; finger holes; tone holes; nasal sound; haunting sound',
#   'piano_action.n.01: system of levers; felt hammer; strike strings; key depressed\npiano.n.01: keyboard instrument; played by depressing keys; hammers strike strings; produce sounds\nbaby_grand.n.01: small grand piano',
#   'hand-held_computer.n.01: portable; battery-powered; small enough to be carried in your pocket\n\nportable_computer.n.01: personal; computer; easily carried by hand\n\npersonal_computer.n.01: small; digital; computer; based on a microprocessor; designed to be used by one person at a time',
#   'organ.n.05: wind instrument with pipes; pipes arranged in sets; air supplied from bellows; controlled by musical keyboard; complex keyboard; large keyboard\norgan_loft.n.01: gallery; church organ; occupied by organ\namerican_organ.n.01: free-reed instrument; air drawn in through reeds; suction bellows',
#   'pickup.n.01: light truck; open body; low sides; tailboard\ntruck.n.01: automotive vehicle; suitable for hauling\nhighboy.n.01: tall chest of drawers; divided into two sections; supported on four legs',
#   'parking_meter.n.01: coin-operated timer; located next to a parking space; depositing money; entitled to park; specified length of time\nmeter_maid.n.01: policewoman; assigned to write parking tickets\ntaximeter.n.01: meter; in a taxi; registers the fare; based on the length of the ride.',
#   'minibus.n.01: light bus; small bus; compact bus; 4-10 passenger bus; \npassenger_van.n.01: van for passengers; people carrier; transport van; \nshuttle_bus.n.01: bus shuttle; point-to-point bus; transportation shuttle.',
#   'medical_scientist.n.01: studying disease processes; working with microscopes; researching cures for illnesses; analyzing data from experiments; collaborating with medical professionals\n\nlab_coat.n.01: protective clothing for lab work; covering regular clothing; made of light materials; disposable or reusable; buttoned or zipped\n\nmolecular_biologist.n.01: researching macromolecules; studying genetic material; examining protein structures; analyzing chemical reactions; using advanced laboratory techniques',
#   'dome.n.04: hemispherical roof; rounded roof; half-sphere roof; curved roof\ndome.n.03: roofed stadium; covered stadium; enclosed stadium; domed arena\ncupola.n.02: domed roof; circular roof; rounded roof; hemisphere-shaped roof\ncupola.n.01: cylindrical furnace; vertical furnace; metal-melting furnace; cast iron furnace\nobservation_dome.n.01: lookout dome; observatory dome; spherical observatory; curved observatory roof',
#   'trolleybus.n.01: electric passenger bus; overhead wires; public transport; \nbus.n.01: passenger vehicle; many passengers; public transport; \nshuttle_bus.n.01: shuttle vehicle; travels between two points; bus; public transport.',
#   'rumble_seat.n.01: folding; outside seat; back; early cars\nhorseless_carriage.n.01: early term; automobile\njaunting_car.n.01: open; two-wheeled; one-horse cart; formerly widely used in Ireland.',
#   'stock_car.n.02: racing car; commercially available car chassis; high-performance vehicle; speed machine; racecar; NASCAR vehicle.\n\ntouring_car.n.01: open car; large car; convertible; four-seater; folding top car; roadster.\n\nauto_racing.n.01: motorsport; car racing; speed competition; track racing; high-speed competition; Grand Prix; NASCAR.',
#   'apiary.n.01: a shed for keeping beehives; a structure for housing multiple beehives; a place for beekeeping; a farm for raising bees; a collection of bee colonies;\nbeekeeper.n.01: a farmer who keeps bees; a person who tends to bees; a honey producer; an apiarist; a keeper of beehives;\nbeehive.n.04: a man-made receptacle for bees; a wooden box for bee colonies; a hive for honeybees; a structure for housing bees; a container for a bee swarm.',
#   'mexican_hat.n.01: coneflower with flower heads resembling a Mexican hat; tall red-brown disk; drooping yellow rays; yellow and red-brown rays; grows in the great plains; grows along base of Rocky Mountains\nsombrero.n.02: straw hat; tall crown; broad brim; worn in American southwest; worn in Mexico\ncowboy_hat.n.01: wide brim hat; soft crown; worn by American ranch hands.',
#   'mobile_home.n.01: large; house trailer; connected to utilities; parked in one place; permanent housing\ntrailer_camp.n.01: camp; space for house trailers; rented; utilities provided\nprefab.n.01: prefabricated structure',
