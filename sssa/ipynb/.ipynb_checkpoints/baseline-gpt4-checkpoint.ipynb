# %%
import sys
sys.path.append('/home/sheng/sssa/')
sys.path.append('/home/sheng/sssa/')
# sys.path.append('/home/sheng/sssa/CLIP/')

import os
import json
import re
import time
import pickle
from typing import Union, List
from pprint import pprint
from tqdm import tqdm
from copy import deepcopy
import random
import itertools
import numpy as np
from functools import reduce, partial
from itertools import zip_longest
import seaborn as sns
from collections import Counter, defaultdict, OrderedDict
import matplotlib.pyplot as plt
import heapq
from wordnet_utils import *
import scipy.io
from PIL import Image

import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode
from torchvision.datasets import ImageFolder

from ipynb_utils import get_hier_datasets, get_classifier, MCMF_assign_labels
# import clip
import model as clip
from data.datasets import build_transform, get_hier_datasets, Vocab
from data.imagenet_datasets import get_datasets_oszsl


class Config:
    device = 'cuda:3'
    arch = 'ViT-B/16'
    dataset = 'imagenet'
    n_sampled_classes = 100
    input_size = 224
    estimate_k = 252
    
    batch_size = 100
    use_def = False
    clip_checkpoint = None
    # clip_checkpoint = '/home/sheng/MUST-output/make_nonliving26/baseline-04_22_1/checkpoint-current.pth'
    # clip_checkpoint = '/home/sheng/MUST-output/make_nonliving26/chatgpt_init-warmup=2/checkpoint-current.pth'
    # clip_checkpoint = '/home/sheng/MUST-output/make_entity13/sssa/checkpoint-current.pth'
    f_classifier = './cache/wordnet_classifier_in21k_word.pth'
    # f_classifier = './cache/wordnet_classifier_in21k_word_L.pth'
    templates_name = 'templates_small'
    seed = 0
    
args = Config()


def load_templates(args):
    with open(f'../{args.templates_name}.json', 'rb') as f:
        templates = json.load(f)['imagenet']
    return templates

def get_vocab():
    """
    Args:
        vocab: {`names`: list, `ids`: synset ids, `parents`: [{synset ids}]}
    """
    with open('/home/sheng/dataset/wordnet_nouns_with_synset_4.pkl', 'rb') as f:
        vocab = pickle.load(f)
    return vocab

def get_subsample_vocab(sample_synset_id: set):
    vocab = get_vocab()
    index = np.array([ i for i in range(len(vocab['synsets'])) if vocab['synsets'][i] in sample_synset_id ]).astype(np.int32)
    for k in vocab.keys():
        vocab[k] = np.array(vocab[k])[index].tolist()
    return vocab

def read_imagenet21k_classes():
    with open('/home/sheng/dataset/imagenet21k/imagenet21k_wordnet_ids.txt', 'r') as f:
        data = f.read()
        data = list(filter(lambda x: len(x), data.split('\n')))
    return data

templates = load_templates(args)
vocab = get_vocab()
nouns = [ wn.synset(s) for s in vocab['synsets'] ]
classnames = vocab['names']
parents = vocab['parents']
defs = vocab['def']


def load_clip(args):
    model, preprocess = clip.load(args.arch)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model, preprocess

def load_clip2(args):
    model = clip.load(args.arch, device=args.device)
    if args.clip_checkpoint:
        model.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model.to(args.device).eval()
    input_resolution = model.visual.input_resolution
    context_length = model.context_length
    vocab_size = model.vocab_size

    print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
    print("Input resolution:", input_resolution)
    print("Context length:", context_length)
    print("Vocab size:", vocab_size)
    return model

def load_mixture_clip(args, decay=1.0):
    model1 = clip.load(args.arch)
    if args.clip_checkpoint:
        model1.load_state_dict({k[len('model.'):]:v for k, v in torch.load(args.clip_checkpoint, map_location='cpu')['model_ema'].items()}, strict=False)
    model1.to(args.device).eval()
    model2 = clip.load(args.arch)
    model2.to(args.device).eval()
    with torch.no_grad():
        msd = model1.state_dict()
        for k, ema_v in model2.state_dict().items():
            # if needs_module:
            #     k = 'module.' + k
            model_v = msd[k].detach()
            ema_v.copy_(ema_v * decay + (1. - decay) * model_v)
    return model2

def topk_acc(all_pred_voc_topk, all_gt_voc):
    acc = []
    ### topK accuracy
    for i in range(all_pred_voc_topk.size(1)):
        vec = torch.zeros(all_pred_voc_topk.size(0)).bool()
        for j in range(i+1):
            vec |= (all_pred_voc_topk[:, j]==all_gt_voc)
        print(f'k={i} acc={vec.float().mean()}')
        acc.append(vec.float().mean().item())
    return acc

def semantic_acc(y_pred, y_true, metrics={}):
    """ compute soft semantic acc for @y_pred and @y_true """
    assert len(metrics)>0
    assert y_pred.size(0)==y_true.size(0)
    scores = {m:[] for m in metrics.keys()}
    with tqdm(total=y_pred.size(0)) as pbar:
        for i in range(y_pred.size(0)):
            syn_pred = mapping_vocidx_to_synsets(y_pred[i].item(), vocab)
            syn_true = mapping_vocidx_to_synsets(y_true[i].item(), vocab)
            pairs = list(itertools.product(range(len(syn_pred)), range(len(syn_true))))
            for m_name, m in metrics.items():
                scores[m_name].append( max([ m(syn_pred[p[0]], syn_true[p[1]]) for p in pairs ]) )
            pbar.update(1)
    for m_name in metrics.keys():
        scores[m_name] = np.array(scores[m_name]).mean()
    return scores
    
""" from MUST """
from clip.simple_tokenizer import SimpleTokenizer as _Tokenizer
_tokenizer = _Tokenizer()

def tokenize(texts: Union[str, List[str]], context_length: int = 77, truncate: bool = False) -> torch.LongTensor:
    if isinstance(texts, str):
        texts = [texts]

    sot_token = _tokenizer.encoder["<|startoftext|>"]
    eot_token = _tokenizer.encoder["<|endoftext|>"]
    all_tokens = [[sot_token] + _tokenizer.encode(text) + [eot_token] for text in texts]
    result = torch.zeros(len(all_tokens), context_length, dtype=torch.long)

    for i, tokens in enumerate(all_tokens):
        if len(tokens) > context_length:
            if truncate:
                tokens = tokens[:context_length]
                tokens[-1] = eot_token
            else:
                raise RuntimeError(f"Input {texts[i]} is too long for context length {context_length}")
        result[i, :len(tokens)] = torch.tensor(tokens)

    return result


def agg_by_pred_cluster(args, pred_kmeans, all_topk_voc, voc_size):
    """
    Args:
        pred_kmeans: np.array([N])
        all_topk_voc: np.array([N x K])
        voc_size: int
    Returns:
        all_clu_pred: tensor([C x V])
    """
    print('agg_by_pred_cluster')
    all_clu_pred = []
    n_count = []
    for i in np.unique(pred_kmeans):
        selected = (pred_kmeans==i)
        n_count.append( selected.sum().item() )
        counter_voc_ind, counter_val = np.unique((all_topk_voc[selected, :]).ravel(), return_counts=True)
        # counter_val = counter_val/(n_count+1e-20) # L1 norm
        clu_pred = torch.zeros(args.num_voc) # cluster-wise prob
        clu_pred[torch.from_numpy(counter_voc_ind).long()] = torch.from_numpy(counter_val).float()
        # clu_pred = F.normalize(all_topk_voc[selected].sum(dim=0), dim=-1, p=1)
        all_clu_pred.append(clu_pred)
    all_clu_pred = torch.stack(all_clu_pred, dim=0).cpu()
    n_count = torch.tensor(n_count).cpu()
    
    # all_clu_pred = setdiff_assignment(all_clu_pred)
    
    all_clu_pred = all_clu_pred/(n_count.view(-1, 1) + 1e-20)
    
    print('is mutex assignment::', all_clu_pred.argmax(dim=-1).size(0)==all_clu_pred.argmax(dim=-1).unique().size(0))
    print('assignment collision num::', len(list(filter(lambda x: x>1, Counter(all_clu_pred.argmax(dim=-1).numpy()).values()))))
    return all_clu_pred

def linear_assign(all_clu_pred, pred_kmeans, all_gt_voc, return_results=False):
    print('linear_assign')
    cost_mat = all_clu_pred.cpu().numpy()
    print(f'assignment shape={cost_mat.shape}')
    res_ass = linear_assignment(cost_mat.max() - cost_mat)
    label_voc_kmeans = torch.tensor([res_ass[1][x.item()] for x in pred_kmeans])
    inst_acc = (label_voc_kmeans==all_gt_voc).float().mean().item()
    print('instance label acc::', inst_acc)
    if return_results:
        return label_voc_kmeans, res_ass, inst_acc
    return label_voc_kmeans, res_ass

def reassign_by_pred_cluster(label_voc_kmeans, model, classifier, device, 
                             all_prob=None, 
                             instance_selected=None, 
                             classifier_selected=None):
    """
    Args:
        classifier_selected: tensor([C2])
    """
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device)
    if all_prob is None:
        cluster_ind = []
        with tqdm(total=len(loader_f)) as pbar:
            if hasattr(model, 'eval'):
                model.eval()
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                if (instance_selected is not None) and ((~instance_selected[idx_img]).all()):
                    continue
                with amp_autocast():
                    with torch.no_grad():
                        if (instance_selected is not None):
                            logits = model.visual(images[instance_selected[idx_img]])
                        else:
                            logits = model.visual(images)
                            
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        if classifier_selected is not None:
                            similarity = 100 * logits @ classifier[classifier_selected].t()
                            prob = classifier_selected[similarity.softmax(-1)]
                            cluster_ind.append(deepcopy(prob.cpu().argmax(dim=-1)))
                        else:
                            similarity = 100 * logits @ classifier.t()
                            prob = similarity.softmax(-1)
                            cluster_ind.append(deepcopy(prob[:, label_voc_kmeans].cpu().argmax(dim=-1)))
                pbar.update(1)
        cluster_ind = torch.cat(cluster_ind, dim=0)
    else:
        all_prob = all_prob[:, label_voc_kmeans]
        cluster_ind = all_prob.argmax(dim=-1)
        
    if classifier_selected is not None:
        cluster_ind_voc = classifier_selected[cluster_ind]
    else:
        cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc


def reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, device, 
                             preextracted_vfeatures=None):
    """ given vocab label set @label_voc_kmeans, 
    Args:
        label_voc_kmeans: cluster-assigned label on vocab
        ...
        preextracted_vfeatures: np.array([N x D])
    Returns:
        cluster_ind: tensor([N]): re-ordered cluster assignment
        cluster_ind_voc: tensor([N]): cluster assignment indiced by vocab
    """
    print('reassign_by_pred_cluster')
    amp_autocast = torch.cuda.amp.autocast
    label_voc_kmeans = label_voc_kmeans.to(device).unique()
    cluster_ind = []
    with tqdm(total=len(loader_f)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        if preextracted_vfeatures is not None:
            N = len(loader_f.dataset)
            batch_size = 10000
            indices = np.array_split(np.arange(N), N//batch_size)
            with torch.no_grad():
                for group in indices:
                    logits = torch.from_numpy(preextracted_vfeatures[group]).float()
                    logits = logits/logits.norm(dim=-1, keepdim=True)
                    similarity = 100 * logits@classifier.t().cpu()
                    prob = similarity.softmax(-1)
                    cluster_ind.append(deepcopy(prob[:, label_voc_kmeans.cpu()].argmax(dim=-1)))
        else:
            for idx_batch, batch in enumerate(loader_f):
                images, label_voc, label_clu, idx_img = batch[:4]
                images = images.to(device)
                with amp_autocast():
                    with torch.no_grad():
                        if preextracted_vfeatures is not None:
                            logits = torch.from_numpy(preextracted_vfeatures[idx_img.cpu().numpy()]).float().to(device)
                        else:
                            logits = model.ema.extract_vfeatures(images)
                        logits = logits/logits.norm(dim=-1, keepdim=True)
                        similarity = 100 * logits @ classifier.t()
                        prob = similarity.softmax(-1)
                        cluster_ind.append(deepcopy(prob[:, label_voc_kmeans].cpu().argmax(dim=-1)))
                pbar.update(1)
    cluster_ind = torch.cat(cluster_ind, dim=0)
    cluster_ind_voc = label_voc_kmeans[cluster_ind]
    mapping_ind = dict(zip(cluster_ind.unique().numpy(), torch.arange(cluster_ind.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def computation_reassign_by_pred_cluster(row, idx, args, model, classifier, candidate_classifier_ind):
    """
    candidate_classifier_ind = label_voc_kmeans.unique().to(args.device)
    """
    images, label_voc, label_clu, idx_img = row[:4]
    images = images.to(args.device)
    with amp_autocast():
        vfeatures = model.visual(images).float()
        # vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
    vfeatures = F.normalize(vfeatures, dim=-1)
    batch_sim = 100*vfeatures@classifier[candidate_classifier_ind].t()
    cluster_ind = batch_sim.argmax(dim=-1)
    cluster_ind_voc = candidate_classifier_ind[cluster_ind].cpu()
    return cluster_ind_voc

def aggregation_reassign_by_pred_cluster(r, candidate_classifier_ind):
    cluster_ind_voc = torch.cat(r, dim=0)
    mapping_ind = dict(zip(cluster_ind_voc.unique().numpy(), torch.arange(cluster_ind_voc.unique().size(0)).numpy()))
    cluster_ind = torch.tensor([mapping_ind[x.item()] for x in cluster_ind_voc])
    return cluster_ind, cluster_ind_voc


@torch.no_grad()
def extract_vfeatures(model, data_loader, device):
    amp_autocast = torch.cuda.amp.autocast
    all_vfeatures = []
    with tqdm(total=len(data_loader)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        for idx_batch, batch in enumerate(data_loader):
            images, label_voc, label_clu, idx_img = batch[:4]
            images = images.to(device)
            with amp_autocast():
                vfeatures = model.visual(images).float()
            vfeatures = vfeatures/vfeatures.norm(dim=-1, keepdim=True)
            all_vfeatures.append(vfeatures.cpu().numpy())
            pbar.update(1)
    all_vfeatures = np.concatenate(all_vfeatures)
    return all_vfeatures


@torch.no_grad()
def loop_row_collect_results_nograd(obj_iter, computations={}, aggregations={}):
    """ compute and aggregate results, looping over @obj_iter 
    func_computation(@row, @index_row)
    aggregations(list(@results_computation))
    """
    assert set(list(computations.keys())) == set(list(aggregations.keys()))
    collector = { k:[] for k in computations }
    with tqdm(total=len(obj_iter)) as pbar:
        for i, row in enumerate(obj_iter):
            ### apply computations
            for k, func in computations.items():
                collector[k].append(func(row, i))
            pbar.update(1)
    ### aggregate results
    results = {}
    for k, func_agg in aggregations.items():
        results[k] = func_agg(collector[k])
    return results


import math
def batchify(iterable, batch_size=10000):
    N = len(iterable)
    for i in range(math.ceil(N/batch_size)):
        yield iterable[i*batch_size: min(N, (i+1)*batch_size)]
        
        
@torch.no_grad()
def build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=None):
    """ build classifier for chatgpt
    Args:
        all_row_chatgpt_names: [[names]]
    """
    if all_row_key_name is None: ### single name
        with open('../templates_small.json', 'rb') as f: ### template 1
            templates = json.load(f)['imagenet']
    else:
        with open('../templates_small.json', 'rb') as f: ### template 2
            templates = json.load(f)[f'{args.dataset}-parent-3']
            
    len_t = len(templates)
    row_classifier = []
    with tqdm(total=len(all_row_chatgpt_names)) as pbar:
        for idx, row in enumerate(all_row_chatgpt_names):
            len_row = len(row)
            if all_row_key_name is None:
                row_t = [ t.format(name) for name in row for t in templates ]
            else:
                row_t = [ t.format(pname, name) for pname, name in zip(all_row_key_name[idx], row) for t in templates ]
            row_t = tokenize(row_t).to(args.device)
            features = []
            for brow in batchify(row_t, batch_size=101):
                features.append(model.encode_text(brow).cpu())
            features = torch.cat(features, dim=0)
            # features = model.encode_text(row_t)
            features = features.view(len_row, len_t, -1).float()
            features = features/features.norm(dim=-1, keepdim=True)
            features = features.mean(dim=1)
            features = features/features.norm(dim=-1, keepdim=True)
            row_classifier.append(features.cpu())
            
            pbar.update(1)
    return row_classifier
    
import openai
def openai_chatgpt_post(content, parameters={'temperature': 0.7}):
    openai.api_key = "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"
    while 1:
        try:
            completion = openai.ChatCompletion.create(
              model="gpt-3.5-turbo-0301",
              # model="gpt-4-0314",
              messages=[
                {"role": "user", "content": content},
              ],
            **parameters,
            )
            result = completion['choices'][0]['message']['content']
            break
        except Exception as e:
            print(e)
    return result

def partition(lst, size):
    for i in range(0, len(lst), size):
        yield list(itertools.islice(lst, i, i + size))
        

""" prepare dataset and load CLIP """
classes = read_imagenet21k_classes() + os.listdir('/home/sheng/dataset/imagenet-img/')
classes = [wn.synset_from_pos_and_offset('n', int(x[1:])).name() for x in classes]
classes = set(classes)
vocab = get_subsample_vocab(classes)
vocab = Vocab(vocab=vocab)

transform_val = build_transform(is_train=False, args=args, train_config=None)
model = load_clip2(args)


from sklearn.cluster import KMeans
from my_util_package_oszsl.evaluation import cluster_acc
from scipy.optimize import linear_sum_assignment as linear_assignment

subset = ['train', 'val'][0]
mean = (0.48145466, 0.4578275, 0.40821073)
std = (0.26862954, 0.26130258, 0.27577711)

""" load dataset """
transform_f = transforms.Compose([
    transforms.Resize(args.input_size, interpolation=InterpolationMode.BICUBIC),
    transforms.CenterCrop(args.input_size),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=torch.tensor(mean),
        std=torch.tensor(std))
])

# dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f)
store = {}
for dataset_name in [
    # 'sdogs', 'imagenet', 
    # 'make_entity13', 
    # 'make_entity30', 
    # 'make_nonliving26', 'make_living17', 
    'imagenet1k'
]:
    print('='*30)
    print(dataset_name)
    args.dataset = dataset_name
    
    if subset == 'train':
        dataset_f = get_datasets_oszsl(args, vocab, is_train=True, transform=transform_f, seed=0)
    elif subset == 'val':
        dataset_f = get_datasets_oszsl(args, vocab, is_train=False, transform=transform_f, seed=0)
    args.nb_classes = dataset_f.num_classes
    loader_f = torch.utils.data.DataLoader(dataset_f, num_workers=4, batch_size=args.batch_size, shuffle=False)
    
    classifier = get_classifier(args)
    classifier = classifier/classifier.norm(dim=-1, keepdim=True)
    args.num_voc = classifier.size(0)
    amp_autocast = torch.cuda.amp.autocast
    ### collect variables
    prob_k = 1
    all_topk_voc = []
    all_gt_voc = []
    all_label_clu = []
    all_vfeatures = []
    with tqdm(total=len(loader_f)) as pbar:
        if hasattr(model, 'eval'):
            model.eval()
        for idx_batch, batch in enumerate(loader_f):
            images, label_voc, label_clu, idx_img = batch[:4]
            images = images.to(args.device)
            with amp_autocast():
                with torch.no_grad():
                    logits = model.visual.extract_features(images)
                    # logits = model.extract_vfeatures(images)
                    logits = logits/logits.norm(dim=-1, keepdim=True)
                    similarity = 100 * logits @ classifier.t()
                    prob = similarity.softmax(-1)
                    prob_topk_ind = prob.topk(k=prob_k, dim=-1).indices
                    all_topk_voc.append(deepcopy(prob_topk_ind.cpu().numpy()))
                    all_gt_voc.append(deepcopy(label_voc))
                    all_label_clu.append(deepcopy(label_clu))
                    all_vfeatures.append(deepcopy(logits.cpu().numpy()))
            pbar.update(1)

    all_topk_voc = np.concatenate(all_topk_voc)
    all_gt_voc = torch.cat(all_gt_voc, dim=0)
    all_label_clu = torch.cat(all_label_clu, dim=0)
    all_vfeatures = np.concatenate(all_vfeatures)


    pred_kmeans = torch.from_numpy(np.load(f'./cache/cluster/kmeans-{args.dataset}.npy'))
    pred_kmeans_t = pred_kmeans
    history_set_pred = []
    for t in range(3):
        record_pred_kmeans_t = pred_kmeans_t
        all_clu_pred = agg_by_pred_cluster(args, pred_kmeans_t.numpy(), all_topk_voc, voc_size=args.num_voc)
        label_voc_kmeans, res_ass = linear_assign(all_clu_pred, pred_kmeans_t, all_gt_voc)
        pred_kmeans_t, cluster_ind_voc = reassign_by_pred_cluster(label_voc_kmeans, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)
        set_pred = set(res_ass[1].tolist())
        set_gt = set(all_gt_voc.unique().numpy().tolist())
        print('missing label::', len(set_gt - set_pred))
        print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=pred_kmeans_t.numpy()))
        history_set_pred.append(set_pred)

        set_pred = set(res_ass[1].tolist())
        set_gt = set(all_gt_voc.unique().numpy().tolist())
        n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
        n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
        iou_voc = n_inter/n_union
        n_missing_label = all_gt_voc.unique().shape[0] - n_inter
        print('missing label::', n_missing_label)
        print('iou voc::', iou_voc)


    all_clu_gt_voc = []
    for c in record_pred_kmeans_t.unique():
        select = (record_pred_kmeans_t==c)
        all_clu_gt_voc.append(all_gt_voc[select].mode().values)

    all_clu_gt_voc = torch.tensor(all_clu_gt_voc)
    k_1 = 3
    topk_all_clu_pred = all_clu_pred.topk(k=k_1).indices
    cluster_is_correct = torch.zeros(topk_all_clu_pred.size(0)).bool()
    for i in range(k_1):
        cluster_is_correct |= (topk_all_clu_pred[:, i]==all_clu_gt_voc)

    print(f'recall@{k_1} = {cluster_is_correct.float().mean()}')

    """ gather concepts """
    to_name = lambda x: [ s.name() + ': ' + s.definition() for s in x ]
    cluster_row_synsets = []
    for row in topk_all_clu_pred:
        row_synsets = [to_name(mapping_vocidx_to_synsets(voc_idx.item(), vocab)) for voc_idx in row]
        cluster_row_synsets.append(row_synsets)


    """ generate concept requests """
    concept_request = []
    for row in cluster_row_synsets:
        ccpts = reduce(lambda x, y: x+y, row)
        ccpts = list(map(lambda x: "'"+x+".'", ccpts))
        ccpts = ', '.join(ccpts)
        concept_request.append(ccpts)

    template_9_1 = lambda concept_list: "Given visual concepts: "+ concept_list + "Please list all possible visual descriptive phrases for each visual concept without duplication. Please list in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept. No duplication."
    # template_9_2 = lambda concept_list: """Q: 'Given visual concepts: \'african_grey.n.01: commonly domesticated grey parrot with red-and-black tail and white face; native to equatorial Africa.\', \'parrot.n.01: usually brightly colored zygodactyl tropical birds with short hooked beaks and the ability to mimic sounds.\', \'parrot.n.02: a copycat who does not understand the words or acts being imitated.\', \'cockatoo.n.01: white or light-colored crested parrot of the Australian region; often kept as cage birds.\' Goal: to discriminate these visual concepts in a photo. Please list all possible visual descriptive phrases for each visual concept in bullet points. Please list in the format "{concept name}: {all phrases deliminated by semicolons}." for each concept. No duplication.'\nA:african_grey.n.01: grey parrot;red-and-black tail; white face; pale yellow eye; black beak; zygodactyl feet; intelligent and expressive eyes; predominantly grey plumage; native to equatorial Africa\nparrot.n.01: usually brightly colored; zygodactyl; tropical birds; short hooked beaks; broad range of colors and patterns\nparrot.n.01: copycat; imitation of words or actions without understanding; non-visual concept; metaphorical representation of mimicking behavior\ncockatoo.n.01: white or light-colored; often with yellow, pink, or red highlights in the crest or tail; crested parrot; strong, curved beak; zygodactyl feet; native to the Australian region; often kept as cage birds; expressive crest that can be raised or lowered; large, broad wings; known for loud and raucous calls.\n\nGiven visual concepts: """+ concept_list + "Goal: to discriminate these visual concepts in a photo. Please list all possible visual descriptive phrases for each visual concept in bullet points. Please list in the format \"{concept name}: {all phrases deliminated by semicolons}.\" for each concept."

    template_in_use = template_9_1
    concept_templates = []
    for row in concept_request:
        concept_templates.append(template_in_use(row))

    n_repeat = 3


    # try:
    #     with open('./cache/openai/gpt4-prompts.pkl', 'rb') as f:
    #         store = pickle.load(f)
    #     all_chatgpt_res = store[args.dataset]
    #     assert args.dataset in store.keys()
    # except Exception as e:
    #     print(e)
    #     """ collect chatgpt res """
    #     all_chatgpt_res = [[] for _ in range(n_repeat)]
    #     with tqdm(total=n_repeat*len(concept_templates)) as pbar:
    #         for i in range(n_repeat):
    #             for row in concept_templates:
    #                 all_chatgpt_res[i].append(openai_chatgpt_post(row))
    #             # all_chatgpt_res[i] = [openai_chatgpt_post(row) for ind, row in enumerate(partition(concept_templates, 20))]
    #                 pbar.update(1)
            
    with open(f'./cache/openai/topk=1-visual-inov-template=9_1-k_1={k_1}-repeat={n_repeat}-data={args.dataset}.pkl', 'rb') as f:
        all_chatgpt_res = pickle.load(f)
    
    # all_chatgpt_res = store[args.dataset]
        

    while 1:
        """ integrity check """
        while 1:
            invalid_res = []
            for i in range(n_repeat):
                for j, row in enumerate(all_chatgpt_res[i]):
                    extract_synsetid = lambda r: list(map(lambda x: x.split(': ')[0], r))
                    remove_space = lambda r: list(filter(lambda x: len(x), r))
                    synsets = extract_synsetid(remove_space(row.lower().replace('\n\n', '\n').split('\n')))
                    gt_synsets = extract_synsetid(reduce(lambda x,y: x+y, cluster_row_synsets[j]))
                    try:
                        start_idx = [ synsets[k].find(s) for k, s in enumerate(gt_synsets) ]
                        synsets = [ synsets[k][start_idx[k]:start_idx[k]+len(gt_synsets[k])] for k, s in enumerate(synsets) ]
                        assert set(synsets)==set(gt_synsets)
                    except Exception as e:
                        print(i, j)
                        print(synsets, gt_synsets)
                        invalid_res.append((i,j))

            if len(invalid_res)==0:
                break
            else:
                for i,j in invalid_res:
                    print(f'repair {(i,j)}')
                    content = concept_templates[j]
                    while 1:
                        try:
                            res = openai_chatgpt_post(content)
                            break
                        except Exception as e:
                            print(e)
                    all_chatgpt_res[i][j] = res



        """ extract key-value-list from @chatgpt-res """
        extracted_chatgpt_res = []
        for j, row in enumerate(all_chatgpt_res[0]):
            # all_chatgpt_res[0][j] = 
            chatgpt_row_res = {}
            extract_synsetid = lambda r: list(map(lambda x: x.split(': ')[0], r))
            remove_space = lambda r: list(filter(lambda x: len(x), r))
            extract_synnames = lambda r: list(map(lambda x: x.split(': ')[1].split('; '), r))
            for i in range(n_repeat):
                row = all_chatgpt_res[i][j]
                row_data = remove_space(row.lower().replace('\n\n', '\n').split('\n'))
                synsets = extract_synsetid(row_data)
                synnames = extract_synnames(row_data)
                gt_synsets = extract_synsetid(reduce(lambda x,y: x+y, cluster_row_synsets[j]))
                start_idx = [ synsets[k].find(s) for k, s in enumerate(gt_synsets) ]
                synsets = [ synsets[k][start_idx[k]:start_idx[k]+len(gt_synsets[k])] for k, s in enumerate(synsets) ]
                for idx_s, s in enumerate(synsets):
                    chatgpt_row_res.setdefault(s, [])
                    chatgpt_row_res[s].append( remove_space(synnames[idx_s]) )
            extracted_chatgpt_res.append(chatgpt_row_res)

        """ deduplication """
        use_dedup = True
        all_candidates = []
        all_candidates_set = []
        for i, row in enumerate(extracted_chatgpt_res):
            ### flatten multiple results
            row_all_synset_names = list(map(lambda x: x.split('.')[0], row.keys()))
            row_candidates = {}
            row_candidates_set = {}
            for k, v in row.items():
                candidates = list(reduce(lambda x, y: x+y, v))
                candidates = [c for c in candidates if c not in row_all_synset_names] ### remove competing synset names
                set_candidates = set(candidates)
                k = k.split('.')[0] ### key synset name
                row_candidates.setdefault(k, [])
                row_candidates_set.setdefault(k, set([]))
                row_candidates[k].extend(candidates)
                row_candidates_set[k] |= set_candidates
            ### collect duplicates
            duplicates = set()
            for k1, v1 in row.items():
                k1 = k1.split('.')[0]
                for k2, v2 in row.items():
                    k2 = k2.split('.')[0]
                    if k1!=k2:
                        duplicates |= row_candidates_set[k1]&row_candidates_set[k2]
            ### remove duplication with synset-names (keys)
            row_candidates_update = {}
            row_candidates_set_update = {}
            for k1, v1 in row.items():
                k1 = k1.split('.')[0]
                for k2, v2 in row.items():
                    k2 = k2.split('.')[0]
                row_candidates_set_update[k1] = row_candidates_set[k1] - duplicates if use_dedup else row_candidates_set[k1]
                row_candidates_update[k1] = [item for item in row_candidates[k1] if item not in duplicates ] if row_candidates_set[k1] else row_candidates[k1]

            all_candidates.append(row_candidates_update)
            all_candidates_set.append(row_candidates_set_update)


        ### check non-empty
        empty_list = []
        for i, line in enumerate(all_candidates_set):
            for k, v in line.items():
                if len(v)==0:
                    for j in range(n_repeat):
                        empty_list.append(j)
                        print(f'repair {i} {j}')
                        while 1:
                            try:
                                exit()
                                res = openai_chatgpt_post(concept_templates[i])
                                break
                            except Exception as e:
                                print(e)
                        all_chatgpt_res[j][i] = res

        if len(empty_list)==0:
            break

    store[args.dataset] = all_chatgpt_res
    data = \
    {
        'all_candidates': all_candidates,
        'all_candidates_set': all_candidates_set,
    }


    """ counter sorting """
    all_candidates = data['all_candidates']
    all_counter_candidates = []
    all_number_candidates = []
    for row in all_candidates:
        row_counter = {}
        total_num = 0
        for k, v in row.items():
            ct = Counter(v)
            row_counter[k] = OrderedDict(sorted(ct.items())) ### order key
            total_num += sum(ct.values())
        all_counter_candidates.append(OrderedDict(sorted(row_counter.items()))) ### order key
        all_number_candidates.append(total_num)



    ### flatten
    all_row_mapping_idx_synset_name = []
    all_row_chatgpt_names = []
    all_row_i_syn = []
    all_row_weight = []
    all_row_key_name = []
    for i in range(len(all_counter_candidates)):
        row_synset_names = all_counter_candidates[i].keys()
        row_mapping_idx_synset_name = dict(zip(range(len(row_synset_names)), row_synset_names))
        row_i_syn = []
        row_chatgpt_names = []
        row_weight = []
        for i_syn, syn in enumerate(row_synset_names):
            row_i_syn.extend([i_syn for _ in range(len(all_counter_candidates[i][syn]))])
            row_chatgpt_names.extend(list(all_counter_candidates[i][syn]))
            row_weight.extend(list(all_counter_candidates[i][syn].values()))

        all_row_mapping_idx_synset_name.append(row_mapping_idx_synset_name)
        all_row_chatgpt_names.append(row_chatgpt_names)
        all_row_i_syn.append(row_i_syn)
        all_row_weight.append(row_weight)
        all_row_key_name.append(list(map(lambda x: row_mapping_idx_synset_name[x], row_i_syn)))


    all_row_classifier = build_classifier_chatgpt(all_row_chatgpt_names, model, all_row_key_name=all_row_key_name)

    # vfeatures = np.load(f'./cache/features/vfeatures-{args.dataset}.npy')
    """
    Args:
        all_clu_pred: shape
        all_row_classifier
        record_pred_kmeans_t
        all_row_weight
        all_row_i_syn
        vfeatures
    """
    vfeatures = all_vfeatures
    all_clu_pred_chatgpt = torch.zeros_like(all_clu_pred)
    is_correct = []
    k_2 = 3
    enable_weight = True
    instance_pred_voc = torch.zeros_like(record_pred_kmeans_t)
    for c in range(len(all_row_classifier)):
        select = (record_pred_kmeans_t==c)
        row_classifier = all_row_classifier[c]
        sim = torch.from_numpy(vfeatures[select, ...]).to(args.device)@row_classifier.to(args.device).t()
        sim_topk = sim.topk(k=k_2)
        ind, val = sim_topk.indices.flatten().cpu().unique(return_counts=True)
        count_names = torch.zeros(row_classifier.size(0)).long()
        count_names[ind] = val ### count of each name
        count_smask = []
        smask = np.array(all_row_i_syn[c]) ### partition mask
        for s in np.unique(smask):
            if enable_weight:
                row_weight = torch.tensor(all_row_weight[c]).float()
                row_weight[smask==s] = row_weight[smask==s] / row_weight[(smask==s)].sum()
                row_weight /= row_weight.sum()
                count_smask.append((row_weight[smask==s]*count_names[smask==s]).sum().item())
            else:
                count_smask.append(count_names[smask==s].sum())
        name_pred = all_row_mapping_idx_synset_name[c][np.argmax(count_smask)]
        name_gt = all_gt_voc[select].mode().values
        name_gt = vocab.mapping_idx_names[name_gt.item()]
        is_correct.append(name_pred==name_gt)
        instance_pred_voc[select] = vocab.mapping_names_idx[name_pred]

        val_count = torch.tensor(count_smask)
        ind_count = [ all_row_mapping_idx_synset_name[c][ii] for ii in range(k_1) ]
        ind_count = torch.tensor([vocab.mapping_names_idx[xx] for xx in ind_count])
        all_clu_pred_chatgpt[c, ind_count] = val_count

    classifier = get_classifier(args)
    classifier = classifier/classifier.norm(dim=-1, keepdim=True)
    args.num_voc = classifier.size(0)
    a, res_ass = linear_assign(all_clu_pred_chatgpt, record_pred_kmeans_t, all_gt_voc)
    r_pred_kmeans_t, r_cluster_ind_voc = reassign_by_pred_cluster(a, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)

    set_pred = set(res_ass[1].tolist())
    set_gt = set(all_gt_voc.unique().numpy().tolist())
    n_inter = all_gt_voc[r_cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
    n_union = torch.cat([r_cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
    iou_voc = n_inter/n_union
    n_missing_label = all_gt_voc.unique().shape[0] - n_inter
    print('missing label::', n_missing_label)
    print('iou voc::', iou_voc)
    print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=r_pred_kmeans_t.numpy()))
    n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
    n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
    iou_voc = n_inter/n_union
    n_missing_label = all_gt_voc.unique().shape[0] - n_inter
    print('missing label::', n_missing_label)

    mapping_classnames = lambda x: list(map(lambda item: vocab.mapping_idx_names[item], x))
    classnames_pred = mapping_classnames(cluster_ind_voc.cpu().numpy())
    classnames_gt = mapping_classnames(all_gt_voc.cpu().numpy())
    
    from my_util_package.evaluate import measure_similarity_bert
    score = measure_similarity_bert(vocab, classnames_pred, classnames_gt, device=args.device)
    print(f'score=', score)
    
    store[args.dataset] = score
    with open('./cache/score-2.pkl', 'wb') as f:
        pickle.dump(store, f)
# Out:
# ===load nonjit===
# missing keys:
# ['visual.projection_head.0.weight', 'visual.projection_head.0.bias', 'visual.projection_head.2.weight', 'visual.projection_head.2.bias']
# Model parameters: 150,408,193
# Input resolution: 224
# Context length: 77
# Vocab size: 49408
# ==============================
# imagenet1k
# 100%|██████████| 12812/12812 [2:25:07<00:00,  1.47it/s]
# agg_by_pred_cluster
# is mutex assignment:: False
# assignment collision num:: 127
# linear_assign
# assignment shape=(997, 20071)
# instance label acc:: 0.2640974819660187
# reassign_by_pred_cluster
#   0%|          | 0/12812 [02:34<?, ?it/s]
# missing label:: 479
# cluster acc 0.5691648207208009
# missing label:: 479
# iou voc:: 0.3509485094850949
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# assignment shape=(997, 20071)
# instance label acc:: 0.370571494102478
# reassign_by_pred_cluster
#   0%|          | 0/12812 [02:37<?, ?it/s]
# missing label:: 479
# cluster acc 0.5699586164694276
# missing label:: 479
# iou voc:: 0.3509485094850949
# agg_by_pred_cluster
# is mutex assignment:: True
# assignment collision num:: 0
# linear_assign
# assignment shape=(997, 20071)
# instance label acc:: 0.3706073760986328
# reassign_by_pred_cluster
#   0%|          | 0/12812 [02:35<?, ?it/s]
# missing label:: 479
# cluster acc 0.5699586164694276
# missing label:: 479
# iou voc:: 0.3509485094850949
# recall@3 = 0.6639919877052307
# 0 72
# ['banded_krait.n.01', 'common_kingsnake.n.01', '1'] ['banded_krait.n.01', 'common_kingsnake.n.01', 'black-headed_snake.n.01']
# 0 107
# ['1', '1', ''] ['black_and_gold_garden_spider.n.01', 'orb-weaving_spider.n.01', 'comb-footed_spider.n.01']
# 0 108
# ['', '', '1'] ['black_grouse.n.01', 'ruffed_grouse.n.01', 'sharp-tailed_grouse.n.01']
# 0 109
# ['', '1', ''] ['black_kite.n.01', 'white-tailed_kite.n.01', 'marsh_harrier.n.01']
# 0 110
# ['', '', ''] ['black_swan.n.01', 'cygnet.n.01', 'goose.n.01']
# 0 111
# ['1', '1', '1'] ['black_turnstone.n.01', 'ruddy_turnstone.n.01', 'turnstone.n.01']
# 0 112
# ['black_turnstone.n.01', 'ruddy_turnstone.n.01', 'turnstone.n.01'] ['black_vulture.n.02', 'black_vulture.n.01', 'griffon_vulture.n.01', 'vulture.n.01']
# 0 113
# ['black_vulture.n.02', 'black_vulture.n.01', 'griffon_vulture.n.01', 'vulture.n.01'] ['black_widow.n.01', 'comb-footed_spider.n.01', 'european_wolf_spider.n.01']
# 0 114
# ['1', '1', ''] ['blacktail_jackrabbit.n.01', 'white-tailed_jackrabbit.n.01', 'marsh_hare.n.01']
# 0 115
# ['blacktail_jackrabbit.n.01', 'white-tailed_jackrabbit.n.01', 'marsh_hare.n.01'] ['blacktip_shark.n.01', 'whitetip_shark.n.02', 'whitetip_shark.n.01', 'hammerhead.n.03', 'hammerhead.n.02']
# 0 116
# ['blacktip_shark.n.01', 'whitetip_shark.n.02', 'whitetip_shark.n.01', 'hammerhead.n.03', 'hammerhead.n.02'] ['blenheim_spaniel.n.01', 'english_toy_spaniel.n.01', 'king_charles_spaniel.n.01']
# 0 117
# ['', '1', ''] ['blimp.n.02', 'meteorological_balloon.n.01', 'barrage_balloon.n.01']
# 0 118
# ['2', '', ''] ['block_plane.n.01', 'router_plane.n.01', 'cigar_cutter.n.01']
# 0 119
# ['', '1', '1'] ['blue_jay.n.01', 'rocky_mountain_jay.n.01', 'fairy_bluebird.n.01']
# 0 120
# ['blue_jay.n.01', 'rocky_mountain_jay.n.01', 'fairy_bluebird.n.01'] ['blue_peafowl.n.01', 'peacock.n.02', 'peacock.n.01', 'peafowl.n.01']
# 0 121
# ['blue_peafowl.n.01', 'peacock.n.02', 'peacock.n.01', 'peafowl.n.01'] ['boathouse.n.01', 'lake_dwelling.n.01', 'houseboat.n.01']
# 0 122
# ['', '', ''] ['boatyard.n.01', 'marina.n.01', 'harbor.n.02']
# 0 123
# ['boatyard.n.01', 'marina.n.01', 'harbor.n.02'] ['bobbin.n.01', 'spindle.n.04', 'spindle.n.03', 'spindle.n.02', 'darning_needle.n.01']
# 0 124
# ['bobbin.n.01', 'spindle.n.04', 'spindle.n.03', 'spindle.n.02', 'darning_needle.n.01'] ['bobsled.n.02', 'bobsled.n.01', 'luge.n.01', 'bumper_car.n.01']
# 0 125
# ['bobsled.n.02', 'bobsled.n.01', 'luge.n.01', 'bumper_car.n.01'] ['bobsledding.n.01', 'luge.n.01', 'tobogganing.n.01']
# 0 126
# ['', '1', ''] ['body_lotion.n.01', 'face_powder.n.01', 'hand_lotion.n.01']
# 0 127
# ['', '', ''] ['bolo_tie.n.01', 'necklet.n.01', 'locket.n.01']
# 0 128
# ['1', '', ''] ['bonnet_macaque.n.01', 'macaque.n.01', 'langur.n.01']
# 0 129
# ['', '1', '1'] ['book_jacket.n.01', 'three-quarter_binding.n.01', 'cover_girl.n.01']
# 0 130
# ['', '', ''] ['bookshelf.n.01', 'bookcase.n.01', 'bookend.n.01']
# 0 131
# ['', '1', '1'] ['bookshop.n.01', 'newsstand.n.01', 'bookworm.n.02']
# 0 132
# ['1', '', ''] ['border_collie.n.01', 'collie.n.01', 'papillon.n.01']
# 0 133
# ['1', '1', '1'] ['border_terrier.n.01', 'norfolk_terrier.n.01', 'irish_terrier.n.01']
# 0 134
# ['', '', ''] ['borzoi.n.01', 'afghan_hound.n.01', 'wolfhound.n.01']
# 0 135
# ['1', '1', ''] ['bottlecap.n.01', 'brass_buttons.n.01', 'beer_mat.n.01']
# 0 136
# ['1', '', '1'] ['bottled_water.n.01', 'water_bottle.n.01', 'pop_bottle.n.01']
# 0 137
# ['1', '1', ''] ['bouvier_des_flandres.n.01', 'scottish_deerhound.n.01', 'briard.n.01']
# 0 138
# ['', '', '1'] ['boxcar.n.01', 'tagger.n.02', 'cargo_container.n.01']
# 0 139
# ['1', '2', ''] ['brain_coral.n.01', 'stony_coral.n.01', 'coral.n.04']
# 0 140
# ['', '', '4'] ['brambling.n.01', 'chaffinch.n.01', 'northern_sea_robin.n.01']
# 0 141
# ['brambling.n.01', 'chaffinch.n.01', 'northern_sea_robin.n.01'] ['brassiere.n.01', 'lingerie.n.01', 'camisole.n.02', 'camisole.n.01']
# 0 142
# ['brassiere.n.01', 'lingerie.n.01', 'camisole.n.02', 'camisole.n.01'] ['bread_dough.n.01', 'dough.n.01', 'rolling_pin.n.01']
# 0 143
# ['', '1', ''] ['breakwater.n.01', 'foreshore.n.01', 'shoreline.n.01']
# 0 144
# ['breakwater.n.01', 'foreshore.n.01', 'shoreline.n.01'] ['breastplate.n.01', 'gorget.n.01', 'shield.n.02', 'shield.n.01']
# 0 145
# ['breastplate.n.01', 'gorget.n.01', 'shield.n.02', 'shield.n.01'] ['breaststroker.n.01', 'water_polo.n.01', 'headrace.n.01']
# 0 146
# ['', '1', ''] ['breechcloth.n.01', 'pocket-handkerchief.n.01', 'oilcloth.n.01']
# 0 147
# ['', '', '1'] ['bridal_gown.n.01', 'bride.n.03', 'ball_gown.n.01']
# 0 148
# ['1', '3', ''] ['bristle_brush.n.01', 'sponge_mop.n.01', 'brush.n.02']
# 0 149
# ['1', '1', '2'] ['brittany_spaniel.n.01', 'king_charles_spaniel.n.01', 'welsh_springer_spaniel.n.01']
# 0 150
# ['', '1', ''] ['broccoli_raab.n.01', 'cruciferous_vegetable.n.01', 'broccoli_rabe.n.02']
# 0 151
# ['1', '', ''] ['brompton_stock.n.01', 'bicycle_rack.n.01', 'crutch.n.01']
# 0 152
# ['', '', '1'] ['brood_hen.n.01', 'orpington.n.01', 'chicken_yard.n.01']
# 0 153
# ['', '', '1'] ['broodmare.n.01', 'palomino.n.01', 'american_saddle_horse.n.01']
# 0 154
# ['', '1', ''] ['broom.n.01', 'push_broom.n.01', 'sponge_mop.n.01']
# 0 155
# ['1', '', ''] ['brougham.n.01', 'caddy.n.01', 'used-car.n.01']
# 0 156
# ['1', '1', ''] ['brown_snail.n.01', 'garden_snail.n.01', 'seasnail.n.02']
# 0 157
# ['brown_snail.n.01', 'garden_snail.n.01', 'seasnail.n.02'] ['bubble.n.04', 'bubble.n.01', 'bubble_jet_printer.n.01', 'air_bubble.n.01']
# 0 158
# ['bubble.n.04', 'bubble.n.01', 'bubble_jet_printer.n.01', 'air_bubble.n.01'] ['bulbul.n.01', 'bee_eater.n.01', 'black-billed_cuckoo.n.01']
# 0 159
# ['1', '', ''] ['bull_mastiff.n.01', 'mastiff.n.01', 'boxer.n.04']
# 0 160
# ['', '1', '4'] ['bullet_train.n.01', 'passenger_train.n.01', 'car_train.n.01']
# 0 161
# ['1', '', '1'] ['bulletproof_vest.n.01', 'body_armor.n.01', 'military_uniform.n.01']
# 0 162
# ['', '', '1'] ['bullfrog.n.01', 'wood-frog.n.01', 'southern_spadefoot.n.01']
# 0 163
# ['', '1', ''] ['bus.n.01', 'shuttle_bus.n.01', 'public_transport.n.01']
# 0 164
# ['1', '1', ''] ['business_suit.n.01', 'three-piece_suit.n.01', 'lab_coat.n.01']
# 0 165
# ['', '', '1'] ['buskin.n.01', 'violist.n.01', 'sitar_player.n.01']
# 0 166
# ['1', '1', '1'] ['bustard.n.01', 'cream-colored_courser.n.01', 'great_bustard.n.01']
# 0 167
# ['1', '', ''] ['butcher_shop.n.01', 'fishmonger.n.01', 'delicatessen.n.02']
# 0 168
# ['butcher_shop.n.01', 'fishmonger.n.01', 'delicatessen.n.02'] ['butternut_squash.n.02', 'butternut_squash.n.01', 'hubbard_squash.n.02', 'hubbard_squash.n.01', 'cantaloup.n.02']
# 0 169
# ['', '', '', '', ''] ['cab.n.03', 'cab.n.02', 'cab.n.01', 'taxi_dancer.n.01', 'taximeter.n.01']
# 0 170
# ['cab.n.03', 'cab.n.02', 'cab.n.01', 'taxi_dancer.n.01', 'taximeter.n.01'] ['cabernet.n.01', 'winery.n.01', 'wine_bar.n.01']
# 0 171
# ['', '1', '1'] ['caldron.n.01', 'chamberpot.n.01', 'charcoal_burner.n.01']
# 0 172
# ['1', '1', ''] ['california_condor.n.01', 'king_vulture.n.01', 'andean_condor.n.01']
# 0 173
# ['', '1', '1'] ['california_quail.n.01', 'mountain_quail.n.01', 'migratory_quail.n.01']
# 0 174
# ['', '1', ''] ['camera_obscura.n.01', 'panchromatic_film.n.01', 'television_room.n.01']
# 0 175
# ['', '', '1'] ['camera_tripod.n.01', 'tripod.n.01', 'surveying_instrument.n.01']
# 0 176
# ['', '1', ''] ['candle.n.01', 'vigil_light.n.01', "our_lord's_candle.n.01"]
# 0 177
# ['candle.n.01', 'vigil_light.n.01', "our_lord's_candle.n.01"] ['candy_bar.n.01', 'confectionery.n.02', 'confectionery.n.01', 'tuck_shop.n.01']
# 0 178
# ['candy_bar.n.01', 'confectionery.n.02', 'confectionery.n.01', 'tuck_shop.n.01'] ['cannon.n.01', 'cannon.n.04', 'cannon.n.03', 'cannon.n.02', 'naval_gun.n.01', 'artillery.n.01']
# 0 179
# ['cannon.n.01', 'cannon.n.04', 'cannon.n.03', 'cannon.n.02', 'naval_gun.n.01', 'artillery.n.01'] ['cantilever_bridge.n.01', 'pontoon_bridge.n.01', 'toll_bridge.n.01']
# 0 180
# ['', '', ''] ['canyonside.n.01', 'canyon.n.01', 'mesa.n.01']
# 0 181
# ['', '', '1'] ['capuchin.n.02', 'langur.n.01', 'mangabey.n.01']
# 0 182
# ['2', '1', ''] ['car_wheel.n.01', 'car_tire.n.01', 'fitment.n.01']
# 0 183
# ['car_wheel.n.01', 'car_tire.n.01', 'fitment.n.01'] ['carabao.n.01', 'banteng.n.01', 'brahman.n.04', 'brahman.n.02']
# 0 184
# ['carabao.n.01', 'banteng.n.01', 'brahman.n.04', 'brahman.n.02'] ['carbonara.n.01', 'chicken_tetrazzini.n.01', 'pasta.n.01']
# 0 185
# ['carbonara.n.01', 'chicken_tetrazzini.n.01', 'pasta.n.01'] ['cardigan.n.02', 'cardigan.n.01', 'knitwear.n.01', 'double_knit.n.01']
# 0 186
# ['', '', '1', '1'] ['cardoon.n.02', 'cardoon.n.01', 'bull_thistle.n.01', 'welted_thistle.n.01']
# 0 187
# ['cardoon.n.02', 'cardoon.n.01', 'bull_thistle.n.01', 'welted_thistle.n.01'] ['carousel.n.02', 'fairground.n.01', 'amusement_park.n.01']
# 0 188
# ['2', '', ''] ["carpenter's_kit.n.01", 'toolbox.n.01', 'toolshed.n.01']
# 0 189
# ['', '', '1'] ['carrier.n.10', 'warship.n.01', 'ship-towed_long-range_acoustic_detection_system.n.01']
# 0 190
# ['0', '1', ''] ['cash_machine.n.01', 'cash_register.n.01', 'safe-deposit.n.01']
# 0 191
# ['1', '1', ''] ['cassette_deck.n.01', 'cassette_recorder.n.01', 'tape_deck.n.01']
# 0 192
# ['', '', '1'] ['cassette_tape.n.01', 'cassette.n.01', 'cassette_player.n.01']
# 0 193
# ['cassette_tape.n.01', 'cassette.n.01', 'cassette_player.n.01'] ['castle.n.02', 'castle.n.03', 'gatehouse.n.01', 'highland.n.01']
# 0 194
# ['castle.n.02', 'castle.n.03', 'gatehouse.n.01', 'highland.n.01'] ['cat_box.n.01', 'siamese_cat.n.01', 'blue_point_siamese.n.01']
# 0 195
# ['1', '', ''] ['catamaran.n.01', 'trimaran.n.01', 'bareboat.n.01']
# 0 196
# ['catamaran.n.01', 'trimaran.n.01', 'bareboat.n.01'] ['cauliflower.n.02', 'cauliflower.n.01', 'cruciferous_vegetable.n.01', 'macaroni_salad.n.01']
# 0 197
# ['cauliflower.n.02', 'cauliflower.n.01', 'cruciferous_vegetable.n.01', 'macaroni_salad.n.01'] ['cd_player.n.01', 'walkman.n.01', 'hi-fi.n.01']
# 0 198
# ['1', '1', '1'] ['cedar_chest.n.01', 'hope_chest.n.01', 'sea_chest.n.01']
# 0 199
# ['', '', '1'] ['cellblock.n.01', 'detainee.n.01', 'reformatory.n.01']
# 0 200
# ['', '', ''] ['cellist.n.01', 'violist.n.01', 'bass_fiddle.n.01']
# 0 201
# ['', '1', ''] ['cello.n.01', 'bowed_stringed_instrument.n.01', 'violin.n.01']
# 0 202
# ['1', '', ''] ['cenotaph.n.01', 'gravestone.n.01', 'anzac.n.01']
# 0 203
# ['1', '', '1'] ['centipede.n.01', 'millipede.n.01', 'garden_centipede.n.01']
# 0 204
# ['', '1', ''] ['chaetodon.n.01', 'surgeonfish.n.01', 'damselfish.n.01']
# 0 205
# ['chaetodon.n.01', 'surgeonfish.n.01', 'damselfish.n.01'] ['chainlink_fence.n.01', 'fence.n.01', 'fence.n.02', 'rail_fence.n.01']
# 0 206
# ['chainlink_fence.n.01', 'fence.n.01', 'fence.n.02', 'rail_fence.n.01'] ['chambered_nautilus.n.01', 'conch.n.01', 'giant_conch.n.01']
# 0 207
# ['', '1', ''] ['chasuble.n.01', 'vestment.n.01', 'thurifer.n.01']
# 0 208
# ['', '1', ''] ['chateau.n.01', 'manor_hall.n.01', 'manor.n.01']
# 0 209
# ['1', '', '1'] ['cheeseburger.n.01', 'hamburger.n.01', 'tunaburger.n.01']
# 0 210
# ['cheeseburger.n.01', 'hamburger.n.01', 'tunaburger.n.01'] ['cheetah.n.01', 'leopard.n.02', 'leopard.n.01', 'leopardess.n.01']
# 0 211
# ['cheetah.n.01', 'leopard.n.02', 'leopard.n.01', 'leopardess.n.01'] ['chesapeake_bay_retriever.n.01', 'golden_retriever.n.01', 'labrador_retriever.n.01']
# 0 212
# ['', '1', ''] ['chickadee.n.01', 'black-capped_chickadee.n.01', 'carolina_chickadee.n.01']
# 0 213
# ['', '', ''] ['chihuahua.n.03', 'papillon.n.01', 'toy_terrier.n.01']
# 0 214
# ['3', '', ''] ['child_prodigy.n.01', 'violist.n.01', 'pageboy.n.02']
# 0 215
# ['', '1', ''] ['china_cabinet.n.01', 'cabinetwork.n.01', 'etagere.n.01']
# 0 216
# ['1', '', '1'] ['chinese_brown_sauce.n.01', 'oxtail_soup.n.01', 'saltshaker.n.01']
# 0 217
# ['chinese_brown_sauce.n.01', 'oxtail_soup.n.01', 'saltshaker.n.01'] ['chinese_cabbage.n.02', 'savoy_cabbage.n.02', 'savoy_cabbage.n.01', 'chicory_escarole.n.01']
# 0 218
# ['chinese_cabbage.n.02', 'savoy_cabbage.n.02', 'savoy_cabbage.n.01', 'chicory_escarole.n.01'] ['chiton.n.02', 'sea_cucumber.n.01', 'zebra_mussel.n.01']
# 0 219
# ['chiton.n.02', 'sea_cucumber.n.01', 'zebra_mussel.n.01'] ['chop-suey_greens.n.02', 'chop-suey_greens.n.01', 'macrobiotic_diet.n.01', 'crudites.n.01']
# 0 220
# ['', '', '', ''] ['chow.n.03', 'chow.n.02', 'chowchow.n.02', 'keeshond.n.01']
# 0 221
# ['chow.n.03', 'chow.n.02', 'chowchow.n.02', 'keeshond.n.01'] ['chukka.n.02', 'plus_fours.n.01', 'toecap.n.01']
# 0 222
# ['', '1', '1'] ['cicada.n.01', 'dog-day_cicada.n.01', 'cicada_killer.n.01']
# 0 223
# ['cicada.n.01', 'dog-day_cicada.n.01', 'cicada_killer.n.01'] ['clay-colored_robin.n.01', 'robin.n.02', 'robin.n.01', 'northern_sea_robin.n.01']
# 0 224
# ['clay-colored_robin.n.01', 'robin.n.02', 'robin.n.01', 'northern_sea_robin.n.01'] ['cleaver.n.01', 'ax_handle.n.01', 'carving_knife.n.01']
# 0 225
# ['', '1', ''] ['cliff.n.01', 'rock_cornish.n.01', 'cliff_brake.n.01']
# 0 226
# ['1', '', '1'] ['cliff_dwelling.n.01', 'cave.n.01', 'burial_chamber.n.01']
# 0 227
# ['cliff_dwelling.n.01', 'cave.n.01', 'burial_chamber.n.01'] ['cloak.n.02', 'cloak.n.01', 'opera_cloak.n.01', 'surcoat.n.02', 'surcoat.n.01']
# 0 228
# ['cloak.n.02', 'cloak.n.01', 'opera_cloak.n.01', 'surcoat.n.02', 'surcoat.n.01'] ['clock_tower.n.01', 'church_tower.n.01', 'campanile.n.01']
# 0 229
# ['', '1', '1'] ['clubroom.n.01', 'master_bedroom.n.01', 'billiard_room.n.01']
# 0 230
# ['1', '', ''] ['clutch_bag.n.01', 'evening_bag.n.01', 'etui.n.01']
# 0 231
# ['', '', '1'] ['coast.n.02', 'cove.n.02', 'littoral.n.01']
# 0 232
# ['2', '', '1'] ['coca_cola.n.01', 'cola.n.02', 'pop_bottle.n.01']
# 0 233
# ['', '2', '1'] ['cockerel.n.01', 'orpington.n.01', 'weathercock.n.01']
# 0 234
# ['1', '1', ''] ['coffee_maker.n.01', 'coffee_urn.n.01', 'percolator.n.01']
# 0 235
# ['', '', ''] ['coffee_mug.n.01', 'mug.n.04', 'coffee_cup.n.01']
# 0 236
# ['', '4', '1'] ['coho.n.02', 'atlantic_salmon.n.02', 'landlocked_salmon.n.01']
# 0 237
# ['coho.n.02', 'atlantic_salmon.n.02', 'landlocked_salmon.n.01'] ['combination_lock.n.01', 'safe.n.01', 'safe.n.02', 'doorlock.n.01']
# 0 238
# ['combination_lock.n.01', 'safe.n.01', 'safe.n.02', 'doorlock.n.01'] ['comic_book.n.01', 'magazine.n.01', 'webbing.n.03']
# 0 239
# ['1', '', '3'] ['common_brant_goose.n.01', 'goose.n.01', 'barnacle_goose.n.01']
# 0 240
# ['', '', ''] ['common_eland.n.01', 'eland.n.01', 'greater_kudu.n.01']
# 0 241
# ['1', '1', '1'] ['common_garter_snake.n.01', 'western_ribbon_snake.n.01', 'eastern_ground_snake.n.01']
# 0 242
# ['', '', ''] ['common_iguana.n.01', 'marine_iguana.n.01', 'desert_iguana.n.01']
# 0 243
# ['1', '', ''] ['common_roundworm.n.01', 'nematode.n.01', 'oligochaete.n.01']
# 0 244
# ['', '1', '1'] ['common_wallaby.n.01', 'rock_wallaby.n.01', 'nail-tailed_wallaby.n.01']
# 0 245
# ['', '1', ''] ['common_zebra.n.01', "grevy's_zebra.n.01", 'zebra.n.01']
# 0 246
# ['1', '', '1'] ['computational_linguist.n.01', 'beer_drinker.n.01', 'computer_scientist.n.01']
# 0 247
# ['', '1', ''] ['computer_keyboard.n.01', 'qwerty_keyboard.n.01', 'shift_key.n.01']
# 0 248
# ['', '1', '1'] ['computer_monitor.n.01', 'television_monitor.n.01', 'desktop_computer.n.01']
# 0 249
# ['', '', '1'] ['computer_user.n.01', 'typist.n.01', 'hand-held_computer.n.01']
# 0 250
# ['computer_user.n.01', 'typist.n.01', 'hand-held_computer.n.01'] ['computerized_axial_tomography_scanner.n.01', 'scanner.n.04', 'scanner.n.03', 'scanner.n.02', 'xerographic_printer.n.01']
# 0 251
# ['computerized_axial_tomography_scanner.n.01', 'scanner.n.04', 'scanner.n.03', 'scanner.n.02', 'xerographic_printer.n.01'] ['conacaste.n.01', 'piton.n.01', 'caldera.n.01']
# 0 252
# ['1', '', '1'] ['concert_band.n.01', 'band.n.13', 'bandsman.n.01']
# 0 253
# ['concert_band.n.01', 'band.n.13', 'bandsman.n.01'] ['connemara_heath.n.01', 'munro.n.01', 'cairn.n.02', 'cairn.n.01']
# 0 254
# ['connemara_heath.n.01', 'munro.n.01', 'cairn.n.02', 'cairn.n.01'] ['container_ship.n.01', 'cargo_ship.n.01', 'shipowner.n.01']
# 0 255
# ['container_ship.n.01', 'cargo_ship.n.01', 'shipowner.n.01'] ['convertible.n.01', 'convertible.n.03', 'hardtop.n.01', 'roadster.n.01']
# 0 256
# ['', '', '', '1'] ['cookstove.n.01', 'stove.n.02', 'stove.n.01', 'charcoal_burner.n.01']
# 0 257
# ['cookstove.n.01', 'stove.n.02', 'stove.n.01', 'charcoal_burner.n.01'] ['copilot.n.01', 'driver.n.05', 'safety_belt.n.01']
# 0 258
# ['1', '5', '1'] ['coral_fungus.n.01', 'common_morel.n.01', 'white_fungus.n.01']
# 0 259
# ['1', '', ''] ['coral_necklace.n.01', 'necklet.n.01', 'necklace.n.01']
# 0 260
# ['', '1', '1'] ['coral_reef.n.01', 'staghorn_coral.n.01', 'barrier_reef.n.01']
# 0 261
# ['', '', '1'] ['corgi.n.01', 'dingo.n.01', 'smooth-haired_fox_terrier.n.01']
# 0 262
# ['1', '1', ''] ['corn_cockle.n.01', 'flint_corn.n.01', 'common_corn_salad.n.01']
# 0 263
# ['', '1', ''] ['cottage_pie.n.01', 'boiled_dinner.n.01', 'tamale_pie.n.01']
# 0 264
# ['', '1', ''] ['coucal.n.01', 'black-billed_cuckoo.n.01', 'towhee.n.01']
# 0 265
# ['', '', '1'] ['cougar.n.01', 'lynx.n.02', 'caracal.n.01']
# 0 266
# ['1', '2', '1'] ['coursing.n.01', 'greyhound_racing.n.01', 'sporting_dog.n.01']
# 0 267
# ['1', '', ''] ['cowboy_boot.n.01', 'riding_boot.n.01', 'bootmaker.n.01']
# 0 268
# ['', '', ''] ['cowboy_hat.n.01', 'ranch_hand.n.01', 'sunhat.n.01']
# 0 269
# ['1', '1', '1'] ['cownose_ray.n.01', 'electric_ray.n.01', 'stingray.n.01']
# 0 270
# ['', '', ''] ['coyote.n.01', 'coydog.n.01', 'jackal.n.01']
# 0 271
# ['1', '1', '1'] ['crab-eating_macaque.n.01', 'macaque.n.01', 'pygmy_chimpanzee.n.01']
# 0 272
# ['crab-eating_macaque.n.01', 'macaque.n.01', 'pygmy_chimpanzee.n.01'] ['crane.n.05', 'crane.n.04', 't-bar_lift.n.01', 'derrick.n.02', 'derrick.n.01']
# 0 273
# ['crane.n.05', 'crane.n.04', 't-bar_lift.n.01', 'derrick.n.02', 'derrick.n.01'] ['crate.n.01', 'pallet.n.03', 'treasure_chest.n.01']
# 0 274
# ['1', '', ''] ['cream_pitcher.n.01', 'jug.n.01', 'tankard.n.01']
# 0 275
# ['', '1', '1'] ['crock_pot.n.01', 'pressure_cooker.n.01', 'food_processor.n.01']
# 0 276
# ['', '', ''] ['croquet.n.01', 'croquet_mallet.n.01', 'croquet_ball.n.01']
# 0 277
# ['1', 'croquet_mallet.n.01', 'croquet_ball.n.01'] ['croquet_equipment.n.01', 'croquet_mallet.n.01', 'croquet_ball.n.01']
# 0 278
# ['1', '', ''] ['cross-country_riding.n.01', 'cycling.n.01', 'motorcycling.n.01']
# 0 279
# ['', '', ''] ['cross-country_skiing.n.01', 'skier.n.01', 'skiing.n.01']
# 0 280
# ['cross-country_skiing.n.01', 'skier.n.01', 'skiing.n.01'] ['crossword_puzzle.n.01', 'newspaper.n.03', 'newspaper.n.01', 'newspaper_editor.n.01']
# 0 281
# ['crossword_puzzle.n.01', 'newspaper.n.03', 'newspaper.n.01', 'newspaper_editor.n.01'] ['cruise_ship.n.01', 'luxury_liner.n.01', 'cruse.n.01']
# 0 282
# ['1', '', '1'] ['cuckoo-bumblebee.n.01', 'honeybee.n.01', 'rocky_mountain_bee_plant.n.01']
# 0 283
# ['', '', ''] ['cuirass.n.01', 'sallet.n.01', 'chain_mail.n.01']
# 0 284
# ['cuirass.n.01', 'sallet.n.01', 'chain_mail.n.01'] ['custard_apple.n.02', 'custard_apple.n.01', 'cherimoya.n.02', 'cherimoya.n.01', 'sweetsop.n.02', 'sweetsop.n.01']
# 0 285
# ['custard_apple.n.02', 'custard_apple.n.01', 'cherimoya.n.02', 'cherimoya.n.01', 'sweetsop.n.02', 'sweetsop.n.01'] ['dam.n.03', 'dam.n.01', 'hydroelectric_turbine.n.01', 'weir.n.01', 'weir.n.02']
# 0 286
# ['"dam.n.03', '"dam.n.01', '"hydroelectric_turbine.n.01', '"weir.n.01', '"weir.n.02'] ['damselfly.n.01', 'dragonfly.n.01', 'darter.n.02']
# 0 287
# ['1', '1', '2'] ['dandie_dinmont.n.01', 'norfolk_terrier.n.01', 'old_english_sheepdog.n.01']
# 0 288
# ['', '', ''] ['dashboard.n.02', 'odometer.n.01', 'gearshift.n.01']
# 0 289
# ['2', '', '1'] ['delivery_truck.n.01', 'lorry.n.02', 'trailer_truck.n.01']
# 0 290
# ['', '2', ''] ['denim.n.02', "levi's.n.01", 'jean.n.01']
# 0 291
# ['', '', '1'] ['dhole.n.01', 'dingo.n.01', 'coydog.n.01']
# 0 292
# ['1', '1', '1'] ['diesel-electric_locomotive.n.01', 'electric_locomotive.n.01', 'diesel-hydraulic_locomotive.n.01']
# 0 293
# ['', '', ''] ['digital_clock.n.01', 'alarm_clock.n.01', 'time_clock.n.01']
# 0 294
# ['', '', '1'] ['digital_watch.n.01', 'stopwatch.n.01', 'chronograph.n.01']
# 0 295
# ['1', '1', '1'] ['dining-room_furniture.n.01', 'dining-room_table.n.01', 'tilt-top_table.n.01']
# 0 296
# ['', '', ''] ['dining_area.n.01', 'grillroom.n.01', 'bistro.n.01']
# 0 297
# ['', '1', '1'] ['dipper.n.01', 'water_ouzel.n.01', 'european_water_ouzel.n.01']
# 0 298
# ['1', '', ''] ['dish_rack.n.01', 'plate_rack.n.01', 'kitchenware.n.01']
# 0 299
# ['dish_rack.n.01', 'plate_rack.n.01', 'kitchenware.n.01'] ['dishwasher.n.01', 'home_appliance.n.01', 'appliance.n.02', 'appliance.n.01']
# 0 300
# ['dishwasher.n.01', 'home_appliance.n.01', 'appliance.n.02', 'appliance.n.01'] ['disk_clutch.n.01', 'drum_brake.n.01', 'disk_brake.n.01']
# 0 301
# ['', '', ''] ['dita.n.01', 'negligee.n.01', 'flapper.n.01']
# 0 302
# ['1', '', '1'] ['dive_bomber.n.01', 'biplane.n.01', 'lighter-than-air_craft.n.01']
# 0 303
# ['', '1', ''] ['dog_food.n.01', 'crab-eating_dog.n.01', 'petfood.n.01']
# 0 304
# ['', '', '1'] ['dogsled.n.01', 'musher.n.01', 'sled_dog.n.01']
# 0 305
# ['dogsled.n.01', 'musher.n.01', 'sled_dog.n.01'] ['domestic_llama.n.01', 'llama.n.01', 'alpaca.n.03', 'alpaca.n.02']
# 0 306
# ['domestic_llama.n.01', 'llama.n.01', 'alpaca.n.03', 'alpaca.n.02'] ['domestic_sheep.n.01', "ram's-head.n.01", 'ewe.n.03']
# 0 307
# ['', '', '3'] ['doormat.n.02', 'carpet_pad.n.01', 'welcome_wagon.n.01']
# 0 308
# ['2', '1', '1'] ['dowitcher.n.01', 'curlew_sandpiper.n.01', 'least_sandpiper.n.01']
# 0 309
# ['', '', '1'] ['drawers.n.01', 'taboret.n.01', 'chest_of_drawers.n.01']
# 0 310
# ['1', '1', ''] ['drilling_platform.n.01', 'drill_rig.n.01', 'oilfield.n.01']
# 0 311
# ['', '1', '1'] ['drummer.n.01', 'percussionist.n.01', 'drumstick.n.02']
# 0 312
# ['', '', '2'] ['dugong.n.01', 'manatee.n.01', 'pygmy_sperm_whale.n.01']
# 0 313
# ['1', '1', ''] ['dumbbell.n.01', 'gym_suit.n.01', 'gym_rat.n.01']
# 0 314
# ['1', '1', '1'] ['dung_beetle.n.01', 'japanese_beetle.n.01', 'ground_beetle.n.01']
# 0 315
# ['1', '', '1'] ['dungeness_crab.n.02', 'king_crab.n.03', 'soft-shell_crab.n.02']
# 0 316
# ['2', '', ''] ['eastern_cottontail.n.01', 'leveret.n.01', 'marsh_hare.n.01']
# 0 317
# ['1', '1', ''] ['ecclesiastical_attire.n.01', 'archbishop.n.01', 'eparchy.n.02']
# 0 318
# ['ecclesiastical_attire.n.01', 'archbishop.n.01', 'eparchy.n.02'] ['echidna.n.02', 'echidna.n.01', 'long-tailed_porcupine.n.01', 'hedgehog.n.02']
# 0 319
# ['echidna.n.02', 'echidna.n.01', 'long-tailed_porcupine.n.01', 'hedgehog.n.02'] ['edible_banana.n.01', 'abyssinian_banana.n.01', 'japanese_banana.n.01']
# 0 320
# ['1', '', ''] ['edible_sea_urchin.n.01', 'sea_urchin.n.01', 'porcupine_ball.n.01']
# 0 321
# ['', '1', ''] ['eggnog.n.01', 'pina_colada.n.01', 'milk_punch.n.01']
# 0 322
# ['1', '', '1'] ['electric_drill.n.01', 'power_tool.n.01', 'pneumatic_drill.n.01']
# 0 323
# ['electric_drill.n.01', 'power_tool.n.01', 'pneumatic_drill.n.01'] ['electric_fan.n.01', 'exhaust_fan.n.01', 'fan.n.01', 'fan.n.03']
# 0 324
# ['electric_fan.n.01', 'exhaust_fan.n.01', 'fan.n.01', 'fan.n.03'] ['electric_guitar.n.01', 'guitarist.n.01', 'bass_guitar.n.01']
# 0 325
# ['1', '1', '1'] ['electronic_fetal_monitor.n.01', 'analytical_balance.n.01', 'densitometer.n.01']
# 0 326
# ['', '', ''] ['enamelware.n.01', 'sugar_bowl.n.01', 'mixing_bowl.n.01']
# 0 327
# ['1', '', '1'] ['english_foxhound.n.01', 'beagle.n.01', 'walker_hound.n.01']
# 0 328
# ['', '1', '1'] ['enlisted_woman.n.01', 'military_uniform.n.01', 'full-dress_uniform.n.01']
# 0 329
# ['', '', ''] ['ensemble.n.05', 'cabaret.n.01', 'viola_da_braccio.n.01']
# 0 330
# ['5', '1', ''] ['entertainment_center.n.01', 'wall_unit.n.01', 'television_room.n.01']
# 0 331
# ['', '1', ''] ['entlebucher.n.01', 'rottweiler.n.01', 'beagle.n.01']
# 0 332
# ['entlebucher.n.01', 'rottweiler.n.01', 'beagle.n.01'] ['envelope.n.02', 'envelope.n.01', 'envelope.n.06', 'envelope.n.03', 'window_envelope.n.01', 'mail.n.03']
# 0 333
# ['envelope.n.02', 'envelope.n.01', 'envelope.n.06', 'envelope.n.03', 'window_envelope.n.01', 'mail.n.03'] ['erlenmeyer_flask.n.01', 'round-bottom_flask.n.01', 'molecular_biologist.n.01']
# 0 334
# ['', '', ''] ['eskimo_dog.n.01', 'keeshond.n.01', 'norwegian_elkhound.n.01']
# 0 335
# ['', '1', ''] ['espresso.n.01', 'cappuccino.n.01', 'turkish_coffee.n.01']
# 0 336
# ['1', '', ''] ['espresso_maker.n.01', 'coffee_urn.n.01', 'percolator.n.01']
# 0 337
# ['1', '', '1'] ['eurasian_hamster.n.01', 'hamster.n.01', 'golden_hamster.n.01']
# 0 338
# ['', '1', ''] ['european_bittern.n.01', 'american_bittern.n.01', 'least_bittern.n.01']
# 0 339
# ['european_bittern.n.01', 'american_bittern.n.01', 'least_bittern.n.01'] ['european_fire_salamander.n.01', 'spotted_salamander.n.02', 'spotted_salamander.n.01', 'tiger_salamander.n.01']
# 0 340
# ['european_fire_salamander.n.01', 'spotted_salamander.n.02', 'spotted_salamander.n.01', 'tiger_salamander.n.01'] ['european_wildcat.n.01', 'bobcat.n.01', 'lynx.n.02']
# 0 341
# ['', '1', '2'] ['executrix.n.01', 'hobble_skirt.n.01', 'transvestite.n.01']
# 0 342
# ['1', '', ''] ['false_scorpion.n.01', 'scorpion.n.03', 'vinegarroon.n.01']
# 0 343
# ['', '', ''] ['fan_vaulting.n.01', 'nave.n.01', 'cloister.n.02']
# 0 344
# ['', '1', ''] ['farm_machine.n.01', 'traction_engine.n.01', 'farmer.n.01']
# 0 345
# ['1', '', '1'] ["farmer's_market.n.01", 'punnet.n.01', 'grocery_store.n.01']
# 0 346
# ['', '1', ''] ['feather_boa.n.01', 'flapper.n.01', 'fancy_dress.n.01']
# 0 347
# ['1', '', ''] ['female_child.n.01', 'doll.n.01', 'sunbonnet.n.01']
# 0 348
# ['', '1', '1'] ['ferret.n.02', 'polecat.n.02', 'black-footed_ferret.n.01']
# 0 349
# ['2', '2', ''] ['fiddler_crab.n.01', 'hermit_crab.n.01', 'rock_crab.n.01']
# 0 350
# ['1', '1', '1'] ['film_director.n.01', 'photojournalist.n.01', 'stage_director.n.01']
# 0 351
# ['', '', '1'] ['fire_engine.n.01', 'ladder_truck.n.01', 'visiting_fireman.n.01']
# 0 352
# ['', '', ''] ['fire_screen.n.01', 'fireplace.n.01', 'headboard.n.01']
# 0 353
# ['', '', '1'] ['fireboat.n.01', 'tugboat.n.01', 'pilot_boat.n.01']
# 0 354
# ['1', '1', ''] ["fisherman's_knot.n.01", 'clove_hitch.n.01', 'rope.n.01']
# 0 355
# ['', '', '1'] ['fishing_gear.n.01', 'fly_rod.n.01', 'fishing_rod.n.01']
# 0 356
# ['', '', ''] ['flagpole.n.02', 'flag.n.01', 'half-mast.n.01']
# 0 357
# ['', '1', '1'] ['flamingo.n.01', 'pink_cockatoo.n.01', 'flamingo_flower.n.01']
# 0 358
# ['flamingo.n.01', 'pink_cockatoo.n.01', 'flamingo_flower.n.01'] ['flanker_back.n.01', 'harrier.n.03', 'harrier.n.02', 'afterburner.n.01']
# 0 359
# ['flanker_back.n.01', 'harrier.n.03', 'harrier.n.02', 'afterburner.n.01'] ['flat-coated_retriever.n.01', 'curly-coated_retriever.n.01', 'labrador_retriever.n.01']
# 0 360
# ['', '', '1'] ['flat_tip_screwdriver.n.01', 'phillips_screwdriver.n.01', 'spiral_ratchet_screwdriver.n.01']
# 0 361
# ['', '', ''] ['fleet_street.n.02', 'parliamentary_agent.n.01', 'business_district.n.01']
# 0 362
# ['', '', ''] ['flugelhorn.n.01', 'brazilian_trumpeter.n.01', 'euphonium.n.01']
# 0 363
# ['', '', ''] ['flutist.n.01', 'bassoon.n.01', 'oboist.n.01']
# 0 364
# ['flutist.n.01', 'bassoon.n.01', 'oboist.n.01'] ['fly_agaric.n.01', 'royal_agaric.n.01', 'agaric.n.02', 'agaric.n.01']
# 0 365
# ['', '1', '2', '1'] ['foal.n.01', "przewalski's_horse.n.01", 'yearling.n.03', 'yearling.n.02']
# 0 366
# ['foal.n.01', "przewalski's_horse.n.01", 'yearling.n.03', 'yearling.n.02'] ['foie_gras.n.01', 'pot-au-feu.n.01', 'greylag.n.01']
# 0 367
# ['1', '', '1'] ['food_hamper.n.01', 'hamper.n.02', 'cafeteria_tray.n.01']
# 0 368
# ['1', '2', '1'] ['football_helmet.n.01', 'crash_helmet.n.01', 'football_player.n.01']
# 0 369
# ['', '', ''] ['forklift.n.01', 'backhoe.n.01', 'hand_truck.n.01']
# 0 370
# ['', '1', '1'] ['fountain.n.01', 'drinking_fountain.n.01', 'cascade_liquefier.n.01']
# 0 371
# ['fountain.n.01', 'drinking_fountain.n.01', 'cascade_liquefier.n.01'] ['fountain_pen.n.01', 'pen.n.05', 'pen.n.01', 'writing_implement.n.01']
# 0 372
# ['fountain_pen.n.01', 'pen.n.05', 'pen.n.01', 'writing_implement.n.01'] ['freewheel.n.01', 'disk_brake.n.01', 'mudguard.n.01']
# 0 373
# ['1', '', ''] ['freight_car.n.01', 'dining_car.n.01', 'pullman.n.01']
# 0 374
# ['1', '1', '1'] ['freight_liner.n.01', 'freight_train.n.01', 'trailer_truck.n.01']
# 0 375
# ['', '1', ''] ['french_bread.n.01', 'caraway_seed_bread.n.01', 'italian_bread.n.01']
# 0 376
# ['1', '', '1'] ['french_bulldog.n.01', 'bulldog.n.01', 'seeing_eye_dog.n.01']
# 0 377
# ['', '1', ''] ['french_horn.n.01', 'euphonium.n.01', 'cornet.n.01']
# 0 378
# ['1', '1', '1'] ['frilled_lizard.n.01', 'african_monitor.n.01', 'horned_lizard.n.01']
# 0 379
# ['frilled_lizard.n.01', 'african_monitor.n.01', 'horned_lizard.n.01'] ['front_projector.n.01', 'projector.n.02', 'projector.n.01', 'slide_projector.n.01']
# 0 380
# ['front_projector.n.01', 'projector.n.02', 'projector.n.01', 'slide_projector.n.01'] ['frying_pan.n.01', 'electric_frying_pan.n.01', 'omelet_pan.n.01']
# 0 381
# ['1', '', '1'] ['fuel_filter.n.01', 'brake_cylinder.n.01', 'ignition_coil.n.01']
# 0 382
# ['', '', ''] ['fur_coat.n.01', 'sheepskin_coat.n.01', 'fur_hat.n.01']
# 0 383
# ['fur_coat.n.01', 'sheepskin_coat.n.01', 'fur_hat.n.01'] ['gagman.n.02', 'gagman.n.01', 'peking_man.n.01', 'mongoloid.n.01']
# 0 384
# ['gagman.n.02', 'gagman.n.01', 'peking_man.n.01', 'mongoloid.n.01'] ['galleon.n.01', 'brigantine.n.01', 'treasure_ship.n.01']
# 0 385
# ['', '1', ''] ['gar.n.01', 'pacific_sturgeon.n.01', 'bowfin.n.01']
# 0 386
# ['1', '', '1'] ['garbage_truck.n.01', 'dump_truck.n.01', 'dumpster.n.01']
# 0 387
# ['', '1', ''] ['garter_stitch.n.01', 'double_knit.n.01', 'knit.n.01']
# 0 388
# ['', '1', '1'] ['gas_heater.n.01', 'air_conditioner.n.01', 'heater.n.01']
# 0 389
# ['', '', '1'] ['gas_pump.n.01', 'gasoline_gauge.n.01', 'forecourt.n.01']
# 0 390
# ['1', '', '1'] ['geastrum_coronatum.n.01', 'earthstar.n.01', 'clitocybe_robusta.n.01']
# 0 391
# ['', '', ''] ['geneva_gown.n.01', 'ball_gown.n.01', 'tea_gown.n.01']
# 0 392
# ['1', '', '1'] ['german_short-haired_pointer.n.01', 'bluetick.n.01', 'english_setter.n.01']
# 0 393
# ['', '1', ''] ['geyser.n.01', 'hot_spring.n.01', 'spume.n.01']
# 0 394
# ['1', '', '1'] ['giant_panda.n.01', 'colobus.n.01', 'asian_wild_ox.n.01']
# 0 395
# ['', '', ''] ['gibbon.n.02', 'langur.n.01', 'woolly_monkey.n.01']
# 0 396
# ['2', '1', ''] ['gila_monster.n.01', 'african_monitor.n.01', 'beaded_lizard.n.01']
# 0 397
# ['', '', ''] ['glasses_case.n.01', 'etui.n.01', 'pouch.n.01']
# 0 398
# ['', '1', '1'] ['go-kart.n.01', 'racing.n.01', 'bumper_car.n.01']
# 0 399
# ['1', '', '1'] ['goldfinch.n.02', 'siskin.n.01', 'golden_oriole.n.01']
# 0 400
# ['', '1', ''] ['goldfish.n.01', 'swordtail.n.01', 'platy.n.01']
# 0 401
# ['1', '1', '1'] ['golf_ball.n.01', 'golf_equipment.n.01', 'golf-club_head.n.01']
# 0 402
# ['', '', '1'] ['golfcart.n.01', 'golf_club.n.02', 'professional_golf.n.01']
# 0 403
# ['1', '', ''] ['gondolier.n.01', 'gondola.n.02', 'sampan.n.01']
# 0 404
# ['', '2', ''] ['gong.n.01', 'high-hat_cymbal.n.01', 'cymbal.n.01']
# 0 405
# ['1', '1', '1'] ['graduated_cylinder.n.01', 'water-soluble_vitamin.n.01', 'primary_color_for_pigments.n.01']
# 0 406
# ['', '', ''] ['granddaughter.n.01', 'great-niece.n.01', 'baby_blue-eyes.n.01']
# 0 407
# ['granddaughter.n.01', 'great-niece.n.01', 'baby_blue-eyes.n.01'] ['grate.n.01', 'grate.n.03', 'chain_mail.n.01', 'drain_basket.n.01']
# 0 408
# ['grate.n.01', 'grate.n.03', 'chain_mail.n.01', 'drain_basket.n.01'] ['great-nephew.n.01', 'highchair.n.01', 'baby_farmer.n.01']
# 0 409
# ['1', '1', ''] ['great_grey_owl.n.01', 'barred_owl.n.01', 'spotted_owl.n.01']
# 0 410
# ['1', '1', '1'] ['great_yellowcress.n.01', 'yellow_bedstraw.n.01', 'field_mustard.n.01']
# 0 411
# ['1', '1', ''] ['greater_swiss_mountain_dog.n.01', 'swiss_mountain_pine.n.01', 'rottweiler.n.01']
# 0 412
# ['', '', '1'] ["green_adder's_mouth.n.01", 'massasauga.n.02', 'eastern_ground_snake.n.01']
# 0 413
# ['', '', ''] ['green_lacewing.n.01', 'leafhopper.n.01', 'lacewing.n.01']
# 0 414
# ['', '1', ''] ['green_lizard.n.01', 'american_chameleon.n.01', 'touraco.n.01']
# 0 415
# ['green_lizard.n.01', 'american_chameleon.n.01', 'touraco.n.01'] ['green_snake.n.02', 'green_snake.n.01', 'rough_green_snake.n.01', 'vine_snake.n.01']
# 0 416
# ['2', '', '', '1'] ['greengrocery.n.02', 'fig.n.04', 'fig.n.02', 'raw_vegetable.n.01']
# 0 417
# ['', '4', '2', ''] ['greenhouse.n.01', 'conservatory.n.03', 'conservatory.n.02', 'cold_frame.n.01']
# 0 418
# ['greenhouse.n.01', 'conservatory.n.03', 'conservatory.n.02', 'cold_frame.n.01'] ['grey_whale.n.01', 'humpback.n.03', 'right_whale.n.01']
# 0 419
# ['', '3', '1'] ['grille.n.02', 'headlight.n.01', 'bumper_guard.n.01']
# 0 420
# ['2', '', ''] ['groenendael.n.01', 'kelpie.n.02', 'keeshond.n.01']
# 0 421
# ['groenendael.n.01', 'kelpie.n.02', 'keeshond.n.01'] ['groom.n.03', 'groom.n.01', 'formalwear.n.01', 'bow_tie.n.01']
# 0 422
# ['groom.n.03', 'groom.n.01', 'formalwear.n.01', 'bow_tie.n.01'] ['guacamole.n.01', 'tostada.n.01', 'salsa.n.01']
# 0 423
# ['1', '1', '1'] ['guadalupe_fur_seal.n.01', 'california_sea_lion.n.01', 'sea_otter.n.01']
# 0 424
# ['guadalupe_fur_seal.n.01', 'california_sea_lion.n.01', 'sea_otter.n.01'] ["guard's_van.n.01", 'armored_car.n.02', 'armored_car.n.01', 'horsebox.n.01']
# 0 425
# ["guard's_van.n.01", 'armored_car.n.02', 'armored_car.n.01', 'horsebox.n.01'] ['guenon.n.01', 'colobus.n.01', 'langur.n.01']
# 0 426
# ['1', '1', '1'] ['guestroom.n.01', 'hotel_room.n.01', 'master_bedroom.n.01']
# 0 427
# ['1', '', ''] ['guillotine.n.02', 'winepress.n.01', 'gallows.n.01']
# 0 428
# ['', '', '1'] ['guinea_pig.n.02', 'cavy.n.01', 'golden_hamster.n.01']
# 0 429
# ['2', '1', ''] ['guitar_pick.n.01', 'pendant_earring.n.01', 'fingerstall.n.01']
# 0 430
# ['', '', '1'] ['gym_shoe.n.01', 'baby_shoe.n.01', 'bowling_shoe.n.01']
# 0 431
# ['', '1', ''] ['gymnast.n.01', 'gymnastics.n.01', 'vaulter.n.01']
# 0 432
# ['1', 'gymnastics.n.01', 'vaulter.n.01'] ['gymnastic_apparatus.n.01', 'gymnastics.n.01', 'vaulter.n.01']
# 0 433
# ['', '1', '1'] ['gypsy_cab.n.01', 'taxi_dancer.n.01', 'used-car.n.01']
# 0 434
# ['1', '1', '1'] ['gyromitra_sphaerospora.n.01', 'gyromitra_infula.n.01', 'common_morel.n.01']
# 0 435
# ['', '', '1'] ['hair_slide.n.01', 'barrette.n.01', 'pendant_earring.n.01']
# 0 436
# ['', '1', ''] ['hair_spray.n.01', 'curling_iron.n.01', 'hairdresser.n.01']
# 0 437
# ['', '1', ''] ['hairstreak.n.01', 'hippodamia_convergens.n.01', 'large_white.n.01']
# 0 438
# ['', '', ''] ['handbarrow.n.01', 'spreader.n.01', 'hand_shovel.n.01']
# 0 439
# ['', '1', ''] ['handcart.n.01', 'motorized_wheelchair.n.01', 'buckboard.n.01']
# 0 440
# ['', '', '1'] ['handset.n.01', 'dial_telephone.n.01', 'cellular_telephone.n.01']
# 0 441
# ['1', '', ''] ['harmonica.n.01', 'kazoo.n.01', 'cigar_lighter.n.01']
# 0 442
# ['harmonica.n.01', 'kazoo.n.01', 'cigar_lighter.n.01'] ['harp.n.01', 'harp.n.02', 'aeolian_harp.n.01', "jew's_harp.n.01"]
# 0 443
# ['harp.n.01', 'harp.n.02', 'aeolian_harp.n.01', "jew's_harp.n.01"] ['hartebeest.n.01', 'sable_antelope.n.01', 'waterbuck.n.01']
# 0 444
# ['hartebeest.n.01', 'sable_antelope.n.01', 'waterbuck.n.01'] ['harvester.n.02', 'combine.n.01', 'skidder.n.03', 'skidder.n.02']
# 0 445
# ['harvester.n.02', 'combine.n.01', 'skidder.n.03', 'skidder.n.02'] ['harvestman.n.01', 'comb-footed_spider.n.01', 'asian_tiger_mosquito.n.01']
# 0 446
# ['harvestman.n.01', 'comb-footed_spider.n.01', 'asian_tiger_mosquito.n.01'] ['hay.n.01', 'hay_bale.n.01', 'hayrack.n.02', 'hayrack.n.01']
# 0 447
# ['hay.n.01', 'hay_bale.n.01', 'hayrack.n.02', 'hayrack.n.01'] ['hearing_dog.n.01', 'labrador_retriever.n.01', 'golden_retriever.n.01']
# 0 448
# ['1', '1', ''] ['hen-of-the-woods.n.01', 'morchella_semilibera.n.01', 'common_morel.n.01']
# 0 449
# ['hen-of-the-woods.n.01', 'morchella_semilibera.n.01', 'common_morel.n.01'] ['hickory_nut.n.01', 'fig_tree.n.01', 'fig.n.04', 'fig.n.02']
# 0 450
# ['hickory_nut.n.01', 'fig_tree.n.01', 'fig.n.04', 'fig.n.02'] ['high_altar.n.01', 'altarpiece.n.01', 'nave.n.01']
# 0 451
# ['', '', '1'] ['highboy.n.01', 'chiffonier.n.01', 'pickup.n.01']
# 0 452
# ['1', '', '1'] ['hippopotamus.n.01', 'babirusa.n.01', 'malayan_tapir.n.01']
# 0 453
# ['', '1', ''] ['hoary_marmot.n.01', 'yellowbelly_marmot.n.01', 'marmot.n.01']
# 0 454
# ['hoary_marmot.n.01', 'yellowbelly_marmot.n.01', 'marmot.n.01'] ['holster.n.01', 'holster.n.02', 'stock_saddle.n.01', 'shoulder_holster.n.01']
# 0 455
# ['holster.n.01', 'holster.n.02', 'stock_saddle.n.01', 'shoulder_holster.n.01'] ['home_theater.n.01', 'television_room.n.01', 'wall_unit.n.01']
# 0 456
# ['home_theater.n.01', 'television_room.n.01', 'wall_unit.n.01'] ['honeycomb.n.02', 'honeycomb.n.01', "wasp's_nest.n.01", 'beehive.n.04']
# 0 457
# ['honeycomb.n.02', 'honeycomb.n.01', "wasp's_nest.n.01", 'beehive.n.04'] ['hornbill.n.01', 'toucan.n.01', 'toucanet.n.01']
# 0 458
# ['1', '1', '1'] ['horse-drawn_vehicle.n.01', 'percheron.n.01', 'pony_cart.n.01']
# 0 459
# ['', '', '1'] ['horse_cart.n.01', 'pony_cart.n.01', 'pony-trekking.n.01']
# 0 460
# ['1', '', ''] ['horsehair_wig.n.01', 'wig.n.01', 'afro-wig.n.01']
# 0 461
# ['1', '1', '1'] ['hot-air_balloon.n.01', 'meteorological_balloon.n.01', 'barrage_balloon.n.01']
# 0 462
# ['', '', '1'] ['hot-fudge_sauce.n.01', 'chocolate_sauce.n.01', 'chocolate_pudding.n.01']
# 0 463
# ['1', '', ''] ['hot-water_bottle.n.01', 'water_bottle.n.01', 'water_jug.n.01']
# 0 464
# ['', '', '1'] ['hot_pot.n.01', 'sukiyaki.n.01', 'oxtail_soup.n.01']
# 0 465
# ['', '', ''] ['hot_rod.n.01', 'pickup.n.01', 'caddy.n.01']
# 0 466
# ['', '1', '1'] ['hot_tub.n.01', 'hot_spring.n.01', 'wading_pool.n.01']
# 0 467
# ['', '1', ''] ['hotdog.n.02', 'frankfurter_bun.n.01', 'chili_dog.n.01']
# 0 468
# ['2', '', '1'] ['hourglass.n.01', 'sandglass.n.01', 'clock_pendulum.n.01']
# 0 469
# ['1', '1', ''] ['house_centipede.n.01', 'silverfish.n.01', 'sea_louse.n.01']
# 0 470
# ['', '', '1'] ['housekeeper.n.01', 'vacuum.n.04', 'carpet_sweeper.n.01']
# 0 471
# ['1', '4', ''] ['howler_monkey.n.01', 'woolly_monkey.n.01', 'langur.n.01']
# 0 472
# ['howler_monkey.n.01', 'woolly_monkey.n.01', 'langur.n.01'] ['hummingbird.n.01', 'feeder.n.01', 'feeder.n.06', 'rufous_rubber_cup.n.01']
# 0 473
# ['hummingbird.n.01', 'feeder.n.01', 'feeder.n.06', 'rufous_rubber_cup.n.01'] ['hydroplane_racing.n.01', 'racing_boat.n.01', 'boat_racing.n.01']
# 0 474
# ['', '', '1'] ['ibizan_hound.n.01', 'dingo.n.01', 'walker_hound.n.01']
# 0 475
# ['1', '1', ''] ['ice-cream_cake.n.01', 'tiramisu.n.01', 'dessert.n.01']
# 0 476
# ['1', '1', '1'] ['ice-cream_sundae.n.01', 'strawberry_ice_cream.n.01', 'chocolate_ice_cream.n.01']
# 0 477
# ['ice-cream_sundae.n.01', 'strawberry_ice_cream.n.01', 'chocolate_ice_cream.n.01'] ['ice_bear.n.01', 'cub.n.03', 'cub.n.02', 'arctic.n.02']
# 0 478
# ['ice_bear.n.01', 'cub.n.03', 'cub.n.02', 'arctic.n.02'] ['ice_hockey.n.01', 'hockey_skate.n.01', 'hockey_stick.n.01']
# 0 479
# ['', '', '1'] ['ice_lolly.n.01', 'lollipop.n.02', 'strawberry_ice_cream.n.01']
# 0 480
# ['', '', ''] ['impala.n.01', 'caddy.n.01', 'used-car.n.01']
# 0 481
# ['1', '1', '1'] ['indian_mongoose.n.01', 'mongoose.n.01', 'longtail_weasel.n.01']
# 0 482
# ['', '', ''] ['indigo_bunting.n.01', 'cotinga.n.01', 'bluebird.n.02']
# 0 483
# ['', '', '2'] ['indri.n.01', 'colobus.n.01', 'flying_lemur.n.01']
# 0 484
# ['indri.n.01', 'colobus.n.01', 'flying_lemur.n.01'] ['infielder.n.01', 'right_fielder.n.01', 'bunt.n.04', 'bunt.n.03']
# 0 485
# ['infielder.n.01', 'right_fielder.n.01', 'bunt.n.04', 'bunt.n.03'] ['internal_drive.n.01', 'disk_drive.n.01', 'removable_disk.n.01']
# 0 486
# ['', '', ''] ['ipod.n.01', 'video_ipod.n.01', 'walkman.n.01']
# 0 487
# ['1', '1', '1'] ['irish_setter.n.01', 'gordon_setter.n.01', 'english_setter.n.01']
# 0 488
# ['1', '', '1'] ['irish_water_spaniel.n.01', 'water_spaniel.n.01', 'american_water_spaniel.n.01']
# 0 489
# ['', '1', ''] ['italian_greyhound.n.01', 'mexican_hairless.n.01', 'greyhound.n.01']
# 0 490
# ['', '', ''] ['jacamar.n.01', 'bee_eater.n.01', 'motmot.n.01']
# 0 491
# ['1', '1', '1'] ["jack-o'-lantern.n.02", 'pumpkin_seed.n.01', 'pumpkin_ash.n.01']
# 0 492
# ["jack-o'-lantern.n.02", 'pumpkin_seed.n.01', 'pumpkin_ash.n.01'] ['jackfruit.n.02', 'jackfruit.n.01', 'pulasan.n.02', 'pulasan.n.01', 'breadfruit.n.02', 'breadfruit.n.01']
# 0 493
# ['jackfruit.n.02', 'jackfruit.n.01', 'pulasan.n.02', 'pulasan.n.01', 'breadfruit.n.02', 'breadfruit.n.01'] ['jaguar.n.01', 'leopard.n.02', 'leopard.n.01', 'leopardess.n.01']
# 0 494
# ['jaguar.n.01', 'leopard.n.02', 'leopard.n.01', 'leopardess.n.01'] ['jaunting_car.n.01', 'horseless_carriage.n.01', 'traction_engine.n.01']
# 0 495
# ['', '', ''] ['jellyfish.n.02', "calf's-foot_jelly.n.01", 'coelenterate.n.01']
# 0 496
# ['2', '', ''] ['jigsaw_puzzle.n.01', 'jigsaw.n.02', 'decoupage.n.01']
# 0 497
# ['', '', '1'] ['jodhpur.n.01', 'ashram.n.02', 'indian_elephant.n.01']
# 0 498
# ['1', '2', ''] ['joystick.n.02', 'wrist_pad.n.01', 'trackball.n.01']
# 0 499
# ['joystick.n.02', 'wrist_pad.n.01', 'trackball.n.01'] ['jukebox.n.01', 'radio.n.03', 'radio.n.01', 'automat.n.02', 'automat.n.01']
# 0 500
# ['jukebox.n.01', 'radio.n.03', 'radio.n.01', 'automat.n.02', 'automat.n.01'] ['junco.n.01', 'dark-eyed_junco.n.01', 'towhee.n.01']
# 0 501
# ['', '', '1'] ['kayak.n.01', 'canoe.n.01', 'dugout_canoe.n.01']
# 0 502
# ['1', '1', '1'] ['kennel.n.01', 'rabbit_hutch.n.01', 'seizure-alert_dog.n.01']
# 0 503
# ['1', '1', '1'] ['kerry_blue_terrier.n.01', 'standard_schnauzer.n.01', 'scottish_deerhound.n.01']
# 0 504
# ['', '', ''] ['kidney_stone.n.01', 'bladder_stone.n.01', 'pallasite.n.01']
# 0 505
# ['', '', '1'] ['killer_whale.n.01', 'blackfish.n.02', 'pilot_whale.n.01']
# 0 506
# ['', '', ''] ['kimono.n.01', 'chigetai.n.01', 'jinrikisha.n.01']
# 0 507
# ['1', '1', '1'] ['king_penguin.n.01', 'emperor_penguin.n.01', 'jackass_penguin.n.01']
# 0 508
# ['king_penguin.n.01', 'emperor_penguin.n.01', 'jackass_penguin.n.01'] ['kit_fox.n.02', 'kit_fox.n.01', 'grey_fox.n.01', 'jackal.n.01']
# 0 509
# ['kit_fox.n.02', 'kit_fox.n.01', 'grey_fox.n.01', 'jackal.n.01'] ['kitbag.n.01', 'duffel_bag.n.01', 'etui.n.01']
# 0 510
# ['1', '1', '1'] ['kitchen.n.01', 'kitchenette.n.01', 'range_hood.n.01']
# 0 511
# ['kitchen.n.01', 'kitchenette.n.01', 'range_hood.n.01'] ['kitchen_utensil.n.01', 'spatula.n.02', 'spatula.n.01', 'cooking_utensil.n.01']
# 0 512
# ['kitchen_utensil.n.01', 'spatula.n.02', 'spatula.n.01', 'cooking_utensil.n.01'] ['kitten-tails.n.01', 'blue_point_siamese.n.01', 'siamese_cat.n.01']
# 0 513
# ['', '', ''] ['knee_brace.n.01', 'crutch.n.01', 'elbow_pad.n.01']
# 0 514
# ['', '1', '1'] ['knobkerrie.n.01', 'ax_handle.n.01', 'double-reed_instrument.n.01']
# 0 515
# ['', '1', ''] ['koala.n.01', 'tree_wallaby.n.01', 'marsupial.n.01']
# 0 516
# ['1', '1', '1'] ['komodo_dragon.n.01', 'african_monitor.n.01', 'chuckwalla.n.01']
# 0 517
# ['', '1', '1'] ['komondor.n.01', 'old_english_sheepdog.n.01', 'afghan_hound.n.01']
# 0 518
# ['', '', '1'] ['kuvasz.n.01', 'great_pyrenees.n.01', 'golden_retriever.n.01']
# 0 519
# ['1', '', ''] ['lakeside.n.01', 'lake_whitefish.n.01', 'lakefront.n.01']
# 0 520
# ['', '', '1'] ['lapdog.n.01', 'rottweiler.n.01', 'norwegian_elkhound.n.01']
# 0 521
# ['', '1', ''] ['laptop.n.01', 'hand-held_computer.n.01', 'lapboard.n.01']
# 0 522
# ['1', '1', '1'] ["large_yellow_lady's_slipper.n.01", "yellow_lady's_slipper.n.01", "california_lady's_slipper.n.01"]
# 0 523
# ['', '', ''] ['latin_american.n.01', 'nicaraguan.n.01', 'mestiza.n.01']
# 0 524
# ['latin_american.n.01', 'nicaraguan.n.01', 'mestiza.n.01'] ['leash.n.01', 'lanyard.n.01', 'halter.n.03', 'halter.n.01']
# 0 525
# ['leash.n.01', 'lanyard.n.01', 'halter.n.03', 'halter.n.01'] ['leatherback_turtle.n.01', 'hawksbill_turtle.n.01', 'sea_turtle.n.01']
# 0 526
# ['leatherback_turtle.n.01', 'hawksbill_turtle.n.01', 'sea_turtle.n.01'] ['lemon_extract.n.01', 'lemon.n.04', 'lemon.n.01', 'lemon.n.03', 'citron.n.01', 'citron.n.02']
# 0 527
# ['lemon_extract.n.01', 'lemon.n.04', 'lemon.n.01', 'lemon.n.03', 'citron.n.01', 'citron.n.02'] ['lemur.n.01', 'banded_palm_civet.n.01', 'vervet.n.01']
# 0 528
# ['1', '', ''] ['lens_cap.n.01', 'camera_lens.n.01', 'loupe.n.01']
# 0 529
# ['1', '1', '1'] ['lentil_soup.n.01', 'split-pea_soup.n.01', 'eggdrop_soup.n.01']
# 0 530
# ['', '1', '1'] ['leonberg.n.01', 'norwegian_elkhound.n.01', 'german_shepherd.n.01']
# 0 531
# ['1', '', ''] ['lesser_panda.n.01', 'flying_fox.n.01', 'american_marten.n.01']
# 0 532
# ['1', '1', '1'] ['lesser_prairie_chicken.n.01', 'prairie_chicken.n.01', 'sharp-tailed_grouse.n.01']
# 0 533
# ['lesser_prairie_chicken.n.01', 'prairie_chicken.n.01', 'sharp-tailed_grouse.n.01'] ['library.n.01', 'library.n.05', 'library.n.02', 'repository.n.03', 'archivist.n.01']
# 0 534
# ['library.n.01', 'library.n.05', 'library.n.02', 'repository.n.03', 'archivist.n.01'] ['life_office.n.01', 'office_furniture.n.01', 'land_office.n.01']
# 0 535
# ['', '', '1'] ['lifeboat.n.01', 'pilot_boat.n.01', 'rescue_equipment.n.01']
# 0 536
# ['', '1', ''] ['lighter.n.02', 'cigar_lighter.n.01', 'cigarette_case.n.01']
# 0 537
# ['2', '', ''] ['limousine.n.01', 'hearse.n.01', 'caddy.n.01']
# 0 538
# ['', '1', '1'] ['limpkin.n.01', 'openbill.n.01', 'american_bittern.n.01']
# 0 539
# ['', '', ''] ['lioness.n.01', 'lion.n.01', 'lion_cub.n.01']
# 0 540
# ['1', '1', '1'] ['lionfish.n.01', 'sea_cucumber.n.01', 'polychaete.n.01']
# 0 541
# ['', '', ''] ['lipstick.n.01', 'lip-gloss.n.01', 'makeup.n.01']
# 0 542
# ['1', '1', '1'] ['liqueur_glass.n.01', 'cheval_glass.n.01', 'beer_glass.n.01']
# 0 543
# ['', '', '1'] ['litter.n.02', 'breeder.n.01', 'foster-mother.n.01']
# 0 544
# ['2', '', ''] ['litterbin.n.01', 'bin.n.01', 'recycling_bin.n.01']
# 0 545
# ['1', '1', ''] ['little_blue_heron.n.01', 'openbill.n.01', 'heron.n.02']
# 0 546
# ['1', '1', '2'] ['liver-spotted_dalmatian.n.01', 'dalmatian.n.02', 'english_setter.n.01']
# 0 547
# ['', '2', '1'] ['living_room.n.01', 'television_room.n.01', 'duplex_apartment.n.01']
# 0 548
# ['', '1', ''] ['loggerhead.n.02', 'hawksbill_turtle.n.01', 'sea_turtle.n.01']
# 0 549
# ['2', '1', ''] ['long-horned_grasshopper.n.01', 'short-horned_grasshopper.n.01', 'katydid.n.01']
# 0 550
# ['', '', '1'] ['longbow.n.01', 'crossbow.n.01', 'bow_and_arrow.n.01']
# 0 551
# ['longbow.n.01', 'crossbow.n.01', 'bow_and_arrow.n.01'] ['macaw.n.01', 'parrot.n.01', 'parrot.n.02', 'lory.n.01']
# 0 552
# ['1', '1', '2', '1'] ['magnetic_compass.n.01', 'mercury_barometer.n.01', 'compass.n.01', 'compass.n.04']
# 0 553
# ['', '', '1', '4'] ['magpie.n.01', 'australian_magpie.n.01', 'butcherbird.n.02', 'butcherbird.n.01']
# 0 554
# ['magpie.n.01', 'australian_magpie.n.01', 'butcherbird.n.02', 'butcherbird.n.01'] ['mailbox.n.01', 'postage_meter.n.01', 'mail.n.03']
# 0 555
# ['1', '1', '3'] ['malinois.n.01', 'german_shepherd.n.01', 'norwegian_elkhound.n.01']
# 0 556
# ['', '', ''] ['mallard.n.01', 'cold_duck.n.01', 'wood_duck.n.01']
# 0 557
# ['1', '', ''] ['maltese_dog.n.01', 'maltese.n.03', 'papillon.n.01']
# 0 558
# ['1', '', ''] ['manhole_cover.n.01', 'sewer.n.01', 'pothole.n.01']
# 0 559
# ['', '1', '1'] ['maraca.n.01', 'juggler.n.01', 'percussion_instrument.n.01']
# 0 560
# ['1', '1', ''] ['margate.n.01', 'port_jackson_heath.n.01', 'martello_tower.n.01']
# 0 561
# ['', '', ''] ['marimba.n.01', 'vibraphone.n.01', 'percussionist.n.01']
# 0 562
# ['', '', ''] ['marquee.n.02', 'theater.n.01', 'showplace.n.01']
# 0 563
# ['2', '1', '1'] ['mashed_potato.n.01', 'potato_salad.n.01', 'mornay_sauce.n.01']
# 0 564
# ['mashed_potato.n.01', 'potato_salad.n.01', 'mornay_sauce.n.01'] ['mask.n.01', 'mask.n.04', 'bar_mask.n.01', 'masquerader.n.01']
# 0 565
# ['mask.n.01', 'mask.n.04', 'bar_mask.n.01', 'masquerader.n.01'] ['matchstick.n.01', 'safety_match.n.01', 'fire_tongs.n.01']
# 0 566
# ['', '1', ''] ['maypole.n.01', 'morris_dancer.n.01', 'stickball.n.01']
# 0 567
# ['maypole.n.01', 'morris_dancer.n.01', 'stickball.n.01'] ['maze.n.01', 'fairy_ring.n.01', 'amphitheater.n.02', 'amphitheater.n.01']
# 0 568
# ['maze.n.01', 'fairy_ring.n.01', 'amphitheater.n.02', 'amphitheater.n.01'] ['measuring_cup.n.01', 'shot_glass.n.01', 'water-soluble_vitamin.n.01']
# 0 569
# ['1', '', ''] ['measuring_stick.n.01', 'slide_rule.n.01', 'yardstick.n.02']
# 0 570
# ['', '', '2'] ['meat_counter.n.01', 'abattoir.n.01', 'grocery_store.n.01']
# 0 571
# ['', '1', '1'] ['meat_loaf.n.01', 'pork-and-veal_goulash.n.01', 'barbecued_spareribs.n.01']
# 0 572
# ...
# repair (1, 441)
# repair (1, 442)
# repair (1, 443)
# repair (1, 444)
# repair (1, 445)
# repair (1, 446)
# repair (1, 447)
# repair (1, 448)
# repair (1, 449)
# repair (1, 450)
# repair (1, 451)
# repair (1, 452)
# repair (1, 453)
# repair (1, 454)
# repair (1, 455)
# repair (1, 456)
# repair (1, 457)
# repair (1, 458)
# repair (1, 459)
# repair (1, 460)
# repair (1, 461)
# repair (1, 462)
# repair (1, 463)
# repair (1, 464)
# repair (1, 465)
# repair (1, 466)
# repair (1, 467)
# repair (1, 468)
# repair (1, 469)
# repair (1, 470)
# repair (1, 471)
# repair (1, 472)
# repair (1, 473)
# repair (1, 474)
# repair (1, 475)
# repair (1, 476)
# repair (1, 477)
# repair (1, 478)
# repair (1, 479)
# repair (1, 480)
# repair (1, 481)
# repair (1, 482)
# repair (1, 483)
# repair (1, 484)
# repair (1, 485)
# repair (1, 486)
# repair (1, 487)
# repair (1, 488)
# repair (1, 489)
# repair (1, 490)
# repair (1, 491)
# repair (1, 492)
# repair (1, 493)
# repair (1, 494)
# repair (1, 495)
# repair (1, 496)
# repair (1, 497)
# repair (1, 498)
# repair (1, 499)
# repair (1, 500)
# repair (1, 501)
# repair (1, 502)
# repair (1, 503)
# repair (1, 504)
# repair (1, 505)
# repair (1, 506)
# repair (1, 507)
# repair (1, 508)
# repair (1, 509)
# repair (1, 510)
# repair (1, 511)
# repair (1, 512)
# repair (1, 513)
# repair (1, 514)
# repair (1, 515)
# repair (1, 516)
# repair (1, 517)
# repair (1, 518)
# repair (1, 519)
# repair (1, 520)
# repair (1, 521)
# repair (1, 522)
# repair (1, 523)
# repair (1, 524)
# repair (1, 525)
# repair (1, 526)
# repair (1, 527)
# repair (1, 528)
# repair (1, 529)
# repair (1, 530)
# repair (1, 531)
# repair (1, 532)
# repair (1, 533)
# repair (1, 534)
# repair (1, 535)
# repair (1, 536)
# repair (1, 537)
# repair (1, 538)
# repair (1, 539)
# repair (1, 540)
# repair (1, 541)
# repair (1, 542)
# repair (1, 543)
# repair (1, 544)
# repair (1, 545)
# repair (1, 546)
# repair (1, 547)
# repair (1, 548)
# repair (1, 549)
# repair (1, 550)
# repair (1, 551)
# repair (1, 552)
# repair (1, 553)
# repair (1, 554)
# repair (1, 555)
# repair (1, 556)
# repair (1, 557)
# repair (1, 558)
# repair (1, 559)
# repair (1, 560)
# repair (1, 561)
# repair (1, 562)
# repair (1, 563)
# repair (1, 564)
# repair (1, 565)
# repair (1, 566)
# repair (1, 567)
# repair (1, 568)
# repair (1, 569)
# repair (1, 570)
# repair (1, 571)
# repair (1, 572)
# repair (1, 573)
# repair (1, 574)
# repair (1, 575)
# repair (1, 576)
# repair (1, 577)
# repair (1, 578)
# repair (1, 579)
# repair (1, 580)
# repair (1, 581)
# repair (1, 582)
# repair (1, 583)
# repair (1, 584)
# repair (1, 585)
# repair (1, 586)
# repair (1, 587)
# repair (1, 588)
# repair (1, 589)
# repair (1, 590)
# repair (1, 591)
# repair (1, 592)
# repair (1, 593)
# repair (1, 594)
# repair (1, 595)
# repair (1, 596)
# repair (1, 597)
# repair (1, 598)
# repair (1, 599)
# repair (1, 600)
# repair (1, 601)
# repair (1, 602)
# repair (1, 603)
# repair (1, 604)
# repair (1, 605)
# repair (1, 606)
# repair (1, 607)
# repair (1, 608)
# repair (1, 609)
# repair (1, 610)
# repair (1, 611)
# repair (1, 612)
# repair (1, 613)
# repair (1, 614)
# repair (1, 615)
# repair (1, 616)
# repair (1, 617)
# repair (1, 618)
# repair (1, 619)
# repair (1, 620)
# repair (1, 621)
# repair (1, 622)
# repair (1, 623)
# repair (1, 624)
# repair (1, 625)
# repair (1, 626)
# repair (1, 627)
# repair (1, 628)
# repair (1, 629)
# repair (1, 630)
# repair (1, 631)
# repair (1, 632)
# repair (1, 633)
# repair (1, 634)
# repair (1, 635)
# repair (1, 636)
# repair (1, 637)
# repair (1, 638)
# repair (1, 639)
# repair (1, 640)
# repair (1, 641)
# repair (1, 642)
# repair (1, 643)
# repair (1, 644)
# repair (1, 645)
# repair (1, 646)
# repair (1, 647)
# repair (1, 648)
# repair (1, 649)
# repair (1, 650)
# repair (1, 651)
# repair (1, 652)
# repair (1, 653)
# repair (1, 654)
# repair (1, 655)
# repair (1, 656)
# repair (1, 657)
# repair (1, 658)
# repair (1, 659)
# repair (1, 660)
# repair (1, 661)
# repair (1, 662)
# repair (1, 663)
# repair (1, 664)
# repair (1, 665)
# repair (1, 666)
# repair (1, 667)
# repair (1, 668)
# repair (1, 669)
# repair (1, 670)
# repair (1, 671)
# repair (1, 672)
# repair (1, 673)
# repair (1, 674)
# repair (1, 675)
# repair (1, 676)
# repair (1, 677)
# repair (1, 678)
# repair (1, 679)
# repair (1, 680)
# repair (1, 681)
# repair (1, 682)
# repair (1, 683)
# repair (1, 684)
# repair (1, 685)
# repair (1, 686)
# repair (1, 687)
# repair (1, 688)
# repair (1, 689)
# repair (1, 690)
# repair (1, 691)
# repair (1, 692)
# repair (1, 693)
# repair (1, 694)
# repair (1, 695)
# repair (1, 696)
# repair (1, 697)
# repair (1, 698)
# repair (1, 699)
# repair (1, 700)
# repair (1, 701)
# repair (1, 702)
# repair (1, 703)
# repair (1, 704)
# repair (1, 705)
# repair (1, 706)
# repair (1, 707)
# repair (1, 708)
# repair (1, 709)
# repair (1, 710)
# repair (1, 711)
# repair (1, 712)
# repair (1, 713)
# repair (1, 714)
# repair (1, 715)
# repair (1, 716)
# repair (1, 717)
# repair (1, 718)
# repair (1, 719)
# repair (1, 720)
# repair (1, 721)
# repair (1, 722)
# repair (2, 72)
# repair (2, 107)
# repair (2, 108)
# repair (2, 109)
# repair (2, 110)
# repair (2, 111)
# repair (2, 112)
# repair (2, 113)
# repair (2, 114)
# repair (2, 115)
# repair (2, 116)
# repair (2, 117)
# repair (2, 118)
# repair (2, 119)
# repair (2, 120)
# repair (2, 121)
# repair (2, 122)
# repair (2, 123)
# repair (2, 124)
# repair (2, 125)
# repair (2, 126)
# repair (2, 127)
# repair (2, 128)
# repair (2, 129)
# repair (2, 130)
# repair (2, 131)
# repair (2, 132)
# repair (2, 133)
# repair (2, 134)
# repair (2, 135)
# repair (2, 136)
# repair (2, 137)
# repair (2, 138)
# repair (2, 139)
# repair (2, 140)
# repair (2, 141)
# repair (2, 142)
# repair (2, 143)
# repair (2, 144)
# repair (2, 145)
# repair (2, 146)
# repair (2, 147)
# repair (2, 148)
# repair (2, 149)
# repair (2, 150)
# repair (2, 151)
# repair (2, 152)
# repair (2, 153)
# repair (2, 154)
# repair (2, 155)
# repair (2, 156)
# repair (2, 157)
# repair (2, 158)
# repair (2, 159)
# repair (2, 160)
# repair (2, 161)
# repair (2, 162)
# repair (2, 163)
# repair (2, 164)
# repair (2, 165)
# repair (2, 166)
# repair (2, 167)
# repair (2, 168)
# repair (2, 169)
# repair (2, 170)
# repair (2, 171)
# repair (2, 172)
# repair (2, 173)
# repair (2, 174)
# repair (2, 175)
# repair (2, 176)
# repair (2, 177)
# repair (2, 178)
# repair (2, 179)
# repair (2, 180)
# repair (2, 181)
# repair (2, 182)
# repair (2, 183)
# repair (2, 184)
# repair (2, 185)
# repair (2, 186)
# repair (2, 187)
# repair (2, 188)
# repair (2, 189)
# repair (2, 190)
# repair (2, 191)
# repair (2, 192)
# repair (2, 193)
# repair (2, 194)
# repair (2, 195)
# repair (2, 196)
# repair (2, 197)
# repair (2, 198)
# repair (2, 199)
# repair (2, 200)
# repair (2, 201)
# repair (2, 202)
# repair (2, 203)
# repair (2, 204)
# repair (2, 205)
# repair (2, 206)
# repair (2, 207)
# repair (2, 208)
# repair (2, 209)
# repair (2, 210)
# repair (2, 211)
# repair (2, 212)
# repair (2, 213)
# repair (2, 214)
# repair (2, 215)
# repair (2, 216)
# repair (2, 217)
# repair (2, 218)
# repair (2, 219)
# repair (2, 220)
# repair (2, 221)
# repair (2, 222)
# repair (2, 223)
# repair (2, 224)
# repair (2, 225)
# repair (2, 226)
# repair (2, 227)
# repair (2, 228)
# repair (2, 229)
# repair (2, 230)
# repair (2, 231)
# repair (2, 232)
# repair (2, 233)
# repair (2, 234)
# repair (2, 235)
# repair (2, 236)
# repair (2, 237)
# repair (2, 238)
# repair (2, 239)
# repair (2, 240)
# repair (2, 241)
# repair (2, 242)
# repair (2, 243)
# repair (2, 244)
# repair (2, 245)
# repair (2, 246)
# repair (2, 247)
# repair (2, 248)
# repair (2, 249)
# repair (2, 250)
# repair (2, 251)
# repair (2, 252)
# repair (2, 253)
# repair (2, 254)
# repair (2, 255)
# repair (2, 256)
# repair (2, 257)
# repair (2, 258)
# repair (2, 259)
# repair (2, 260)
# repair (2, 261)
# repair (2, 262)
# repair (2, 263)
# repair (2, 264)
# repair (2, 265)
# repair (2, 266)
# repair (2, 267)
# repair (2, 268)
# repair (2, 269)
# repair (2, 270)
# repair (2, 271)
# repair (2, 272)
# repair (2, 273)
# repair (2, 274)
# repair (2, 275)
# repair (2, 276)
# repair (2, 277)
# repair (2, 278)
# repair (2, 279)
# repair (2, 280)
# repair (2, 281)
# repair (2, 282)
# repair (2, 283)
# repair (2, 284)
# repair (2, 285)
# repair (2, 286)
# repair (2, 287)
# repair (2, 288)
# repair (2, 289)
# repair (2, 290)
# repair (2, 291)
# repair (2, 292)
# repair (2, 293)
# repair (2, 294)
# repair (2, 295)
# repair (2, 296)
# repair (2, 297)
# repair (2, 298)
# repair (2, 299)
# repair (2, 300)
# repair (2, 301)
# repair (2, 302)
# repair (2, 303)
# repair (2, 304)
# repair (2, 305)
# repair (2, 306)
# repair (2, 307)
# repair (2, 308)
# repair (2, 309)
# repair (2, 310)
# repair (2, 311)
# repair (2, 312)
# repair (2, 313)
# repair (2, 314)
# repair (2, 315)
# repair (2, 316)
# repair (2, 317)
# repair (2, 318)
# repair (2, 319)
# repair (2, 320)
# repair (2, 321)
# repair (2, 322)
# repair (2, 323)
# repair (2, 324)
# repair (2, 325)
# repair (2, 326)
# repair (2, 327)
# repair (2, 328)
# repair (2, 329)
# repair (2, 330)
# repair (2, 331)
# repair (2, 332)
# repair (2, 333)
# repair (2, 334)
# repair (2, 335)
# repair (2, 336)
# repair (2, 337)
# repair (2, 338)
# repair (2, 339)
# repair (2, 340)
# repair (2, 341)
# repair (2, 342)
# repair (2, 343)
# repair (2, 344)
# repair (2, 345)
# repair (2, 346)
# repair (2, 347)
# repair (2, 348)
# repair (2, 349)
# repair (2, 350)
# repair (2, 351)
# repair (2, 352)
# repair (2, 353)
# repair (2, 354)
# repair (2, 355)
# repair (2, 356)
# repair (2, 357)
# repair (2, 358)
# repair (2, 359)
# repair (2, 360)
# repair (2, 361)
# repair (2, 362)
# repair (2, 363)
# repair (2, 364)
# repair (2, 365)
# repair (2, 366)
# repair (2, 367)
# repair (2, 368)
# repair (2, 369)
# repair (2, 370)
# repair (2, 371)
# repair (2, 372)
# repair (2, 373)
# repair (2, 374)
# repair (2, 375)
# repair (2, 376)
# repair (2, 377)
# repair (2, 378)
# repair (2, 379)
# repair (2, 380)
# repair (2, 381)
# repair (2, 382)
# repair (2, 383)
# repair (2, 384)
# repair (2, 385)
# repair (2, 386)
# repair (2, 387)
# repair (2, 388)
# repair (2, 389)
# repair (2, 390)
# repair (2, 391)
# repair (2, 392)
# repair (2, 393)
# repair (2, 394)
# repair (2, 395)
# repair (2, 396)
# repair (2, 397)
# repair (2, 398)
# repair (2, 399)
# repair (2, 400)
# repair (2, 401)
# repair (2, 402)
# repair (2, 403)
# repair (2, 404)
# repair (2, 405)
# repair (2, 406)
# repair (2, 407)
# repair (2, 408)
# repair (2, 409)
# repair (2, 410)
# repair (2, 411)
# repair (2, 412)
# repair (2, 413)
# repair (2, 414)
# repair (2, 415)
# repair (2, 416)
# repair (2, 417)
# repair (2, 418)
# repair (2, 419)
# repair (2, 420)
# repair (2, 421)
# repair (2, 422)
# repair (2, 423)
# repair (2, 424)
# repair (2, 425)
# repair (2, 426)
# repair (2, 427)
# repair (2, 428)
# repair (2, 429)
# repair (2, 430)
# repair (2, 431)
# repair (2, 432)
# repair (2, 433)
# repair (2, 434)
# repair (2, 435)
# repair (2, 436)
# repair (2, 437)
# repair (2, 438)
# repair (2, 439)
# repair (2, 440)
# repair (2, 441)
# repair (2, 442)
# repair (2, 443)
# repair (2, 444)
# repair (2, 445)
# repair (2, 446)
# repair (2, 447)
# repair (2, 448)
# repair (2, 449)
# repair (2, 450)
# repair (2, 451)
# repair (2, 452)
# repair (2, 453)
# repair (2, 454)
# repair (2, 455)
# repair (2, 456)
# repair (2, 457)
# repair (2, 458)
# repair (2, 459)
# repair (2, 460)
# repair (2, 461)
# repair (2, 462)
# repair (2, 463)
# repair (2, 464)
# repair (2, 465)
# repair (2, 466)
# repair (2, 467)
# repair (2, 468)
# repair (2, 469)
# repair (2, 470)
# repair (2, 471)
# repair (2, 472)
# repair (2, 473)
# repair (2, 474)
# repair (2, 475)
# repair (2, 476)
# repair (2, 477)
# repair (2, 478)
# repair (2, 479)
# repair (2, 480)
# repair (2, 481)
# repair (2, 482)
# repair (2, 483)
# repair (2, 484)
# repair (2, 485)
# repair (2, 486)
# repair (2, 487)
# repair (2, 488)
# repair (2, 489)
# repair (2, 490)
# repair (2, 491)
# repair (2, 492)
# repair (2, 493)
# repair (2, 494)
# repair (2, 495)
# repair (2, 496)
# repair (2, 497)
# repair (2, 498)
# repair (2, 499)
# repair (2, 500)
# repair (2, 501)
# repair (2, 502)
# repair (2, 503)
# repair (2, 504)
# repair (2, 505)
# repair (2, 506)
# repair (2, 507)
# repair (2, 508)
# repair (2, 509)
# repair (2, 510)
# repair (2, 511)
# repair (2, 512)
# repair (2, 513)
# repair (2, 514)
# repair (2, 515)
# repair (2, 516)
# repair (2, 517)
# repair (2, 518)
# repair (2, 519)
# repair (2, 520)
# repair (2, 521)
# repair (2, 522)
# repair (2, 523)
# repair (2, 524)
# repair (2, 525)
# repair (2, 526)
# repair (2, 527)
# repair (2, 528)
# repair (2, 529)
# repair (2, 530)
# repair (2, 531)
# repair (2, 532)
# repair (2, 533)
# repair (2, 534)
# repair (2, 535)
# repair (2, 536)
# repair (2, 537)
# repair (2, 538)
# repair (2, 539)
# repair (2, 540)
# repair (2, 541)
# repair (2, 542)
# repair (2, 543)
# repair (2, 544)
# repair (2, 545)
# repair (2, 546)
# repair (2, 547)
# repair (2, 548)
# repair (2, 549)
# repair (2, 550)
# repair (2, 551)
# repair (2, 552)
# repair (2, 553)
# repair (2, 554)
# repair (2, 555)
# repair (2, 556)
# repair (2, 557)
# repair (2, 558)
# repair (2, 559)
# repair (2, 560)
# repair (2, 561)
# repair (2, 562)
# repair (2, 563)
# repair (2, 564)
# repair (2, 565)
# repair (2, 566)
# repair (2, 567)
# repair (2, 568)
# repair (2, 569)
# repair (2, 570)
# repair (2, 571)
# repair (2, 572)
# repair (2, 573)
# repair (2, 574)
# repair (2, 575)
# repair (2, 576)
# repair (2, 577)
# repair (2, 578)
# repair (2, 579)
# repair (2, 580)
# repair (2, 581)
# repair (2, 582)
# repair (2, 583)
# repair (2, 584)
# repair (2, 585)
# repair (2, 586)
# repair (2, 587)
# repair (2, 588)
# repair (2, 589)
# repair (2, 590)
# repair (2, 591)
# repair (2, 592)
# repair (2, 593)
# repair (2, 594)
# repair (2, 595)
# repair (2, 596)
# repair (2, 597)
# repair (2, 598)
# repair (2, 599)
# repair (2, 600)
# repair (2, 601)
# repair (2, 602)
# repair (2, 603)
# repair (2, 604)
# repair (2, 605)
# repair (2, 606)
# repair (2, 607)
# repair (2, 608)
# repair (2, 609)
# repair (2, 610)
# repair (2, 611)
# repair (2, 612)
# repair (2, 613)
# repair (2, 614)
# repair (2, 615)
# repair (2, 616)
# repair (2, 617)
# repair (2, 618)
# repair (2, 619)
# repair (2, 620)
# repair (2, 621)
# repair (2, 622)
# repair (2, 623)
# repair (2, 624)
# repair (2, 625)
# repair (2, 626)
# repair (2, 627)
# repair (2, 628)
# repair (2, 629)
# repair (2, 630)
# repair (2, 631)
# repair (2, 632)
# repair (2, 633)
# repair (2, 634)
# repair (2, 635)
# repair (2, 636)
# repair (2, 637)
# repair (2, 638)
# repair (2, 639)
# repair (2, 640)
# repair (2, 641)
# repair (2, 642)
# repair (2, 643)
# repair (2, 644)
# repair (2, 645)
# repair (2, 646)
# repair (2, 647)
# repair (2, 648)
# repair (2, 649)
# repair (2, 650)
# repair (2, 651)
# repair (2, 652)
# repair (2, 653)
# repair (2, 654)
# repair (2, 655)
# repair (2, 656)
# repair (2, 657)
# repair (2, 658)
# repair (2, 659)
# repair (2, 660)
# repair (2, 661)
# repair (2, 662)
# repair (2, 663)
# repair (2, 664)
# repair (2, 665)
# repair (2, 666)
# repair (2, 667)
# repair (2, 668)
# repair (2, 669)
# repair (2, 670)
# repair (2, 671)
# repair (2, 672)
# repair (2, 673)
# repair (2, 674)
# repair (2, 675)
# repair (2, 676)
# repair (2, 677)
# repair (2, 678)
# repair (2, 679)
# repair (2, 680)
# repair (2, 681)
# repair (2, 682)
# repair (2, 683)
# repair (2, 684)
# repair (2, 685)
# repair (2, 686)
# repair (2, 687)
# repair (2, 688)
# repair (2, 689)
# repair (2, 690)
# repair (2, 691)
# repair (2, 692)
# repair (2, 693)
# repair (2, 694)
# repair (2, 695)
# repair (2, 696)
# repair (2, 697)
# repair (2, 698)
# repair (2, 699)
# repair (2, 700)
# repair (2, 701)
# repair (2, 702)
# repair (2, 703)
# repair (2, 704)
# repair (2, 705)
# repair (2, 706)
# repair (2, 707)
# repair (2, 708)
# repair (2, 709)
# repair (2, 710)
# repair (2, 711)
# repair (2, 712)
# repair (2, 713)
# repair (2, 714)
# repair (2, 715)
# repair (2, 716)
# repair (2, 717)
# repair (2, 718)
# repair (2, 719)
# repair (2, 720)
# repair (2, 721)
# repair (2, 722)
# 0 178
# ['cannon.n.01', '', 'cannon.n.03', '', 'naval_gun.n.01', 'artillery.n.01'] ['cannon.n.01', 'cannon.n.04', 'cannon.n.03', 'cannon.n.02', 'naval_gun.n.01', 'artillery.n.01']
# 0 219
# ['', '', 'macrobiotic_diet.n.01', 'crudites.n.01'] ['chop-suey_greens.n.02', 'chop-suey_greens.n.01', 'macrobiotic_diet.n.01', 'crudites.n.01']
# 0 492
# ['', '', '', '', '', ''] ['jackfruit.n.02', 'jackfruit.n.01', 'pulasan.n.02', 'pulasan.n.01', 'breadfruit.n.02', 'breadfruit.n.01']
# 1 185
# ['', '', 'knitwear.n.01', 'double_knit.n.01'] ['cardigan.n.02', 'cardigan.n.01', 'knitwear.n.01', 'double_knit.n.01']
# 2 673
# ['', 'pinwheel.n.02', '', 'pinwheel_roll.n.01', 'crotchet.n.04'] ['pinwheel.n.03', 'pinwheel.n.02', 'pinwheel.n.01', 'pinwheel_roll.n.01', 'crotchet.n.04']
# repair (0, 178)
# repair (0, 219)
# repair (0, 492)
# repair (1, 185)
# repair (2, 673)
# 0 178
# ['cannon.n.01', '', 'cannon.n.03', '', 'naval_gun.n.01', 'artillery.n.01'] ['cannon.n.01', 'cannon.n.04', 'cannon.n.03', 'cannon.n.02', 'naval_gun.n.01', 'artillery.n.01']
# repair (0, 178)
# 0 178
# ['cannon.n.01', '', 'cannon.n.03', '', 'naval_gun.n.01', 'artillery.n.01'] ['cannon.n.01', 'cannon.n.04', 'cannon.n.03', 'cannon.n.02', 'naval_gun.n.01', 'artillery.n.01']
# repair (0, 178)
# 100%|██████████| 997/997 [04:48<00:00,  3.46it/s]
# linear_assign
# assignment shape=(997, 20071)
# instance label acc:: 0.3767321705818176
# reassign_by_pred_cluster
#   0%|          | 0/12812 [01:01<?, ?it/s]
# missing label:: 467
# iou voc:: 0.3620218579234973
# cluster acc 0.5688229499854042
# missing label:: 479
# score= {'nli-bert-large': 0.7645950045809177, 'all-mpnet-base-v2': 0.6497054685183284}

# %%
with open('./cache/openai/gpt4-prompts.pkl', 'wb') as f:
    pickle.dump(store, f)

# %%
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
a, res_ass = linear_assign(all_clu_pred_chatgpt, record_pred_kmeans_t, all_gt_voc)
r_pred_kmeans_t, r_cluster_ind_voc = reassign_by_pred_cluster(a, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)

set_pred = set(res_ass[1].tolist())
set_gt = set(all_gt_voc.unique().numpy().tolist())
n_inter = all_gt_voc[r_cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([r_cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
print('iou voc::', iou_voc)
print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=r_pred_kmeans_t.numpy()))
n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)

mapping_classnames = lambda x: list(map(lambda item: vocab.mapping_idx_names[item], x))
classnames_pred = mapping_classnames(cluster_ind_voc.cpu().numpy())
classnames_gt = mapping_classnames(all_gt_voc.cpu().numpy())

from my_util_package.evaluate import measure_similarity_bert
score = measure_similarity_bert(vocab, classnames_pred, classnames_gt, device=args.device)
print(f'score=', score)
# Out:
# linear_assign
# assignment shape=(240, 20071)
# instance label acc:: 0.48374617099761963
# reassign_by_pred_cluster
#   0%|          | 0/2405 [00:10<?, ?it/s]
# missing label:: 98
# iou voc:: 0.42011834319526625
# cluster acc 0.7086848474020173
# missing label:: 103
# score= {'nli-bert-large': 0.8071384140839747, 'all-mpnet-base-v2': 0.7088442820971181}

# %%
# with open('./cache/openai/updated-prompts-08_13-part3.pkl', 'wb') as f:
#     pickle.dump(store, f)

# with open('./cache/openai/updated-prompts-08_10-part2.pkl', 'wb') as f:
#     pickle.dump(store, f)

# %%
classifier = get_classifier(args)
classifier = classifier/classifier.norm(dim=-1, keepdim=True)
args.num_voc = classifier.size(0)
a, res_ass = linear_assign(all_clu_pred_chatgpt, record_pred_kmeans_t, all_gt_voc)
r_pred_kmeans_t, r_cluster_ind_voc = reassign_by_pred_cluster(a, loader_f, model, classifier, args.device, preextracted_vfeatures=all_vfeatures)

set_pred = set(res_ass[1].tolist())
set_gt = set(all_gt_voc.unique().numpy().tolist())
n_inter = all_gt_voc[r_cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([r_cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
print('iou voc::', iou_voc)
print('cluster acc', cluster_acc(y_true=all_label_clu.numpy(), y_pred=r_pred_kmeans_t.numpy()))
n_inter = all_gt_voc[cluster_ind_voc.cpu()==all_gt_voc].unique().shape[0]
n_union = torch.cat([cluster_ind_voc.cpu(), all_gt_voc]).unique().shape[0]
iou_voc = n_inter/n_union
n_missing_label = all_gt_voc.unique().shape[0] - n_inter
print('missing label::', n_missing_label)
# Out:
# linear_assign
# assignment shape=(240, 20071)
# instance label acc:: 0.470323383808136
# reassign_by_pred_cluster
#   0%|          | 0/2405 [00:37<?, ?it/s]
# missing label:: 101
# iou voc:: 0.40762463343108507
# cluster acc 0.7108450955869215
# missing label:: 103

# %%
with open('./cache/openai/updated-prompts-08_10.pkl', 'rb') as f:
    prompts = pickle.load(f)

# %%
prompts.keys()
# Out:
# dict_keys(['sdogs', 'imagenet', 'make_entity13'])
