# %%
import os
import openai
import json
import pickle

import itertools

# from descriptor_strings import stringtolist

openai.api_key = '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'
def stringtolist(description):
    return [descriptor[2:] for descriptor in description.split('\n') if (descriptor != '') and (descriptor.startswith('- '))]

def generate_prompt(category_name: str):
    # you can replace the examples with whatever you want; these were random and worked, could be improved
    return f"""Q: What are useful visual features for distinguishing a lemur in a photo?
A: There are several useful visual features to tell there is a lemur in a photo:
- four-limbed primate
- black, grey, white, brown, or red-brown
- wet and hairless nose with curved nostrils
- long tail
- large eyes
- furry bodies
- clawed hands and feet

Q: What are useful visual features for distinguishing a television in a photo?
A: There are several useful visual features to tell there is a television in a photo:
- electronic device
- black or grey
- a large, rectangular screen
- a stand or mount to support the screen
- one or more speakers
- a power cord
- input ports for connecting to other devices
- a remote control

Q: What are useful features for distinguishing a {category_name} in a photo?
A: There are several useful visual features to tell there is a {category_name} in a photo:
-
"""

ctx = [
"""Q: What are discriminative visual features for distinguishing a madagascar_cat from egyptian_cat and tiger_cat in a photo? 
A: There are several discriminative visual features to tell there is a madagascar_cat from egyptian_cat and tiger_cat in a photo: 
- long fur with bluish-black-silver patterning
- large eyes, round and yellow or green in color
- stocky, muscular legs
- prominent shoulder blades
- a rhythmically swaying
- a pointed tip and whiskers muzzle
- long, furry ears

Q: What are discriminative visual features for distinguishing a television from screen and monitor in a photo?
A: There are several discriminative visual features to tell there is a television from screen and monitor in a photo: 
- knob or remote controls
- an external antenna
- visible speakers 
- a display beyond the base, typically encased in glass or plastic
- curved or rounded corners
- an additional set of VCR buttons 
- ports for external devices 
- stand for support
""",

]
def generate_prompt_discrminative(category_name: str, neighbors: str, idx=0):
    # you can replace the examples with whatever you want; these were random and worked, could be improved
    requests = [
    f"""Q: What are discriminative visual features for distinguishing a madagascar_cat from egyptian_cat and tiger_cat in a photo? 
A: There are several discriminative visual features to tell there is a madagascar_cat from egyptian_cat and tiger_cat in a photo: 
- long fur with bluish-black-silver patterning
- large eyes, round and yellow or green in color
- stocky, muscular legs
- prominent shoulder blades
- a rhythmically swaying
- a pointed tip and whiskers muzzle
- long, furry ears

Q: What are discriminative visual features for distinguishing a television from screen and monitor in a photo?
A: There are several discriminative visual features to tell there is a television from screen and monitor in a photo: 
- knob or remote controls
- an external antenna
- visible speakers 
- a display beyond the base, typically encased in glass or plastic
- curved or rounded corners
- an additional set of VCR buttons 
- ports for external devices 
- stand for support

Q: What are useful features for distinguishing a {category_name} from {neighbors[0]} and {neighbors[1]} in a photo?
A: There are several useful visual features to tell there is a {category_name} from {neighbors[0]} and {neighbors[1]} in a photo:
""", 
f"""Q: What are discriminative visual features for distinguishing a madagascar_cat in a photo that egyptian_cat and tiger_cat do not have? 
A: There are several discriminative visual features to tell there is a madagascar_cat in a photo that egyptian_cat and tiger_cat do not have: 
- long fur with bluish-black-silver patterning
- large eyes, round and yellow or green in color
- stocky, muscular legs
- prominent shoulder blades
- a rhythmically swaying
- a pointed tip and whiskers muzzle
- long, furry ears

Q: What are discriminative visual features for distinguishing a television in a photo that screen and monitor do not have?
A: There are several discriminative visual features to tell there is a television in a photo that screen and monitor do not have: 
- knob or remote controls
- an external antenna
- visible speakers 
- a display beyond the base, typically encased in glass or plastic
- curved or rounded corners
- an additional set of VCR buttons 
- ports for external devices 
- stand for support

Q: What are useful features for distinguishing a {category_name} in a photo that {neighbors[0]} and {neighbors[1]} do not have?
A: There are several useful visual features to tell there is a {category_name} in a photo that {neighbors[0]} and {neighbors[1]} do not have:
""", 
f"""Q: What are discriminative visual features for distinguishing a madagascar cat in a photo from egyptian cat and tiger cat? 
A: There are several discriminative visual features to tell there is a madagascar cat in a photo from egyptian cat and tiger cat: 
- long fur with bluish-black-silver patterning
- large eyes, round and yellow or green in color
- stocky, muscular legs
- prominent shoulder blades
- a rhythmically swaying
- a pointed tip and whiskers muzzle
- long, furry ears

Q: What are discriminative visual features for distinguishing a television in a photo from screen and monitor?
A: There are several discriminative visual features to tell there is a television in a photo from screen and monitor: 
- knob or remote controls
- an external antenna
- visible speakers 
- a display beyond the base, typically encased in glass or plastic
- curved or rounded corners
- an additional set of VCR buttons 
- ports for external devices 
- stand for support

Q: What are useful features for distinguishing a {category_name} in a photo from {neighbors[0]} and {neighbors[1]}?
A: There are several useful visual features to tell there is a {category_name} in a photo from {neighbors[0]} and {neighbors[1]}:
""", 
f"""Q: What are discriminative visual features for distinguishing a madagascar cat in a photo from egyptian cat and tiger cat? 
A: There are several discriminative visual features to tell there is a madagascar cat in a photo from egyptian cat and tiger cat: 
- long fur with bluish-black-silver patterning
- large eyes, round and yellow or green in color
- stocky, muscular legs
- prominent shoulder blades
- a rhythmically swaying
- a pointed tip
- whiskers muzzle
- long, furry ears
- black, grey, white, brown, or red-brown
- wet and hairless nose 
- curved nostrils
- long tail
- large eyes
- furry bodies
- clawed hands and feet

Q: What are discriminative visual features for distinguishing a television in a photo from screen and monitor?
A: There are several discriminative visual features to tell there is a television in a photo from screen and monitor: 
- knob or remote controls
- an external antenna
- visible speakers
- a display beyond the base, typically encased in glass or plastic
- curved or rounded corners
- an additional set of VCR buttons
- ports for external devices
- stand for support
- a visible screen with moving images
- electronic device
- black or grey
- a large, rectangular smooth and glossy screen
- a stand or mount to support the screen
- one or more speakers
- a power cord
- input ports for connecting to other devices
- a remote control

Q: What are useful features for distinguishing a {category_name} in a photo from {neighbors[0]} and {neighbors[1]}?
A: There are several useful visual features to tell there is a {category_name} in a photo from {neighbors[0]} and {neighbors[1]}:
""",
f"""Q: What are discriminative visual features for distinguishing a madagascar cat in a photo from egyptian cat and tiger cat? 
A: There are several discriminative visual features to tell there is a madagascar cat in a photo from egyptian cat and tiger cat: 
- long fur with bluish-black-silver patterning
- large eyes, round and yellow or green in color
- stocky, muscular legs
- prominent shoulder blades
- a rhythmically swaying
- a pointed tip and whiskers muzzle
- long, furry ears
- four-limbed primate
- black, grey, white, brown, or red-brown
- wet and hairless nose with curved nostrils
- long tail
- large eyes
- furry bodies
- clawed hands and feet

Q: What are discriminative visual features for distinguishing a television in a photo from screen and monitor?
A: There are several discriminative visual features to tell there is a television in a photo from screen and monitor: 
- knob or remote controls
- an external antenna
- visible speakers 
- a display beyond the base, typically encased in glass or plastic
- curved or rounded corners
- an additional set of VCR buttons 
- ports for external devices 
- stand for support
- electronic device
- black or grey
- a large, rectangular screen
- a stand or mount to support the screen
- one or more speakers
- a power cord
- input ports for connecting to other devices
- a remote control

Q: What are useful features for distinguishing a {category_name} in a photo from {neighbors[0]} and {neighbors[1]}?
A: There are several useful visual features to tell there is a {category_name} in a photo from {neighbors[0]} and {neighbors[1]}:
""", 
    ]
    return requests[idx]

# generator 
def partition(lst, size):
    for i in range(0, len(lst), size):
        yield list(itertools.islice(lst, i, i + size))
        
        
def request_with_exception(**kwargs):
    while 1:
        try:
            res = openai.Completion.create(**kwargs)
            break
        except Exception as e:
            print(e)
    return res
    
def obtain_descriptors_and_save(filename, class_list):
    responses = {}
    descriptors = {}
    
    
    
    # prompts = [generate_prompt(category.replace('_', ' ')) for category in class_list]
    with open('/home/sheng/sssa/ipynb/cache/in1k_candidates.pkl', 'rb') as f:
        candidates = pickle.load(f)
    prompts = [generate_prompt_discrminative(category, neighbors=candidates[category.lower()], idx=0) for category in class_list]
    
    
    # most efficient way is to partition all prompts into the max size that can be concurrently queried from the OpenAI API
    responses = [request_with_exception(model="text-davinci-003",
                                            prompt=prompt_partition,
                                            temperature=0.,
                                            max_tokens=100,
                                            ) for prompt_partition in partition(prompts, 20)]
    response_texts = [r["text"] for resp in responses for r in resp['choices']]
    descriptors_list = [stringtolist(response_text) for response_text in response_texts]
    descriptors = {cat: descr for cat, descr in zip(class_list, descriptors_list)}

    # save descriptors to json file
    if not filename.endswith('.json'):
        filename += '.json'
    with open(filename, 'w') as fp:
        json.dump(descriptors, fp)
    

with open('/home/sheng/sssa/VCD/descriptors/descriptors_imagenet.json', 'rb') as f:
    name_list = json.load(f)
obtain_descriptors_and_save('test-3.json', name_list)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Input In [2], in <cell line: 270>()
#     268 with open('/home/sheng/sssa/VCD/descriptors/descriptors_imagenet.json', 'rb') as f:
#     269     name_list = json.load(f)
# --> 270 obtain_descriptors_and_save('test-3.json', name_list)
#
# Input In [2], in obtain_descriptors_and_save(filename, class_list)
#     245 # prompts = [generate_prompt(category.replace('_', ' ')) for category in class_list]
#     246 with open('/home/sheng/sssa/ipynb/cache/in1k_candidates.pkl', 'rb') as f:
# --> 247     candidates = pickle.load(f)
#     248 prompts = [generate_prompt_discrminative(category, neighbors=candidates[category.lower()], idx=0) for category in class_list]
#     251 # most efficient way is to partition all prompts into the max size that can be concurrently queried from the OpenAI API
#
# EOFError: Ran out of input
